# %% [markdown]
# ## Exploring 311 Service Requests Data of NYC

# %% [markdown]
# The dataset is obtained from NYC Open Data and it contains all 311 Service Requests from 2010 to present. This information is automatically updated daily

# %% [markdown]
# ### Team Members:
# - Ritik Lnu
# - Neel Shah
# - Vishal Shah

# %% [markdown]
# We import the openclean library which helps immensely in cleaning the dataset.
# It contains many functions such as outlier detectionl, clustering and removing missing values.

# %%
pip install openclean[full]
# Out:
# Requirement already satisfied: openclean[full] in /usr/local/lib/python3.7/dist-packages (0.2.1)
# Requirement already satisfied: openclean-core==0.4.1 in /usr/local/lib/python3.7/dist-packages (from openclean[full]) (0.4.1)
# Requirement already satisfied: docker in /usr/local/lib/python3.7/dist-packages (from openclean[full]) (5.0.3)
# Requirement already satisfied: openclean-pattern==0.0.1 in /usr/local/lib/python3.7/dist-packages (from openclean[full]) (0.0.1)
# Requirement already satisfied: openclean-metanome==0.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean[full]) (0.2.0)
# Requirement already satisfied: openclean-notebook==0.1.7 in /usr/local/lib/python3.7/dist-packages (from openclean[full]) (0.1.7)
# Requirement already satisfied: openclean-geo==0.1.0 in /usr/local/lib/python3.7/dist-packages (from openclean[full]) (0.1.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (2.8.2)
# Requirement already satisfied: flowserv-core>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (0.9.2)
# Requirement already satisfied: histore>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (0.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (0.16.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (0.3.4)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (1.1.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (2.23.0)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (1.4.4)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (3.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (1.4.1)
# Requirement already satisfied: refdata>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (0.2.0)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (0.8.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from openclean-core==0.4.1->openclean[full]) (0.23.2)
# Requirement already satisfied: Shapely>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from openclean-geo==0.1.0->openclean[full]) (1.8.0)
# Requirement already satisfied: datamart-profiler==0.9 in /usr/local/lib/python3.7/dist-packages (from openclean-notebook==0.1.7->openclean[full]) (0.9)
# Requirement already satisfied: datamart-geo==0.2.1 in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean-notebook==0.1.7->openclean[full]) (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean-notebook==0.1.7->openclean[full]) (1.19.5)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean-notebook==0.1.7->openclean[full]) (0.12.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from datamart-profiler==0.9->openclean-notebook==0.1.7->openclean[full]) (2019.12.20)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean[full]) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean[full]) (21.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean[full]) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean[full]) (4.8.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.2.0->openclean-core==0.4.1->openclean[full]) (0.18.0)
# Requirement already satisfied: scikit-bio in /usr/local/lib/python3.7/dist-packages (from openclean-pattern==0.0.1->openclean[full]) (0.5.6)
# Requirement already satisfied: pygtrie==2.3.3 in /usr/local/lib/python3.7/dist-packages (from openclean-pattern==0.0.1->openclean[full]) (2.3.3)
# Requirement already satisfied: pyyaml-include in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (1.2.post2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (5.4.1)
# Requirement already satisfied: paramiko in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (2.8.0)
# Requirement already satisfied: passlib in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (1.7.4)
# Requirement already satisfied: Click in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (7.1.2)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (1.4.27)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.7/dist-packages (from flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (3.1.24)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from histore>=0.4.0->openclean-core==0.4.1->openclean[full]) (5.4.8)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->openclean-core==0.4.1->openclean[full]) (2018.9)
# Requirement already satisfied: datasize>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean[full]) (1.0.0)
# Requirement already satisfied: tableprint in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean[full]) (0.9.1)
# Requirement already satisfied: pooch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from refdata>=0.2.0->openclean-core==0.4.1->openclean[full]) (1.5.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean[full]) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core==0.4.1->openclean[full]) (3.0.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->openclean-core==0.4.1->openclean[full]) (1.1.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy>=1.3.18->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (1.1.2)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from docker->openclean[full]) (1.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean[full]) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean[full]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean[full]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->openclean-core==0.4.1->openclean[full]) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (3.10.0.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->jsonschema>=3.2.0->openclean-core==0.4.1->openclean[full]) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.4.1->openclean[full]) (3.0.6)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (36.0.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (3.2.0)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko->flowserv-core>=0.8.0->openclean-core==0.4.1->openclean[full]) (2.21)
# Requirement already satisfied: IPython>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from scikit-bio->openclean-pattern==0.0.1->openclean[full]) (5.5.0)
# Requirement already satisfied: matplotlib>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from scikit-bio->openclean-pattern==0.0.1->openclean[full]) (3.2.2)
# Requirement already satisfied: CacheControl>=0.11.5 in /usr/local/lib/python3.7/dist-packages (from scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.12.10)
# Requirement already satisfied: natsort>=4.0.3 in /usr/local/lib/python3.7/dist-packages (from scikit-bio->openclean-pattern==0.0.1->openclean[full]) (5.5.0)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.7/dist-packages (from scikit-bio->openclean-pattern==0.0.1->openclean[full]) (4.4.2)
# Requirement already satisfied: hdmedians>=0.13 in /usr/local/lib/python3.7/dist-packages (from scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.14.2)
# Requirement already satisfied: lockfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.12.2)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from CacheControl>=0.11.5->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (1.0.2)
# Requirement already satisfied: Cython>=0.23 in /usr/local/lib/python3.7/dist-packages (from hdmedians>=0.13->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.29.24)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (5.1.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.7.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=1.4.3->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.11.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython>=3.2.0->scikit-bio->openclean-pattern==0.0.1->openclean[full]) (0.7.0)

# %% [markdown]
# ## Data Source
# The data used in this project was obtained from the following sources:
#
# - [NYC Open Data's 311 Service Requests from 2010 to Present](https://data.cityofnewyork.us/Social-Services/311-Service-Requests-from-2010-to-Present/erm2-nwe9)
#   - This dataset contains information about the time, location, complaint type, and status of more than 24 million 311 service requests made in New York City within the past decade.

# %%
# Loading all the relevant libraries
import pandas as pd
import numpy as np
from openclean.profiling.dataset import dataset_profile
from openclean.cluster.key import KeyCollision
from openclean.function.value.key.fingerprint import Fingerprint
from openclean.operator.map.violations import fd_violations
from openclean.operator.collector.count import distinct
from openclean.function.eval.logic import And
from openclean.function.value.phonetic import Soundex, soundex
from openclean.pipeline import stream
from openclean.data.load import dataset
from openclean.cluster.key import KeyCollision
from openclean_geo.address.usstreet import USStreetNameKey
from openclean_geo.address.usstreet import StandardizeUSStreetName

# %% [markdown]
# We have used Google Colaboratory to clean this dataset and hence to access the data we first upload it to Google Drive and then access it from here by  mounting the Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### As we have 27M rows, we need to work on the subset of the dataset. So we have sampled our data into 5% of the full data which is around 1.395M rows.

# %%
#Please change path for your system
datafile = '311_Service_Requests_from_2010_to_Present.csv'

# %%
import pandas as pd
df = pd.read_csv(datafile)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-e900fb2721ca> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv(datafile)
#       3 df.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '311_Service_Requests_from_2010_to_Present.csv'

# %%
df_new = df.sample(frac=0.05, random_state=43)

# %%
df_new.shape

# %%
#Please change the path for your system
df_new.to_csv('Sampled_Data.csv', header=True, encoding="utf-8")

# %% [markdown]
# ## Scrubbing the Data

# %%
# Loading dataset
#Please change the path for your system
original_df = pd.read_csv("Sampled_Data.csv",low_memory = False)

df = original_df.copy()
df.head()
# Out:
#    Unnamed: 0  Unique Key  ...  Longitude                                  Location
# 0     1161152    31247536  ... -73.776357  (40.782517127277416, -73.77635733957257)
# 1    19331004    49902206  ... -73.782130   (40.59525476424622, -73.78213009462443)
# 2    20420950    26123456  ...        NaN                                       NaN
# 3    22013676    37085573  ... -73.744300   (40.66472182521037, -73.74430045066177)
# 4    11790222    16279399  ...        NaN                                       NaN
#
# [5 rows x 42 columns]

# %%
df.shape
# Out:
# (1353465, 42)

# %% [markdown]
# ##Remove Duplicate Rows from the dataset

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1353465, 42)

# %% [markdown]
# ## Data Profiling
# In many data analytics projects, data profiling is an essential first step. Profiling allows users to understand the properties of data and to identify data quality problems. <b>openclean</b> allows users to generate metadata about the data at hand using a variety of different data profiling operators. openclean is designed to be extensible, to make it easy to add new functionality, and to customize data profiling and cleaning operators.<br><br>
# We can make use of the default column profiler to compute statistics such as the number of distinct values in each column, the number of missing values, etc. These results are compiled into a dictionary. Using the stats() method, a summary of the results is accessible as a data frame.

# %%
profiles = dataset_profile(df)
profiles.stats()

# %%
print(profiles.types())

# %% [markdown]
# ## Dealing with Missing and Superfluous Data
# Let's check the column data types and identify columns with missing values greater than 50 % of the total rows in the dataset. We remove such columns as we cannot obtain any useful information from missing values in the dataset.

# %%
'''We Are Removing Some Coloumns that have more than 50% missing data And Unnecessary column'''

df.replace('Unspecified',np.nan,inplace=True)
columns_with_nan_values=df.isnull().sum() 
size = df.shape[0]
remove = []
for key,value in columns_with_nan_values.items():
    k = value/size 
    print(k,key) 
    if (value/size) > 0.5: 
        remove.append(key) 

df.drop(labels = remove, axis =1, inplace =True)
# Out:
# 0.0 Unnamed: 0
# 0.0 Unique Key
# 0.0 Created Date
# 0.02059610760785737 Closed Date
# 0.0 Agency
# 0.0 Agency Name
# 0.0 Complaint Type
# 0.0 Descriptor
# 0.20924686165352135 Location Type
# 0.0 Incident Zip
# 0.18924375085061018 Incident Address
# 0.1892729146279026 Street Name
# 0.3559633443723631 Cross Street 1
# 0.35691278734421683 Cross Street 2
# 0.8367411747169493 Intersection Street 1
# 0.8367217321987543 Intersection Street 2
# 0.046425493029857226 Address Type
# 0.0 City
# 0.9656483107692109 Landmark
# 0.7068133064594526 Facility Type
# 3.2404196991594352e-06 Status
# 0.5037232422343342 Due Date
# 0.02226492375292448 Resolution Description
# 0.007796449796177601 Resolution Action Updated Date
# 0.0 Community Board
# 0.24172234787849722 BBL
# 0.0082598298131574 Borough
# 0.06668135656930285 X Coordinate (State Plane)
# 0.06668135656930285 Y Coordinate (State Plane)
# 0.0 Open Data Channel Type
# 0.9880558129888983 Park Facility Name
# 0.0082598298131574 Park Borough
# 0.999552822081516 Vehicle Type
# 0.9989565848568707 Taxi Company Borough
# 0.9909430269408493 Taxi Pick Up Location
# 0.9979002080349447 Bridge Highway Name
# 0.9979002080349447 Bridge Highway Direction
# 0.9979131697137413 Road Ramp
# 0.9979131697137413 Bridge Highway Segment
# 0.06668135656930285 Latitude
# 0.06668135656930285 Longitude
# 0.06668135656930285 Location

# %% [markdown]
# We remove the columns named 'Unnamed:0' and 'Unique Key' as they are only random sequences and cannot be used for our further analysis.

# %%
df = df.drop(["Unnamed: 0", "Unique Key"], axis = 1)

# %% [markdown]
# #### The dataset consists of float, integer, and object data types. Most of the columns that contain missing values appear to be associated with particular complaint types. Next, we overwrite the dataframe to include only the rows and columns of interest.
#
# #### Below are the names of the columns with missing values that have been removed

# %%
set(original_df.columns) - set(df.columns)
# Out:
# set()

# %% [markdown]
# Below are the columns which are remaining after removing the rows with majority missing values and redundant columns.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unique Key', 'Created Date', 'Closed Date', 'Agency',
#        'Agency Name', 'Complaint Type', 'Descriptor', 'Location Type',
#        'Incident Zip', 'Incident Address', 'Street Name', 'Cross Street 1',
#        'Cross Street 2', 'Intersection Street 1', 'Intersection Street 2',
#        'Address Type', 'City', 'Landmark', 'Facility Type', 'Status',
#        'Due Date', 'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %% [markdown]
# #### The 'Created_Date' and 'Closed Date' column currently contains string values so the pandas.to_datetime() method converts each string value to a datetime object below. This will be useful to us to know more about the data in temporal terms.

# %%
df['Created Date'] = pd.to_datetime(df['Created Date'])
df['Closed Date'] = pd.to_datetime(df['Closed Date'])
df['Resolution Action Updated Date'] = pd.to_datetime(df['Resolution Action Updated Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-15d8264b31c3> in <module>()
# ----> 1 df['Created Date'] = pd.to_datetime(df['Created Date'])
#       2 df['Closed Date'] = pd.to_datetime(df['Closed Date'])
#       3 df['Resolution Action Updated Date'] = pd.to_datetime(df['Resolution Action Updated Date'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     801             result = arg.map(cache_array)
#     802         else:
# --> 803             values = convert_listlike(arg._values, format)
#     804             result = arg._constructor(values, index=arg.index, name=arg.name)
#     805     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     464             errors=errors,
#     465             require_iso8601=require_iso8601,
# --> 466             allow_object=True,
#     467         )
#     468
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2053             dayfirst=dayfirst,
#    2054             yearfirst=yearfirst,
# -> 2055             require_iso8601=require_iso8601,
#    2056         )
#    2057     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing._parse_dateabbr_string()
#
# /usr/lib/python3.7/_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.7/_strptime.py in _strptime(data_string, format)
#     329     with _cache_lock:
#     330         locale_time = _TimeRE_cache.locale_time
# --> 331         if (_getlang() != locale_time.lang or
#     332             time.tzname != locale_time.tzname or
#     333             time.daylight != locale_time.daylight):
#
# /usr/lib/python3.7/_strptime.py in _getlang()
#      26 def _getlang():
#      27     # Figure out what the current language is set to.
# ---> 28     return locale.getlocale(locale.LC_TIME)
#      29
#      30 class LocaleTime(object):
#
# /usr/lib/python3.7/locale.py in getlocale(category)
#     589     if category == LC_ALL and ';' in localename:
#     590         raise TypeError('category LC_ALL is not supported')
# --> 591     return _parse_localename(localename)
#     592
#     593 def setlocale(category, locale=None):
#
# /usr/lib/python3.7/locale.py in _parse_localename(localename)
#     479
#     480     """
# --> 481     code = normalize(localename)
#     482     if '@' in code:
#     483         # Deal with locale modifiers
#
# /usr/lib/python3.7/locale.py in normalize(localename)
#     422     if modifier:
#     423         lookup_name += '@' + modifier
# --> 424     code = locale_alias.get(lookup_name, None)
#     425     if code is not None:
#     426         return code
#
# KeyboardInterrupt:

# %% [markdown]
# #### The values in the 'Agengy' & 'AgengyName' column also have inconsistent formatting: all but one have abbreviated names.

# %%
df["Agency"].unique()
# Out:
# array(['DPR', 'HPD', 'DOF', 'DOT', 'NYPD', 'DOHMH', 'DSNY', 'DEP', 'DOB',
#        'TLC', 'DFTA', '3-1-1', 'DCA', 'DHS', 'HRA', 'EDC',
#        'MAYORâ\x80\x99S OFFICE OF SPECIAL ENFORCEMENT', 'DOE', 'DOITT',
#        'DCP', 'NYCEM', 'ACS', 'DCAS', 'DORIS', 'TAX', 'DVS', 'COIB',
#        'FDNY'], dtype=object)

# %%
df["Agency Name"].unique()
# Out:
# array(['Department of Parks and Recreation',
#        'Department of Housing Preservation and Development',
#        'Refunds and Adjustments', 'Department of Transportation',
#        'New York City Police Department',
#        'Department of Health and Mental Hygiene', 'Brooklyn North 03',
#        'Lot Cleaning', 'BCC - Queens West',
#        'Department of Environmental Protection',
#        'Personal Exemption Unit', 'Department of Buildings',
#        'Taxi and Limousine Commission', 'Department of Sanitation',
#        'Bronx 10', 'BCC - Brooklyn South', 'Department for the Aging',
#        '3-1-1 Call Center', 'BCC - Bronx',
#        'Department of Consumer Affairs', 'Property Exec Office',
#        'Department of Homeless Services', 'A - Queens',
#        'Brooklyn South 10', 'BCC - Brooklyn North',
#        'HRA Benefit Card Replacement', 'DHS Advantage Programs',
#        'Bronx 04',
#        'A - Illegal Posting Staten Island, Queens and Brooklyn',
#        'A - Illegal Posting Manhattan and Bronx', 'BCC - Queens East',
#        'BCC - Staten Island', 'Economic Development Corporation',
#        'Senior Citizen Rent Increase Exemption Unit', 'A - Brooklyn',
#        'Operations Unit - Department of Homeless Services',
#        'Land Records', 'HealthCare Connections', 'Correspondence Unit',
#        'Mayorâ\x80\x99s Office of Special Enforcement', 'Exemption Unit',
#        'Discrepancy and Billing', 'Revenue Accounting', 'Queens West 03',
#        'Manhattan 01', 'Central - Department of Education',
#        'Queens East 10',
#        'Department of Information Technology and Telecommunications',
#        'Queens West 06', 'Queens East 12',
#        'A - Canine Task Force Citywide', 'A - Bronx',
#        'Office of the Taxpayer Advocate', 'External Affairs Unit',
#        'Manhattan 06', 'DCP', 'A - Manhattan',
#        'Adjudication - Hearing by Mail', 'P - Brooklyn and Staten Island',
#        'School - PS 182', 'BCC - Manhattan', 'DOB Inspections - Queens',
#        'Queens West 02', 'Manhattan 07', 'Bronx 03',
#        'NYC Emergency Management', 'Manhattan 03', 'School - PS-MS 194',
#        'Traffic Management Center', 'School - The Facing History School',
#        'School - International High School at Lafayette',
#        'Condo or CoOp Unit', 'RPIE Unit', 'Commercial Exemption Unit',
#        'Bronx 08', 'Manhattan 02', 'P - Commercial Recycling Citywide',
#        'Queens West 04', 'A - Staten Island', 'Bronx 11',
#        'School - The Brooklyn New School - PS 146', 'Manhattan 05',
#        'School - PS 67 Charles A Dorsey', 'Manhattan 04',
#        'Payment Operations', 'Disability Rent Increase Exemption Unit',
#        'School - PS 16 Leonard Dunkly', 'DRIE Unit', 'P - Queens',
#        'Manhattan 08', 'School - James Weldon Johnson',
#        'Correspondence - Taxi and Limousine Commission',
#        'School - PS 47 John Randolph', 'Accounts Examination',
#        'P - Manhattan and Bronx', 'Bronx 05', 'Department of Education',
#        'Adjudication - Appeals Unit',
#        'Child Care and Camps Complaint Unit',
#        'School - IS 141 The Steinway', 'School - PS 46 Edgar Allan Poe',
#        'School - PS 60 Woodhaven', "School - PS 63 Author's Academy",
#        'School - PS 198 Isador E Ida Straus',
#        'School - Academy of Finance and Enterprise', 'Valuation Policy',
#        'DOT', 'Division of Alternative Management',
#        "School - Young Women's Leadership School", 'ACS',
#        'School - The Christa McAuliffe School - IS 187', 'DCAS',
#        'Mosquito Control', 'Dunning Unit',
#        'School - PS 197 The Kings Highway Academy',
#        'School - PS 160 William T Sampson',
#        'School - IS 24 Myra S Barnes', 'School - PS 24',
#        'School - MS 61 Dr Gladstone H Atwell',
#        'School - PS 200 Benson School', 'School - Ella Baker School',
#        'School - PS 179', 'School - IS 206 Ann Mersereau',
#        'School - Pace High School',
#        'School - The Brooklyn School for Social Justice',
#        'School - Midwood High School', 'School - Pioneer Academy',
#        'School - PS 132 The Conselyea School',
#        'School - IS 227 Louis Armstrong', 'School - MS 53 Brian Piccolo',
#        '311 Administrative Supervisor', 'School - PS 45 John Tyler',
#        'School - PS 99 Kew Gardens', 'School - PS 50 Clara Barton',
#        'School - South Shore Educational Complex YABC',
#        'School - PS 288 The Shirley Tanyhill', 'School - PS 97 Bronx',
#        'School - Art and Design High School',
#        'School - PS-IS 45 Horace E Greene',
#        'School - The Cultural Arts Academy at Spring Creek Charter School',
#        'School - PS 206 Joseph F Lamb',
#        'School - Fort Greene Preparatory Academy',
#        'School - PS 255 Barbara Reing School', 'School - PS 205 Clarion',
#        'School - PS 153 Homecrest', 'School - PS 107 Thomas A Dooley',
#        'School - John Adams High School',
#        'School - The Fresh Creek School',
#        'School - PS 14 Senator John Calandra',
#        'School - Long Island City High School',
#        'School - Stuyvesant High School',
#        'School - The Angelo Patri Middle School',
#        'School - PS 321 William Penn',
#        'School - Brooklyn Technical High School',
#        'School - John F Kennedy High School',
#        'School - PS 149 Sojourner Truth', 'School - Walton YABC',
#        'School - PS 152 Evergreen',
#        'School - High School of Computers and Technology',
#        'School - Metropolitan Diploma Plus High School',
#        'Municipal Archives',
#        'School - Manhattan School for Career Development',
#        'School - PS 116 Elizabeth L Farrell',
#        'School - In-Tech Academy (MS-HS 368)',
#        'School - PS 75 Emily Dickinson',
#        'School - William Cullen Bryant High School',
#        'School - Franklin Delano Roosevelt High School',
#        'School - John Ericsson Middle School 126',
#        'Exemption Policy Unit', 'School - PS 168',
#        'School - PS 192 The Magnet School for Math and Science Inquiry',
#        'School - Fiorello H LaGuardia High School of Music and Art and Performing Arts',
#        'School - PS 3 The Margaret Gioiosa School',
#        'School - The Urban Assembly Academy for Future Leaders', 'TAX',
#        'School - New York City Academy for Discovery',
#        'School - PS 149 Christa Mcauliffe',
#        'School - PS 163 Alfred E Smith',
#        'School - Washington Irving High School',
#        'DOB Inspections - Bronx', 'School - The School for Human Rights',
#        'School - JHS 226 Virgil I Grissom',
#        'School - Community Health Academy of the Heights',
#        'School - W H Maxwell Career and Technical Education High School',
#        'School - Academy of American Studies',
#        'DOB Inspections - Brooklyn',
#        'School - The Queens School of Inquiry',
#        'School - PS 1 Alfred E Smith', 'NYPD',
#        'School - Washington Heights Expeditionary Learning School',
#        'School - PS 33 Timothy Dwight',
#        'School - Childrens Workshop at PS 361',
#        'School - South Richmond High School IS-PS 25',
#        'School - PS 180 Hugo Newman', 'School - PS 150 Queens',
#        'DOF Legal Affairs - Taxpayer Services Unit',
#        'School - The Urban Assembly Gateway School for Technology',
#        'School - School for Tourism and Hospitality',
#        'School - Murry Bergtraum High School for Business Careers',
#        'School - MS 113 Ronald Edmonds Learning Center',
#        'School - PS 220 Edward Mandel', 'School - PS 310 Marble Hill',
#        'School - PS 105 Senator Abraham Bernstein',
#        'School - Cynthia Jenkins School', 'School - New Dorp High School',
#        'School - JHS 54 Booker T Washington', 'Office of the Sheriff',
#        'School - PS 333 Manhattan School for Children',
#        'School - PS 30 Westerleigh', 'School - PS 165 Edith K Bergtraum',
#        'School - PS 195 William Haberle', 'School - PS 89 Bronx',
#        'School - PS 139 Alexine A Fenty', 'School - Bayside High School',
#        'School - PS 65 The Raymond York Elementary School',
#        'School - PS 184 Newport', 'School - PS 199 Jessie Isador Straus',
#        'School - The Urban Assembly School for the Performing Arts',
#        'School - Brooklyn Studio Secondary School', 'School - PS 196',
#        'School - PS 145 Andrew Jackson', 'School - PS 47 Chris Galas',
#        'School - PS 76 A Philip Randolph',
#        'School - Jonas Bronck Academy',
#        'School - New Utrecht High School', 'School - PS 97 The Highlawn',
#        'School - Port Richmond High School',
#        'School - JHS 8 Richard S Grossley',
#        'School - High School of Economics and Finance',
#        'School - PS 54 Samuel C Barnes',
#        'School - PS 186 Dr Irving A Gladstone',
#        'School - PS 50 Vito Marcantonio',
#        'School - Queens Preparatory Academy', 'School - PS 51 Elias Howe',
#        'School - PS 81 Thaddeus Stevens', 'School - PS 123',
#        'School - PS 197 John B Russwurm',
#        'School - Herbert H Lehman High School',
#        'School - Secondary School for Journalism',
#        'School - PS 163 Bath Beach', 'DOB Inspections - Manhattan',
#        'School - PS 127 Aerospace Science Magnet School',
#        'School - PS 44 David C Farragut', 'School - PS 162 John Golden',
#        'School - Magnet School for Science and Technology',
#        'School - PS 195 Manhattan Beach',
#        'School - PS 178 Dr Selman Waksman', 'School - PS 57 Crescent',
#        'School - PS 96', 'School - PS 106 Edward Everett Hale',
#        'School - Kappa II', 'School - Richmond Hill High School',
#        'School - PS 316 Elijah Stroud', 'School - JHS 45 John S Roberts',
#        'School - JHS 223 The Montauk', 'School - PS 91 Bronx',
#        'School - Neighborhood Charter School of Harlem',
#        'School - PS 217 Colonel David Marcus School',
#        'School - JHS 162 Lola Rodriguez De Tio',
#        'School - Park East High School', 'LinkNYC Unit',
#        'School - Mark Twain IS 239 for the Gifted and Talented',
#        'School - Bronx High School for the Visual Arts',
#        'School - Gaynor McCown Expeditionary Learning School',
#        'School - PS 43', 'School - PS-MS 114 Belle Harbor',
#        'School - PS 175 The Lynn Gross Discovery School',
#        'School - Community School for Social Justice', 'DVS',
#        'School - Humanities Preparatory Academy', 'School - PS 138',
#        'School - PS 20 Clinton Hill', 'School - PS MS 138 Sunrise',
#        'School - PS 251 Paerdegat', 'School - PS 95 Eastwood',
#        'School - PS 38 George Cromwell',
#        'School - Grace Dodge Career and Technical Education High School',
#        'School - Health Opportunities High School',
#        'School - Brooklyn School for Music and Theatre',
#        'School - Bronx Academy for Software Engineering (BASE)',
#        'School - PS 100 The Coney Island School',
#        'School - PS 143 Louis Armstrong', 'School - PS 158 Warwick',
#        'School - JHS 62 Ditmas', 'School - PS 32 Samuel Mills Sprole',
#        'School - PS-IS 323',
#        'School - Aviation Career and Technical Education High School',
#        'School - PS 166 The Richard Rodgers School of the Arts and Technology',
#        'School - PS 166 Henry Gradstein',
#        'School - Aspirations Diploma Plus High School',
#        'School - James Madison High School',
#        'School - PS 327 Dr Rose B English',
#        'School - PS 214 Michael Friedsam', 'School - Erasmus YABC',
#        'School - PS-IS 54',
#        'School - The Felisa Rincon de Gautier Institute for Law and Public Policy',
#        'School - International High School at Prospect Heights',
#        'School - PS 243K The Weeksville School',
#        'School - Pathways College Preparatory School: A College Board School',
#        'School - PS 209 Clearview Gardens',
#        'School - Morris Academy for Collaborative Studies',
#        'School - PS X114 Luis Llorens Torres Schools',
#        'School - PS 122 Mamie Fay', 'School - PS 3 The Bedford Village',
#        'School - IS 211 John Wilson',
#        'School - PS 118 Lorraine Hansberry',
#        'School - PS 188 Michael E Berdy',
#        'School - University Heights Secondary School', 'DPR',
#        'School - Robert F Wagner Jr Secondary School for Arts and Technology',
#        'School - ALC John Jay', 'School - PS 38 Roberto Clemente',
#        'School - Baccalaureate School for Global Education',
#        'School - Ampark Neighborhood',
#        'School - Frederick Douglass Academy VII High School',
#        'School - IS 25 Adrien Block', 'School - PS 43 Jonas Bronck',
#        'School - PS 161 The Crown', 'School - PS 36 Saint Albans School',
#        'School - PS 8 Shirlee Solomon', 'School - PS 88 Seneca',
#        'School - Bronx Lab School', 'School - JHS 278 Marine Park',
#        'School - PS 274 Kosciusko',
#        'School - PS 117 J Keld Briarwood School',
#        'School - Careers in Sports High School',
#        'School - Brooklyn High School of the Arts',
#        'School - PS 178 Saint Clair Mckelway',
#        'School - STEM Institute of Manhattan', 'School - PS 48 Mapleton',
#        'School - PS 116 Mary Lindley Murray',
#        'School - Fort Hamilton High School',
#        'School - PS 114 - Luis Llorens Torres Schools',
#        'School - PS-IS 217 Roosevelt Island',
#        'School - PS 298 Dr Betty Shabazz', 'School - PS 42 Eltingville',
#        'School - PS 201 The Discovery School for Inquiry and Research',
#        'School - PS-IS 295', 'School - PS 94 Kings College School',
#        'School - Ralph R McKee Career and Technical Education High School',
#        'School - PS 91 The Albany Avenue School',
#        'School - Young Voices Academy of the Bronx',
#        'School - PS 200 The James Mccune Smith School',
#        'School - PS 206 The Horace Harding School',
#        'School - PS 48 P O Michael J Buczek',
#        'School - PS 165 Robert E Simon', 'School - Newtown High School',
#        'School - Legacy School', 'School - PS 87 William Sherman',
#        'School - All City Leadership Secondary School',
#        'School - Explorations Academy High School',
#        'School - PS 98 Shorac Kappock', 'School - PS 97 Forest Park',
#        'School - PS K077', 'School - Mott Hall V',
#        'School - PS 183 Robert L Stevenson',
#        'School - South Bronx Preparatory: A College Board School',
#        'School - PS 134 George F Bristow',
#        'School - PS 107 John W Kimball',
#        'School - Frederick Douglass Academy VIII Middle School',
#        'School - Medgar Evers College Preparatory School',
#        'School - PS 108 Captain Vincent G Fowler',
#        'School - PS 261 Philip Livingston',
#        'School - Jane Addams High School for Academic Careers',
#        'School - Kingsborough Early College School',
#        'School - Talent Unlimited High School',
#        'School - The Riverside School for Makers and Artists',
#        'School - Baruch College Campus High School',
#        'School - IS 117 Joseph H Wade', 'School - PS 153 Helen Keller',
#        'School - PS 79 Francis Lewis', 'School - PS 63 Old South',
#        'School - IS 230', 'School - PS 157 Grove Hill',
#        'School - JHS 123 James M Kieran', 'DoITT',
#        'School - The Windsor Terrace School',
#        'School - PS 35 Nathaniel Woodhull',
#        'School - In-Tech Academy MS-HS 368',
#        'School - The Stephanie A Vierno School',
#        'School - PS 98 The Douglaston School',
#        'School - PS 67 Mohegan School',
#        'School - PS 171 Peter G Van Alst', 'School - Murray Hill Academy',
#        'School - Bronx Theatre High School',
#        'School - PS 11 Thomas Dongan School',
#        'School - Manhattan Center for Science and Mathematics',
#        'School - PS 14 Fairview', 'School - Hillcrest High School',
#        'School - PS 66 School of Higher Expectations',
#        'School - PS 84 Lillian Weber',
#        'School - Esperanza Preparatory Academy',
#        'School - PS 1 The Bergen',
#        'School - Queens High School for Information, Research, and Technology',
#        'School - PS 123 Mahalia Jackson',
#        'School - MS 142 John Philip Sousa', 'School - PS 68 Cambridge',
#        'School - PS 205 Alexander Graham Bell',
#        'School - Bronx Academy of Health Careers',
#        'School - PS 29 Queens', 'School - PS 192 Jacob H Schiff',
#        'School - PS 205 Fiorello LaGuardia',
#        'School - PS 6 Lillie D Blake',
#        'School - Metropolitan Expeditionary Learning School',
#        'School - Achievement First Endeavor Charter School',
#        'School - PS 71 Rose E Scala', 'School - PS 230 Doris L Cohen',
#        'School - School for Global Leaders',
#        'School - Harlem Renaissance High School',
#        'School - IS 181 Pablo Casals', 'School - PS 33 Edward M Funk',
#        'School - PS 193 Alfred J Kennedy',
#        'School - PS 332 Charles H Houston',
#        'School - PS 26 The Carteret School', 'DOHMH',
#        'School - PS 49 Dorothy Bonawit Kole',
#        'School - PS 282 Park Slope',
#        'School - MS 326 - Writers Today and Leaders Tomorrow',
#        'School - The 47 American Sign Language and English Lower School',
#        'School - International Community High School',
#        'School - Lyons Community School', 'School - PS 54 Hillside',
#        'School - PS 152 Gwendoline N Alleyne School',
#        'School - PS 22 Graniteville', 'School - PS 114 Ryder Elementary',
#        'School - IS 296 The Anna Gonzalez Community School',
#        'Investigation Review Section',
#        'School - KIPP Infinity Charter School',
#        'School - PS 92 Mary McLeod Bethune',
#        'School - Independence High School', 'COIB',
#        'School - PS 184m Shuang Wen',
#        'School - Satellite East Middle School',
#        'School - PS 721 - Manhattan Occupational Training Center',
#        'School - PS 30 Queens', 'School - PS 140 Nathan Straus',
#        'School - PS 219 Paul Klapper',
#        'School - IS 303 Herbert S Eisenberg', 'School - PS 315',
#        'School - PS 204 Vince Lombardi',
#        'School - High School of Sports Management',
#        'School - PS 250 George H Lindsay',
#        'School - Christopher Avenue Community School',
#        'School - PS 194 Raoul Wallenberg',
#        'School - IS 229 Roland Patterson', 'School - PS 209',
#        'School - PS 94 David D Porter',
#        'School - Eagle Academy for Young Men III',
#        'School - Life Academy High School for Film and Music',
#        'School - PS 398 Walter Weaver',
#        'School - PS-IS 210 Twenty-First Century Academy for Community Leadership',
#        'School - Beach Channel High School',
#        'School - PS 111 Seton Falls',
#        'School - PS-MS 31 The William Lloyd Garrison',
#        'School - PS-IS 208',
#        'School - Hudson High School of Learning Technologies',
#        'School - PS 32 The Gifford School',
#        'School - PS 272 Curtis Estabrook', 'School - PS 315 Lab School',
#        "School - MS 137 America's School of Heroes",
#        'School - PS 40 Augustus Saint-Gaudens',
#        'School - PS 6 Corporal Allan F Kivlehan School',
#        'School - Tag Young Scholars', 'School - PS 38 The Pacific',
#        'School - The Urban Assembly School of Business for Young Women',
#        'School - Mott Hall High School',
#        'School - PS 503 The School of Discovery',
#        'School - The Bronx High School of Science',
#        'School - Neighborhood School',
#        'School - Abraham Lincoln High School',
#        'School - IS 218 Salome Urena',
#        'School - JHS 210 Elizabeth Blackwell',
#        'School - PS 132 Juan Pablo Duarte', 'School - PS 32 State Street',
#        'School - Stephen T Mather Building Arts and Craftsmanship High School',
#        'School - JHS 201 The Dyker Heights',
#        'School - Our World Neighborhood Charter School',
#        'School - The High School of Fashion Industries',
#        'School - PS 191 Paul Robeson',
#        'School - August Martin High School',
#        'School - IS 61 William A Morris',
#        'School - PS 264 Bay Ridge Elementary School for the Arts',
#        'School - PS 222 Katherine R Snyder',
#        'School - Bronx River High School',
#        'School - Bronx Leadership Academy High School',
#        'School - Civic Leadership Academy', 'Fire Department of New York',
#        'School - MS 322', 'School - JHS 125 Henry Hudson',
#        'School - PS-IS 187 Hudson Cliffs',
#        'School - PS 234 Independence School',
#        'School - PS 158 Bayard Taylor', 'School - PS 198 Brooklyn',
#        'School - Achievement First Crown Heights Charter School',
#        'School - The Bronx Mathematics Preparatory School',
#        'School - Curtis High School',
#        'School - A Philip Randolph Campus High School',
#        'School - PS 94 The Henry Longfellow',
#        'School - Staten Island School of Civic Leadership',
#        'School - PS Q255', 'School - Brooklyn Landmark Elementary School',
#        'School - PS 1 Tottenville', 'School - PS 312 Bergen Beach',
#        'School - PS 115 Daniel Mucatel School',
#        'School - MS 266 Park Place Community Middle School',
#        'School - PS 253 Brooklyn',
#        'School - Bayard Rustin Educational Complex',
#        'School - Fairmont Neighborhood School', 'School - PS 121 Queens',
#        'School - PS 345 Patrolman Robert Bolden',
#        'School - Eagle Academy for Young Men II',
#        'School - Cultural Academy for the Arts and Sciences',
#        'School - Chelsea Career and Technical Education High School',
#        'School - PS 11 Kathryn Phelan',
#        'School - The Active Learning Elementary School',
#        'School - PS-MS 498 Van Nest Academy',
#        'School - PS 238 Anne Sullivan',
#        'School - Forest Hills High School',
#        'School - IS 7 Elias Bernstein', 'School - PS 102 Bayview',
#        'School - ACORN Community High School',
#        'School - IS 68 Isaac Bildersee', 'School - PS 49 Willis Avenue',
#        'School - MS 126 John Ericsson', 'School - PS 112 Dutch Kills',
#        'School - East Williamsburg Scholars Academy', 'School - PS 70',
#        'School - PS 188',
#        'School - PS 50 Talfourd Lawn Elementary School',
#        'School - Castle Bridge School', 'School - PS-MS 42 R Vernam',
#        'School - PS 15 Institute for Environmental Learning',
#        'School - NYC Lab School for Collaborative Studies',
#        'School - IS 125 Thom J McCann Woodside',
#        'School - PS 124 Osmond A Church',
#        'School - IS 281 Joseph B Cavallaro',
#        'School - PS 254 The Rosa Parks School',
#        'School - PS 144 Col Jeromus Remsen',
#        'School - PS 36 J C Drumgoole', 'School - PS 75 Mayda Cortiella',
#        'School - PS 56 The Louis Desario School',
#        'School - PS 126 Dr Marjorie H Dunbar',
#        'School - Food and Finance High School',
#        'School - PS 112 Bronxwood',
#        'School - Thomas A Edison Career and Technical Education High School',
#        'School - PS 273 Wortman', 'School - PS 41 Greenwich Village',
#        'School - Brooklyn Community Arts and Media High School (BCAM)',
#        'School - PS 226 Alfred De B Mason',
#        'School - PS 55 Henry M Boehm',
#        'School - Brooklyn High School for Leadership and Community Service',
#        'School - PS 8 Isaac Varian', 'School - PS 214',
#        'School - Andries Hudde', 'School - Space Shuttle Columbia School',
#        'School - Bronx Career and College Preparatory High School',
#        'School - PS 164 Caesar Rodney', 'School - PS 306 Ethan Allen',
#        'School - PS 129 John H Finley', 'School - PS 105 The Bay School',
#        'School - Beacon High School', 'School - PS 167 The Parkway',
#        'School - Cornerstone Academy for Social Action',
#        'School - East Brooklyn Community High School',
#        'School - PS-IS 218 Rafael Hernandez Dual Language Magnet School',
#        'School - PS 23 at Queens Children Center',
#        'School - Samuel Gompers Career and Technical Education High School',
#        'School - PS 202 Ernest S Jenkyns',
#        'School - El Puente Academy for Peace and Justice',
#        'School - PS 48 William G Wilcox',
#        'School - PS-MS 20 PO George J Werdann III',
#        'School - West Brooklyn Community High School',
#        'School - Benjamin N Cardozo High School', 'School - PS 87 Bronx',
#        'School - PS 130 The Parkside', 'School - The STAR Academy PS63',
#        'School - PS 102 Jacques Cartier',
#        'School - Academy for Environmental Leadership',
#        'School - PS 76 The Bennington School',
#        'School - PS 228 Early Childhood Magnet School of the Arts',
#        'School - PS 396 - Bronx',
#        'School - Peninsula Preparatory Academy Charter School',
#        'School - MS 394', 'School - High School for Violin and Dance',
#        'School - PS 254 Dag Hammarskjold',
#        'School - JHS 216 George J Ryan', 'School - PS 3 Charrette School',
#        'School - HS 560 City As School', 'School - PS 207 Rockwood Park',
#        'School - Bronx Writing Academy',
#        'School - PS 242 The Young Diplomats Magnet Academy',
#        'School - Amber Charter School',
#        'School - Evander Childs Evening High School',
#        'School - PS 18 Winchester',
#        'School - PS 307 Daniel Hale Williams',
#        'School - PS 175 City Island',
#        'School - Family Life Academy Charter School', 'CFC - Queens East',
#        'School - PS 211',
#        'School - Merrick Academy Queens Public Charter School',
#        'School - Frank Mccourt High School',
#        'School - Norman Thomas High School',
#        'School - PS 106 Parkchester', 'School - PS 134 Henrietta Szold',
#        'School - PS 164 Queens Valley', 'School - PS 68 Bronx',
#        'School - Sheepshead Bay High School', 'School - PS 123 Suydam',
#        'School - Clara Barton High School',
#        'School - PS 196 Grand Central Parkway',
#        'School - PS 160 Walt Disney',
#        "School - Harlem Children's Zone Promise Academy II",
#        'School - PS 102 The Bayview', 'School - PS 93 Albert G Oliver',
#        'School - JHS 143 Eleanor Roosevelt', 'School - PS 193 Gil Hodges',
#        'School - Lafayette High School', 'School - PS 79 - Horan School',
#        'School - Waterside School for Leadership',
#        'School - Monroe Academy for Business-Law',
#        'School - PS 42 Claremont',
#        'School - The Urban Assembly Academy of Government and Law',
#        'School - IS 187', 'School - Manhattan Hunter Science High School',
#        'School - PS 329 Surfside', 'School - PS 153 Maspeth Elem',
#        'School - Magnet School of Math, Science and Design Technology',
#        'School - IS 237', 'School - PS 346 Abe Stark',
#        'School - PS 115 Alexander Humboldt',
#        'School - PS 397 Foster-Laurie', 'School - PS 156 Waverly',
#        'School - PS 9 Teunis G Bergen',
#        'School - Frederick Douglass Academy',
#        'School - High School for Environmental Studies',
#        'School - PS 28 The Warren Prep Academy',
#        'School - PS 173 Fresh Meadows',
#        'School - EBC High School for Public Service Bushwick',
#        'School - PS 29 John M Harrigan',
#        'School - DeWitt Clinton High School',
#        'School - PS 9 Sarah Anderson', 'Alternative Superintendency',
#        'School - PS 133 Queens',
#        'School - New Explorations Science, Technology and Math High School',
#        'School - Explore Exceed Charter School',
#        'School - Science Skills Center High School for Science, Technology, and the Creative Arts',
#        'School - New York City Lab Middle School for Collaborative Studies',
#        'School - PS 35 The Clove Valley School', 'School - PS-IS 266',
#        'School - Unity Center for Urban Technologies',
#        'School - JHS 227 Edward B Shallow',
#        'School - IS 119 The Glendale',
#        'School - East-West School of International Studies',
#        'School - PS 189', 'School - PS 81 Robert J Christen',
#        'School - IS 232', 'School - Harry S Truman High School',
#        'School - PS 132 Garret A Morgan', 'NYCEM Property Damage',
#        'School - PS 50 Frank Hankinson',
#        'School - Edward A Reynolds West Side High School',
#        'School - PS 28 Wright Brothers',
#        'School - The Gordon Parks School',
#        'School - PS-IS 157 The Benjamin Franklin Health and Science Academy',
#        'School - PS 279 Herman Schreiber', 'School - PS 246 Poe Center',
#        'School - High School for Public Service: Heroes of Tomorrow',
#        'School - PS 15 Patrick F Daly',
#        'School - PS X015 Institute for Environmental Learning',
#        'School - Bronx Leadership Academy II High School',
#        'School - PS 233 Langston Hughes', 'School - PS 231',
#        'School - PS 124 Silas B Dutcher',
#        'School - PS M169 Robert F Kennedy',
#        'School - PS 21 Philip H Sheridan',
#        'School - PS 93 William H Prescott',
#        'School - PS 41 Gun Hill Road',
#        'School - PS 225 The Eileen E Zaglin',
#        'School - PS 12 James B Colgate', 'School - PS Q177'], dtype=object)

# %% [markdown]
# ##### We'll convert the ''MAYOR'S OFFICE OF SPECIAL ENFORCEMENT" value to its abbreviated name, OSE for both the colummns named 'Agency' and 'Agency Name'

# %%
def update_OSE(agency):

  """Takes in an agency name and converts to abbreviated form, if the agency is
     the Office of Special Enforcement."Mayorâ\x80\x99s Office of Special Enforcement'"""

  if agency == 'MAYORâ\x80\x99S OFFICE OF SPECIAL ENFORCEMENT' or  agency == 'Mayorâ\x80\x99s Office of Special Enforcement' :
      return "OSE"
  else:
      return agency

# %%
df["Agency"] = df["Agency"].map(lambda agency: update_OSE(agency))
df["Agency Name"] = df["Agency Name"].map(lambda agency: update_OSE(agency))

# %%
df["Agency"].unique()
# Out:
# array(['DPR', 'HPD', 'DOF', 'DOT', 'NYPD', 'DOHMH', 'DSNY', 'DEP', 'DOB',
#        'TLC', 'DFTA', '3-1-1', 'DCA', 'DHS', 'HRA', 'EDC', 'OSE', 'DOE',
#        'DOITT', 'DCP', 'NYCEM', 'ACS', 'DCAS', 'DORIS', 'TAX', 'DVS',
#        'COIB', 'FDNY'], dtype=object)

# %%
df["Agency Name"].unique()
# Out:
# array(['Department of Parks and Recreation',
#        'Department of Housing Preservation and Development',
#        'Refunds and Adjustments', 'Department of Transportation',
#        'New York City Police Department',
#        'Department of Health and Mental Hygiene', 'Brooklyn North 03',
#        'Lot Cleaning', 'BCC - Queens West',
#        'Department of Environmental Protection',
#        'Personal Exemption Unit', 'Department of Buildings',
#        'Taxi and Limousine Commission', 'Department of Sanitation',
#        'Bronx 10', 'BCC - Brooklyn South', 'Department for the Aging',
#        '3-1-1 Call Center', 'BCC - Bronx',
#        'Department of Consumer Affairs', 'Property Exec Office',
#        'Department of Homeless Services', 'A - Queens',
#        'Brooklyn South 10', 'BCC - Brooklyn North',
#        'HRA Benefit Card Replacement', 'DHS Advantage Programs',
#        'Bronx 04',
#        'A - Illegal Posting Staten Island, Queens and Brooklyn',
#        'A - Illegal Posting Manhattan and Bronx', 'BCC - Queens East',
#        'BCC - Staten Island', 'Economic Development Corporation',
#        'Senior Citizen Rent Increase Exemption Unit', 'A - Brooklyn',
#        'Operations Unit - Department of Homeless Services',
#        'Land Records', 'HealthCare Connections', 'Correspondence Unit',
#        'OSE', 'Exemption Unit', 'Discrepancy and Billing',
#        'Revenue Accounting', 'Queens West 03', 'Manhattan 01',
#        'Central - Department of Education', 'Queens East 10',
#        'Department of Information Technology and Telecommunications',
#        'Queens West 06', 'Queens East 12',
#        'A - Canine Task Force Citywide', 'A - Bronx',
#        'Office of the Taxpayer Advocate', 'External Affairs Unit',
#        'Manhattan 06', 'DCP', 'A - Manhattan',
#        'Adjudication - Hearing by Mail', 'P - Brooklyn and Staten Island',
#        'School - PS 182', 'BCC - Manhattan', 'DOB Inspections - Queens',
#        'Queens West 02', 'Manhattan 07', 'Bronx 03',
#        'NYC Emergency Management', 'Manhattan 03', 'School - PS-MS 194',
#        'Traffic Management Center', 'School - The Facing History School',
#        'School - International High School at Lafayette',
#        'Condo or CoOp Unit', 'RPIE Unit', 'Commercial Exemption Unit',
#        'Bronx 08', 'Manhattan 02', 'P - Commercial Recycling Citywide',
#        'Queens West 04', 'A - Staten Island', 'Bronx 11',
#        'School - The Brooklyn New School - PS 146', 'Manhattan 05',
#        'School - PS 67 Charles A Dorsey', 'Manhattan 04',
#        'Payment Operations', 'Disability Rent Increase Exemption Unit',
#        'School - PS 16 Leonard Dunkly', 'DRIE Unit', 'P - Queens',
#        'Manhattan 08', 'School - James Weldon Johnson',
#        'Correspondence - Taxi and Limousine Commission',
#        'School - PS 47 John Randolph', 'Accounts Examination',
#        'P - Manhattan and Bronx', 'Bronx 05', 'Department of Education',
#        'Adjudication - Appeals Unit',
#        'Child Care and Camps Complaint Unit',
#        'School - IS 141 The Steinway', 'School - PS 46 Edgar Allan Poe',
#        'School - PS 60 Woodhaven', "School - PS 63 Author's Academy",
#        'School - PS 198 Isador E Ida Straus',
#        'School - Academy of Finance and Enterprise', 'Valuation Policy',
#        'DOT', 'Division of Alternative Management',
#        "School - Young Women's Leadership School", 'ACS',
#        'School - The Christa McAuliffe School - IS 187', 'DCAS',
#        'Mosquito Control', 'Dunning Unit',
#        'School - PS 197 The Kings Highway Academy',
#        'School - PS 160 William T Sampson',
#        'School - IS 24 Myra S Barnes', 'School - PS 24',
#        'School - MS 61 Dr Gladstone H Atwell',
#        'School - PS 200 Benson School', 'School - Ella Baker School',
#        'School - PS 179', 'School - IS 206 Ann Mersereau',
#        'School - Pace High School',
#        'School - The Brooklyn School for Social Justice',
#        'School - Midwood High School', 'School - Pioneer Academy',
#        'School - PS 132 The Conselyea School',
#        'School - IS 227 Louis Armstrong', 'School - MS 53 Brian Piccolo',
#        '311 Administrative Supervisor', 'School - PS 45 John Tyler',
#        'School - PS 99 Kew Gardens', 'School - PS 50 Clara Barton',
#        'School - South Shore Educational Complex YABC',
#        'School - PS 288 The Shirley Tanyhill', 'School - PS 97 Bronx',
#        'School - Art and Design High School',
#        'School - PS-IS 45 Horace E Greene',
#        'School - The Cultural Arts Academy at Spring Creek Charter School',
#        'School - PS 206 Joseph F Lamb',
#        'School - Fort Greene Preparatory Academy',
#        'School - PS 255 Barbara Reing School', 'School - PS 205 Clarion',
#        'School - PS 153 Homecrest', 'School - PS 107 Thomas A Dooley',
#        'School - John Adams High School',
#        'School - The Fresh Creek School',
#        'School - PS 14 Senator John Calandra',
#        'School - Long Island City High School',
#        'School - Stuyvesant High School',
#        'School - The Angelo Patri Middle School',
#        'School - PS 321 William Penn',
#        'School - Brooklyn Technical High School',
#        'School - John F Kennedy High School',
#        'School - PS 149 Sojourner Truth', 'School - Walton YABC',
#        'School - PS 152 Evergreen',
#        'School - High School of Computers and Technology',
#        'School - Metropolitan Diploma Plus High School',
#        'Municipal Archives',
#        'School - Manhattan School for Career Development',
#        'School - PS 116 Elizabeth L Farrell',
#        'School - In-Tech Academy (MS-HS 368)',
#        'School - PS 75 Emily Dickinson',
#        'School - William Cullen Bryant High School',
#        'School - Franklin Delano Roosevelt High School',
#        'School - John Ericsson Middle School 126',
#        'Exemption Policy Unit', 'School - PS 168',
#        'School - PS 192 The Magnet School for Math and Science Inquiry',
#        'School - Fiorello H LaGuardia High School of Music and Art and Performing Arts',
#        'School - PS 3 The Margaret Gioiosa School',
#        'School - The Urban Assembly Academy for Future Leaders', 'TAX',
#        'School - New York City Academy for Discovery',
#        'School - PS 149 Christa Mcauliffe',
#        'School - PS 163 Alfred E Smith',
#        'School - Washington Irving High School',
#        'DOB Inspections - Bronx', 'School - The School for Human Rights',
#        'School - JHS 226 Virgil I Grissom',
#        'School - Community Health Academy of the Heights',
#        'School - W H Maxwell Career and Technical Education High School',
#        'School - Academy of American Studies',
#        'DOB Inspections - Brooklyn',
#        'School - The Queens School of Inquiry',
#        'School - PS 1 Alfred E Smith', 'NYPD',
#        'School - Washington Heights Expeditionary Learning School',
#        'School - PS 33 Timothy Dwight',
#        'School - Childrens Workshop at PS 361',
#        'School - South Richmond High School IS-PS 25',
#        'School - PS 180 Hugo Newman', 'School - PS 150 Queens',
#        'DOF Legal Affairs - Taxpayer Services Unit',
#        'School - The Urban Assembly Gateway School for Technology',
#        'School - School for Tourism and Hospitality',
#        'School - Murry Bergtraum High School for Business Careers',
#        'School - MS 113 Ronald Edmonds Learning Center',
#        'School - PS 220 Edward Mandel', 'School - PS 310 Marble Hill',
#        'School - PS 105 Senator Abraham Bernstein',
#        'School - Cynthia Jenkins School', 'School - New Dorp High School',
#        'School - JHS 54 Booker T Washington', 'Office of the Sheriff',
#        'School - PS 333 Manhattan School for Children',
#        'School - PS 30 Westerleigh', 'School - PS 165 Edith K Bergtraum',
#        'School - PS 195 William Haberle', 'School - PS 89 Bronx',
#        'School - PS 139 Alexine A Fenty', 'School - Bayside High School',
#        'School - PS 65 The Raymond York Elementary School',
#        'School - PS 184 Newport', 'School - PS 199 Jessie Isador Straus',
#        'School - The Urban Assembly School for the Performing Arts',
#        'School - Brooklyn Studio Secondary School', 'School - PS 196',
#        'School - PS 145 Andrew Jackson', 'School - PS 47 Chris Galas',
#        'School - PS 76 A Philip Randolph',
#        'School - Jonas Bronck Academy',
#        'School - New Utrecht High School', 'School - PS 97 The Highlawn',
#        'School - Port Richmond High School',
#        'School - JHS 8 Richard S Grossley',
#        'School - High School of Economics and Finance',
#        'School - PS 54 Samuel C Barnes',
#        'School - PS 186 Dr Irving A Gladstone',
#        'School - PS 50 Vito Marcantonio',
#        'School - Queens Preparatory Academy', 'School - PS 51 Elias Howe',
#        'School - PS 81 Thaddeus Stevens', 'School - PS 123',
#        'School - PS 197 John B Russwurm',
#        'School - Herbert H Lehman High School',
#        'School - Secondary School for Journalism',
#        'School - PS 163 Bath Beach', 'DOB Inspections - Manhattan',
#        'School - PS 127 Aerospace Science Magnet School',
#        'School - PS 44 David C Farragut', 'School - PS 162 John Golden',
#        'School - Magnet School for Science and Technology',
#        'School - PS 195 Manhattan Beach',
#        'School - PS 178 Dr Selman Waksman', 'School - PS 57 Crescent',
#        'School - PS 96', 'School - PS 106 Edward Everett Hale',
#        'School - Kappa II', 'School - Richmond Hill High School',
#        'School - PS 316 Elijah Stroud', 'School - JHS 45 John S Roberts',
#        'School - JHS 223 The Montauk', 'School - PS 91 Bronx',
#        'School - Neighborhood Charter School of Harlem',
#        'School - PS 217 Colonel David Marcus School',
#        'School - JHS 162 Lola Rodriguez De Tio',
#        'School - Park East High School', 'LinkNYC Unit',
#        'School - Mark Twain IS 239 for the Gifted and Talented',
#        'School - Bronx High School for the Visual Arts',
#        'School - Gaynor McCown Expeditionary Learning School',
#        'School - PS 43', 'School - PS-MS 114 Belle Harbor',
#        'School - PS 175 The Lynn Gross Discovery School',
#        'School - Community School for Social Justice', 'DVS',
#        'School - Humanities Preparatory Academy', 'School - PS 138',
#        'School - PS 20 Clinton Hill', 'School - PS MS 138 Sunrise',
#        'School - PS 251 Paerdegat', 'School - PS 95 Eastwood',
#        'School - PS 38 George Cromwell',
#        'School - Grace Dodge Career and Technical Education High School',
#        'School - Health Opportunities High School',
#        'School - Brooklyn School for Music and Theatre',
#        'School - Bronx Academy for Software Engineering (BASE)',
#        'School - PS 100 The Coney Island School',
#        'School - PS 143 Louis Armstrong', 'School - PS 158 Warwick',
#        'School - JHS 62 Ditmas', 'School - PS 32 Samuel Mills Sprole',
#        'School - PS-IS 323',
#        'School - Aviation Career and Technical Education High School',
#        'School - PS 166 The Richard Rodgers School of the Arts and Technology',
#        'School - PS 166 Henry Gradstein',
#        'School - Aspirations Diploma Plus High School',
#        'School - James Madison High School',
#        'School - PS 327 Dr Rose B English',
#        'School - PS 214 Michael Friedsam', 'School - Erasmus YABC',
#        'School - PS-IS 54',
#        'School - The Felisa Rincon de Gautier Institute for Law and Public Policy',
#        'School - International High School at Prospect Heights',
#        'School - PS 243K The Weeksville School',
#        'School - Pathways College Preparatory School: A College Board School',
#        'School - PS 209 Clearview Gardens',
#        'School - Morris Academy for Collaborative Studies',
#        'School - PS X114 Luis Llorens Torres Schools',
#        'School - PS 122 Mamie Fay', 'School - PS 3 The Bedford Village',
#        'School - IS 211 John Wilson',
#        'School - PS 118 Lorraine Hansberry',
#        'School - PS 188 Michael E Berdy',
#        'School - University Heights Secondary School', 'DPR',
#        'School - Robert F Wagner Jr Secondary School for Arts and Technology',
#        'School - ALC John Jay', 'School - PS 38 Roberto Clemente',
#        'School - Baccalaureate School for Global Education',
#        'School - Ampark Neighborhood',
#        'School - Frederick Douglass Academy VII High School',
#        'School - IS 25 Adrien Block', 'School - PS 43 Jonas Bronck',
#        'School - PS 161 The Crown', 'School - PS 36 Saint Albans School',
#        'School - PS 8 Shirlee Solomon', 'School - PS 88 Seneca',
#        'School - Bronx Lab School', 'School - JHS 278 Marine Park',
#        'School - PS 274 Kosciusko',
#        'School - PS 117 J Keld Briarwood School',
#        'School - Careers in Sports High School',
#        'School - Brooklyn High School of the Arts',
#        'School - PS 178 Saint Clair Mckelway',
#        'School - STEM Institute of Manhattan', 'School - PS 48 Mapleton',
#        'School - PS 116 Mary Lindley Murray',
#        'School - Fort Hamilton High School',
#        'School - PS 114 - Luis Llorens Torres Schools',
#        'School - PS-IS 217 Roosevelt Island',
#        'School - PS 298 Dr Betty Shabazz', 'School - PS 42 Eltingville',
#        'School - PS 201 The Discovery School for Inquiry and Research',
#        'School - PS-IS 295', 'School - PS 94 Kings College School',
#        'School - Ralph R McKee Career and Technical Education High School',
#        'School - PS 91 The Albany Avenue School',
#        'School - Young Voices Academy of the Bronx',
#        'School - PS 200 The James Mccune Smith School',
#        'School - PS 206 The Horace Harding School',
#        'School - PS 48 P O Michael J Buczek',
#        'School - PS 165 Robert E Simon', 'School - Newtown High School',
#        'School - Legacy School', 'School - PS 87 William Sherman',
#        'School - All City Leadership Secondary School',
#        'School - Explorations Academy High School',
#        'School - PS 98 Shorac Kappock', 'School - PS 97 Forest Park',
#        'School - PS K077', 'School - Mott Hall V',
#        'School - PS 183 Robert L Stevenson',
#        'School - South Bronx Preparatory: A College Board School',
#        'School - PS 134 George F Bristow',
#        'School - PS 107 John W Kimball',
#        'School - Frederick Douglass Academy VIII Middle School',
#        'School - Medgar Evers College Preparatory School',
#        'School - PS 108 Captain Vincent G Fowler',
#        'School - PS 261 Philip Livingston',
#        'School - Jane Addams High School for Academic Careers',
#        'School - Kingsborough Early College School',
#        'School - Talent Unlimited High School',
#        'School - The Riverside School for Makers and Artists',
#        'School - Baruch College Campus High School',
#        'School - IS 117 Joseph H Wade', 'School - PS 153 Helen Keller',
#        'School - PS 79 Francis Lewis', 'School - PS 63 Old South',
#        'School - IS 230', 'School - PS 157 Grove Hill',
#        'School - JHS 123 James M Kieran', 'DoITT',
#        'School - The Windsor Terrace School',
#        'School - PS 35 Nathaniel Woodhull',
#        'School - In-Tech Academy MS-HS 368',
#        'School - The Stephanie A Vierno School',
#        'School - PS 98 The Douglaston School',
#        'School - PS 67 Mohegan School',
#        'School - PS 171 Peter G Van Alst', 'School - Murray Hill Academy',
#        'School - Bronx Theatre High School',
#        'School - PS 11 Thomas Dongan School',
#        'School - Manhattan Center for Science and Mathematics',
#        'School - PS 14 Fairview', 'School - Hillcrest High School',
#        'School - PS 66 School of Higher Expectations',
#        'School - PS 84 Lillian Weber',
#        'School - Esperanza Preparatory Academy',
#        'School - PS 1 The Bergen',
#        'School - Queens High School for Information, Research, and Technology',
#        'School - PS 123 Mahalia Jackson',
#        'School - MS 142 John Philip Sousa', 'School - PS 68 Cambridge',
#        'School - PS 205 Alexander Graham Bell',
#        'School - Bronx Academy of Health Careers',
#        'School - PS 29 Queens', 'School - PS 192 Jacob H Schiff',
#        'School - PS 205 Fiorello LaGuardia',
#        'School - PS 6 Lillie D Blake',
#        'School - Metropolitan Expeditionary Learning School',
#        'School - Achievement First Endeavor Charter School',
#        'School - PS 71 Rose E Scala', 'School - PS 230 Doris L Cohen',
#        'School - School for Global Leaders',
#        'School - Harlem Renaissance High School',
#        'School - IS 181 Pablo Casals', 'School - PS 33 Edward M Funk',
#        'School - PS 193 Alfred J Kennedy',
#        'School - PS 332 Charles H Houston',
#        'School - PS 26 The Carteret School', 'DOHMH',
#        'School - PS 49 Dorothy Bonawit Kole',
#        'School - PS 282 Park Slope',
#        'School - MS 326 - Writers Today and Leaders Tomorrow',
#        'School - The 47 American Sign Language and English Lower School',
#        'School - International Community High School',
#        'School - Lyons Community School', 'School - PS 54 Hillside',
#        'School - PS 152 Gwendoline N Alleyne School',
#        'School - PS 22 Graniteville', 'School - PS 114 Ryder Elementary',
#        'School - IS 296 The Anna Gonzalez Community School',
#        'Investigation Review Section',
#        'School - KIPP Infinity Charter School',
#        'School - PS 92 Mary McLeod Bethune',
#        'School - Independence High School', 'COIB',
#        'School - PS 184m Shuang Wen',
#        'School - Satellite East Middle School',
#        'School - PS 721 - Manhattan Occupational Training Center',
#        'School - PS 30 Queens', 'School - PS 140 Nathan Straus',
#        'School - PS 219 Paul Klapper',
#        'School - IS 303 Herbert S Eisenberg', 'School - PS 315',
#        'School - PS 204 Vince Lombardi',
#        'School - High School of Sports Management',
#        'School - PS 250 George H Lindsay',
#        'School - Christopher Avenue Community School',
#        'School - PS 194 Raoul Wallenberg',
#        'School - IS 229 Roland Patterson', 'School - PS 209',
#        'School - PS 94 David D Porter',
#        'School - Eagle Academy for Young Men III',
#        'School - Life Academy High School for Film and Music',
#        'School - PS 398 Walter Weaver',
#        'School - PS-IS 210 Twenty-First Century Academy for Community Leadership',
#        'School - Beach Channel High School',
#        'School - PS 111 Seton Falls',
#        'School - PS-MS 31 The William Lloyd Garrison',
#        'School - PS-IS 208',
#        'School - Hudson High School of Learning Technologies',
#        'School - PS 32 The Gifford School',
#        'School - PS 272 Curtis Estabrook', 'School - PS 315 Lab School',
#        "School - MS 137 America's School of Heroes",
#        'School - PS 40 Augustus Saint-Gaudens',
#        'School - PS 6 Corporal Allan F Kivlehan School',
#        'School - Tag Young Scholars', 'School - PS 38 The Pacific',
#        'School - The Urban Assembly School of Business for Young Women',
#        'School - Mott Hall High School',
#        'School - PS 503 The School of Discovery',
#        'School - The Bronx High School of Science',
#        'School - Neighborhood School',
#        'School - Abraham Lincoln High School',
#        'School - IS 218 Salome Urena',
#        'School - JHS 210 Elizabeth Blackwell',
#        'School - PS 132 Juan Pablo Duarte', 'School - PS 32 State Street',
#        'School - Stephen T Mather Building Arts and Craftsmanship High School',
#        'School - JHS 201 The Dyker Heights',
#        'School - Our World Neighborhood Charter School',
#        'School - The High School of Fashion Industries',
#        'School - PS 191 Paul Robeson',
#        'School - August Martin High School',
#        'School - IS 61 William A Morris',
#        'School - PS 264 Bay Ridge Elementary School for the Arts',
#        'School - PS 222 Katherine R Snyder',
#        'School - Bronx River High School',
#        'School - Bronx Leadership Academy High School',
#        'School - Civic Leadership Academy', 'Fire Department of New York',
#        'School - MS 322', 'School - JHS 125 Henry Hudson',
#        'School - PS-IS 187 Hudson Cliffs',
#        'School - PS 234 Independence School',
#        'School - PS 158 Bayard Taylor', 'School - PS 198 Brooklyn',
#        'School - Achievement First Crown Heights Charter School',
#        'School - The Bronx Mathematics Preparatory School',
#        'School - Curtis High School',
#        'School - A Philip Randolph Campus High School',
#        'School - PS 94 The Henry Longfellow',
#        'School - Staten Island School of Civic Leadership',
#        'School - PS Q255', 'School - Brooklyn Landmark Elementary School',
#        'School - PS 1 Tottenville', 'School - PS 312 Bergen Beach',
#        'School - PS 115 Daniel Mucatel School',
#        'School - MS 266 Park Place Community Middle School',
#        'School - PS 253 Brooklyn',
#        'School - Bayard Rustin Educational Complex',
#        'School - Fairmont Neighborhood School', 'School - PS 121 Queens',
#        'School - PS 345 Patrolman Robert Bolden',
#        'School - Eagle Academy for Young Men II',
#        'School - Cultural Academy for the Arts and Sciences',
#        'School - Chelsea Career and Technical Education High School',
#        'School - PS 11 Kathryn Phelan',
#        'School - The Active Learning Elementary School',
#        'School - PS-MS 498 Van Nest Academy',
#        'School - PS 238 Anne Sullivan',
#        'School - Forest Hills High School',
#        'School - IS 7 Elias Bernstein', 'School - PS 102 Bayview',
#        'School - ACORN Community High School',
#        'School - IS 68 Isaac Bildersee', 'School - PS 49 Willis Avenue',
#        'School - MS 126 John Ericsson', 'School - PS 112 Dutch Kills',
#        'School - East Williamsburg Scholars Academy', 'School - PS 70',
#        'School - PS 188',
#        'School - PS 50 Talfourd Lawn Elementary School',
#        'School - Castle Bridge School', 'School - PS-MS 42 R Vernam',
#        'School - PS 15 Institute for Environmental Learning',
#        'School - NYC Lab School for Collaborative Studies',
#        'School - IS 125 Thom J McCann Woodside',
#        'School - PS 124 Osmond A Church',
#        'School - IS 281 Joseph B Cavallaro',
#        'School - PS 254 The Rosa Parks School',
#        'School - PS 144 Col Jeromus Remsen',
#        'School - PS 36 J C Drumgoole', 'School - PS 75 Mayda Cortiella',
#        'School - PS 56 The Louis Desario School',
#        'School - PS 126 Dr Marjorie H Dunbar',
#        'School - Food and Finance High School',
#        'School - PS 112 Bronxwood',
#        'School - Thomas A Edison Career and Technical Education High School',
#        'School - PS 273 Wortman', 'School - PS 41 Greenwich Village',
#        'School - Brooklyn Community Arts and Media High School (BCAM)',
#        'School - PS 226 Alfred De B Mason',
#        'School - PS 55 Henry M Boehm',
#        'School - Brooklyn High School for Leadership and Community Service',
#        'School - PS 8 Isaac Varian', 'School - PS 214',
#        'School - Andries Hudde', 'School - Space Shuttle Columbia School',
#        'School - Bronx Career and College Preparatory High School',
#        'School - PS 164 Caesar Rodney', 'School - PS 306 Ethan Allen',
#        'School - PS 129 John H Finley', 'School - PS 105 The Bay School',
#        'School - Beacon High School', 'School - PS 167 The Parkway',
#        'School - Cornerstone Academy for Social Action',
#        'School - East Brooklyn Community High School',
#        'School - PS-IS 218 Rafael Hernandez Dual Language Magnet School',
#        'School - PS 23 at Queens Children Center',
#        'School - Samuel Gompers Career and Technical Education High School',
#        'School - PS 202 Ernest S Jenkyns',
#        'School - El Puente Academy for Peace and Justice',
#        'School - PS 48 William G Wilcox',
#        'School - PS-MS 20 PO George J Werdann III',
#        'School - West Brooklyn Community High School',
#        'School - Benjamin N Cardozo High School', 'School - PS 87 Bronx',
#        'School - PS 130 The Parkside', 'School - The STAR Academy PS63',
#        'School - PS 102 Jacques Cartier',
#        'School - Academy for Environmental Leadership',
#        'School - PS 76 The Bennington School',
#        'School - PS 228 Early Childhood Magnet School of the Arts',
#        'School - PS 396 - Bronx',
#        'School - Peninsula Preparatory Academy Charter School',
#        'School - MS 394', 'School - High School for Violin and Dance',
#        'School - PS 254 Dag Hammarskjold',
#        'School - JHS 216 George J Ryan', 'School - PS 3 Charrette School',
#        'School - HS 560 City As School', 'School - PS 207 Rockwood Park',
#        'School - Bronx Writing Academy',
#        'School - PS 242 The Young Diplomats Magnet Academy',
#        'School - Amber Charter School',
#        'School - Evander Childs Evening High School',
#        'School - PS 18 Winchester',
#        'School - PS 307 Daniel Hale Williams',
#        'School - PS 175 City Island',
#        'School - Family Life Academy Charter School', 'CFC - Queens East',
#        'School - PS 211',
#        'School - Merrick Academy Queens Public Charter School',
#        'School - Frank Mccourt High School',
#        'School - Norman Thomas High School',
#        'School - PS 106 Parkchester', 'School - PS 134 Henrietta Szold',
#        'School - PS 164 Queens Valley', 'School - PS 68 Bronx',
#        'School - Sheepshead Bay High School', 'School - PS 123 Suydam',
#        'School - Clara Barton High School',
#        'School - PS 196 Grand Central Parkway',
#        'School - PS 160 Walt Disney',
#        "School - Harlem Children's Zone Promise Academy II",
#        'School - PS 102 The Bayview', 'School - PS 93 Albert G Oliver',
#        'School - JHS 143 Eleanor Roosevelt', 'School - PS 193 Gil Hodges',
#        'School - Lafayette High School', 'School - PS 79 - Horan School',
#        'School - Waterside School for Leadership',
#        'School - Monroe Academy for Business-Law',
#        'School - PS 42 Claremont',
#        'School - The Urban Assembly Academy of Government and Law',
#        'School - IS 187', 'School - Manhattan Hunter Science High School',
#        'School - PS 329 Surfside', 'School - PS 153 Maspeth Elem',
#        'School - Magnet School of Math, Science and Design Technology',
#        'School - IS 237', 'School - PS 346 Abe Stark',
#        'School - PS 115 Alexander Humboldt',
#        'School - PS 397 Foster-Laurie', 'School - PS 156 Waverly',
#        'School - PS 9 Teunis G Bergen',
#        'School - Frederick Douglass Academy',
#        'School - High School for Environmental Studies',
#        'School - PS 28 The Warren Prep Academy',
#        'School - PS 173 Fresh Meadows',
#        'School - EBC High School for Public Service Bushwick',
#        'School - PS 29 John M Harrigan',
#        'School - DeWitt Clinton High School',
#        'School - PS 9 Sarah Anderson', 'Alternative Superintendency',
#        'School - PS 133 Queens',
#        'School - New Explorations Science, Technology and Math High School',
#        'School - Explore Exceed Charter School',
#        'School - Science Skills Center High School for Science, Technology, and the Creative Arts',
#        'School - New York City Lab Middle School for Collaborative Studies',
#        'School - PS 35 The Clove Valley School', 'School - PS-IS 266',
#        'School - Unity Center for Urban Technologies',
#        'School - JHS 227 Edward B Shallow',
#        'School - IS 119 The Glendale',
#        'School - East-West School of International Studies',
#        'School - PS 189', 'School - PS 81 Robert J Christen',
#        'School - IS 232', 'School - Harry S Truman High School',
#        'School - PS 132 Garret A Morgan', 'NYCEM Property Damage',
#        'School - PS 50 Frank Hankinson',
#        'School - Edward A Reynolds West Side High School',
#        'School - PS 28 Wright Brothers',
#        'School - The Gordon Parks School',
#        'School - PS-IS 157 The Benjamin Franklin Health and Science Academy',
#        'School - PS 279 Herman Schreiber', 'School - PS 246 Poe Center',
#        'School - High School for Public Service: Heroes of Tomorrow',
#        'School - PS 15 Patrick F Daly',
#        'School - PS X015 Institute for Environmental Learning',
#        'School - Bronx Leadership Academy II High School',
#        'School - PS 233 Langston Hughes', 'School - PS 231',
#        'School - PS 124 Silas B Dutcher',
#        'School - PS M169 Robert F Kennedy',
#        'School - PS 21 Philip H Sheridan',
#        'School - PS 93 William H Prescott',
#        'School - PS 41 Gun Hill Road',
#        'School - PS 225 The Eileen E Zaglin',
#        'School - PS 12 James B Colgate', 'School - PS Q177'], dtype=object)

# %% [markdown]
# #### If we look at unique values in the 'complaint type' column, we'll see that some values are in title case while others are in upper case. Also some values contains a value with special characters.

# %%
df["Complaint Type"].unique()
# Out:
# array(['Root/Sewer/Sidewalk Condition', 'HEAT/HOT WATER',
#        'DOF Property - Payment Issue', 'Street Condition',
#        'Traffic Signal Condition', 'ELECTRIC', 'Noise - Residential',
#        'Illegal Parking', 'Rodent', 'Sanitation Condition', 'Vacant Lot',
#        'Street Light Condition', 'Standing Water', 'Snow', 'Sewer',
#        'Food Establishment', 'DOF Property - Reduction Issue',
#        'Water System', 'PLUMBING', 'Indoor Air Quality',
#        'Blocked Driveway', 'WATER LEAK', 'Building/Use',
#        'For Hire Vehicle Complaint',
#        'Request Large Bulky Item Collection', 'Illegal Fireworks',
#        'Noise - Street/Sidewalk', 'DOOR/WINDOW', 'New Tree Request',
#        'OUTSIDE BUILDING', 'General Construction/Plumbing',
#        'PAINT/PLASTER', 'Sidewalk Condition', 'Food Poisoning',
#        'Missed Collection (All Materials)', 'Posting Advertisement',
#        'Damaged Tree', 'Water Quality', 'Broken Muni Meter',
#        'Elder Abuse', 'Traffic', 'Asbestos', 'HEATING', 'Noise Survey',
#        'UNSANITARY CONDITION', 'Noise - Park', 'Consumer Complaint',
#        'Noise - Vehicle', 'DOF Property - Owner Issue', 'PAINT - PLASTER',
#        'Homeless Person Assistance', 'GENERAL CONSTRUCTION', 'Elevator',
#        'Dirty Conditions', 'GENERAL', 'Graffiti', 'Noise',
#        'Litter Basket / Request', 'Dead Tree', 'Benefit Card Replacement',
#        'DHS Advantage -Landlord/Broker', 'Street Sign - Damaged',
#        'Emergency Response Team (ERT)', 'Boilers', 'Noise - Helicopter',
#        'Water Conservation', 'Derelict Vehicles',
#        'Non-Emergency Police Matter', 'SCRIE', 'APPLIANCE',
#        'Abandoned Vehicle', 'Construction Safety Enforcement',
#        'Taxi Complaint', 'Other Enforcement', 'Smoking',
#        'Overgrown Tree/Branches', 'Industrial Waste',
#        'Violation of Park Rules', 'Maintenance or Facility',
#        'FLOORING/STAIRS', 'Hazardous Materials', 'Plumbing',
#        'Noise - Commercial', 'Animal Abuse', 'DHS Advantage - Tenant',
#        'NONCONST', 'SAFETY', 'Homeless Street Condition', 'Air Quality',
#        'DOF Property - Update Account', 'Housing Options', 'Vending',
#        'Electronics Waste', 'DOF Property - Request Copy',
#        'Derelict Vehicle', 'Animal-Abuse', 'Illegal Dumping',
#        'Animal in a Park', 'DOF Parking - Payment Issue', 'Encampment',
#        'Homeless Encampment', 'NonCompliance with Phased Reopening',
#        'HPD Literature Request',
#        'DCA / DOH New License Application Request', 'Highway Condition',
#        'Mass Gathering Complaint', 'Ferry Complaint', 'Dead/Dying Tree',
#        'Housing - Low Income Senior', 'CONSTRUCTION',
#        'Non-Residential Heat', 'Lead', 'Bus Stop Shelter Complaint',
#        'Street Sign - Missing', 'Teaching/Learning/Instruction',
#        'Derelict Bicycle', 'Curb Condition', 'Public Payphone Complaint',
#        'Electrical', 'Day Care', 'Noise - House of Worship',
#        'Broken Parking Meter', 'Advocate-Personal Exemptions',
#        'Mobile Food Vendor', 'Bike/Roller/Skate Chronic', 'Drug Activity',
#        'Electronics Waste Appointment', 'Borough Office',
#        'Research Questions', 'Bridge Condition', 'Street Sign - Dangling',
#        'Drinking', 'BEST/Site Safety', 'DOF Parking - Request Status',
#        'DOF Parking - Request Copy', 'Highway Sign - Damaged',
#        'City Vehicle Placard Complaint', 'School Maintenance', 'Safety',
#        'Investigations and Discipline (IAD)', 'Missed Collection',
#        'Construction', 'Lost Property', 'Illegal Tree Damage',
#        'Unsanitary Animal Pvt Property',
#        'Private or Charter School Reopening',
#        'Vaccine Mandate Non-Compliance', 'OEM Literature Request',
#        'Collection Truck Noise', 'Panhandling', 'Recycling Enforcement',
#        'COVID-19 Non-essential Construction',
#        'DHS Advantage - Third Party',
#        'Special Projects Inspection Team (SPIT)',
#        'DOF Property - RPIE Issue', 'Traffic/Illegal Parking',
#        'Snow Removal', 'Overflowing Litter Baskets',
#        'Unsanitary Pigeon Condition', 'ELEVATOR',
#        'Home Delivered Meal - Missed Delivery', 'Dirty Condition',
#        'DPR Internal', 'Urinating in Public',
#        'Sustainability Enforcement', 'Miscellaneous Categories', 'FATF',
#        'Lot Condition', 'Beach/Pool/Sauna Complaint',
#        'Illegal Animal Kept as Pet', 'Senior Center Complaint',
#        'Taxi Report', 'Obstruction', 'Sweeping/Missed-Inadequate',
#        'Unsanitary Condition', 'Unleashed Dog',
#        'Request Xmas Tree Collection', 'Indoor Sewage', 'Home Repair',
#        'Adopt-A-Basket', 'DOF Parking - Tax Exemption', 'Outdoor Dining',
#        'Unsanitary Animal Facility', 'DRIE', 'OEM Disabled Vehicle',
#        'Cranes and Derricks', 'Scaffold Safety', 'Window Guard', 'Plant',
#        'Sweeping/Missed', 'Dead Animal', 'Utility Program',
#        'Quality of Life', 'Special Enforcement', 'Mold', 'Mosquitoes',
#        'Taxi Compliment', 'Building Marshals office',
#        'Wood Pile Remaining', 'Pet Shop', 'Ferry Inquiry',
#        'Advocate - RPIE', 'For Hire Vehicle Report',
#        'Executive Inspections', 'Storm', 'Disorderly Youth',
#        'Bus Stop Shelter Placement', 'Tattooing', 'Public Toilet',
#        'Litter Basket Request', 'DOF Property - Property Value',
#        'Sweeping/Inadequate', 'Residential Disposal Complaint', 'Forms',
#        'Abandoned Bike', 'Special Natural Area District (SNAD)',
#        'Question', 'Found Property', 'Municipal Parking Facility',
#        'Summer Camp', 'DOF Parking - DMV Clearance',
#        'Forensic Engineering', 'General', 'Home Care Provider Complaint',
#        'Weatherization', 'DOF Property - City Rebate', 'LinkNYC',
#        'Advocate-Prop Class Incorrect', 'HEAP Assistance',
#        'Water Maintenance', 'Facades', 'Stalled Sites', 'Cooling Tower',
#        'Peeling Paint', 'Sanitation Worker or Vehicle Complaint',
#        'Illegal Animal Sold', 'Drinking Water',
#        'Animal Facility - No Permit', 'Construction Lead Dust',
#        'Eviction', 'Harboring Bees/Wasps', 'Bike Rack Condition',
#        'Overflowing Recycling Baskets', "Alzheimer's Care",
#        'Street Sweeping Complaint', 'Special Operations', 'Parking Card',
#        'Highway Sign - Missing', 'Registration and Transfers',
#        'Poison Ivy', 'DEP Street Condition', 'No Child Left Behind',
#        'Discipline and Suspension', 'ATF',
#        'Advocate-Prop Refunds/Credits',
#        'Legal Services Provider Complaint', 'Uprooted Stump',
#        'Illegal Posting', 'Tunnel Condition',
#        'Case Management Agency Complaint', 'Ferry Permit', 'Tanning',
#        'Green Taxi Complaint', 'DOR Literature Request',
#        'Bereavement Support Group', 'FCST', 'Dumpster Complaint',
#        'Bottled Water', 'Advocate-Co-opCondo Abatement',
#        'Home Delivered Meal Complaint', 'Taxpayer Advocate Inquiry',
#        'DOF Parking - Address Update', 'Calorie Labeling', 'Health',
#        'Highway Sign - Dangling', 'E-Scooter', 'Comments',
#        'Unlicensed Dog', 'Radioactive Material',
#        'Litter Basket Complaint', 'X-Ray Machine/Equipment',
#        'Advocate - Other', 'STRUCTURAL', 'Dept of Investigations',
#        "Misc. Comments' and 6049=60...",
#        'Transportation Provider Complaint', 'Parent Leadership',
#        'Lifeguard', 'Commercial Disposal Complaint', 'Building Condition',
#        'Squeegee', 'Advocate-SCRIE/DRIE',
#        "a'a\\'b&quot;c&gt;?&gt;%}}%%...", 'AGENCY', '../WEB-INF/web.xml',
#        '@(9313*3464)', 'DHS Income Savings Requirement', 'ZTESTINT',
#        '...\\./...\\./...\\./...\\./......', 'Foam Ban Enforcement',
#        'DSNY Spillage', 'Green Taxi Report', 'Advocate-Property Value',
#        'Employee Behavior', 'Taxi Licensee Complaint', 'Incorrect Data',
#        'Sprinkler - Mechanical', 'FHV Licensee Complaint',
#        'DEP Highway Condition', "{!xmlparser v='&lt;!DOCTYPE...",
#        'Fire Alarm - Reinspection', 'qfix4${695*589}lixaf',
#        'Dispatched Taxi Complaint', 'Standpipe - Mechanical',
#        'Fire Alarm - New System',
#        '..\\..\\..\\..\\..\\..\\..\\..\\..\\...'], dtype=object)

# %%
df = df[~df['Complaint Type'].str.contains(r'[\.@*$]+')]

# %%
# We convert the values into title case
df['Complaint Type']=df['Complaint Type'].astype(str).apply(lambda x: x.capitalize())

# %% [markdown]
# #### Below, all of the unnecessry values in the column are removed.

# %%
df["Complaint Type"].unique()
# Out:
# array(['Root/sewer/sidewalk condition', 'Heat/hot water',
#        'Dof property - payment issue', 'Street condition',
#        'Traffic signal condition', 'Electric', 'Noise - residential',
#        'Illegal parking', 'Rodent', 'Sanitation condition', 'Vacant lot',
#        'Street light condition', 'Standing water', 'Snow', 'Sewer',
#        'Food establishment', 'Dof property - reduction issue',
#        'Water system', 'Plumbing', 'Indoor air quality',
#        'Blocked driveway', 'Water leak', 'Building/use',
#        'For hire vehicle complaint',
#        'Request large bulky item collection', 'Illegal fireworks',
#        'Noise - street/sidewalk', 'Door/window', 'New tree request',
#        'Outside building', 'General construction/plumbing',
#        'Paint/plaster', 'Sidewalk condition', 'Food poisoning',
#        'Missed collection (all materials)', 'Posting advertisement',
#        'Damaged tree', 'Water quality', 'Broken muni meter',
#        'Elder abuse', 'Traffic', 'Asbestos', 'Heating', 'Noise survey',
#        'Unsanitary condition', 'Noise - park', 'Consumer complaint',
#        'Noise - vehicle', 'Dof property - owner issue', 'Paint - plaster',
#        'Homeless person assistance', 'General construction', 'Elevator',
#        'Dirty conditions', 'General', 'Graffiti', 'Noise',
#        'Litter basket / request', 'Dead tree', 'Benefit card replacement',
#        'Dhs advantage -landlord/broker', 'Street sign - damaged',
#        'Emergency response team (ert)', 'Boilers', 'Noise - helicopter',
#        'Water conservation', 'Derelict vehicles',
#        'Non-emergency police matter', 'Scrie', 'Appliance',
#        'Abandoned vehicle', 'Construction safety enforcement',
#        'Taxi complaint', 'Other enforcement', 'Smoking',
#        'Overgrown tree/branches', 'Industrial waste',
#        'Violation of park rules', 'Maintenance or facility',
#        'Flooring/stairs', 'Hazardous materials', 'Noise - commercial',
#        'Animal abuse', 'Dhs advantage - tenant', 'Nonconst', 'Safety',
#        'Homeless street condition', 'Air quality',
#        'Dof property - update account', 'Housing options', 'Vending',
#        'Electronics waste', 'Dof property - request copy',
#        'Derelict vehicle', 'Animal-abuse', 'Illegal dumping',
#        'Animal in a park', 'Dof parking - payment issue', 'Encampment',
#        'Homeless encampment', 'Noncompliance with phased reopening',
#        'Hpd literature request',
#        'Dca / doh new license application request', 'Highway condition',
#        'Mass gathering complaint', 'Ferry complaint', 'Dead/dying tree',
#        'Housing - low income senior', 'Construction',
#        'Non-residential heat', 'Lead', 'Bus stop shelter complaint',
#        'Street sign - missing', 'Teaching/learning/instruction',
#        'Derelict bicycle', 'Curb condition', 'Public payphone complaint',
#        'Electrical', 'Day care', 'Noise - house of worship',
#        'Broken parking meter', 'Advocate-personal exemptions',
#        'Mobile food vendor', 'Bike/roller/skate chronic', 'Drug activity',
#        'Electronics waste appointment', 'Borough office',
#        'Research questions', 'Bridge condition', 'Street sign - dangling',
#        'Drinking', 'Best/site safety', 'Dof parking - request status',
#        'Dof parking - request copy', 'Highway sign - damaged',
#        'City vehicle placard complaint', 'School maintenance',
#        'Investigations and discipline (iad)', 'Missed collection',
#        'Lost property', 'Illegal tree damage',
#        'Unsanitary animal pvt property',
#        'Private or charter school reopening',
#        'Vaccine mandate non-compliance', 'Oem literature request',
#        'Collection truck noise', 'Panhandling', 'Recycling enforcement',
#        'Covid-19 non-essential construction',
#        'Dhs advantage - third party',
#        'Special projects inspection team (spit)',
#        'Dof property - rpie issue', 'Traffic/illegal parking',
#        'Snow removal', 'Overflowing litter baskets',
#        'Unsanitary pigeon condition',
#        'Home delivered meal - missed delivery', 'Dirty condition',
#        'Dpr internal', 'Urinating in public',
#        'Sustainability enforcement', 'Miscellaneous categories', 'Fatf',
#        'Lot condition', 'Beach/pool/sauna complaint',
#        'Illegal animal kept as pet', 'Senior center complaint',
#        'Taxi report', 'Obstruction', 'Sweeping/missed-inadequate',
#        'Unleashed dog', 'Request xmas tree collection', 'Indoor sewage',
#        'Home repair', 'Adopt-a-basket', 'Dof parking - tax exemption',
#        'Outdoor dining', 'Unsanitary animal facility', 'Drie',
#        'Oem disabled vehicle', 'Cranes and derricks', 'Scaffold safety',
#        'Window guard', 'Plant', 'Sweeping/missed', 'Dead animal',
#        'Utility program', 'Quality of life', 'Special enforcement',
#        'Mold', 'Mosquitoes', 'Taxi compliment',
#        'Building marshals office', 'Wood pile remaining', 'Pet shop',
#        'Ferry inquiry', 'Advocate - rpie', 'For hire vehicle report',
#        'Executive inspections', 'Storm', 'Disorderly youth',
#        'Bus stop shelter placement', 'Tattooing', 'Public toilet',
#        'Litter basket request', 'Dof property - property value',
#        'Sweeping/inadequate', 'Residential disposal complaint', 'Forms',
#        'Abandoned bike', 'Special natural area district (snad)',
#        'Question', 'Found property', 'Municipal parking facility',
#        'Summer camp', 'Dof parking - dmv clearance',
#        'Forensic engineering', 'Home care provider complaint',
#        'Weatherization', 'Dof property - city rebate', 'Linknyc',
#        'Advocate-prop class incorrect', 'Heap assistance',
#        'Water maintenance', 'Facades', 'Stalled sites', 'Cooling tower',
#        'Peeling paint', 'Sanitation worker or vehicle complaint',
#        'Illegal animal sold', 'Drinking water',
#        'Animal facility - no permit', 'Construction lead dust',
#        'Eviction', 'Harboring bees/wasps', 'Bike rack condition',
#        'Overflowing recycling baskets', "Alzheimer's care",
#        'Street sweeping complaint', 'Special operations', 'Parking card',
#        'Highway sign - missing', 'Registration and transfers',
#        'Poison ivy', 'Dep street condition', 'No child left behind',
#        'Discipline and suspension', 'Atf',
#        'Advocate-prop refunds/credits',
#        'Legal services provider complaint', 'Uprooted stump',
#        'Illegal posting', 'Tunnel condition',
#        'Case management agency complaint', 'Ferry permit', 'Tanning',
#        'Green taxi complaint', 'Dor literature request',
#        'Bereavement support group', 'Fcst', 'Dumpster complaint',
#        'Bottled water', 'Advocate-co-opcondo abatement',
#        'Home delivered meal complaint', 'Taxpayer advocate inquiry',
#        'Dof parking - address update', 'Calorie labeling', 'Health',
#        'Highway sign - dangling', 'E-scooter', 'Comments',
#        'Unlicensed dog', 'Radioactive material',
#        'Litter basket complaint', 'X-ray machine/equipment',
#        'Advocate - other', 'Structural', 'Dept of investigations',
#        'Transportation provider complaint', 'Parent leadership',
#        'Lifeguard', 'Commercial disposal complaint', 'Building condition',
#        'Squeegee', 'Advocate-scrie/drie', 'Agency',
#        'Dhs income savings requirement', 'Ztestint',
#        'Foam ban enforcement', 'Dsny spillage', 'Green taxi report',
#        'Advocate-property value', 'Employee behavior',
#        'Taxi licensee complaint', 'Incorrect data',
#        'Sprinkler - mechanical', 'Fhv licensee complaint',
#        'Dep highway condition', 'Fire alarm - reinspection',
#        'Dispatched taxi complaint', 'Standpipe - mechanical',
#        'Fire alarm - new system'], dtype=object)

# %% [markdown]
# #### To numerically encode the "Descriptor" column in the modeling phase, we'll first need to exclude all values that aren't letters and we also need to remove the Null values. Below, an empty space is substituted for all numbers and non-letter symbols.

# %%
df['Descriptor'].isnull().sum()
df = df[df['Descriptor'].notna()]

# %%
print('The unique categories are: %d \n\nThey are the following: \n%s' % (len(df.Descriptor.unique()), df.Descriptor.unique()))
# Out:
# The unique categories are: 1483
#
# They are the following:
# ['Sidewalk Consultation' 'APARTMENT ONLY' 'Property Refunds and Credits'
#  ... 'Pool/Billiard Hall' 'Warning Buzzer' 'Debris']

# %%
import re
num_pattern = r'[-()0-9]'
df.Descriptor = df.Descriptor.map(lambda x: re.sub(num_pattern, '', x).lower())
df.Descriptor = df.Descriptor.map(lambda x: re.sub('/', ' ', x))
# We convert the values into title case
df['Descriptor']=df['Descriptor'].astype(str).apply(lambda x: x.capitalize())

# %% [markdown]
# #### Since Incident Zip is the most accurate value in the dataset because through that only we can know the area from where we get the most compaints. So, we are removing rows with Null values

# %%
df = df[df['Incident Zip'].notna()]

# %%
df["Incident Zip"].unique()
# Out:
# array(['11360.0', '11691.0', '11216.0', '11413.0', '10475.0', '10457',
#        '11206.0', '10466.0', '11205.0', '10303.0', '11436.0', '10009',
#        '10452.0', '11416.0', '11691', '11432', '11219', '10312.0',
#        '11201.0', '11213.0', '11374', '11385.0', '11368.0', '10305.0',
#        '10473.0', '11226', '11234.0', '11235.0', '11413', '11220.0',
#        '11419', '11385', '11233.0', '11236', '10032.0', '11221', '10026',
#        '10027.0', '11226.0', '11218.0', '11214.0', '10465.0', '11223.0',
#        '10039.0', '11434.0', '11207.0', '11204', '11355.0', '10309.0',
#        '10033', '10038.0', '11203', '10034.0', '11230.0', '10025.0',
#        '11208', '10031.0', '10472.0', '11236.0', '10013', '11365.0',
#        '11104', '11105', '11208.0', '11235', '10462.0', '10002.0',
#        '10011.0', '10306', '10035.0', '10035', '10467.0', '11225.0',
#        '10453.0', '11435.0', '11212.0', '10016.0', '11239.0', '10021.0',
#        '10003', '10456', '11414', '10028.0', '10458.0', '10013.0',
#        '11372', '11361', '11377', '11218', '11106.0', '10032', '11228',
#        '11423', '10451.0', '10456.0', '10460.0', '10017.0', '11418.0',
#        '10459.0', '11217.0', '10040.0', '11377.0', '11231', '10467',
#        '11411.0', '10302.0', '11357.0', '10457.0', '11213', '11429.0',
#        '10314', '11362', '11419.0', '11357', '10454.0', '11435',
#        '11370.0', '10025', '11210.0', '11219.0', '11229', '11373.0',
#        '10033.0', '11238', '11369', '11430.0', '11210', '10461.0',
#        '10306.0', '10474.0', '11204.0', '10009.0', '10007', '11370',
#        '11354.0', '10075.0', '11363.0', '10029.0', '10314.0', '11432.0',
#        '10128.0', '10023.0', '10065.0', '11423.0', '11221.0', '11375.0',
#        '10452', '10002', '10019.0', '10004', '11238.0', '10451', '11358',
#        '11411', '10039', '11421.0', '10014.0', '11358.0', '10011',
#        '11414.0', '10016', '10460', '10001.0', '11105.0', '10461',
#        '11369.0', '11249', '11367.0', '11203.0', '10462', '11364.0',
#        '11412.0', '11217', '11101', '11214', '11418', '11378.0', '11355',
#        '10465', '10471', '10301', '11220', '10310', '11434', '10036.0',
#        '11233', '11433.0', '11417', '10128', '10469.0', '10304.0',
#        '10463.0', '10069.0', '11229.0', '10453', '11365', '11216',
#        '11695', '7020.0', '92626.0', '07307', '08223', '7621.0', '18503',
#        '32256', '11030', '14220', '91367.0', '77252', 'NEWARK', '89052',
#        '01010', '14692-2878', '7304.0', '08837', '11797', '75007-1912',
#        '10116.0', '17108-0988', '23113.0', '10516.0', '10805.0',
#        '32256-7412', '10804', '60191', '11096.0', '45040', '19850',
#        '07008', '11010', '11779', '18773-9635', '61826', '07024', '10591',
#        '11577', '94509-1380', '07071', '10594', '10522', '13221', '91302'],
#       dtype=object)

# %% [markdown]
# #### Standardize the Zipcode using Zfill method as every zipcode is 5 digit long and remove if it contains non-numeric character

# %%
df['Incident Zip'] = df['Incident Zip'].apply(lambda x: str(x).zfill(5))
df = df[df['Incident Zip'].str.contains(r'^\d{5}$')]

# %%
df['Incident Zip'].unique()
# Out:
# array(['10457', '10009', '11691', '11432', '11219', '11374', '11226',
#        '11413', '11419', '11385', '11236', '11221', '10026', '11204',
#        '10033', '11203', '11208', '10013', '11104', '11105', '11235',
#        '10306', '10035', '10003', '10456', '11414', '11372', '11361',
#        '11377', '11218', '10032', '11228', '11423', '11231', '10467',
#        '11213', '10314', '11362', '11357', '11435', '10025', '11229',
#        '11238', '11369', '11210', '10007', '11370', '10452', '10002',
#        '10004', '10451', '11358', '11411', '10039', '10011', '10016',
#        '10460', '10461', '11249', '10462', '11217', '11101', '11214',
#        '11418', '11355', '10465', '10471', '10301', '11220', '10310',
#        '11434', '11233', '11417', '10128', '10453', '11365', '11216',
#        '10458', '11375', '10469', '11224', '10031', '11215', '11422',
#        '10018', '11230', '10021', '10468', '11367', '10034', '10027',
#        '11103', '11222', '11354', '11225', '11106', '11207', '11427',
#        '10024', '11420', '10472', '10029', '11416', '11212', '10038',
#        '11415', '11102', '11368', '10019', '11234', '11209', '10036',
#        '10030', '11206', '11205', '10012', '10000', '10001', '10014',
#        '10010', '10304', '10466', '10023', '11412', '10463', '10312',
#        '11373', '11211', '11692', '11378', '10308', '10028', '11421',
#        '10455', '11201', '11237', '11433', '11693', '10040', '10065',
#        '10302', '11379', '10309', '11223', '10459', '11004', '10305',
#        '10470', '10303', '10129', '10464', '10075', '10454', '11366',
#        '10048', '10473', '11232', '11356', '10022', '10017', '11429',
#        '10307', '11426', '11694', '11436', '11239', '11364', '10005',
#        '11040', '11360', '11001', '11428', '10037', '11363', '10474',
#        '07047', '10044', '10006', '02459', '10280', '11430', '10162',
#        '10475', '11598', '11580', '11109', '10119', '11801', '11697',
#        '11570', '00000', '11371', '07114', '10281', '98036', '10069',
#        '10106', '07302', '10282', '11050', '11557', '11005', '00083',
#        '11003', '10171', '10532', '11021', '11507', '10169', '10020',
#        '33304', '61702', '10601', '07102', '91910', '11530', '10154',
#        '10111', '07030', '10801', '11042', '22309', '10121', '22408',
#        '11558', '08054', '11359', '18504', '10605', '11501', '11730',
#        '08879', '01103', '11725', '10103', '33442', '11251', '07094',
#        '10153', '50613', '07823', '10573', '11729', '07010', '10704',
#        '11137', '10112', '11756', '11581', '11561', '07304', '19044',
#        '11111', '07201', '98335', '11563', '07712', '10549', '10701',
#        '06604', '24033', '11552', '11549', '10172', '02061', '07654',
#        '11590', '32801', '11559', '11704', '07203', '07052', '14206',
#        '11710', '55164', '10602', '10583', '07016', '11431', '10921',
#        '08876', '08759', '10803', '27802', '11514', '19053', '10055',
#        '11241', '07660', '10278', '15563', '12345', '09262', '07093',
#        '01404', '11735', '10275', '07631', '54467', '11646', '10041',
#        '10506', '11510', '10705', '11774', '10165', '89434', '10595',
#        '11566', '02140', '75240', '10271', '11554', '11243', '11783',
#        '07054', '66062', '10120', '07601', '11749', '23562', '10177',
#        '07652', '11244', '11747', '01234', '10158', '14225', '11803',
#        '30360', '07206', '11793', '37214', '60006', '11758', '80231',
#        '07111', '07407', '26554', '07405', '07670', '85053', '77084',
#        '55439', '07807', '94954', '43054', '91367', '07410', '10603',
#        '85251', '98057', '99999', '10118', '10925', '75007', '10710',
#        '07644', '10105', '07144', '10708', '03110', '29601', '10552',
#        '07310', '29616', '10553', '10707', '11780', '95037', '97008',
#        '62002', '11545', '32207', '07306', '30344', '11714', '11764',
#        '43218', '08859', '10543', '10101', '14228', '10115', '33063',
#        '14208', '35209', '57117', '11560', '11550', '10279', '11553',
#        '18505', '85062', '01122', '10150', '07026', '11776', '11791',
#        '29615', '18519', '11425', '53566', '07101', '11695', '07307',
#        '08223', '18503', '32256', '11030', '14220', '77252', '89052',
#        '01010', '08837', '11797', '10804', '60191', '45040', '19850',
#        '07008', '11010', '11779', '61826', '07024', '10591', '11577',
#        '07071', '10594', '10522', '13221', '91302'], dtype=object)

# %% [markdown]
# #### City column also has relevance with the target variable. It is important to know from which city we are getting the maximum number of compalaints so that we can resolve that immediately.

# %%
df['City'].unique()
# Out:
# array(['BRONX', 'NEW YORK', 'Far Rockaway', 'JAMAICA', 'BROOKLYN',
#        'REGO PARK', 'Springfield Gardens', 'SOUTH RICHMOND HILL',
#        'RIDGEWOOD', 'SUNNYSIDE', 'ASTORIA', 'STATEN ISLAND', 'Jamaica',
#        'Howard Beach', 'JACKSON HEIGHTS', 'BAYSIDE', 'WOODSIDE', 'HOLLIS',
#        'Little Neck', 'FAR ROCKAWAY', 'WHITESTONE', 'EAST ELMHURST',
#        'Woodside', 'FLUSHING', 'CAMBRIA HEIGHTS', 'South Richmond Hill',
#        'LONG ISLAND CITY', 'RICHMOND HILL', 'OZONE PARK', 'Flushing',
#        'FRESH MEADOWS', 'Forest Hills', 'Rosedale', 'Bayside', 'Astoria',
#        'Queens Village', 'South Ozone Park', 'Long Island City',
#        'Sunnyside', 'Ozone Park', 'KEW GARDENS', 'CORONA', 'HOWARD BEACH',
#        'Ridgewood', 'Saint Albans', 'Elmhurst', 'SOUTH OZONE PARK',
#        'SAINT ALBANS', 'Arverne', 'MASPETH', 'Richmond Hill',
#        'FOREST HILLS', 'ELMHURST', 'WOODHAVEN', 'Cambria Heights',
#        'Middle Village', 'Glen Oaks', 'ROSEDALE', 'LITTLE NECK',
#        'Fresh Meadows', 'COLLEGE POINT', 'SPRINGFIELD GARDENS',
#        'Woodhaven', 'Kew Gardens', nan, 'East Elmhurst', 'BELLEROSE',
#        'Rockaway Park', 'QUEENS VILLAGE', 'Jackson Heights', 'ARVERNE',
#        'GLEN OAKS', 'MIDDLE VILLAGE', 'Whitestone', 'ROCKAWAY PARK',
#        'College Point', 'Bellerose', 'OAKLAND GARDENS', 'NEW HYDE PARK',
#        'Corona', 'FLORAL PARK', 'Rego Park', 'Maspeth', 'Hollis',
#        'NORTH BERGEN', 'QUEENS', 'NEWTON', 'Oakland Gardens', 'WOODMERE',
#        'VALLEY STREAM', 'HICKSVILLE', 'New Hyde Park', 'Breezy Point',
#        'ROTKBILLE CENTRE', 'NEWARK', 'Floral Park', 'BREEZY POINT',
#        'LYNWOOD', 'BROOLYN', 'BKLYN', 'JERSEY CITY', 'PORT WASHINGTON',
#        'MANHATAN', 'HEWLETT', 'CENTRAL PARK', 'ELMONT', 'HAWTHORNE',
#        'GREAT NECK', 'NORTH HILLS', 'FORT LAUDERDALE', 'BLOOMINGTON',
#        'WHITE PLAINS', 'CHULA VISTA', 'Garden City', 'HOBOKEN',
#        'NEW ROCHELLE', 'LAKE SUCCESS', 'ALEXANDRIA', 'FREDERICKSBURG',
#        'HIGHLAND PARK', 'MOUNT LAUREL', 'SCRANTON', 'WESTCHESTER',
#        'MINEOLA', 'NY', 'EAST ISLIP', 'SOUTH AMBOY', 'LONG ISLAND',
#        'COMMACK', 'DEERFIELD BEACH', 'SECAUCUS', 'CEDAR FALLS',
#        'SAN ANTONIO', 'PORT CHESTER', 'DEAR PARK', 'CLIFFSIDE PARK',
#        'YONKERS', 'LEVITTOWN', 'NEW JERSEY', 'LONG BEACH', 'HORSHAM',
#        'MANHATTAN', 'TEXAS', 'ST ALBANS', 'GARDEN CITY', 'GIG HARBOR',
#        'LYNBROOK', 'OCEAN', 'KISCO', 'BRIDGEPORT', 'WHITE STONE',
#        'ROANOKE', 'WEST HEMPSTEAD', 'HEMPSTEAD', 'NORWELL', 'WESTBURY',
#        'ORLANDO', 'LAWRENCE', 'NORTH BABYLON', 'ROCHELLE', 'WEST ORANGE',
#        'BUFFALO', 'BELMORE', 'SAINT PAULS', 'WEST BABYLON', 'WHITEPLAINS',
#        'SCARSDALE', 'CRANFORD', 'FLORIDA', 'SOMERVILLE', 'WHITING',
#        'ROCKY MOUNT', 'TREVOSE', 'RIDGEFIELD PARK', 'NEW YORK CITY',
#        'COSTA MESSA', 'GUTTEMBERG', 'LOCKPORT', 'JERICHO', 'ENGLEWOOD',
#        'PLOVER', 'BEDFORD', 'ROOSEVELT AVENUE', 'BALDWIN', 'BRANDON',
#        'MELLVILLE', 'ISLAND PARK', 'SPARKS', 'VALHALLA', 'MERRICK',
#        'CAMBRIDGE', 'LOS ANGELES', 'DALLAS', 'NASSAU', 'SEAFORD',
#        'PARSIPPANY', 'ALATHA', 'HACKENSACK', 'HOBOKIN', 'ISLANDIA', 'AL',
#        'NORTHFOLK', 'BELLMORE', 'PARAMUS', 'VALEY STREAM', 'MELVILL',
#        'WEEHAWKEN', 'PLAINVIEW', 'ATLATA', 'ASBURY PARK', 'ELIZABETH',
#        'WANTAGH', 'NASHVILLE', 'ARLINGTON HEIGHTS', 'MASSAPEQUA',
#        'DENVER', 'IRVINGTON', 'BUTLER', 'LEVVITOWN', 'TENAFLY', 'ATLANTA',
#        'PHOENIX', 'HOUSTON', 'MINNEAPOLIS', 'UNION CITY', 'MINEAPOLIS',
#        'MAHATTAN', 'PETALUMA', 'NEW ALBANY', 'WOODLAND HILL', 'FAIRLAWN',
#        'SC0TTSDALE', 'RENTON', 'GREENWOOD LAKE', 'FARMINGDALE',
#        'WESTBERY', 'CARROLTON', 'LONG ISLAND  CITY', 'LODI', 'BRONXVILLE',
#        'GREENSVILLE', 'MOUNT VERNON', 'GREENVILLE', '999', 'MALT BONER',
#        'TUCKAHOE', 'ST JAMES', 'MORGAN HILL', 'BEAVERTON', 'ALTON',
#        'MT VERNON', 'GLENHEAD NY', 'JACKSONVILLE', 'EASTPOINT',
#        'BETHPAGE', 'MILLER PLACE', 'NEWARKK', 'COLUMBUS', 'PARLIN',
#        'MAMARONECK', 'EMHURST', 'MARGATE', 'BIRMINGHAM', 'SIOUX FALLS',
#        'RIDGEWOD', 'UNIONDALE', 'PHIONEX', 'EAST MEADOW', 'GARFIELD',
#        'FORT JEFFERSON STATI', 'SYSSET', 'DICKSON CITY', '0', 'MONROE',
#        'ISLANDER', 'CLARA BARTON', 'CROTONA PARK', 'ITHICA', 'MANHASSET',
#        'HENDERSON', 'UNKNOWN', '311 TEST SERVICE REQ', 'EDISON',
#        'SOUTH OZONE', 'WOODBURY', 'BRONXS', 'WOOD DALE', 'MASON',
#        'WILMINGTON', 'CARTERET', 'FRANKLIN SQUARE', 'VALLY STREAM',
#        'ROCKVILLE CENTER', 'RONKONKOMA', 'CHAMPAIGN', 'ST PAULS',
#        'BERGEN COUNTY', 'TARRY TOWN', '00', 'PATCHOGUE', 'NEW ROCHELL',
#        'LYNDHURST', 'THORNWOOD', 'DOBBS FERRY', 'CALABASAS', 'TARRYTOWN'],
#       dtype=object)

# %%
#Bringing to standard form
df['City'] = df['City'].str.strip()
df['City']=df['City'].astype(str).apply(lambda x: x.capitalize())

#Removing rows containing only numeric in city name
df = df[~df['City'].str.isnumeric()]

# %%
df['City'].unique()
# Out:
# array(['Bronx', 'New york', 'Far rockaway', 'Jamaica', 'Brooklyn',
#        'Rego park', 'Springfield gardens', 'South richmond hill',
#        'Ridgewood', 'Sunnyside', 'Astoria', 'Staten island',
#        'Howard beach', 'Jackson heights', 'Bayside', 'Woodside', 'Hollis',
#        'Little neck', 'Whitestone', 'East elmhurst', 'Flushing',
#        'Cambria heights', 'Long island city', 'Richmond hill',
#        'Ozone park', 'Fresh meadows', 'Forest hills', 'Rosedale',
#        'Queens village', 'South ozone park', 'Kew gardens', 'Corona',
#        'Saint albans', 'Elmhurst', 'Arverne', 'Maspeth', 'Woodhaven',
#        'Middle village', 'Glen oaks', 'College point', 'Nan', 'Bellerose',
#        'Rockaway park', 'Oakland gardens', 'New hyde park', 'Floral park',
#        'North bergen', 'Queens', 'Newton', 'Woodmere', 'Valley stream',
#        'Hicksville', 'Breezy point', 'Rotkbille centre', 'Newark',
#        'Lynwood', 'Broolyn', 'Bklyn', 'Jersey city', 'Port washington',
#        'Manhatan', 'Hewlett', 'Central park', 'Elmont', 'Hawthorne',
#        'Great neck', 'North hills', 'Fort lauderdale', 'Bloomington',
#        'White plains', 'Chula vista', 'Garden city', 'Hoboken',
#        'New rochelle', 'Lake success', 'Alexandria', 'Fredericksburg',
#        'Highland park', 'Mount laurel', 'Scranton', 'Westchester',
#        'Mineola', 'Ny', 'East islip', 'South amboy', 'Long island',
#        'Commack', 'Deerfield beach', 'Secaucus', 'Cedar falls',
#        'San antonio', 'Port chester', 'Dear park', 'Cliffside park',
#        'Yonkers', 'Levittown', 'New jersey', 'Long beach', 'Horsham',
#        'Manhattan', 'Texas', 'St albans', 'Gig harbor', 'Lynbrook',
#        'Ocean', 'Kisco', 'Bridgeport', 'White stone', 'Roanoke',
#        'West hempstead', 'Hempstead', 'Norwell', 'Westbury', 'Orlando',
#        'Lawrence', 'North babylon', 'Rochelle', 'West orange', 'Buffalo',
#        'Belmore', 'Saint pauls', 'West babylon', 'Whiteplains',
#        'Scarsdale', 'Cranford', 'Florida', 'Somerville', 'Whiting',
#        'Rocky mount', 'Trevose', 'Ridgefield park', 'New york city',
#        'Costa messa', 'Guttemberg', 'Lockport', 'Jericho', 'Englewood',
#        'Plover', 'Bedford', 'Roosevelt avenue', 'Baldwin', 'Brandon',
#        'Mellville', 'Island park', 'Sparks', 'Valhalla', 'Merrick',
#        'Cambridge', 'Los angeles', 'Dallas', 'Nassau', 'Seaford',
#        'Parsippany', 'Alatha', 'Hackensack', 'Hobokin', 'Islandia', 'Al',
#        'Northfolk', 'Bellmore', 'Paramus', 'Valey stream', 'Melvill',
#        'Weehawken', 'Plainview', 'Atlata', 'Asbury park', 'Elizabeth',
#        'Wantagh', 'Nashville', 'Arlington heights', 'Massapequa',
#        'Denver', 'Irvington', 'Butler', 'Levvitown', 'Tenafly', 'Atlanta',
#        'Phoenix', 'Houston', 'Minneapolis', 'Union city', 'Mineapolis',
#        'Mahattan', 'Petaluma', 'New albany', 'Woodland hill', 'Fairlawn',
#        'Sc0ttsdale', 'Renton', 'Greenwood lake', 'Farmingdale',
#        'Westbery', 'Carrolton', 'Long island  city', 'Lodi', 'Bronxville',
#        'Greensville', 'Mount vernon', 'Greenville', 'Malt boner',
#        'Tuckahoe', 'St james', 'Morgan hill', 'Beaverton', 'Alton',
#        'Mt vernon', 'Glenhead ny', 'Jacksonville', 'Eastpoint',
#        'Bethpage', 'Miller place', 'Newarkk', 'Columbus', 'Parlin',
#        'Mamaroneck', 'Emhurst', 'Margate', 'Birmingham', 'Sioux falls',
#        'Ridgewod', 'Uniondale', 'Phionex', 'East meadow', 'Garfield',
#        'Fort jefferson stati', 'Sysset', 'Dickson city', 'Monroe',
#        'Islander', 'Clara barton', 'Crotona park', 'Ithica', 'Manhasset',
#        'Henderson', 'Unknown', '311 test service req', 'Edison',
#        'South ozone', 'Woodbury', 'Bronxs', 'Wood dale', 'Mason',
#        'Wilmington', 'Carteret', 'Franklin square', 'Vally stream',
#        'Rockville center', 'Ronkonkoma', 'Champaign', 'St pauls',
#        'Bergen county', 'Tarry town', 'Patchogue', 'New rochell',
#        'Lyndhurst', 'Thornwood', 'Dobbs ferry', 'Calabasas', 'Tarrytown'],
#       dtype=object)

# %% [markdown]
# ####We found that soundex and other fuzzy logics were not efficiently working for few city names such as 'New York' and 'Newark'. It did not recognize that they are different and hence we went ahead with filling it with the most common values with respect to zip codes.

# %%
# Multiple cities for single zip code 

new= df[df['Incident Zip'] == '07114']
new[['Incident Zip','City']]
# Out:
#         Incident Zip        City
# 35570          07114      Newark
# 82119          07114    New york
# 191440         07114      Newark
# 233796         07114  New jersey
# 286352         07114      Newark
# 343324         07114      Newark
# 402737         07114      Newark
# 412708         07114      Newark
# 539518         07114      Newark
# 641452         07114      Newark
# 798176         07114      Newark
# 892305         07114      Newark
# 918535         07114      Newark
# 1000891        07114      Newark
# 1055385        07114      Newark
# 1143849        07114      Newark
# 1250956        07114      Newark
# 1277267        07114  New jersey
# 1315673        07114      Newark
# 1324493        07114      Newark

# %%
# Collecting all possible values for each zip code with cities and their counts

zip_dicti ={}
for index, row in df.iterrows():
    if row['Incident Zip'] in zip_dicti:
        if row['City'] in zip_dicti[row['Incident Zip']]:
            zip_dicti[row['Incident Zip']][row['City']] +=1
        else:
            dicti = {row['City']: 1}
            zip_dicti[row['Incident Zip']].update(dicti)
    else:
        zip_dicti[row['Incident Zip']] = {row['City'] : 1}

print(zip_dicti)
# Out:
# {'10457': {'Bronx': 3401, 'Nan': 2}, '10009': {'New york': 2202, 'Nan': 10}, '11691': {'Far rockaway': 1840, 'Queens': 4}, '11432': {'Jamaica': 2077, 'Bellerose': 1, 'Hollis': 3, 'Flushing': 2}, '11219': {'Brooklyn': 2221, 'Nan': 4}, '11374': {'Rego park': 1369, 'Nan': 8, 'Elmhurst': 3}, '11226': {'Brooklyn': 5073, 'Nan': 7}, '11413': {'Springfield gardens': 1276, 'Rosedale': 1, 'Queens': 7, 'Nan': 3}, '11419': {'South richmond hill': 2140, 'South ozone park': 2, 'Nan': 2}, '11385': {'Ridgewood': 4119, 'Nan': 10, 'Brooklyn': 5, 'Queens': 4, 'Forest hills': 2, 'Kew gardens': 1, 'Ridgewod': 1}, '11236': {'Brooklyn': 2566, 'Nan': 6}, '11221': {'Brooklyn': 3643, 'Nan': 5}, '10026': {'New york': 1576, 'Nan': 6}, '11204': {'Brooklyn': 2277, 'Nan': 5}, '10033': {'New york': 2457, 'Manhatan': 1, 'Nan': 10}, '11203': {'Brooklyn': 2945, 'Nan': 7}, '11208': {'Brooklyn': 3682, 'Queens': 17, 'Nan': 17}, '10013': {'New york': 1644, 'Nan': 4}, '11104': {'Sunnyside': 928, 'Long island city': 2, 'Nan': 1}, '11105': {'Astoria': 1326, 'Nan': 1, 'Queens': 1}, '11235': {'Brooklyn': 2845, '
 5, 'Staten island': 1, 'Bronxs': 1}, '10471': {'Bronx': 664, 'Nan': 3}, '10301': {'Staten island': 1823, 'Nan': 4}, '11220': {'Brooklyn': 2961, 'Nan': 10, 'Astoria': 1}, '10310': {'Staten island': 951, 'Nan': 5}, '11434': {'Jamaica': 1889, 'Nan': 6, 'South ozone park': 3, 'Queens': 1}, '11233': {'Brooklyn': 3108, 'Nan': 3}, '11417': {'Ozone park': 1319, 'Nan': 10}, '10128': {'New york': 1348, 'Nan': 2}, '10453': {'Bronx': 3585, 'Nan': 10}, '11365': {'Fresh meadows': 1262, 'Queens': 1, 'Oakland gar ...

# %%
# Mapping each zip code with most common used city name

final_zip ={}
for key,value in zip_dicti.items():
    final_zip[key] =max(value, key=value.get)

print(final_zip)
# Out:
# {'10457': 'Bronx', '10009': 'New york', '11691': 'Far rockaway', '11432': 'Jamaica', '11219': 'Brooklyn', '11374': 'Rego park', '11226': 'Brooklyn', '11413': 'Springfield gardens', '11419': 'South richmond hill', '11385': 'Ridgewood', '11236': 'Brooklyn', '11221': 'Brooklyn', '10026': 'New york', '11204': 'Brooklyn', '10033': 'New york', '11203': 'Brooklyn', '11208': 'Brooklyn', '10013': 'New york', '11104': 'Sunnyside', '11105': 'Astoria', '11235': 'Brooklyn', '10306': 'Staten island', '10035': 'New york', '10003': 'New york', '10456': 'Bronx', '11414': 'Howard beach', '11372': 'Jackson heights', '11361': 'Bayside', '11377': 'Woodside', '11218': 'Brooklyn', '10032': 'New york', '11228': 'Brooklyn', '11423': 'Hollis', '11231': 'Brooklyn', '10467': 'Bronx', '11213': 'Brooklyn', '10314': 'Staten island', '11362': 'Little neck', '11357': 'Whitestone', '11435': 'Jamaica', '10025': 'New york', '11229': 'Brooklyn', '11238': 'Brooklyn', '11369': 'East elmhurst', '11210': 'Brooklyn', '10007': 'New york', '11370': 'East elmhurst', '10452': 'Bronx', '10002': 'New york', '10004': 'New york', '10451': 'Bronx', '11358': 'Flushing', '11411': 'Cambria heights', '10039': 'New york', '10011': 'New york', '10016': 'New york', '10460': 'Bronx', '10461': 'Bronx', '11249': 'Brooklyn', '10462': 'Bronx', '11217': 'Brooklyn', '11101': 'Long island city', '11214': 'Brooklyn', '11418': 'Richmond hill', '11355': 'Flushing', '10465': 'Bronx', '10471': 'Bronx', '10301': 'Staten island', '11220': 'Brooklyn', '10310': 'Staten island', '11434': 'Jamaica', '11233': 'Brooklyn', '11417': 'Ozone park', '10128': 'New york', '10453': 'Bronx', '11365': 'Fresh meadows', '11216': 'Brooklyn', '10458': 'Bronx', '11375': 'Forest hills', '10469': 'Bronx', '11224': 'Brooklyn', '10031': 'New york', '11215': 'Brooklyn', '11422': 'Rosedale', '10018': 'New york', '11230': 'Brooklyn', '10021': 'New york', '10468': 'Bronx', '11367': 'Flushing', '10034': 'New york', '10027': 'New york', '11103': 'Astoria', '11222': 'Brooklyn', '11354': 'Flushing', '11225': 'Brooklyn', '11106': 'Astoria', '11207': 'Brooklyn', '11427': 'Queens village', '10024': 'New york', '11420': 'South ozone park', '10472': 'Bronx', '10029': 'New york', '11416': 'Ozone park', '11212': 'Brooklyn', '10038': 'New york', '11415': 'Kew gardens', '11102': 'Astoria', '11368': 'Corona', '10019': 'New york', '11234': 'Brooklyn', '11209': 'Brooklyn', '10036': 'New york', '10030': 'New york', '11206': 'Brooklyn', '11205': 'Brooklyn', '10012': 'New york', '10000': 'New york', '10001': 'New york', '10014': 'New york', '10010': 'New york', '10304': 'Staten island', '10466': 'Bronx', '10023': 'New york', '11412': 'Saint albans', '10463': 'Bronx', '10312': 'Staten island', '11373': 'Elmhurst', '11211': 'Brooklyn', '11692': 'Arverne', '11378': 'Maspeth', '10308': 'Staten island', '10028': 'New york', '11421': 'Woodhaven', '10455': 'Bronx', '11201': 'Brooklyn', '11237': 'Brooklyn', '11433': 'Jamaica', '11693': 'Far rockaway', '10040': 'New york', '10065': 'New york', '10302': 'Staten island', '11379': 'Middle village', '10309': 'Staten island', '11223': 'Brooklyn', '10459': 'Bronx', '11004': 'Glen oaks', '10305': 'Staten island', '10470': 'Bronx', '10303': 'Staten island', '10129': 'New york', '10464': 'Bronx', '10075': 'New york', '10454': 'Bronx', '11366': 'Fresh meadows', '10048': 'New york', '10473': 'Bronx', '11232': 'Brooklyn', '11356': 'College point', '10022': 'New york', '10017': 'New york', '11429': 'Queens village', '10307': 'Staten island', '11426': 'Bellerose', '11694': 'Rockaway park', '11436': 'Jamaica', '11239': 'Brooklyn', '11364': 'Oakland gardens', '10005': 'New york', '11040': 'New hyde park', '11360': 'Bayside', '11001': 'Floral park', '11428': 'Queens village', '10037': 'New york', '11363': 'Little neck', '10474': 'Bronx', '07047': 'North bergen', '10044': 'New york', '10006': 'New york', '02459': 'Newton', '10280': 'New york', '11430': 'Jamaica', '10162': 'New york', '10475': 'Bronx', '11598': 'Woodmere', ...

# %% [markdown]
# #### Replacing NAN and less common/wrong values with most common city name for each zip code

# %%
for index, row in df.iterrows():
    if row['Incident Zip'] in final_zip:
        if row['City'] != final_zip[row['Incident Zip']]:
            df.at[index, 'City'] = final_zip[row['Incident Zip']]

# %% [markdown]
# #### We have total of 5 Borough in NYC. But with Null value it sums up to 6.

# %%
df['Borough'].unique()
# Out:
# array(['BRONX', 'MANHATTAN', 'QUEENS', 'BROOKLYN', nan, 'STATEN ISLAND'],
#       dtype=object)

# %% [markdown]
# #### Single zip code has mutliple or unknown values or might have wrong values.

# %%
new = df[df['Incident Zip'] == '10452']
new['Borough'].unique()
# Out:
# array(['BRONX', nan], dtype=object)

# %% [markdown]
# #### We have use nyc_zip_borough.csv master data for checking the Zipcode of our data for the NYC Boroughs with the right one.
#
# We have obtained the list of the Boroughs of NYC and their Zip Codes and we check if a zip code is in a specific NYC Borough. The data was obtained from the following website.
# https://data.beta.nyc/en/dataset/pediacities-nyc-neighborhoods/resource/7caac650-d082-4aea-9f9b-3681d568e8a5

# %%
#Please change the path for your system
boro_df = pd.read_csv("nyc_zip_borough.csv")

boro_dict ={}
for _, row in boro_df.iterrows():
    boro_dict[str(row['zip'])] = str(row['borough'])

Queens', '11355': 'Queens', '11356': 'Queens', '11357': 'Queens', '11358': 'Queens', '11360': 'Queens', '11361': 'Queens', '11362': 'Queens', '11363': 'Queens', '11364': 'Queens', '11365': 'Queens', '11366': 'Queens', '11367': 'Queens', '11368': 'Queens', '11369': 'Queens', '11370': 'Queens', '11372': 'Queens', '11373': 'Queens', '11374': 'Queens', '11375': 'Queens', '11377': 'Queens', '11378': 'Queens', '11379': 'Queens', '11385': 'Queens', '11411': 'Queens', '11412': 'Queens', '11413': 'Queens', '11414': 'Queens', '11415': 'Queens', '11416': 'Queens', '11417': 'Queens', '11418': 'Queens', '11419': 'Queens', '11420': 'Queens', '11421': 'Queens', '11422': 'Queens', '11423': 'Queens', '11426': 'Queens', '11427': 'Queens', '11428': 'Queens', '11429': 'Queens', '11432': 'Queens', '11433': 'Queens', '11434': 'Queens', '11435': 'Queens', '11436': 'Queens', '11691': 'Queens', '11692': 'Queens', '11693': 'Queens', '11694': 'Queens', '11697': 'Queens'}

# %% [markdown]
# #### Update every row with true value of Borough.

# %%
for index, row in df.iterrows():
    if row['Incident Zip'] in boro_dict:
            df.at[index, 'Borough'] = boro_dict[row['Incident Zip']].upper()

# %%
#result
new= df[df['Incident Zip'] == '10452']
new['Borough'].unique()
# Out:
# array(['BRONX'], dtype=object)

# %%
df.to_csv('pre_clustering.csv',encoding ='utf-8')

# %% [markdown]
# #### Updating the Incident_address column

# %%
df['Incident Address'].unique()
# Out:
# array(['248 EAST  174 STREET', '525 EAST 6 STREET', '14-25 PEARL STREET',
#        ..., '1115 63 STREET', '411 EAST 10 STREET',
#        '284 WEST 12TH STREET'], dtype=object)

# %%
ds = stream("pre_clustering.csv")

# %% [markdown]
# ##We use clustering from OpenClean to cluster similar values and then update the values in the same cluster with the most common value.

# %%
incident_address = ds.update('Incident Address', str.upper).distinct('Incident Address')
clusters = KeyCollision(func=Fingerprint()).clusters(incident_address)

# %%
incident_address_dict = {}
cluster_dict = {}
def print_k_clusters(clusters):
    clusters = sorted(clusters, key=lambda x: len(x), reverse=True)
    val_count = sum([len(c) for c in clusters])
    print('Total number of clusters is {} with {} values'.format(len(clusters), val_count))
    for i in range(len(clusters)):
        print('\nCluster {}'.format(i + 1))
        temp_dict = {}
        for key, cnt in clusters[i].items():
          if key == '':
            key = "''"
          print(f'  {key} (x {cnt})')
          temp_dict[key] = int(cnt)
          cluster_dict[key] = i

        incident_address_dict[i] = temp_dict
        
print_k_clusters(clusters)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Cluster 3383
#   711 EAST  231 STREET (x 10)
#   711 EAST 231 STREET (x 1)
#
# Cluster 3384
#   966 EAST 231 STREET (x 2)
#   966 EAST  231 STREET (x 1)
#
# Cluster 3385
#   232 WEST   29 STREET (x 2)
#   232 WEST 29 STREET (x 2)
#
# Cluster 3386
#   232 WEST   60 STREET (x 1)
#   232 WEST 60 STREET (x 1)
#
# Cluster 3387
#   664 EAST 232 STREET (x 1)
#   664 EAST  232 STREET (x 1)
#
# Cluster 3388
#   667 EAST 232 STREET (x 6)
#   667 EAST  232 STREET (x 4)
#
# Cluster 3389
#   674 EAST 232 STREET (x 1)
#   674 EAST  232 STREET (x 1)
#
# Cluster 3390
#   857 EAST 232 STREET (x 1)
#   857 EAST  232 STREET (x 1)
#
# Cluster 3391
#   954 EAST  232 STREET (x 1)
#   954 EAST 232 STREET (x 1)
#
# Cluster 3392
#   233 EAST 3 STREET (x 1)
#   233 EAST    3 STREET (x 1)
#
# Cluster 3393
#   233 SOUTH 3 STREET (x 2)
#   233 SOUTH    3 STREET (x 1)
#
# Cluster 3394
#   233 SOUTH    4 STREET (x 3)
#   233 SOUTH 4 STREET (x 4)
#
# Cluster 3395
#   233 WEST    4 STREET (x 1)
#   233 WEST 4 STREET (x 2)
#
# Cluster 3396
#   634 EAST  233 STREET (x 7)
#   634 EAST 233 STREET (x 1)
#
# Cluster 3397
#   642 EAST  233 STREET (x 1)
#   642 EAST 233 STREET (x 2)
#
# Cluster 3398
#   654 EAST 233 STREET (x 1)
#   654 EAST  233 STREET (x 1)
#
# Cluster 3399
#   655 EAST  233 STREET (x 3)
#   655 EAST 233 STREET (x 3)
#
# Cluster 3400
#   666 EAST  233 STREET (x 5)
#   666 EAST 233 STREET (x 4)
#
# Cluster 3401
#   675 EAST 233 STREET (x 2)
#   675 EAST  233 STREET (x 1)
#
# Cluster 3402
#   233 EAST 69 STREET (x 2)
#   233 EAST   69 STREET (x 1)
#
# Cluster 3403
#   719 EAST 233 STREET (x 12)
#   719 EAST  233 STREET (x 2)
#
# Cluster 3404
#   233 WEST   83 STREET (x 1)
#   233 WEST 83 STREET (x 1)
#
# Cluster 3405
#   23-30 BROADWAY (x 1)
#   2330 BROADWAY (x 1)
#
# Cluster 3406
#   234 EAST   24 STREET (x 1)
#   234 EAST 24 STREET (x 1)
#
# Cluster 3407
#   234 EAST 25 STREET (x 1)
#   234 EAST   25 STREET (x 2)
#
# Cluster 3408
#   234 EAST   28 STREET (x 1)
#   234 EAST 28 STREET (x 1)
#
# Cluster 3409
#   283 EAST 234 STREET (x 2)
#   283 EAST  234 STREET (x 1)
#
# Cluster 3410
#   234 EAST 4 STREET (x 2)
#   234 EAST    4 STREET (x 3)
#
# Cluster 3411
#   234 WEST   42 STREET (x 3)
#   234 WEST 42 STREET (x 2)
#
# Cluster 3412
#   234 WEST   48 STREET (x 1)
#   234 WEST 48 STREET (x 1)
#
# Cluster 3413
#   234 EAST 50 STREET (x 5)
#   234 EAST   50 STREET (x 1)
#
# Cluster 3414
#   516 EAST  234 STREET (x 1)
#   516 EAST 234 STREET (x 1)
#
# Cluster 3415
#   234 EAST   52 STREET (x 1)
#   234 EAST 52 STREET (x 2)
#
# Cluster 3416
#   530 EAST 234 STREET (x 4)
#   530 EAST  234 STREET (x 4)
#
# Cluster 3417
#   683 EAST  234 STREET (x 2)
#   683 EAST 234 STREET (x 3)
#
# Cluster 3418
#   686 EAST 234 STREET (x 11)
#   686 EAST  234 STREET (x 13)
#
# Cluster 3419
#   764 EAST  234 STREET (x 1)
#   764 EAST 234 STREET (x 1)
#
# Cluster 3420
#   234 EAST 87 STREET (x 1)
#   234 EAST   87 STREET (x 1)
#
# Cluster 3421
#   234 EAST   95 STREET (x 4)
#   234 EAST 95 STREET (x 1)
#
# Cluster 3422
#   235 WEST 46 STREET (x 1)
#   235 WEST   46 STREET (x 2)
#
# Cluster 3423
#   235 WEST   48 STREET (x 5)
#   235 WEST 48 STREET (x 2)
#
# Cluster 3424
#   500 WEST  235 STREET (x 5)
#   500 WEST 235 STREET (x 3)
#
# Cluster 3425
#   519 EAST  235 STREET (x 1)
#   519 EAST 235 STREET (x 1)
#
# Cluster 3426
#   235 EAST   53 STREET (x 1)
#   53 EAST  235 STREET (x 1)
#
# Cluster 3427
#   710 EAST 235 STREET (x 1)
#   710 EAST  235 STREET (x 1)
#
# Cluster 3428
#   805 EAST  235 STREET (x 5)
#   805 EAST 235 STREET (x 2)
#
# Cluster 3429
#   235 EAST   83 STREET (x 2)
#   235 EAST 83 STREET (x 1)
#
# Cluster 3430
#   235 EAST 84 STREET (x 3)
#   235 EAST   84 STREET (x 2)
#
# Cluster 3431
#   235 EAST EAST   95 STREET (x 1)
#   235 EAST 95 STREET (x 1)
#
# Cluster 3432
#   235 WEST STREET (x 1)
#   WEST 235 STREET (x 1)
#
# Cluster 3433
#   236 EAST   28 STREET (x 3)
#   236 EAST 28 STREET (x 1)
#
# Cluster 3434
#   356 EAST  236 STREET (x 1)
#   356 EAST 236 STREET (x 1)
#
# Cluster 3435
#   524 EAST  236 STREET (x 3)
#   524 EAST 236 STREET (x 1)
#
# Cluster 3436
#   530 EAST 236 STREET (x 1)
#   530 EAST  236 STREET (x 1)
#
# Cluster 3437
#   530 WEST  236 STREET (x 4)
#   530 WEST 236 STREET (x 2)
#
# Cluster 3438
#   545 WEST 236 STREET (x 4)
#   545 WEST  236 STREET (x 1)
#
# Cluster 3439
#   236 WEST 64 STREET (x 3)
#   236 WEST   64 STREET (x 1)
#
# Cluster 3440
#   651 EAST 236 STREET (x 1)
#   651 EAST  236 STREET (x 2)
#
# Cluster 3441
#   693 EAST  236 STREET (x 5)
#   693 EAST 236 STREET (x 1)
#
# Cluster 3442
#   236 EAST   77 STREET (x 2)
#   236 EAST 77 STREET (x 1)
#
# Cluster 3443
#   EAST  236 STREET (x 1)
#   EAST 236 STREET (x 1)
#
# Cluster 3444
#   237 EAST 26 STREET (x 1)
#   237 EAST   26 STREET (x 1)
#
# Cluster 3445
#   262 EAST  237 STREET (x 1)
#   262 EAST 237 STREET (x 1)
#
# Cluster 3446
#   272 EAST  237 STREET (x 4)
#   272 EAST 237 STREET (x 1)
#
# Cluster 3447
#   278 EAST 237 STREET (x 1)
#   278 EAST  237 STREET (x 5)
#
# Cluster 3448
#   237 EAST 31 STREET (x 3)
#   237 EAST   31 STREET (x 2)
#
# Cluster 3449
#   237 WEST 42 STREET (x 1)
#   237 WEST   42 STREET (x 1)
#
# Cluster 3450
#   2375 EAST    3 STREET (x 3)
#   2375 EAST 3 STREET (x 4)
#
# Cluster 3451
#   238 EAST   26 STREET (x 6)
#   238 EAST 26 STREET (x 3)
#
# Cluster 3452
#   275 WEST 238 STREET (x 1)
#   275 WEST  238 STREET (x 2)
#
# Cluster 3453
#   440 WEST  238 STREET (x 1)
#   440 WEST 238 STREET (x 2)
#
# Cluster 3454
#   238 WEST 56 STREET (x 1)
#   238 WEST   56 STREET (x 1)
#
# Cluster 3455
#   238 EAST 58 STREET (x 2)
#   238 EAST   58 STREET (x 1)
#
# Cluster 3456
#   68 WEST  238 STREET (x 4)
#   68 WEST 238 STREET (x 1)
#
# Cluster 3457
#   238 EAST    7 STREET (x 4)
#   238 EAST 7 STREET (x 1)
#
# Cluster 3458
#   2382 EAST 5 STREET (x 1)
#   2382 EAST    5 STREET (x 1)
#
# Cluster 3459
#   337 EAST  239 STREET (x 1)
#   337 EAST 239 STREET (x 1)
#
# Cluster 3460
#   239 WEST 63 STREET (x 1)
#   239 WEST   63 STREET (x 1)
#
# Cluster 3461
#   2466 EAST 24 STREET (x 1)
#   2466 EAST   24 STREET (x 2)
#
# Cluster 3462
#   25 WEST   24 STREET (x 9)
#   25 WEST 24 STREET (x 1)
#
# Cluster 3463
#   262 WEST 24 STREET (x 2)
#   262 WEST   24 STREET (x 1)
#
# Cluster 3464
#   2850 WEST   24 STREET (x 1)
#   2850 WEST 24 STREET (x 2)
#
# Cluster 3465
#   2950 WEST 24 STREET (x 5)
#   2950 WEST   24 STREET (x 9)
#
# Cluster 3466
#   2960 WEST 24 STREET (x 13)
#   2960 WEST   24 STREET (x 3)
#
# Cluster 3467
#   2970 WEST 24 STREET (x 10)
#   2970 WEST   24 STREET (x 6)
#
# Cluster 3468
#   305 EAST   24 STREET (x 1)
#   305 EAST 24 STREET (x 2)
#
# Cluster 3469
#   3058 WEST   24 STREET (x 2)
#   3058 WEST 24 STREET (x 1)
#
# Cluster 3470
#   400 WEST   24 STREET (x 2)
#   400 WEST 24 STREET (x 1)
#
# Cluster 3471
#   41 WEST   24 STREET (x 2)
#   41 WEST 24 STREET (x 1)
#
# Cluster 3472
#   653 EAST   24 STREET (x 1)
#   653 EAST 24 STREET (x 1)
#
# Cluster 3473
#   24 EAST 7 STREET (x 1)
#   24 EAST    7 STREET (x 1)
#
# Cluster 3474
#   24 WEST 76 STREET (x 1)
#   76 WEST   24 STREET (x 1)
#
# Cluster 3475
#   87-53 24 AVENUE (x 1)
#   8753 24 AVENUE (x 1)
#
# Cluster 3476
#   24 WEST WEST 91 STREET (x 1)
#   24 WEST 91 STREET (x 2)
#
# Cluster 3477
#   24 EAST 97 STREET (x 2)
#   24 EAST   97 STREET (x 1)
#
# Cluster 3478
#   EAST 24 STREET (x 2)
#   EAST   24 STREET (x 3)
#
# Cluster 3479
#   WEST   24 STREET (x 1)
#   WEST 24 STREET (x 4)
#
# Cluster 3480
#   240 EAST   27 STREET (x 4)
#   240 EAST 27 STREET (x 4)
#
# Cluster 3481
#   240 WEST 37 STREET (x 1)
#   240 WEST   37 STREET (x 1)
#
# Cluster 3482
#   240 WEST 40 STREET (x 1)
#   240 WEST   40 STREET (x 1)
#
# Cluster 3483
#   240 WEST 65 STREET (x 4)
#   240 WEST   65 STREET (x 2)
#
# Cluster 3484
#   240 EAST   86 STREET (x 2)
#   240 EAST 86 STREET (x 1)
#
# Cluster 3485
#   240 EAST 93 STREET (x 1)
#   240 EAST   93 STREET (x 1)
#
# Cluster 3486
#   241 WEST   54 STREET (x 1)
#   241 WEST 54 STREET (x 1)
#
# Cluster 3487
#   241 EAST 76 STREET (x 1)
#   241 EAST   76 STREET (x 1)
#
# Cluster 3488
#   241 EAST MOSHOLU PARKWAY NORTH (x 3)
#   241 EAST EAST MOSHOLU PARKWAY NORTH (x 1)
#
# Cluster 3489
#   2411 EAST    3 STREET (x 2)
#   2411 EAST 3 STREET (x 1)
#
# Cluster 3490
#   2418 EAST   69 STREET (x 2)
#   2418 EAST 69 STREET (x 5)
#
# Cluster 3491
#   242 EAST   25 STREET (x 1)
#   242 EAST 25 STREET (x 3)
#
# Cluster 3492
#   242 SOUTH 3 STREET (x 1)
#   242 SOUTH    3 STREET (x 1)
#
# Cluster 3493
#   660 EAST  242 STREET (x 4)
#   660 EAST 242 STREET (x 1)
#
# Cluster 3494
#   707 EAST 242 STREET (x 16)
#   707 EAST  242 STREET (x 13)
#
# Cluster 3495
#   717 EAST 242 STREET (x 1)
#   717 EAST  242 STREET (x 1)
#
# Cluster 3496
#   735 EAST  242 STREET (x 7)
#   735 EAST 242 STREET (x 3)
#
# Cluster 3497
#   242 EAST 75 STREET (x 1)
#   242 EAST   75 STREET (x 1)
#
# Cluster 3498
#   24-29 86 STREET (x 1)
#   2429 86 STREET (x 2)
#
# Cluster 3499
#   243 EAST   27 STREET (x 2)
#   243 EAST 27 STREET (x 2)
#
# Cluster 3500
#   243 WEST 63 STREET (x 2)
#   243 WEST   63 STREET (x 1)
#
# Cluster 3501
#   710 EAST 243 STREET (x 3)
#   710 EAST  243 STREET (x 4)
#
# Cluster 3502
#   738 EAST  243 STREET (x 13)
#   738 EAST 243 STREET (x 11)
#
# Cluster 3503
#   740 EAST  243 STREET (x 4)
#   740 EAST 243 STREET (x 5)
#
# Cluster 3504
#   243 WEST 76 STREET (x 3)
#   243 WEST   76 STREET (x 1)
#
# Cluster 3505
#   2431 EAST   27 STREET (x 6)
#   2431 EAST 27 STREET (x 5)
#
# Cluster 3506
#   244 SOUTH    3 STREET (x 2)
#   244 SOUTH 3 STREET (x 1)
#
# Cluster 3507
#   244 EAST 46 STREET (x 1)
#   244 EAST   46 STREET (x 1)
#
# Cluster 3508
#   244 EAST 60 STREET (x 1)
#   244 EAST   60 STREET (x 1)
#
# Cluster 3509
#   244 EAST    7 STREET (x 1)
#   244 EAST 7 STREET (x 1)
#
# Cluster 3510
#   244 WEST   99 STREET (x 3)
#   244 WEST 99 STREET (x 1)
#
# Cluster 3511
#   2440 EAST 29 STREET (x 8)
#   2440 EAST   29 STREET (x 2)
#
# Cluster 3512
#   24-44 86 STREET (x 1)
#   2444 86 STREET (x 1)
#
# Cluster 3513
#   245 WEST   25 STREET (x 4)
#   245 WEST 25 STREET (x 1)
#
# Cluster 3514
#   245 EAST 30 STREET (x 4)
#   245 EAST   30 STREET (x 5)
#
# Cluster 3515
#   245 EAST 34 STREET (x 8)
#   245 EAST   34 STREET (x 1)
#
# Cluster 3516
#   245 EAST 40 STREET (x 1)
#   245 EAST   40 STREET (x 1)
#
# Cluster 3517
#   245 EAST 54 STREET (x 2)
#   245 EAST   54 STREET (x 2)
#
# Cluster 3518
#   245 WEST   75 STREET (x 1)
#   245 WEST 75 STREET (x 1)
#
# Cluster 3519
#   245 WEST   77 STREET (x 1)
#   245 WEST 77 STREET (x 1)
#
# Cluster 3520
#   245 EAST 93 STREET (x 1)
#   245 EAST   93 STREET (x 1)
#
# Cluster 3521
#   2452 EAST 66 STREET (x 1)
#   2452 EAST   66 STREET (x 1)
#
# Cluster 3522
#   246 EAST   32 STREET (x 1)
#   246 EAST 32 STREET (x 1)
#
# Cluster 3523
#   485 WEST 246 STREET (x 1)
#   485 WEST  246 STREET (x 2)
#
# Cluster 3524
#   600 WEST  246 STREET (x 1)
#   600 WEST 246 STREET (x 1)
#
# Cluster 3525
#   630 WEST  246 STREET (x 2)
#   630 WEST 246 STREET (x 1)
#
# Cluster 3526
#   2466 EAST   29 STREET (x 1)
#   2466 EAST 29 STREET (x 1)
#
# Cluster 3527
#   247 EAST 28 STREET (x 1)
#   247 EAST   28 STREET (x 3)
#
# Cluster 3528
#   247 WEST   29 STREET (x 1)
#   247 WEST 29 STREET (x 1)
#
# Cluster 3529
#   247 SOUTH 3 STREET (x 3)
#   247 SOUTH    3 STREET (x 1)
#
# Cluster 3530
#   247 EAST 33 STREET (x 1)
#   247 EAST   33 STREET (x 1)
#
# Cluster 3531
#   247 WEST   46 STREET (x 2)
#   247 WEST 46 STREET (x 3)
#
# Cluster 3532
#   247 EAST 52 STREET (x 1)
#   247 EAST   52 STREET (x 1)
#
# Cluster 3533
#   247 WEST 63 STREET (x 2)
#   247 WEST   63 STREET (x 1)
#
# Cluster 3534
#   248 NORTH 8 STREET (x 1)
#   248 NORTH    8 STREET (x 1)
#
# Cluster 3535
#   249 EAST   52 STREET (x 4)
#   249 EAST 52 STREET (x 1)
#
# Cluster 3536
#   249 EAST   77 STREET (x 1)
#   249 EAST 77 STREET (x 2)
#
# Cluster 3537
#   266 WEST   25 STREET (x 2)
#   266 WEST 25 STREET (x 1)
#
# Cluster 3538
#   269 WEST 25 STREET (x 1)
#   269 WEST   25 STREET (x 1)
#
# Cluster 3539
#   2950 WEST 25 STREET (x 1)
#   2950 WEST   25 STREET (x 1)
#
# Cluster 3540
#   310 EAST   25 STREET (x 6)
#   310 EAST 25 STREET (x 3)
#
# Cluster 3541
#   319 EAST   25 STREET (x 1)
#   319 EAST 25 STREET (x 2)
#
# Cluster 3542
#   334 EAST 25 STREET (x 1)
#   334 EAST   25 STREET (x 1)
#
# Cluster 3543
#   401 WEST   25 STREET (x 1)
#   401 WEST 25 STREET (x 1)
#
# Cluster 3544
#   410 BEACH   25 STREET (x 1)
#   410 BEACH 25 STREET (x 1)
#
# Cluster 3545
#   412 WEST   25 STREET (x 1)
#   412 WEST 25 STREET (x 1)
#
# Cluster 3546
#   415 EAST 25 STREET (x 2)
#   415 EAST   25 STREET (x 1)
#
# Cluster 3547
#   416 WEST   25 STREET (x 5)
#   416 WEST 25 STREET (x 1)
#
# Cluster 3548
#   42 BAY   25 STREET (x 1)
#   42 BAY 25 STREET (x 1)
#
# Cluster 3549
#   425 EAST 25 STREET (x 2)
#   425 EAST   25 STREET (x 2)
#
# Cluster 3550
#   425 WEST   25 STREET (x 1)
#   425 WEST 25 STREET (x 7)
#
# Cluster 3551
#   25 EAST   45 STREET (x 1)
#   45 EAST 25 STREET (x 1)
#
# Cluster 3552
#   25 WEST   45 STREET (x 1)
#   45 WEST 25 STREET (x 1)
#
# Cluster 3553
#   25 EAST   51 STREET (x 1)
#   51 EAST 25 STREET (x 1)
#
# Cluster 3554
#   55 EAST   25 STREET (x 1)
#   55 EAST 25 STREET (x 1)
#
# Cluster 3555
#   25 EAST   77 STREET (x 1)
#   25 EAST 77 STREET (x 3)
#
# Cluster 3556
#   EAST 25 STREET (x 3)
#   EAST   25 STREET (x 2)
#
# Cluster 3557
#   WEST 25 STREET (x 5)
#   WEST   25 STREET (x 2)
#
# Cluster 3558
#   250 EAST 29 STREET (x 9)
#   250 EAST   29 STREET (x 18)
#
# Cluster 3559
#   250 EAST   40 STREET (x 2)
#   250 EAST 40 STREET (x 1)
#
# Cluster 3560
#   250 WEST 43 STREET (x 3)
#   250 WEST WEST 43 STREET (x 1)
#
# Cluster 3561
#   250 EAST   58 STREET (x 1)
#   250 EAST 58 STREET (x 1)
#
# Cluster 3562
#   250 EAST 63 STREET (x 1)
#   250 EAST   63 STREET (x 1)
#
# Cluster 3563
#   250 WEST   76 STREET (x 1)
#   250 WEST 76 STREET (x 1)
#
# Cluster 3564
#   250 EAST 87 STREET (x 1)
#   250 EAST   87 STREET (x 1)
#
# Cluster 3565
#   250 EAST   96 STREET (x 1)
#   250 EAST 96 STREET (x 1)
#
# Cluster 3566
#   2501 86 STREET (x 1)
#   25-01 86 STREET (x 1)
#
# Cluster 3567
#   251 WEST   26 STREET (x 2)
#   251 WEST 26 STREET (x 2)
#
# Cluster 3568
#   251 EAST 29 STREET (x 5)
#   251 EAST   29 STREET (x 1)
#
# Cluster 3569
#   251 WEST   48 STREET (x 2)
#   251 WEST 48 STREET (x 12)
#
# Cluster 3570
#   251 WEST 50 STREET (x 1)
#   251 WEST   50 STREET (x 1)
#
# Cluster 3571
#   251 WEST   92 STREET (x 3)
#   251 WEST 92 STREET (x 2)
#
# Cluster 3572
#   2518 BROADWAY (x 1)
#   25-18 BROADWAY (x 1)
#
# Cluster 3573
#   252 SOUTH    4 STREET (x 3)
#   252 SOUTH 4 STREET (x 1)
#
# Cluster 3574
#   2522 EAST   63 STREET (x 1)
#   2522 EAST 63 STREET (x 1)
#
# Cluster 3575
#   25-26 BROADWAY (x 3)
#   2526 BROADWAY (x 1)
#
# Cluster 3576
#   25-27 BROADWAY (x 18)
#   2527 BROADWAY (x 1)
#
# Cluster 3577
#   253 WEST   72 STREET (x 3)
#   253 WEST 72 STREET (x 4)
#
# Cluster 3578
#   253 EAST 77 STREET (x 1)
#   253 EAST   77 STREET (x 1)
#
# Cluster 3579
#   253 EAST   94 STREET (x 2)
#   253 EAST 94 STREET (x 3)
#
# Cluster 3580
#   254 WEST 73 STREET (x 2)
#   254 WEST   73 STREET (x 1)
#
# Cluster 3581
#   255 WEST 43 STREET (x 7)
#   255 WEST   43 STREET (x 2)
#
# Cluster 3582
#   2553 EAST   28 STREET (x 1)
#   2553 EAST 28 STREET (x 1)
#
# Cluster 3583
#   258 EAST 7 STREET (x 1)
#   258 EAST    7 STREET (x 1)
#
# Cluster 3584
#   28 WEST 26 STREET (x 1)
#   28 WEST   26 STREET (x 1)
#
# Cluster 3585
#   301 EAST 26 STREET (x 1)
#   301 EAST   26 STREET (x 1)
#
# Cluster 3586
#   31 WEST   26 STREET (x 1)
#   31 WEST 26 STREET (x 1)
#
# Cluster 3587
#   330 EAST 26 STREET (x 6)
#   330 EAST   26 STREET (x 1)
#
# Cluster 3588
#   350 WEST   26 STREET (x 1)
#   350 WEST 26 STREET (x 1)
#
# Cluster 3589
#   378 EAST   26 STREET (x 1)
#   378 EAST 26 STREET (x 1)
#
# Cluster 3590
#   411 EAST 26 STREET (x 1)
#   411 EAST   26 STREET (x 1)
#
# Cluster 3591
#   421 EAST 26 STREET (x 1)
#   421 EAST   26 STREET (x 1)
#
# Cluster 3592
#   427 WEST   26 STREET (x 2)
#   427 WEST 26 STREET (x 4)
#
# Cluster 3593
#   51 EAST   26 STREET (x 1)
#   51 EAST 26 STREET (x 1)
#
# Cluster 3594
#   55 WEST 26 STREET (x 1)
#   55 WEST   26 STREET (x 1)
#
# Cluster 3595
#   554 EAST   26 STREET (x 1)
#   554 EAST 26 STREET (x 1)
#
# Cluster 3596
#   567 EAST 26 STREET (x 3)
#   567 EAST   26 STREET (x 1)
#
# Cluster 3597
#   26 EAST   60 STREET (x 6)
#   26 EAST 60 STREET (x 3)
#
# Cluster 3598
#   600 EAST 26 STREET (x 1)
#   600 EAST   26 STREET (x 1)
#
# Cluster 3599
#   657 EAST 26 STREET (x 1)
#   657 EAST   26 STREET (x 4)
#
# Cluster 3600
#   26 WEST 9 STREET (x 1)
#   9 WEST 26 STREET (x 2)
#
# Cluster 3601
#   26 EAST 91 STREET (x 1)
#   26 EAST   91 STREET (x 1)
#
# Cluster 3602
#   EAST   26 STREET (x 4)
#   EAST 26 STREET (x 2)
#
# Cluster 3603
#   WEST 26 STREET (x 2)
#   26 WEST STREET (x 2)
#
# Cluster 3604
#   260 WEST   39 STREET (x 1)
#   260 WEST 39 STREET (x 1)
#
# Cluster 3605
#   260 WEST 52 STREET (x 1)
#   260 WEST   52 STREET (x 2)
#
# Cluster 3606
#   260 WEST 54 STREET (x 1)
#   260 WEST   54 STREET (x 2)
#
# Cluster 3607
#   270 WEST  261 STREET (x 1)
#   270 WEST 261 STREET (x 1)
#
# Cluster 3608
#   265 WEST 37 STREET (x 1)
#   265 WEST   37 STREET (x 2)
#
# Cluster 3609
#   265 EAST   78 STREET (x 1)
#   265 EAST 78 STREET (x 5)
#
# Cluster 3610
#   265 WEST   87 STREET (x 3)
#   265 WEST 87 STREET (x 1)
#
# Cluster 3611
#   266 EAST   78 STREET (x 1)
#   266 EAST 78 STREET (x 1)
#
# Cluster 3612
#   267 WEST   70 STREET (x 2)
#   267 WEST 70 STREET (x 2)
#
# Cluster 3613
#   2675 WEST 36 STREET (x 4)
#   2675 WEST   36 STREET (x 1)
#
# Cluster 3614
#   268 BAY   38 STREET (x 1)
#   268 BAY 38 STREET (x 2)
#
# Cluster 3615
#   268 WEST 77 STREET (x 1)
#   268 WEST   77 STREET (x 1)
#
# Cluster 3616
#   27 EAST 29 STREET (x 5)
#   27 EAST   29 STREET (x 4)
#
# Cluster 3617
#   2970 WEST 27 STREET (x 11)
#   2970 WEST   27 STREET (x 4)
#
# Cluster 3618
#   37 WEST   27 STREET (x 2)
#   37 WEST 27 STREET (x 1)
#
# Cluster 3619
#   43 WEST 27 STREET (x 1)
#   43 WEST   27 STREET (x 1)
#
# Cluster 3620
#   505 WEST 27 STREET (x 1)
#   505 WEST   27 STREET (x 1)
#
# Cluster 3621
#   27 NORTH    6 STREET (x 4)
#   27 NORTH 6 STREET (x 1)
#
# Cluster 3622
#   27 WEST   71 STREET (x 1)
#   27 WEST 71 STREET (x 1)
#
# Cluster 3623
#   712 EAST 27 STREET (x 1)
#   712 EAST   27 STREET (x 1)
#
# Cluster 3624
#   714 EAST   27 STREET (x 6)
#   714 EAST 27 STREET (x 1)
#
# Cluster 3625
#   27 WEST   72 STREET (x 3)
#   27 WEST 72 STREET (x 3)
#
# Cluster 3626
#   723 EAST   27 STREET (x 4)
#   723 EAST 27 STREET (x 3)
#
# Cluster 3627
#   27 WEST   96 STREET (x 10)
#   27 WEST 96 STREET (x 2)
#
# Cluster 3628
#   EAST 27 STREET (x 4)
#   EAST   27 STREET (x 3)
#
# Cluster 3629
#   27 WEST STREET (x 1)
#   WEST 27 STREET (x 2)
#
# Cluster 3630
#   270 WEST   38 STREET (x 2)
#   270 WEST 38 STREET (x 1)
#
# Cluster 3631
#   270 SOUTH 5 STREET (x 2)
#   270 SOUTH    5 STREET (x 1)
#
# Cluster 3632
#   270 EAST   92 STREET (x 2)
#   270 EAST 92 STREET (x 1)
#
# Cluster 3633
#   271 WEST   47 STREET (x 2)
#   271 WEST 47 STREET (x 1)
#
# Cluster 3634
#   271 EAST 7 STREET (x 1)
#   271 EAST    7 STREET (x 1)
#
# Cluster 3635
#   2714 AVENUE D (x 7)
#   2714 D AVENUE (x 1)
#
# Cluster 3636
#   2717 EAST   28 STREET (x 1)
#   2717 EAST 28 STREET (x 1)
#
# Cluster 3637
#   274 EAST 3 STREET (x 1)
#   274 EAST    3 STREET (x 2)
#
# Cluster 3638
#   275 BAY   37 STREET (x 2)
#   275 BAY 37 STREET (x 2)
#
# Cluster 3639
#   275 WEST 96 STREET (x 1)
#   275 WEST   96 STREET (x 3)
#
# Cluster 3640
#   2750 WEST 33 STREET (x 2)
#   2750 WEST   33 STREET (x 3)
#
# Cluster 3641
#   2758 EAST   63 STREET (x 1)
#   2758 EAST 63 STREET (x 1)
#
# Cluster 3642
#   2770 WEST 5 STREET (x 1)
#   2770 WEST    5 STREET (x 1)
#
# Cluster 3643
#   279 EAST   44 STREET (x 2)
#   279 EAST 44 STREET (x 1)
#
# Cluster 3644
#   2828 WEST 28 STREET (x 2)
#   2828 WEST   28 STREET (x 3)
#
# Cluster 3645
#   2980 WEST   28 STREET (x 8)
#   2980 WEST 28 STREET (x 2)
#
# Cluster 3646
#   305 WEST 28 STREET (x 2)
#   305 WEST   28 STREET (x 2)
#
# Cluster 3647
#   329 EAST 28 STREET (x 1)
#   329 EAST   28 STREET (x 1)
#
# Cluster 3648
#   340 WEST   28 STREET (x 1)
#   340 WEST 28 STREET (x 1)
#
# Cluster 3649
#   36 WEST   28 STREET (x 1)
#   36 WEST 28 STREET (x 1)
#
# Cluster 3650
#   28 WEST   47 STREET (x 2)
#   47 WEST 28 STREET (x 1)
#
# Cluster 3651
#   28 WEST   48 STREET (x 1)
#   28 WEST 48 STREET (x 1)
#
# Cluster 3652
#   520 WEST 28 STREET (x 2)
#   520 WEST   28 STREET (x 1)
#
# Cluster 3653
#   525 WEST 28 STREET (x 3)
#   525 WEST   28 STREET (x 3)
#
# Cluster 3654
#   632 WEST 28 STREET (x 1)
#   632 WEST   28 STREET (x 1)
#
# Cluster 3655
#   28 EAST   72 STREET (x 5)
#   28 EAST 72 STREET (x 2)
#
# Cluster 3656
#   75 EAST 28 STREET (x 2)
#   75 EAST   28 STREET (x 1)
#
# Cluster 3657
#   874 EAST   28 STREET (x 1)
#   874 EAST 28 STREET (x 1)
#
# Cluster 3658
#   28 WEST 97 STREET (x 3)
#   28 WEST   97 STREET (x 3)
#
# Cluster 3659
#   EAST   28 STREET (x 4)
#   EAST 28 STREET (x 4)
#
# Cluster 3660
#   WEST 28 STREET (x 3)
#   WEST   28 STREET (x 4)
#
# Cluster 3661
#   280 ST MARK'S AVENUE (x 1)
#   280 ST MARKS AVENUE (x 1)
#
# Cluster 3662
#   2804 BRIGHTON 8 STREET (x 2)
#   2804 BRIGHTON    8 STREET (x 2)
#
# Cluster 3663
#   2814 WEST 35 STREET (x 1)
#   2814 WEST   35 STREET (x 2)
#
# Cluster 3664
#   282 EAST 35 STREET (x 2)
#   282 EAST   35 STREET (x 1)
#
# Cluster 3665
#   2845 WEST   37 STREET (x 1)
#   2845 WEST 37 STREET (x 1)
#
# Cluster 3666
#   2849 BRIGHTON    6 STREET (x 1)
#   2849 BRIGHTON 6 STREET (x 3)
#
# Cluster 3667
#   285 EAST 3 STREET (x 1)
#   285 EAST    3 STREET (x 3)
#
# Cluster 3668
#   285 EAST   35 STREET (x 4)
#   285 EAST 35 STREET (x 1)
#
# Cluster 3669
#   2850 WEST 36 STREET (x 3)
#   2850 WEST   36 STREET (x 1)
#
# Cluster 3670
#   2-86 DUNE STREET (x 1)
#   286 DUNE STREET (x 1)
#
# Cluster 3671
#   2866 BRIGHTON 4 STREET (x 3)
#   2866 BRIGHTON    4 STREET (x 1)
#
# Cluster 3672
#   288 EAST 4 STREET (x 1)
#   288 EAST    4 STREET (x 1)
#
# Cluster 3673
#   288 EAST   95 STREET (x 3)
#   288 EAST 95 STREET (x 1)
#
# Cluster 3674
#   289 EAST 94 STREET (x 3)
#   289 EAST   94 STREET (x 1)
#
# Cluster 3675
#   2955 WEST 29 STREET (x 2)
#   2955 WEST   29 STREET (x 4)
#
# Cluster 3676
#   2960 WEST 29 STREET (x 2)
#   2960 WEST   29 STREET (x 1)
#
# Cluster 3677
#   30 BAY 29 STREET (x 1)
#   30 BAY   29 STREET (x 2)
#
# Cluster 3678
#   29 EAST 30 STREET (x 2)
#   30 EAST   29 STREET (x 3)
#
# Cluster 3679
#   301 WEST 29 STREET (x 1)
#   301 WEST   29 STREET (x 1)
#
# Cluster 3680
#   306 EAST   29 STREET (x 3)
#   306 EAST 29 STREET (x 1)
#
# Cluster 3681
#   329 WEST   29 STREET (x 1)
#   329 WEST 29 STREET (x 1)
#
# Cluster 3682
#   333 WEST   29 STREET (x 3)
#   333 WEST 29 STREET (x 1)
#
# Cluster 3683
#   34 EAST 29 STREET (x 2)
#   29 EAST   34 STREET (x 1)
#
# Cluster 3684
#   346 EAST 29 STREET (x 3)
#   346 EAST   29 STREET (x 2)
#
# Cluster 3685
#   351 WEST   29 STREET (x 1)
#   351 WEST 29 STREET (x 1)
#
# Cluster 3686
#   37 EAST   29 STREET (x 1)
#   29 EAST 37 STREET (x 1)
#
# Cluster 3687
#   373 EAST   29 STREET (x 1)
#   373 EAST 29 STREET (x 1)
#
# Cluster 3688
#   525 WEST   29 STREET (x 1)
#   525 WEST 29 STREET (x 3)
#
# Cluster 3689
#   529 WEST   29 STREET (x 2)
#   529 WEST 29 STREET (x 1)
#
# Cluster 3690
#   536 WEST 29 STREET (x 3)
#   536 WEST   29 STREET (x 1)
#
# Cluster 3691
#   601 WEST 29 STREET (x 1)
#   601 WEST   29 STREET (x 1)
#
# Cluster 3692
#   29 EAST 64 STREET (x 1)
#   29 EAST   64 STREET (x 1)
#
# Cluster 3693
#   29 WEST 65 STREET (x 3)
#   29 WEST   65 STREET (x 1)
#
# Cluster 3694
#   86 BAY 29 STREET (x 2)
#   86 BAY   29 STREET (x 1)
#
# Cluster 3695
#   924 EAST 29 STREET (x 1)
#   924 EAST   29 STREET (x 1)
#
# Cluster 3696
#   966 EAST   29 STREET (x 1)
#   966 EAST 29 STREET (x 1)
#
# Cluster 3697
#   EAST 29 STREET (x 8)
#   29 EAST 29 STREET (x 2)
#
# Cluster 3698
#   290 EAST    3 STREET (x 1)
#   290 EAST 3 STREET (x 2)
#
# Cluster 3699
#   290 EAST   56 STREET (x 1)
#   290 EAST 56 STREET (x 1)
#
# Cluster 3700
#   2901 BROADWAY (x 1)
#   29-01 BROADWAY (x 3)
#
# Cluster 3701
#   2910 BROADWAY (x 1)
#   29-10 BROADWAY (x 1)
#
# Cluster 3702
#   2911 BRIGHTON 5 STREET (x 1)
#   2911 BRIGHTON    5 STREET (x 2)
#
# Cluster 3703
#   292 EAST 40 STREET (x 1)
#   292 EAST   40 STREET (x 1)
#
# Cluster 3704
#   2923 BRIGHTON 3 STREET (x 1)
#   2923 BRIGHTON    3 STREET (x 1)
#
# Cluster 3705
#   2925 WEST 5 STREET (x 2)
#   2925 WEST    5 STREET (x 1)
#
# Cluster 3706
#   2928 WEST    5 STREET (x 2)
#   2928 WEST 5 STREET (x 1)
#
# Cluster 3707
#   2929 WEST   30 STREET (x 1)
#   2929 WEST 30 STREET (x 1)
#
# Cluster 3708
#   2929 WEST   31 STREET (x 6)
#   2929 WEST 31 STREET (x 3)
#
# Cluster 3709
#   2930 WEST   30 STREET (x 6)
#   2930 WEST 30 STREET (x 2)
#
# Cluster 3710
#   2930 WEST    5 STREET (x 2)
#   2930 WEST 5 STREET (x 1)
#
# Cluster 3711
#   2932 WEST 5 STREET (x 2)
#   2932 WEST    5 STREET (x 1)
#
# Cluster 3712
#   294 WEST   92 STREET (x 2)
#   294 WEST 92 STREET (x 1)
#
# Cluster 3713
#   294 EAST 98 STREET (x 1)
#   294 EAST   98 STREET (x 1)
#
# Cluster 3714
#   2940 WEST 33 STREET (x 2)
#   2940 WEST   33 STREET (x 2)
#
# Cluster 3715
#   2942 WEST 5 STREET (x 3)
#   2942 WEST    5 STREET (x 1)
#
# Cluster 3716
#   2951 WEST 3 STREET (x 4)
#   2951 WEST    3 STREET (x 1)
#
# Cluster 3717
#   2952 BRIGHTON    8 STREET (x 1)
#   2952 BRIGHTON 8 STREET (x 1)
#
# Cluster 3718
#   2975 WEST 33 STREET (x 3)
#   2975 WEST   33 STREET (x 1)
#
# Cluster 3719
#   298 EAST    3 STREET (x 15)
#   298 EAST 3 STREET (x 9)
#
# Cluster 3720
#   299 EAST 8 STREET (x 1)
#   299 EAST    8 STREET (x 1)
#
# Cluster 3721
#   300 EAST 3 STREET (x 1)
#   300 EAST    3 STREET (x 1)
#
# Cluster 3722
#   308 SOUTH 3 STREET (x 1)
#   308 SOUTH    3 STREET (x 1)
#
# Cluster 3723
#   3100 BRIGHTON    3 STREET (x 1)
#   3100 BRIGHTON 3 STREET (x 1)
#
# Cluster 3724
#   311 EAST 3 STREET (x 1)
#   311 EAST    3 STREET (x 2)
#
# Cluster 3725
#   3110 BRIGHTON    3 STREET (x 3)
#   3110 BRIGHTON 3 STREET (x 1)
#
# Cluster 3726
#   316 EAST    3 STREET (x 1)
#   316 EAST 3 STREET (x 1)
#
# Cluster 3727
#   357 SOUTH    3 STREET (x 3)
#   357 SOUTH 3 STREET (x 1)
#
# Cluster 3728
#   380 SOUTH    3 STREET (x 1)
#   380 SOUTH 3 STREET (x 1)
#
# Cluster 3729
#   391 SOUTH 3 STREET (x 1)
#   391 SOUTH    3 STREET (x 1)
#
# Cluster 3730
#   392 SOUTH    3 STREET (x 3)
#   392 SOUTH 3 STREET (x 1)
#
# Cluster 3731
#   3 EAST 40 STREET (x 1)
#   40 EAST    3 STREET (x 1)
#
# Cluster 3732
#   3 EAST   43 STREET (x 1)
#   3 EAST 43 STREET (x 1)
#
# Cluster 3733
#   3 EAST 48 STREET (x 3)
#   48 EAST    3 STREET (x 1)
#
# Cluster 3734
#   50 EAST    3 STREET (x 1)
#   50 EAST 3 STREET (x 2)
#
# Cluster 3735
#   509 EAST 3 STREET (x 1)
#   509 EAST    3 STREET (x 1)
#
# Cluster 3736
#   51 EAST    3 STREET (x 1)
#   51 EAST 3 STREET (x 1)
#
# Cluster 3737
#   54 EAST    3 STREET (x 3)
#   54 EAST 3 STREET (x 2)
#
# Cluster 3738
#   59 EAST    3 STREET (x 1)
#   59 EAST 3 STREET (x 2)
#
# Cluster 3739
#   61 EAST    3 STREET (x 3)
#   61 EAST 3 STREET (x 1)
#
# Cluster 3740
#   64 EAST 3 STREET (x 1)
#   64 EAST    3 STREET (x 1)
#
# Cluster 3741
#   73 EAST    3 STREET (x 4)
#   3 EAST   73 STREET (x 1)
#
# Cluster 3742
#   82 WEST 3 STREET (x 2)
#   82 WEST    3 STREET (x 1)
#
# Cluster 3743
#   85 NORTH 3 STREET (x 2)
#   85 NORTH    3 STREET (x 2)
#
# Cluster 3744
#   3 EAST 86 STREET (x 1)
#   86 EAST 3 STREET (x 1)
#
# Cluster 3745
#   91 EAST 3 STREET (x 1)
#   91 EAST    3 STREET (x 2)
#
# Cluster 3746
#   3 STREET (x 3)
#   3 3 STREET (x 1)
#
# Cluster 3747
#   308 WEST   30 STREET (x 2)
#   308 WEST 30 STREET (x 4)
#
# Cluster 3748
#   309 WEST   30 STREET (x 1)
#   309 WEST 30 STREET (x 1)
#
# Cluster 3749
#   30 EAST 31 STREET (x 1)
#   30 EAST   31 STREET (x 3)
#
# Cluster 3750
#   30 EAST 32 STREET (x 1)
#   32 EAST 30 STREET (x 1)
#
# Cluster 3751
#   320 WEST 30 STREET (x 3)
#   320 WEST WEST 30 STREET (x 1)
#
# Cluster 3752
#   324 WEST   30 STREET (x 5)
#   324 WEST 30 STREET (x 2)
#
# Cluster 3753
#   330 WEST   30 STREET (x 2)
#   330 WEST 30 STREET (x 42)
#
# Cluster 3754
#   338 EAST 30 STREET (x 2)
#   338 EAST   30 STREET (x 1)
#
# Cluster 3755
#   355 WEST   30 STREET (x 1)
#   355 WEST 30 STREET (x 1)
#
# Cluster 3756
#   363 WEST   30 STREET (x 3)
#   363 WEST 30 STREET (x 1)
#
# Cluster 3757
#   400 EAST   30 STREET (x 3)
#   400 EAST 30 STREET (x 1)
#
# Cluster 3758
#   30 WEST   50 STREET (x 1)
#   50 WEST   30 STREET (x 1)
#
# Cluster 3759
#   500 WEST   30 STREET (x 3)
#   500 WEST 30 STREET (x 1)
#
# Cluster 3760
#   501 WEST 30 STREET (x 2)
#   501 WEST   30 STREET (x 3)
#
# Cluster 3761
#   553 WEST   30 STREET (x 1)
#   553 WEST 30 STREET (x 1)
#
# Cluster 3762
#   30 EAST 71 STREET (x 1)
#   30 EAST   71 STREET (x 1)
#
# Cluster 3763
#   30 WEST 73 STREET (x 2)
#   30 WEST   73 STREET (x 1)
#
# Cluster 3764
#   30 CLARKE PLACE EAST (x 3)
#   30 EAST CLARKE PLACE (x 1)
#
# Cluster 3765
#   300 EAST 39 STREET (x 3)
#   300 EAST   39 STREET (x 1)
#
# Cluster 3766
#   300 EAST 4 STREET (x 1)
#   300 EAST    4 STREET (x 1)
#
# Cluster 3767
#   300 EAST   40 STREET (x 1)
#   300 EAST 40 STREET (x 1)
#
# Cluster 3768
#   300 WEST   46 STREET (x 4)
#   300 WEST 46 STREET (x 5)
#
# Cluster 3769
#   300 EAST 5 STREET (x 3)
#   300 EAST    5 STREET (x 1)
#
# Cluster 3770
#   300 EAST 51 STREET (x 2)
#   300 EAST EAST 51 STREET (x 1)
#
# Cluster 3771
#   300 WEST 53 STREET (x 1)
#   300 WEST   53 STREET (x 1)
#
# Cluster 3772
#   300 EAST 54 STREET (x 2)
#   300 EAST   54 STREET (x 1)
#
# Cluster 3773
#   300 WEST   55 STREET (x 2)
#   300 WEST 55 STREET (x 2)
#
# Cluster 3774
#   300 EAST   56 STREET (x 1)
#   300 EAST 56 STREET (x 2)
#
# Cluster 3775
#   300 WEST   57 STREET (x 1)
#   300 WEST 57 STREET (x 1)
#
# Cluster 3776
#   301 EAST 38 STREET (x 1)
#   301 EAST   38 STREET (x 1)
#
# Cluster 3777
#   301 WEST   45 STREET (x 3)
#   301 WEST 45 STREET (x 2)
#
# Cluster 3778
#   301 WEST 57 STREET (x 3)
#   301 WEST   57 STREET (x 1)
#
# Cluster 3779
#   301 EAST   69 STREET (x 2)
#   301 EAST 69 STREET (x 1)
#
# Cluster 3780
#   301 EAST 75 STREET (x 1)
#   301 EAST   75 STREET (x 1)
#
# Cluster 3781
#   301 EAST   80 STREET (x 2)
#   301 EAST 80 STREET (x 1)
#
# Cluster 3782
#   301 EAST 87 STREET (x 1)
#   301 EAST   87 STREET (x 1)
#
# Cluster 3783
#   3010 WEST 33 STREET (x 1)
#   3010 WEST   33 STREET (x 1)
#
# Cluster 3784
#   3015 BRIGHTON    4 STREET (x 2)
#   3015 BRIGHTON 4 STREET (x 1)
#
# Cluster 3785
#   3018 BRIGHTON 8 STREET (x 1)
#   3018 BRIGHTON    8 STREET (x 1)
#
# Cluster 3786
#   302 EAST 88 STREET (x 2)
#   302 EAST   88 STREET (x 1)
#
# Cluster 3787
#   3022 BRIGHTON    5 STREET (x 2)
#   3022 BRIGHTON 5 STREET (x 1)
#
# Cluster 3788
#   303 EAST 33 STREET (x 1)
#   303 EAST   33 STREET (x 1)
#
# Cluster 3789
#   303 EAST 4 STREET (x 2)
#   303 EAST    4 STREET (x 1)
#
# Cluster 3790
#   303 EAST 46 STREET (x 9)
#   303 EAST   46 STREET (x 3)
#
# Cluster 3791
#   303 WEST   66 STREET (x 4)
#   303 WEST 66 STREET (x 1)
#
# Cluster 3792
#   303 EAST 8 STREET (x 1)
#   303 EAST    8 STREET (x 1)
#
# Cluster 3793
#   3031 BRIGHTON    7 STREET (x 1)
#   3031 BRIGHTON 7 STREET (x 1)
#
# Cluster 3794
#   3032 BRIGHTON 6 STREET (x 1)
#   3032 BRIGHTON    6 STREET (x 1)
#
# Cluster 3795
#   3039 BRIGHTON    4 STREET (x 2)
#   3039 BRIGHTON 4 STREET (x 1)
#
# Cluster 3796
#   304 EAST   65 STREET (x 1)
#   304 EAST 65 STREET (x 1)
#
# Cluster 3797
#   304 EAST 86 STREET (x 1)
#   304 EAST   86 STREET (x 2)
#
# Cluster 3798
#   304 EAST   93 STREET (x 1)
#   304 EAST 93 STREET (x 1)
#
# Cluster 3799
#   305 EAST   40 STREET (x 1)
#   305 EAST 40 STREET (x 1)
#
# Cluster 3800
#   305 WEST 45 STREET (x 2)
#   305 WEST   45 STREET (x 1)
#
# Cluster 3801
#   305 EAST 46 STREET (x 3)
#   305 EAST   46 STREET (x 1)
#
# Cluster 3802
#   305 WEST 50 STREET (x 2)
#   305 WEST   50 STREET (x 1)
#
# Cluster 3803
#   305 WEST   72 STREET (x 1)
#   305 WEST 72 STREET (x 1)
#
# Cluster 3804
#   305 EAST   86 STREET (x 7)
#   305 EAST 86 STREET (x 2)
#
# Cluster 3805
#   305 WEST 97 STREET (x 5)
#   305 WEST   97 STREET (x 7)
#
# Cluster 3806
#   306 WEST   57 STREET (x 1)
#   306 WEST 57 STREET (x 1)
#
# Cluster 3807
#   306 EAST 80 STREET (x 1)
#   306 EAST   80 STREET (x 1)
#
# Cluster 3808
#   306 WEST 93 STREET (x 1)
#   306 WEST   93 STREET (x 1)
#
# Cluster 3809
#   306 WEST   97 STREET (x 2)
#   306 WEST 97 STREET (x 1)
#
# Cluster 3810
#   307 WEST   36 STREET (x 1)
#   307 WEST 36 STREET (x 1)
#
# Cluster 3811
#   307 WEST   39 STREET (x 2)
#   307 WEST 39 STREET (x 1)
#
# Cluster 3812
#   307 EAST   44 STREET (x 2)
#   307 EAST 44 STREET (x 1)
#
# Cluster 3813
#   307 BEACH 70 STREET (x 1)
#   307 BEACH   70 STREET (x 2)
#
# Cluster 3814
#   307 EAST   76 STREET (x 1)
#   307 EAST 76 STREET (x 2)
#
# Cluster 3815
#   307 EAST 77 STREET (x 1)
#   307 EAST   77 STREET (x 1)
#
# Cluster 3816
#   307 EAST   89 STREET (x 1)
#   307 EAST 89 STREET (x 1)
#
# Cluster 3817
#   308 EAST   38 STREET (x 2)
#   308 EAST 38 STREET (x 2)
#
# Cluster 3818
#   308 EAST 51 STREET (x 1)
#   308 EAST   51 STREET (x 1)
#
# Cluster 3819
#   308 WEST 89 STREET (x 1)
#   308 WEST   89 STREET (x 1)
#
# Cluster 3820
#   308 WEST   94 STREET (x 6)
#   308 WEST 94 STREET (x 6)
#
# Cluster 3821
#   309 EAST 37 STREET (x 2)
#   309 EAST   37 STREET (x 1)
#
# Cluster 3822
#   309 WEST   43 STREET (x 2)
#   309 WEST 43 STREET (x 1)
#
# Cluster 3823
#   309 BEACH   70 STREET (x 1)
#   309 BEACH 70 STREET (x 1)
#
# Cluster 3824
#   309 WEST   99 STREET (x 2)
#   309 WEST 99 STREET (x 1)
#
# Cluster 3825
#   3091 BRIGHTON    5 STREET (x 1)
#   3091 BRIGHTON 5 STREET (x 2)
#
# Cluster 3826
#   3094 BRIGHTON 5 STREET (x 2)
#   3094 BRIGHTON    5 STREET (x 1)
#
# Cluster 3827
#   3099 BRIGHTON 6 STREET (x 2)
#   3099 BRIGHTON    6 STREET (x 2)
#
# Cluster 3828
#   318 BEACH   31 STREET (x 1)
#   318 BEACH 31 STREET (x 1)
#
# Cluster 3829
#   320 WEST   31 STREET (x 1)
#   320 WEST 31 STREET (x 1)
#
# Cluster 3830
#   331 BEACH 31 STREET (x 1)
#   331 BEACH   31 STREET (x 1)
#
# Cluster 3831
#   31 WEST   34 STREET (x 2)
#   31 WEST 34 STREET (x 1)
#
# Cluster 3832
#   348 EAST 31 STREET (x 1)
#   348 EAST   31 STREET (x 1)
#
# Cluster 3833
#   360 EAST 31 STREET (x 1)
#   360 EAST   31 STREET (x 6)
#
# Cluster 3834
#   370 EAST   31 STREET (x 6)
#   370 EAST 31 STREET (x 2)
#
# Cluster 3835
#   406 WEST 31 STREET (x 1)
#   406 WEST   31 STREET (x 1)
#
# Cluster 3836
#   427 WEST   31 STREET (x 1)
#   427 WEST 31 STREET (x 1)
#
# Cluster 3837
#   435 WEST   31 STREET (x 2)
#   435 WEST 31 STREET (x 1)
#
# Cluster 3838
#   5 WEST 31 STREET (x 1)
#   5 WEST   31 STREET (x 1)
#
# Cluster 3839
#   31 WEST   52 STREET (x 1)
#   31 WEST 52 STREET (x 1)
#
# Cluster 3840
#   720 EAST   31 STREET (x 1)
#   720 EAST 31 STREET (x 2)
#
# Cluster 3841
#   745 EAST 31 STREET (x 5)
#   745 EAST   31 STREET (x 1)
#
# Cluster 3842
#   850 EAST   31 STREET (x 7)
#   850 EAST 31 STREET (x 3)
#
# Cluster 3843
#   310 EAST 55 STREET (x 5)
#   310 EAST   55 STREET (x 2)
#
# Cluster 3844
#   310 EAST   74 STREET (x 1)
#   310 EAST 74 STREET (x 3)
#
# Cluster 3845
#   310 EAST 83 STREET (x 4)
#   310 EAST   83 STREET (x 3)
#
# Cluster 3846
#   310 WEST 95 STREET (x 3)
#   310 WEST   95 STREET (x 3)
#
# Cluster 3847
#   3100 BRIGHTON 7 STREET (x 1)
#   3100 BRIGHTON    7 STREET (x 2)
#
# Cluster 3848
#   3108 BRIGHTON 5 STREET (x 1)
#   3108 BRIGHTON    5 STREET (x 1)
#
# Cluster 3849
#   311 BEACH   32 STREET (x 2)
#   311 BEACH 32 STREET (x 1)
#
# Cluster 3850
#   311 WEST 50 STREET (x 2)
#   311 WEST   50 STREET (x 3)
#
# Cluster 3851
#   311 WEST 72 STREET (x 1)
#   311 WEST   72 STREET (x 1)
#
# Cluster 3852
#   311 EAST   73 STREET (x 1)
#   311 EAST 73 STREET (x 1)
#
# Cluster 3853
#   311 WEST   95 STREET (x 4)
#   311 WEST 95 STREET (x 1)
#
# Cluster 3854
#   3111 BRIGHTON 7 STREET (x 2)
#   3111 BRIGHTON    7 STREET (x 1)
#
# Cluster 3855
#   31-16 SEAGIRT AVENUE (x 1)
#   3116 SEAGIRT AVENUE (x 3)
#
# Cluster 3856
#   3117 BROADWAY (x 2)
#   31-17 BROADWAY (x 1)
#
# Cluster 3857
#   312 WEST   48 STREET (x 3)
#   312 WEST 48 STREET (x 2)
#
# Cluster 3858
#   312 WEST   71 STREET (x 1)
#   312 WEST 71 STREET (x 1)
#
# Cluster 3859
#   313 WEST   37 STREET (x 3)
#   313 WEST 37 STREET (x 3)
#
# Cluster 3860
#   313 WEST   47 STREET (x 1)
#   313 WEST 47 STREET (x 1)
#
# Cluster 3861
#   313 WEST 57 STREET (x 1)
#   313 WEST   57 STREET (x 1)
#
# Cluster 3862
#   313 EAST   81 STREET (x 1)
#   313 EAST 81 STREET (x 1)
#
# Cluster 3863
#   314 WEST   39 STREET (x 1)
#   314 WEST 39 STREET (x 1)
#
# Cluster 3864
#   315 WEST   33 STREET (x 2)
#   315 WEST 33 STREET (x 2)
#
# Cluster 3865
#   315 EAST 4 STREET (x 1)
#   315 EAST    4 STREET (x 1)
#
# Cluster 3866
#   315 EAST   56 STREET (x 1)
#   315 EAST 56 STREET (x 1)
#
# Cluster 3867
#   315 WEST 61 STREET (x 1)
#   315 WEST   61 STREET (x 1)
#
# Cluster 3868
#   315 BEACH   90 STREET (x 1)
#   315 BEACH 90 STREET (x 1)
#
# Cluster 3869
#   315 WEST 91 STREET (x 1)
#   315 WEST   91 STREET (x 1)
#
# Cluster 3870
#   315 EAST 95 STREET (x 2)
#   315 EAST   95 STREET (x 1)
#
# Cluster 3871
#   316 WEST 83 STREET (x 1)
#   316 WEST   83 STREET (x 1)
#
# Cluster 3872
#   316 BEACH   84 STREET (x 1)
#   316 BEACH 84 STREET (x 1)
#
# Cluster 3873
#   316 WEST   84 STREET (x 1)
#   316 WEST 84 STREET (x 2)
#
# Cluster 3874
#   316 EAST 92 STREET (x 1)
#   316 EAST   92 STREET (x 4)
#
# Cluster 3875
#   316 EAST 93 STREET (x 4)
#   316 EAST   93 STREET (x 1)
#
# Cluster 3876
#   316 WEST 95 STREET (x 1)
#   316 WEST   95 STREET (x 2)
#
# Cluster 3877
#   317 WEST 45 STREET (x 8)
#   317 WEST   45 STREET (x 1)
#
# Cluster 3878
#   317 WEST 71 STREET (x 2)
#   317 WEST   71 STREET (x 1)
#
# Cluster 3879
#   317 WEST 99 STREET (x 2)
#   317 WEST   99 STREET (x 1)
#
# Cluster 3880
#   318 EAST 34 STREET (x 1)
#   318 EAST   34 STREET (x 1)
#
# Cluster 3881
#   318 EAST 78 STREET (x 1)
#   318 EAST   78 STREET (x 2)
#
# Cluster 3882
#   318 EAST 89 STREET (x 1)
#   318 EAST   89 STREET (x 2)
#
# Cluster 3883
#   318 EAST    9 STREET (x 1)
#   318 EAST 9 STREET (x 1)
#
# Cluster 3884
#   319 WEST   71 STREET (x 1)
#   319 WEST 71 STREET (x 1)
#
# Cluster 3885
#   319 WEST   84 STREET (x 1)
#   319 WEST 84 STREET (x 1)
#
# Cluster 3886
#   319 EAST 91 STREET (x 1)
#   319 EAST   91 STREET (x 1)
#
# Cluster 3887
#   319 WEST 94 STREET (x 4)
#   319 WEST   94 STREET (x 1)
#
# Cluster 3888
#   333 BEACH 32 STREET (x 1)
#   333 BEACH   32 STREET (x 2)
#
# Cluster 3889
#   429 EAST   32 STREET (x 1)
#   429 EAST 32 STREET (x 1)
#
# Cluster 3890
#   44 EAST 32 STREET (x 1)
#   44 EAST   32 STREET (x 1)
#
# Cluster 3891
#   585 EAST   32 STREET (x 1)
#   585 EAST 32 STREET (x 1)
#
# Cluster 3892
#   32 EAST 68 STREET (x 2)
#   32 EAST   68 STREET (x 1)
#
# Cluster 3893
#   32 WEST 69 STREET (x 1)
#   32 WEST WEST 69 STREET (x 1)
#
# Cluster 3894
#   715 EAST   32 STREET (x 2)
#   715 EAST 32 STREET (x 1)
#
# Cluster 3895
#   9 BAY   32 STREET (x 1)
#   9 BAY 32 STREET (x 1)
#
# Cluster 3896
#   9 WEST   32 STREET (x 3)
#   9 WEST 32 STREET (x 1)
#
# Cluster 3897
#   32 EAST 92 STREET (x 1)
#   92 EAST 32 STREET (x 1)
#
# Cluster 3898
#   32 WEST 92 STREET (x 3)
#   32 WEST   92 STREET (x 1)
#
# Cluster 3899
#   EAST 32 STREET (x 6)
#   EAST   32 STREET (x 1)
#
# Cluster 3900
#   320 WEST 36 STREET (x 2)
#   320 WEST   36 STREET (x 1)
#
# Cluster 3901
#   320 EAST 42 STREET (x 1)
#   320 EAST   42 STREET (x 2)
#
# Cluster 3902
#   320 WEST   55 STREET (x 2)
#   320 WEST 55 STREET (x 2)
#
# Cluster 3903
#   320 EAST   57 STREET (x 1)
#   320 EAST 57 STREET (x 1)
#
# Cluster 3904
#   320 WEST 84 STREET (x 1)
#   320 WEST   84 STREET (x 2)
#
# Cluster 3905
#   320 EAST   91 STREET (x 1)
#   320 EAST 91 STREET (x 1)
#
# Cluster 3906
#   320 WEST   96 STREET (x 5)
#   320 WEST 96 STREET (x 1)
#
# Cluster 3907
#   321 WEST   42 STREET (x 5)
#   321 WEST 42 STREET (x 2)
#
# Cluster 3908
#   321 WEST   44 STREET (x 2)
#   321 WEST 44 STREET (x 1)
#
# Cluster 3909
#   321 EAST 45 STREET (x 1)
#   321 EAST   45 STREET (x 1)
#
# Cluster 3910
#   321 EAST   54 STREET (x 1)
#   321 EAST 54 STREET (x 1)
#
# Cluster 3911
#   321 WEST   55 STREET (x 1)
#   321 WEST 55 STREET (x 1)
#
# Cluster 3912
#   321 WEST   94 STREET (x 1)
#   321 WEST 94 STREET (x 2)
#
# Cluster 3913
#   322 WEST 48 STREET (x 2)
#   322 WEST WEST 48 STREET (x 1)
#
# Cluster 3914
#   322 EAST 63 STREET (x 1)
#   322 EAST   63 STREET (x 1)
#
# Cluster 3915
#   32-30 70TH ST (x 2)
#   3230 70TH ST (x 1)
#
# Cluster 3916
#   324 EAST    6 STREET (x 1)
#   324 EAST 6 STREET (x 2)
#
# Cluster 3917
#   324 WEST   84 STREET (x 1)
#   324 WEST 84 STREET (x 4)
#
# Cluster 3918
#   325 WEST   33 STREET (x 1)
#   325 WEST 33 STREET (x 1)
#
# Cluster 3919
#   325 WEST 38 STREET (x 1)
#   325 WEST   38 STREET (x 1)
#
# Cluster 3920
#   325 WEST   45 STREET (x 2)
#   325 WEST 45 STREET (x 2)
#
# Cluster 3921
#   325 EAST 5 STREET (x 2)
#   325 EAST    5 STREET (x 3)
#
# Cluster 3922
#   325 WEST   51 STREET (x 2)
#   325 WEST 51 STREET (x 1)
#
# Cluster 3923
#   325 WEST   57 STREET (x 1)
#   325 WEST 57 STREET (x 1)
#
# Cluster 3924
#   325 EAST 6 STREET (x 2)
#   325 EAST    6 STREET (x 1)
#
# Cluster 3925
#   325 EAST 92 STREET (x 1)
#   325 EAST   92 STREET (x 1)
#
# Cluster 3926
#   326 EAST   35 STREET (x 1)
#   326 EAST 35 STREET (x 1)
#
# Cluster 3927
#   326 EAST 4 STREET (x 2)
#   326 EAST    4 STREET (x 1)
#
# Cluster 3928
#   326 EAST 6 STREET (x 2)
#   326 EAST    6 STREET (x 1)
#
# Cluster 3929
#   326 EAST 81 STREET (x 1)
#   326 EAST   81 STREET (x 1)
#
# Cluster 3930
#   326 EAST 82 STREET (x 2)
#   326 EAST   82 STREET (x 1)
#
# Cluster 3931
#   326 WEST 89 STREET (x 1)
#   326 WEST   89 STREET (x 1)
#
# Cluster 3932
#   327 EAST 50 STREET (x 2)
#   327 EAST   50 STREET (x 1)
#
# Cluster 3933
#   327 EAST   63 STREET (x 1)
#   327 EAST 63 STREET (x 1)
#
# Cluster 3934
#   327 EAST 92 STREET (x 3)
#   327 EAST   92 STREET (x 7)
#
# Cluster 3935
#   328 EAST    4 STREET (x 1)
#   328 EAST 4 STREET (x 1)
#
# Cluster 3936
#   328 WEST 44 STREET (x 1)
#   328 WEST   44 STREET (x 1)
#
# Cluster 3937
#   328 WEST   49 STREET (x 1)
#   328 WEST 49 STREET (x 1)
#
# Cluster 3938
#   328 WEST   53 STREET (x 5)
#   328 WEST 53 STREET (x 2)
#
# Cluster 3939
#   328 BEACH   89 STREET (x 1)
#   328 BEACH 89 STREET (x 1)
#
# Cluster 3940
#   328 EAST   95 STREET (x 1)
#   328 EAST 95 STREET (x 1)
#
# Cluster 3941
#   329 EAST 34 STREET (x 2)
#   329 EAST   34 STREET (x 2)
#
# Cluster 3942
#   329 EAST   63 STREET (x 5)
#   329 EAST 63 STREET (x 3)
#
# Cluster 3943
#   35 WEST   33 STREET (x 4)
#   35 WEST 33 STREET (x 4)
#
# Cluster 3944
#   42 WEST   33 STREET (x 3)
#   33 WEST 42 STREET (x 1)
#
# Cluster 3945
#   530 WEST 33 STREET (x 1)
#   530 WEST   33 STREET (x 1)
#
# Cluster 3946
#   33 EAST 74 STREET (x 1)
#   33 EAST   74 STREET (x 1)
#
# Cluster 3947
#   WEST   33 STREET (x 3)
#   WEST 33 STREET (x 4)
#
# Cluster 3948
#   330 EAST   38 STREET (x 2)
#   330 EAST 38 STREET (x 1)
#
# Cluster 3949
#   330 EAST 39 STREET (x 4)
#   330 EAST   39 STREET (x 5)
#
# Cluster 3950
#   330 WEST 45 STREET (x 1)
#   330 WEST   45 STREET (x 1)
#
# Cluster 3951
#   330 EAST   46 STREET (x 1)
#   330 EAST 46 STREET (x 2)
#
# Cluster 3952
#   330 WEST 51 STREET (x 2)
#   330 WEST   51 STREET (x 3)
#
# Cluster 3953
#   330 EAST 53 STREET (x 1)
#   330 EAST   53 STREET (x 1)
#
# Cluster 3954
#   330 WEST   55 STREET (x 2)
#   330 WEST 55 STREET (x 1)
#
# Cluster 3955
#   330 WEST 58 STREET (x 2)
#   330 WEST   58 STREET (x 3)
#
# Cluster 3956
#   330 EAST 77 STREET (x 2)
#   330 EAST   77 STREET (x 1)
#
# Cluster 3957
#   330 EAST 79 STREET (x 3)
#   330 EAST   79 STREET (x 1)
#
# Cluster 3958
#   330 EAST 80 STREET (x 3)
#   330 EAST EAST 80 STREET (x 1)
#
# Cluster 3959
#   330 WEST 84 STREET (x 1)
#   330 WEST   84 STREET (x 1)
#
# Cluster 3960
#   330 WEST   95 STREET (x 4)
#   330 WEST 95 STREET (x 5)
#
# Cluster 3961
#   331 WEST 35 STREET (x 1)
#   331 WEST   35 STREET (x 1)
#
# Cluster 3962
#   331 EAST    6 STREET (x 3)
#   331 EAST 6 STREET (x 2)
#
# Cluster 3963
#   331 WEST   86 STREET (x 2)
#   331 WEST 86 STREET (x 1)
#
# Cluster 3964
#   332 WEST   37 STREET (x 3)
#   332 WEST 37 STREET (x 3)
#
# Cluster 3965
#   332 EAST    6 STREET (x 2)
#   332 EAST 6 STREET (x 1)
#
# Cluster 3966
#   332 EAST   85 STREET (x 1)
#   332 EAST 85 STREET (x 1)
#
# Cluster 3967
#   332 EAST    9 STREET (x 3)
#   332 EAST 9 STREET (x 2)
#
# Cluster 3968
#   332 EAST   90 STREET (x 3)
#   332 EAST 90 STREET (x 1)
#
# Cluster 3969
#   333 EAST 34 STREET (x 1)
#   333 EAST   34 STREET (x 3)
#
# Cluster 3970
#   333 EAST   46 STREET (x 3)
#   333 EAST 46 STREET (x 1)
#
# Cluster 3971
#   333 WEST 56 STREET (x 1)
#   333 WEST   56 STREET (x 1)
#
# Cluster 3972
#   333 EAST 66 STREET (x 2)
#   333 EAST   66 STREET (x 1)
#
# Cluster 3973
#   333 WEST   86 STREET (x 1)
#   333 WEST 86 STREET (x 1)
#
# Cluster 3974
#   333 EAST 90 STREET (x 1)
#   333 EAST   90 STREET (x 1)
#
# Cluster 3975
#   333 EAST   92 STREET (x 2)
#   333 EAST 92 STREET (x 2)
#
# Cluster 3976
#   33-33 BROADWAY (x 1)
#   3333 BROADWAY (x 1)
#
# Cluster 3977
#   334 BEACH   54 STREET (x 2)
#   334 BEACH 54 STREET (x 4)
#
# Cluster 3978
#   334 EAST 6 STREET (x 1)
#   334 EAST    6 STREET (x 1)
#
# Cluster 3979
#   334 EAST 91 STREET (x 1)
#   334 EAST   91 STREET (x 1)
#
# Cluster 3980
#   335 EAST   65 STREET (x 2)
#   335 EAST 65 STREET (x 1)
#
# Cluster 3981
#   335 EAST 9 STREET (x 1)
#   335 EAST    9 STREET (x 1)
#
# Cluster 3982
#   336 EAST 4 STREET (x 7)
#   336 EAST    4 STREET (x 1)
#
# Cluster 3983
#   336 WEST 49 STREET (x 1)
#   336 WEST   49 STREET (x 1)
#
# Cluster 3984
#   336 EAST 52 STREET (x 1)
#   336 EAST   52 STREET (x 1)
#
# Cluster 3985
#   336 EAST   59 STREET (x 1)
#   336 EAST 59 STREET (x 1)
#
# Cluster 3986
#   336 EAST 81 STREET (x 1)
#   336 EAST   81 STREET (x 2)
#
# Cluster 3987
#   336 WEST 95 STREET (x 1)
#   336 WEST   95 STREET (x 1)
#
# Cluster 3988
#   338 WEST   46 STREET (x 1)
#   338 WEST 46 STREET (x 1)
#
# Cluster 3989
#   338 EAST 65 STREET (x 1)
#   338 EAST   65 STREET (x 2)
#
# Cluster 3990
#   338 BEACH 84 STREET (x 1)
#   338 BEACH   84 STREET (x 3)
#
# Cluster 3991
#   338 EAST   92 STREET (x 2)
#   338 EAST 92 STREET (x 2)
#
# Cluster 3992
#   340 EAST 34 STREET (x 1)
#   340 EAST   34 STREET (x 3)
#
# Cluster 3993
#   34 WEST 35 STREET (x 1)
#   34 WEST   35 STREET (x 1)
#
# Cluster 3994
#   360 WEST   34 STREET (x 4)
#   360 WEST 34 STREET (x 2)
#
# Cluster 3995
#   401 EAST   34 STREET (x 4)
#   401 EAST 34 STREET (x 3)
#
# Cluster 3996
#   414 EAST   34 STREET (x 3)
#   414 EAST 34 STREET (x 1)
#
# Cluster 3997
#   422 EAST   34 STREET (x 3)
#   422 EAST 34 STREET (x 2)
#
# Cluster 3998
#   424 EAST 34 STREET (x 1)
#   424 EAST   34 STREET (x 1)
#
# Cluster 3999
#   436 EAST 34 STREET (x 2)
#   436 EAST   34 STREET (x 2)
#
# Cluster 4000
#   440 WEST 34 STREET (x 2)
#   440 WEST   34 STREET (x 1)
#
# Cluster 4001
#   442 EAST   34 STREET (x 2)
#   442 EAST 34 STREET (x 2)
#
# Cluster 4002
#   455 WEST 34 STREET (x 2)
#   455 WEST   34 STREET (x 2)
#
# Cluster 4003
#   50 WEST   34 STREET (x 3)
#   50 WEST 34 STREET (x 2)
#
# Cluster 4004
#   516 WEST   34 STREET (x 1)
#   516 WEST 34 STREET (x 1)
#
# Cluster 4005
#   55 BAY   34 STREET (x 1)
#   55 BAY 34 STREET (x 1)
#
# Cluster 4006
#   58 EAST   34 STREET (x 1)
#   58 EAST 34 STREET (x 3)
#
# Cluster 4007
#   34 NORTH 6 STREET (x 4)
#   34 NORTH    6 STREET (x 5)
#
# Cluster 4008
#   667 EAST 34 STREET (x 4)
#   667 EAST   34 STREET (x 2)
#
# Cluster 4009
#   844 EAST   34 STREET (x 4)
#   844 EAST 34 STREET (x 1)
#
# Cluster 4010
#   EAST 34 STREET (x 3)
#   EAST   34 STREET (x 2)
#
# Cluster 4011
#   WEST 34 STREET (x 1)
#   WEST   34 STREET (x 3)
#
# Cluster 4012
#   340 EAST   52 STREET (x 2)
#   340 EAST 52 STREET (x 2)
#
# Cluster 4013
#   340 EAST 55 STREET (x 1)
#   340 EAST   55 STREET (x 1)
#
# Cluster 4014
#   340 WEST 57 STREET (x 1)
#   340 WEST   57 STREET (x 1)
#
# Cluster 4015
#   340 EAST   58 STREET (x 1)
#   340 EAST 58 STREET (x 1)
#
# Cluster 4016
#   340 EAST   62 STREET (x 1)
#   340 EAST 62 STREET (x 1)
#
# Cluster 4017
#   340 EAST 63 STREET (x 1)
#   340 EAST   63 STREET (x 3)
#
# Cluster 4018
#   340 EAST 81 STREET (x 2)
#   340 EAST   81 STREET (x 2)
#
# Cluster 4019
#   341 WEST   51 STREET (x 1)
#   341 WEST 51 STREET (x 1)
#
# Cluster 4020
#   3413 BROADWAY (x 6)
#   34-13 BROADWAY (x 1)
#
# Cluster 4021
#   34-15 BROADWAY (x 2)
#   3415 BROADWAY (x 3)
#
# Cluster 4022
#   342 EAST   55 STREET (x 1)
#   342 EAST 55 STREET (x 1)
#
# Cluster 4023
#   342 WEST   71 STREET (x 8)
#   342 WEST 71 STREET (x 4)
#
# Cluster 4024
#   3420 BROADWAY (x 2)
#   34-20 BROADWAY (x 1)
#
# Cluster 4025
#   343 WEST   86 STREET (x 6)
#   343 WEST 86 STREET (x 1)
#
# Cluster 4026
#   344 EAST   65 STREET (x 2)
#   344 EAST 65 STREET (x 1)
#
# Cluster 4027
#   344 WEST   72 STREET (x 30)
#   344 WEST 72 STREET (x 2)
#
# Cluster 4028
#   344 WEST 84 STREET (x 2)
#   344 WEST   84 STREET (x 1)
#
# Cluster 4029
#   344 EAST 85 STREET (x 4)
#   344 EAST   85 STREET (x 4)
#
# Cluster 4030
#   345 WEST 48 STREET (x 3)
#   345 WEST   48 STREET (x 1)
#
# Cluster 4031
#   345 WEST   86 STREET (x 6)
#   345 WEST 86 STREET (x 10)
#
# Cluster 4032
#   345 WEST 88 STREET (x 1)
#   345 WEST   88 STREET (x 1)
#
# Cluster 4033
#   345 EAST 92 STREET (x 2)
#   345 EAST   92 STREET (x 2)
#
# Cluster 4034
#   345 EAST   93 STREET (x 2)
#   345 EAST 93 STREET (x 1)
#
# Cluster 4035
#   346 WEST 51 STREET (x 1)
#   346 WEST   51 STREET (x 2)
#
# Cluster 4036
#   346 WEST 52 STREET (x 3)
#   346 WEST   52 STREET (x 1)
#
# Cluster 4037
#   346 EAST 59 STREET (x 1)
#   346 EAST   59 STREET (x 1)
#
# Cluster 4038
#   347 EAST 51 STREET (x 2)
#   347 EAST   51 STREET (x 2)
#
# Cluster 4039
#   347 WEST   55 STREET (x 5)
#   347 WEST 55 STREET (x 3)
#
# Cluster 4040
#   348 SOUTH 4 STREET (x 5)
#   348 SOUTH    4 STREET (x 1)
#
# Cluster 4041
#   348 WEST   47 STREET (x 3)
#   348 WEST 47 STREET (x 1)
#
# Cluster 4042
#   348 EAST 54 STREET (x 5)
#   348 EAST   54 STREET (x 1)
#
# Cluster 4043
#   348 EAST   76 STREET (x 1)
#   348 EAST 76 STREET (x 2)
#
# Cluster 4044
#   349 WEST 4 STREET (x 1)
#   349 WEST    4 STREET (x 1)
#
# Cluster 4045
#   349 BEACH   57 STREET (x 1)
#   349 BEACH 57 STREET (x 1)
#
# Cluster 4046
#   433 EAST   35 STREET (x 1)
#   433 EAST 35 STREET (x 1)
#
# Cluster 4047
#   51 WEST 35 STREET (x 1)
#   51 WEST   35 STREET (x 1)
#
# Cluster 4048
#   71 WEST 35 STREET (x 1)
#   35 WEST   71 STREET (x 1)
#
# Cluster 4049
#   35 WEST 8 STREET (x 1)
#   35 WEST    8 STREET (x 1)
#
# Cluster 4050
#   350 WEST   39 STREET (x 2)
#   350 WEST 39 STREET (x 2)
#
# Cluster 4051
#   350 SOUTH 4 STREET (x 7)
#   350 SOUTH    4 STREET (x 2)
#
# Cluster 4052
#   350 WEST   42 STREET (x 4)
#   350 WEST 42 STREET (x 4)
#
# Cluster 4053
#   350 WEST   43 STREET (x 2)
#   350 WEST 43 STREET (x 2)
#
# Cluster 4054
#   350 WEST 49 STREET (x 2)
#   350 WEST   49 STREET (x 1)
#
# Cluster 4055
#   350 WEST   50 STREET (x 3)
#   350 WEST 50 STREET (x 1)
#
# Cluster 4056
#   350 WEST   51 STREET (x 3)
#   350 WEST 51 STREET (x 1)
#
# Cluster 4057
#   350 EAST   54 STREET (x 2)
#   350 EAST 54 STREET (x 2)
#
# Cluster 4058
#   350 WEST   55 STREET (x 1)
#   350 WEST 55 STREET (x 2)
#
# Cluster 4059
#   350 EAST 79 STREET (x 1)
#   350 EAST   79 STREET (x 1)
#
# Cluster 4060
#   350 EAST 85 STREET (x 1)
#   350 EAST   85 STREET (x 1)
#
# Cluster 4061
#   350 ST ANNS AVENUE (x 12)
#   350 ST ANN'S AVENUE (x 2)
#
# Cluster 4062
#   351 WEST 42 STREET (x 8)
#   351 WEST   42 STREET (x 6)
#
# Cluster 4063
#   351 WEST 46 STREET (x 1)
#   351 WEST   46 STREET (x 1)
#
# Cluster 4064
#   351 EAST   48 STREET (x 1)
#   351 EAST 48 STREET (x 1)
#
# Cluster 4065
#   351 EAST   84 STREET (x 2)
#   351 EAST 84 STREET (x 1)
#
# Cluster 4066
#   35-17 BROADWAY (x 1)
#   3517 BROADWAY (x 2)
#
# Cluster 4067
#   352 WEST 46 STREET (x 6)
#   352 WEST   46 STREET (x 1)
#
# Cluster 4068
#   352 EAST   51 STREET (x 2)
#   352 EAST 51 STREET (x 2)
#
# Cluster 4069
#   353 WEST   56 STREET (x 1)
#   353 WEST 56 STREET (x 1)
#
# Cluster 4070
# ...
#
# Cluster 4395
#   506 EAST 6 STREET (x 1)
#   506 EAST    6 STREET (x 1)
#
# Cluster 4396
#   508 EAST   78 STREET (x 1)
#   508 EAST 78 STREET (x 1)
#
# Cluster 4397
#   509 EAST 77 STREET (x 1)
#   509 EAST   77 STREET (x 1)
#
# Cluster 4398
#   509 EAST 87 STREET (x 2)
#   509 EAST   87 STREET (x 1)
#
# Cluster 4399
#   522 EAST 51 STREET (x 1)
#   522 EAST   51 STREET (x 3)
#
# Cluster 4400
#   51 EAST   93 STREET (x 1)
#   51 EAST 93 STREET (x 1)
#
# Cluster 4401
#   WEST   51 STREET (x 1)
#   WEST 51 STREET (x 4)
#
# Cluster 4402
#   510 EAST 6 STREET (x 3)
#   510 EAST    6 STREET (x 2)
#
# Cluster 4403
#   511 EAST 6 STREET (x 1)
#   511 EAST    6 STREET (x 1)
#
# Cluster 4404
#   511 EAST   87 STREET (x 5)
#   511 EAST 87 STREET (x 3)
#
# Cluster 4405
#   513 EAST 82 STREET (x 2)
#   513 EAST   82 STREET (x 1)
#
# Cluster 4406
#   515 EAST 6 STREET (x 1)
#   515 EAST    6 STREET (x 1)
#
# Cluster 4407
#   515 EAST 7 STREET (x 1)
#   515 EAST    7 STREET (x 1)
#
# Cluster 4408
#   515 EAST   79 STREET (x 1)
#   515 EAST 79 STREET (x 1)
#
# Cluster 4409
#   515 EAST 81 STREET (x 1)
#   515 EAST   81 STREET (x 1)
#
# Cluster 4410
#   517 EAST   71 STREET (x 1)
#   517 EAST 71 STREET (x 1)
#
# Cluster 4411
#   517 EAST   75 STREET (x 1)
#   517 EAST 75 STREET (x 1)
#
# Cluster 4412
#   518 EAST 80 STREET (x 1)
#   518 EAST   80 STREET (x 1)
#
# Cluster 4413
#   518 EAST 88 STREET (x 1)
#   518 EAST   88 STREET (x 1)
#
# Cluster 4414
#   519 EAST    6 STREET (x 1)
#   519 EAST 6 STREET (x 1)
#
# Cluster 4415
#   519 EAST   82 STREET (x 1)
#   519 EAST 82 STREET (x 1)
#
# Cluster 4416
#   519 EAST   85 STREET (x 1)
#   519 EAST 85 STREET (x 1)
#
# Cluster 4417
#   525 WEST 52 STREET (x 2)
#   525 WEST   52 STREET (x 3)
#
# Cluster 4418
#   535 WEST   52 STREET (x 3)
#   535 WEST 52 STREET (x 1)
#
# Cluster 4419
#   55 EAST EAST   52 STREET (x 1)
#   55 EAST 52 STREET (x 1)
#
# Cluster 4420
#   564 WEST 52 STREET (x 1)
#   564 WEST   52 STREET (x 1)
#
# Cluster 4421
#   52 EAST 7 STREET (x 1)
#   52 EAST    7 STREET (x 1)
#
# Cluster 4422
#   WEST 52 STREET (x 2)
#   WEST   52 STREET (x 5)
#
# Cluster 4423
#   520 EAST   81 STREET (x 2)
#   520 EAST 81 STREET (x 1)
#
# Cluster 4424
#   521 EAST 87 STREET (x 1)
#   521 EAST   87 STREET (x 1)
#
# Cluster 4425
#   524 EAST 53 STREET (x 1)
#   524 EAST   53 STREET (x 1)
#
# Cluster 4426
#   525 EAST   83 STREET (x 2)
#   525 EAST 83 STREET (x 2)
#
# Cluster 4427
#   525 EAST   89 STREET (x 1)
#   525 EAST 89 STREET (x 1)
#
# Cluster 4428
#   526 EAST    6 STREET (x 1)
#   526 EAST 6 STREET (x 1)
#
# Cluster 4429
#   527 EAST   88 STREET (x 4)
#   527 EAST 88 STREET (x 1)
#
# Cluster 4430
#   529 EAST 6 STREET (x 1)
#   529 EAST    6 STREET (x 3)
#
# Cluster 4431
#   554 WEST   53 STREET (x 1)
#   554 WEST 53 STREET (x 2)
#
# Cluster 4432
#   555 WEST   53 STREET (x 1)
#   555 WEST 53 STREET (x 2)
#
# Cluster 4433
#   744 EAST   53 STREET (x 1)
#   744 EAST 53 STREET (x 1)
#
# Cluster 4434
#   87 EAST   53 STREET (x 4)
#   87 EAST 53 STREET (x 3)
#
# Cluster 4435
#   92 EAST   53 STREET (x 6)
#   92 EAST 53 STREET (x 1)
#
# Cluster 4436
#   EAST   53 STREET (x 6)
#   EAST 53 STREET (x 10)
#
# Cluster 4437
#   530 EAST   88 STREET (x 2)
#   530 EAST 88 STREET (x 2)
#
# Cluster 4438
#   530 EAST 90 STREET (x 2)
#   530 EAST   90 STREET (x 1)
#
# Cluster 4439
#   534 EAST 88 STREET (x 2)
#   534 EAST   88 STREET (x 3)
#
# Cluster 4440
#   535 NORTH GANNON AVENUE (x 1)
#   535 GANNON AVENUE NORTH (x 1)
#
# Cluster 4441
#   536 EAST    6 STREET (x 1)
#   536 EAST 6 STREET (x 1)
#
# Cluster 4442
#   536 EAST   82 STREET (x 2)
#   536 EAST 82 STREET (x 1)
#
# Cluster 4443
#   536 EAST   96 STREET (x 2)
#   536 EAST 96 STREET (x 1)
#
# Cluster 4444
#   537 EAST   81 STREET (x 2)
#   537 EAST 81 STREET (x 1)
#
# Cluster 4445
#   550 WEST   54 STREET (x 1)
#   550 WEST 54 STREET (x 2)
#
# Cluster 4446
#   54 WEST 56 STREET (x 1)
#   54 WEST   56 STREET (x 1)
#
# Cluster 4447
#   71 EAST 54 STREET (x 1)
#   71 EAST   54 STREET (x 1)
#
# Cluster 4448
#   54 EAST   91 STREET (x 1)
#   54 EAST 91 STREET (x 1)
#
# Cluster 4449
#   EAST 54 STREET (x 6)
#   EAST   54 STREET (x 4)
#
# Cluster 4450
#   542 EAST   82 STREET (x 1)
#   542 EAST 82 STREET (x 2)
#
# Cluster 4451
#   544 BEACH   72 STREET (x 2)
#   544 BEACH 72 STREET (x 1)
#
# Cluster 4452
#   545 EAST   82 STREET (x 3)
#   545 EAST 82 STREET (x 1)
#
# Cluster 4453
#   569 EAST   55 STREET (x 1)
#   569 EAST 55 STREET (x 1)
#
# Cluster 4454
#   60 EAST 55 STREET (x 2)
#   60 EAST   55 STREET (x 1)
#
# Cluster 4455
#   55 EAST 92 STREET (x 1)
#   55 EAST   92 STREET (x 2)
#
# Cluster 4456
#   55 WEST 92 STREET (x 4)
#   55 WEST   92 STREET (x 1)
#
# Cluster 4457
#   EAST 55 STREET (x 4)
#   EAST   55 STREET (x 2)
#
# Cluster 4458
#   55 WEST 55 STREET (x 1)
#   WEST 55 STREET (x 6)
#
# Cluster 4459
#   552 BEACH   72 STREET (x 1)
#   552 BEACH 72 STREET (x 1)
#
# Cluster 4460
#   555 WEST   57 STREET (x 2)
#   555 WEST 57 STREET (x 1)
#
# Cluster 4461
#   555 WEST 59 STREET (x 1)
#   555 WEST   59 STREET (x 1)
#
# Cluster 4462
#   555 EAST 78 STREET (x 1)
#   555 EAST   78 STREET (x 1)
#
# Cluster 4463
#   555 EAST 86 STREET (x 1)
#   555 EAST   86 STREET (x 1)
#
# Cluster 4464
#   556 EAST   94 STREET (x 1)
#   556 EAST 94 STREET (x 1)
#
# Cluster 4465
#   56 WEST   76 STREET (x 1)
#   56 WEST 76 STREET (x 1)
#
# Cluster 4466
#   901 EAST   56 STREET (x 1)
#   901 EAST 56 STREET (x 3)
#
# Cluster 4467
#   562 BEACH   65 STREET (x 1)
#   562 BEACH 65 STREET (x 1)
#
# Cluster 4468
#   57 WEST 58 STREET (x 2)
#   58 WEST 57 STREET (x 1)
#
# Cluster 4469
#   601 WEST   57 STREET (x 6)
#   601 WEST 57 STREET (x 1)
#
# Cluster 4470
#   625 WEST   57 STREET (x 2)
#   625 WEST 57 STREET (x 1)
#
# Cluster 4471
#   57 WEST 93 STREET (x 1)
#   57 WEST   93 STREET (x 1)
#
# Cluster 4472
#   58 WEST 91 STREET (x 2)
#   58 WEST   91 STREET (x 1)
#
# Cluster 4473
#   EAST   58 STREET (x 5)
#   EAST 58 STREET (x 4)
#
# Cluster 4474
#   581 EAST   80 STREET (x 1)
#   581 EAST 80 STREET (x 1)
#
# Cluster 4475
#   EAST 59 STREET (x 2)
#   EAST   59 STREET (x 5)
#
# Cluster 4476
#   WEST   59 STREET (x 2)
#   WEST 59 STREET (x 1)
#
# Cluster 4477
#   592 EAST 91 STREET (x 1)
#   592 EAST   91 STREET (x 1)
#
# Cluster 4478
#   593 EAST 93 STREET (x 2)
#   593 EAST   93 STREET (x 1)
#
# Cluster 4479
#   595 EAST 87 STREET (x 1)
#   595 EAST   87 STREET (x 1)
#
# Cluster 4480
#   599 EAST    7 STREET (x 1)
#   599 EAST 7 STREET (x 1)
#
# Cluster 4481
#   615 EAST    6 STREET (x 1)
#   615 EAST 6 STREET (x 1)
#
# Cluster 4482
#   620 EAST    6 STREET (x 5)
#   620 EAST 6 STREET (x 1)
#
# Cluster 4483
#   630 EAST    6 STREET (x 1)
#   630 EAST 6 STREET (x 1)
#
# Cluster 4484
#   81 SOUTH 6 STREET (x 6)
#   81 SOUTH    6 STREET (x 1)
#
# Cluster 4485
#   890 EAST    6 STREET (x 4)
#   890 EAST 6 STREET (x 2)
#
# Cluster 4486
#   903 EAST 6 STREET (x 5)
#   903 EAST    6 STREET (x 5)
#
# Cluster 4487
#   920 EAST 6 STREET (x 5)
#   920 EAST    6 STREET (x 1)
#
# Cluster 4488
#   EAST    6 STREET (x 1)
#   EAST 6 STREET (x 1)
#
# Cluster 4489
#   NORTH    6 STREET (x 1)
#   NORTH 6 STREET (x 1)
#
# Cluster 4490
#   60 EAST    8 STREET (x 1)
#   60 EAST 8 STREET (x 2)
#
# Cluster 4491
#   60 EAST 9 STREET (x 1)
#   60 EAST    9 STREET (x 1)
#
# Cluster 4492
#   60 EAST   93 STREET (x 2)
#   60 EAST 93 STREET (x 3)
#
# Cluster 4493
#   60 BEACH STREET (x 1)
#   BEACH 60 STREET (x 1)
#
# Cluster 4494
#   6018 BLEECKER STREET (x 13)
#   60-18 BLEECKER STREET (x 4)
#
# Cluster 4495
#   604 EAST    9 STREET (x 1)
#   604 EAST 9 STREET (x 1)
#
# Cluster 4496
#   WEST   61 STREET (x 1)
#   WEST 61 STREET (x 2)
#
# Cluster 4497
#   618 ST JOHNS PLACE (x 2)
#   618 ST JOHN'S PLACE (x 2)
#
# Cluster 4498
#   62 EAST    7 STREET (x 3)
#   62 EAST 7 STREET (x 2)
#
# Cluster 4499
#   62 WEST   71 STREET (x 3)
#   62 WEST 71 STREET (x 1)
#
# Cluster 4500
#   EAST 62 STREET (x 3)
#   EAST   62 STREET (x 2)
#
# Cluster 4501
#   WEST   62 STREET (x 1)
#   62 WEST 62 STREET (x 1)
#
# Cluster 4502
#   627 EAST   96 STREET (x 2)
#   627 EAST 96 STREET (x 1)
#
# Cluster 4503
#   63 WEST 8 STREET (x 1)
#   63 WEST    8 STREET (x 1)
#
# Cluster 4504
#   EAST 63 STREET (x 3)
#   EAST   63 STREET (x 2)
#
# Cluster 4505
#   631 BEACH 9 STREET (x 4)
#   631 BEACH    9 STREET (x 3)
#
# Cluster 4506
#   EAST   64 STREET (x 2)
#   EAST 64 STREET (x 4)
#
# Cluster 4507
#   642 EAST 96 STREET (x 1)
#   642 EAST   96 STREET (x 3)
#
# Cluster 4508
#   644 EAST   89 STREET (x 2)
#   644 EAST 89 STREET (x 1)
#
# Cluster 4509
#   646 EAST   96 STREET (x 5)
#   646 EAST 96 STREET (x 2)
#
# Cluster 4510
#   65 EAST 96 STREET (x 3)
#   65 EAST   96 STREET (x 1)
#
# Cluster 4511
#   EAST   65 STREET (x 1)
#   EAST 65 STREET (x 1)
#
# Cluster 4512
#   650 EAST 87 STREET (x 1)
#   650 EAST   87 STREET (x 3)
#
# Cluster 4513
#   652 ST JOHNS PLACE (x 1)
#   652 ST JOHN'S PLACE (x 1)
#
# Cluster 4514
#   658 BEACH 69 STREET (x 3)
#   658 BEACH   69 STREET (x 1)
#
# Cluster 4515
#   66 EAST 96 STREET (x 2)
#   66 EAST   96 STREET (x 1)
#
# Cluster 4516
#   66 ST PAUL'S PLACE (x 1)
#   66 ST PAULS PLACE (x 1)
#
# Cluster 4517
#   660 EAST   96 STREET (x 1)
#   660 EAST 96 STREET (x 1)
#
# Cluster 4518
#   660 EAST   98 STREET (x 3)
#   660 EAST 98 STREET (x 1)
#
# Cluster 4519
#   67 WEST 69 STREET (x 1)
#   67 WEST   69 STREET (x 1)
#
# Cluster 4520
#   EAST   67 STREET (x 3)
#   EAST 67 STREET (x 2)
#
# Cluster 4521
#   71 WEST   68 STREET (x 2)
#   71 WEST 68 STREET (x 1)
#
# Cluster 4522
#   77 WEST 68 STREET (x 4)
#   77 WEST   68 STREET (x 1)
#
# Cluster 4523
#   68 ST PAULS PLACE (x 8)
#   68 ST PAUL'S PLACE (x 1)
#
# Cluster 4524
#   WEST 68 STREET (x 2)
#   68 WEST 68 STREET (x 1)
#
# Cluster 4525
#   72 WEST   69 STREET (x 1)
#   72 WEST 69 STREET (x 1)
#
# Cluster 4526
#   69 EAST 8 STREET (x 1)
#   69 EAST    8 STREET (x 1)
#
# Cluster 4527
#   69 WEST 9 STREET (x 1)
#   9 WEST 69 STREET (x 2)
#
# Cluster 4528
#   EAST   69 STREET (x 3)
#   EAST 69 STREET (x 2)
#
# Cluster 4529
#   WEST   69 STREET (x 1)
#   WEST 69 STREET (x 3)
#
# Cluster 4530
#   77 EAST    7 STREET (x 1)
#   77 EAST 7 STREET (x 1)
#
# Cluster 4531
#   7 WEST   82 STREET (x 1)
#   7 WEST 82 STREET (x 1)
#
# Cluster 4532
#   93 EAST    7 STREET (x 3)
#   93 EAST 7 STREET (x 1)
#
# Cluster 4533
#   930 EAST 7 STREET (x 2)
#   930 EAST    7 STREET (x 1)
#
# Cluster 4534
#   99 EAST 7 STREET (x 4)
#   99 EAST    7 STREET (x 1)
#
# Cluster 4535
#   NORTH 7 STREET (x 1)
#   NORTH    7 STREET (x 1)
#
# Cluster 4536
#   70 WEST 93 STREET (x 3)
#   70 WEST   93 STREET (x 3)
#
# Cluster 4537
#   70 WEST   95 STREET (x 4)
#   70 WEST 95 STREET (x 3)
#
# Cluster 4538
#   700 EAST    9 STREET (x 1)
#   700 EAST 9 STREET (x 3)
#
# Cluster 4539
#   707 BEACH    9 STREET (x 6)
#   707 BEACH 9 STREET (x 4)
#
# Cluster 4540
#   EAST   71 STREET (x 1)
#   EAST 71 STREET (x 2)
#
# Cluster 4541
#   71 STREET (x 6)
#   71 71 STREET (x 1)
#
# Cluster 4542
#   710 EAST 94 STREET (x 2)
#   710 EAST   94 STREET (x 1)
#
# Cluster 4543
#   711 SEAGIRT AVENUE (x 22)
#   7-11 SEAGIRT AVENUE (x 1)
#
# Cluster 4544
#   711A SEAGIRT AVENUE (x 5)
#   7-11A SEAGIRT AVENUE (x 1)
#
# Cluster 4545
#   716 EAST 96 STREET (x 1)
#   716 EAST   96 STREET (x 1)
#
# Cluster 4546
#   717 EAST   88 STREET (x 1)
#   717 EAST 88 STREET (x 1)
#
# Cluster 4547
#   719 EAST 85 STREET (x 1)
#   719 EAST   85 STREET (x 1)
#
# Cluster 4548
#   EAST   72 STREET (x 3)
#   EAST 72 STREET (x 4)
#
# Cluster 4549
#   72 STREET (x 4)
#   72 72 STREET (x 1)
#
# Cluster 4550
#   EAST 73 STREET (x 5)
#   EAST   73 STREET (x 1)
#
# Cluster 4551
#   WEST   73 STREET (x 1)
#   WEST 73 STREET (x 6)
#
# Cluster 4552
#   735 EAST    9 STREET (x 1)
#   735 EAST 9 STREET (x 1)
#
# Cluster 4553
#   74 WEST 92 STREET (x 6)
#   74 WEST   92 STREET (x 1)
#
# Cluster 4554
#   740 EAST   98 STREET (x 1)
#   740 EAST 98 STREET (x 1)
#
# Cluster 4555
#   75 EAST 94 STREET (x 1)
#   75 EAST   94 STREET (x 2)
#
# Cluster 4556
#   WEST   75 STREET (x 1)
#   WEST 75 STREET (x 2)
#
# Cluster 4557
#   751 ST MARKS AVENUE (x 16)
#   751 ST MARK'S AVENUE (x 1)
#
# Cluster 4558
#   755 EAST    9 STREET (x 2)
#   755 EAST 9 STREET (x 2)
#
# Cluster 4559
#   756 EAST   81 STREET (x 1)
#   756 EAST 81 STREET (x 1)
#
# Cluster 4560
#   76 BAY 8 STREET (x 1)
#   76 BAY    8 STREET (x 1)
#
# Cluster 4561
#   EAST 76 STREET (x 1)
#   EAST   76 STREET (x 2)
#
# Cluster 4562
#   EAST 77 STREET (x 1)
#   EAST   77 STREET (x 1)
#
# Cluster 4563
#   78 AVENUE (x 12)
#   78 78 AVENUE (x 1)
#
# Cluster 4564
#   780 ST ANNS AVENUE (x 3)
#   780 ST ANN'S AVENUE (x 2)
#
# Cluster 4565
#   EAST   79 STREET (x 2)
#   EAST 79 STREET (x 6)
#
# Cluster 4566
#   791 SAINT JOHNS PLACE (x 1)
#   791 SAINT JOHN'S PLACE (x 1)
#
# Cluster 4567
#   791 ST JOHNS PLACE (x 1)
#   791 ST JOHN'S PLACE (x 1)
#
# Cluster 4568
#   810 EAST    8 STREET (x 2)
#   810 EAST 8 STREET (x 1)
#
# Cluster 4569
#   840 EAST 8 STREET (x 1)
#   840 EAST    8 STREET (x 1)
#
# Cluster 4570
#   939 EAST    8 STREET (x 1)
#   939 EAST 8 STREET (x 1)
#
# Cluster 4571
#   EAST    8 STREET (x 2)
#   EAST 8 STREET (x 7)
#
# Cluster 4572
#   WEST    8 STREET (x 2)
#   WEST 8 STREET (x 1)
#
# Cluster 4573
#   EAST 80 STREET (x 6)
#   EAST   80 STREET (x 1)
#
# Cluster 4574
#   800 ST ANNS AVENUE (x 2)
#   800 ST ANN'S AVENUE (x 2)
#
# Cluster 4575
#   80-40 LEFFERTS BOULEVARD (x 2)
#   8040 LEFFERTS BOULEVARD (x 1)
#
# Cluster 4576
#   805 SAINT MARKS AVENUE (x 1)
#   805 SAINT MARK'S AVENUE (x 1)
#
# Cluster 4577
#   974 EAST 81 STREET (x 1)
#   974 EAST   81 STREET (x 2)
#
# Cluster 4578
#   EAST   81 STREET (x 1)
#   EAST 81 STREET (x 4)
#
# Cluster 4579
#   WEST   81 STREET (x 3)
#   81 WEST STREET (x 1)
#
# Cluster 4580
#   EAST 82 STREET (x 4)
#   EAST   82 STREET (x 1)
#
# Cluster 4581
#   820 ST ANN'S AVENUE (x 1)
#   820 ST ANNS AVENUE (x 7)
#
# Cluster 4582
#   823 ST JOHNS PLACE (x 3)
#   823 ST JOHN'S PLACE (x 1)
#
# Cluster 4583
#   825 EAST    9 STREET (x 2)
#   825 EAST 9 STREET (x 1)
#
# Cluster 4584
#   EAST 83 STREET (x 6)
#   EAST   83 STREET (x 3)
#
# Cluster 4585
#   WEST 83 STREET (x 2)
#   WEST   83 STREET (x 2)
#
# Cluster 4586
#   EAST 84 STREET (x 4)
#   EAST   84 STREET (x 1)
#
# Cluster 4587
#   84 ST MARK'S PLACE (x 1)
#   84 ST MARKS PLACE (x 1)
#
# Cluster 4588
#   840 ST ANNS AVENUE (x 2)
#   840 ST ANN'S AVENUE (x 1)
#
# Cluster 4589
#   8400 SHOREFRONT PARKWAY (x 1)
#   84-00 SHOREFRONT PARKWAY (x 1)
#
# Cluster 4590
#   EAST 85 STREET (x 5)
#   EAST   85 STREET (x 2)
#
# Cluster 4591
#   850 ST MARK'S AVENUE (x 1)
#   850 ST MARKS AVENUE (x 1)
#
# Cluster 4592
#   8-55 WYCKOFF AVENUE (x 1)
#   855 WYCKOFF AVENUE (x 1)
#
# Cluster 4593
#   86 EAST 94 STREET (x 2)
#   86 EAST   94 STREET (x 2)
#
# Cluster 4594
#   946 EAST 86 STREET (x 2)
#   946 EAST   86 STREET (x 1)
#
# Cluster 4595
#   EAST 86 STREET (x 11)
#   EAST   86 STREET (x 3)
#
# Cluster 4596
#   86 STREET (x 22)
#   86 86 STREET (x 1)
#
# Cluster 4597
#   WEST   86 STREET (x 2)
#   WEST 86 STREET (x 3)
#
# Cluster 4598
#   956 EAST   87 STREET (x 1)
#   956 EAST 87 STREET (x 1)
#
# Cluster 4599
#   EAST   87 STREET (x 3)
#   EAST 87 STREET (x 8)
#
# Cluster 4600
#   EAST 88 STREET (x 4)
#   EAST   88 STREET (x 1)
#
# Cluster 4601
#   WEST   88 STREET (x 1)
#   WEST 88 STREET (x 3)
#
# Cluster 4602
#   887 ST JOHNS PLACE (x 3)
#   887 ST JOHN'S PLACE (x 1)
#
# Cluster 4603
#   888 EAST   96 STREET (x 3)
#   888 EAST 96 STREET (x 1)
#
# Cluster 4604
#   EAST   89 STREET (x 5)
#   EAST 89 STREET (x 6)
#
# Cluster 4605
#   96 SOUTH 9 STREET (x 2)
#   96 SOUTH    9 STREET (x 1)
#
# Cluster 4606
#   BEACH 9 STREET (x 1)
#   BEACH    9 STREET (x 1)
#
# Cluster 4607
#   90 AVENUE (x 8)
#   90 90 AVENUE (x 1)
#
# Cluster 4608
#   EAST   90 STREET (x 2)
#   EAST 90 STREET (x 5)
#
# Cluster 4609
#   900 CO-OP CITY BOULEVARD (x 3)
#   900 COOP CITY BOULEVARD (x 1)
#
# Cluster 4610
#   EAST 91 STREET (x 5)
#   EAST   91 STREET (x 3)
#
# Cluster 4611
#   914 EAST   96 STREET (x 1)
#   914 EAST 96 STREET (x 1)
#
# Cluster 4612
#   936 EAST   92 STREET (x 1)
#   936 EAST 92 STREET (x 1)
#
# Cluster 4613
#   EAST 92 STREET (x 7)
#   EAST   92 STREET (x 2)
#
# Cluster 4614
#   WEST 92 STREET (x 2)
#   WEST   92 STREET (x 1)
#
# Cluster 4615
#   EAST 93 STREET (x 7)
#   EAST   93 STREET (x 3)
#
# Cluster 4616
#   WEST   93 STREET (x 1)
#   WEST 93 STREET (x 1)
#
# Cluster 4617
#   9305 L AVENUE (x 1)
#   9305 AVENUE L (x 1)
#
# Cluster 4618
#   945 EAST 94 STREET (x 2)
#   945 EAST   94 STREET (x 1)
#
# Cluster 4619
#   EAST   94 STREET (x 2)
#   EAST 94 STREET (x 2)
#
# Cluster 4620
#   WEST   94 STREET (x 1)
#   WEST 94 STREET (x 1)
#
# Cluster 4621
#   EAST   95 STREET (x 1)
#   EAST 95 STREET (x 4)
#
# Cluster 4622
#   EAST 96 STREET (x 7)
#   EAST   96 STREET (x 4)
#
# Cluster 4623
#   WEST 96 STREET (x 6)
#   WEST   96 STREET (x 1)
#
# Cluster 4624
#   EAST   97 STREET (x 3)
#   EAST 97 STREET (x 2)
#
# Cluster 4625
#   WEST   97 STREET (x 2)
#   WEST 97 STREET (x 1)
#
# Cluster 4626
#   EAST   98 STREET (x 1)
#   EAST 98 STREET (x 4)
#
# Cluster 4627
#   99-10 ASTORIA BOULEVARD (x 1)
#   9910 ASTORIA BOULEVARD (x 1)
#
# Cluster 4628
#   ST MARKS AVENUE (x 6)
#   ST MARK'S AVENUE (x 1)
#
# Cluster 4629
#   AVENUE U (x 7)
#   U AVENUE (x 1)
#
# Cluster 4630
#   FLUSHING MEADOWS CORONA PARK FLUSHING MEADOWS CORONA PARK (x 1)
#   FLUSHING MEADOWS CORONA PARK (x 5)
#
# Cluster 4631
#   ST MARK'S PLACE (x 1)
#   ST MARKS PLACE (x 2)
#
# Cluster 4632
#   N/A N/A (x 4)
#   NA NA (x 1)

# %%
# Cluster Number as key and the values in each cluster and their counts as the value
# It is a dictionary of dictionary which will be used for further processing
incident_address_dict
# Out:
# {0: {'140 WEST  140 STREET': 2,
#   '140 WEST 140 STREET': 1,
#   '140 WEST STREET': 4,
#   'WEST  140 STREET': 1,
#   'WEST 140 STREET': 2},
#  1: {'144 WEST  144 STREET': 2,
#   '144 WEST 144 STREET': 3,
#   '144 WEST STREET': 1,
#   'WEST  144 STREET': 1,
#   'WEST 144 STREET': 2},
#  2: {'100 EAST  111 STREET': 1,
#   '100 EAST 111 STREET': 1,
#   '111 EAST  100 STREET': 12,
#   '111 EAST 100 STREET': 4},
#  3: {'101 EAST  179 STREET': 1,
#   '101 EAST 179 STREET': 2,
#   '179 EAST  101 STREET': 1,
#   '179 EAST 101 STREET': 1},
#  4: {'105 EAST  168 STREET': 2,
#   '105 EAST 168 STREET': 2,
#   '168 EAST  105 STREET': 1,
#   '168 EAST 105 STREET': 1},
#  5: {'106 WEST  113 STREET': 1,
#   '106 WEST 113 STREET': 3,
#   '113 WEST  106 STREET': 1,
#   '113 WEST 106 STREET': 1},
#  6: {'11 EAST   68 STREET': 1,
#   '11 EAST 68 STREET': 1,
#   '68 EAST   11 STREET': 1,
#   '68 EAST 11 STREET': 1},
#  7: {'111 EAST  167 STREET': 4,
#   '111 EAST 167 STREET': 2,
#   '167 EAST  111 STREET': 1,
#   '167 EAST 111 STREET': 2},
#  8: {'111 EAST   88 STREET': 1,
#   '111 EAST 88 STREET': 2,
#   '88 EAST  111 STREET': 1,
#   '88 EAST 111 STREET': 3},
#  9: {'125 WEST   55 STREET': 2,
#   '125 WEST 55 STREET': 2,
#   '55 WEST  125 STREET': 1,
#   '55 WEST 125 STREET': 1},
#  '103 WEST 141 STREET': 373,
#  '103 WEST  141 STREET': 373,
#  '160 EAST  103 STREET': 374,
#  '160 EAST 103 STREET': 374,
#  '103 WEST 183 STREET': 375,
#  '103 WEST  183 STREET': 375,
#  '203 WEST 103 STREET': 376,
#  '203 WEST  103 STREET': 376,
#  '230 WEST 103 STREET': 377,
#  '230 WEST  103 STREET': 377,
#  '3 WEST  103 STREET': 378,
#  '3 WEST 103 STREET': 378,
#  '315 EAST 103 STREET': 379,
#  '315 EAST  103 STREET': 379,
#  '315 WEST  103 STREET': 380,
#  '315 WEST 103 STREET': 380,
#  '5 WEST 103 STREET': 381,
#  '5 WEST  103 STREET': 381,
#  '7 WEST 103 STREET': 382,
#  '7 WEST  103 STREET': 382,
#  '103 WEST   77 STREET': 383,
#  '103 WEST 77 STREET': 383,
#  '103 AVENUE A': 384,
#  '103 A AVENUE': 384,
#  '1030 EAST  233 STREET': 385,
#  '1030 EAST 233 STREET': 385,
#  '1035 EAST  225 STREET': 386,
#  '1035 EAST 225 STREET': 386,
#  '1036 EAST  105 STREET': 387,
#  '1036 EAST 105 STREET': 387,
#  '105 WEST 104 STREET': 388,
#  '105 WEST  104 STREET': 388,
#  '114 EAST 104 STREET': 389,
#  '114 EAST  104 STREET': 389,
#  '133 WEST  104 STREET': 390,
#  '133 WEST 104 STREET': 390,
#  '140 WEST 104 STREET': 391,
#  '140 WEST  104 STREET': 391,
#  '1425 EAST  104 STREET': 392,
#  '1425 EAST 104 STREET': 392,
#  '104 EAST 196 STREET': 393,
#  '104 EAST  196 STREET': 393,
#  '218 WEST  104 STREET': 394,
#  '218 WEST 104 STREET': 394,
#  '29 EAST  104 STREET': 395,
#  '29 EAST 104 STREET': 395,
#  '306 WEST  104 STREET': 396,
#  '306 WEST 104 STREET': 396,
#  '307 EAST 104 STREET': 397,
#  '307 EAST  104 STREET': 397,
#  '316 EAST 104 STREET': 398,
#  '316 EAST  104 STREET': 398,
#  '60 EAST 104 STREET': 399,
#  '60 EAST  104 STREET': 399,
#  '60 WEST 104 STREET': 400,
#  '60 WEST  104 STREET': 400,
#  '615 EAST  104 STREET': 401,
#  '615 EAST 104 STREET': 401,
#  '77 WEST  104 STREET': 402,
#  '77 WEST 104 STREET': 402,
#  '104 WEST   83 STREET': 403,
#  '104 WEST 83 STREET': 403,
#  '1040 EAST   94 STREET': 404,
#  ...}

# %%
final_addr = {}
for key,value in incident_address_dict.items():
    final_addr[key] = max(value, key=value.get)

print(final_addr)
# Out:
# {0: '140 WEST STREET', 1: '144 WEST 144 STREET', 2: '111 EAST  100 STREET', 3: '101 EAST 179 STREET', 4: '105 EAST  168 STREET', 5: '106 WEST 113 STREET', 6: '68 EAST   11 STREET', 7: '111 EAST  167 STREET', 8: '88 EAST 111 STREET', 9: '125 WEST   55 STREET', 10: '13 WEST 13 STREET', 11: '140 WEST  133 STREET', 12: '136 WEST 170 STREET', 13: 'WEST 30 STREET', 14: 'EAST 35 STREET', 15: 'EAST 36 STREET', 16: 'WEST 40 STREET', 17: '
WEST 186 STREET', 115: '570 WEST  189 STREET', 116: '22 WEST   19 STREET', 117: '19 WEST 55 STREET', 118: '500 WEST 190 STREET', 119: '194 EAST 2 STREET', 120: '60 EAST 196 STREET', 121: '32 EAST    2 STREET', 122: '2 EAST   75 STREET', 123: 'EAST 2 STREET', 124: '39 EAST 20 STREET', 125: '551 WEST 204 STREET', 126: '37 WEST 21 STREET', 127: '21 EAST 21 STREET', 128: 'WEST 22 STREET', 129: 'WEST 231 STREET', 130: '474 WEST  238 STREET', 131: 'BAY 25 STREET', 132: 'WEST   29 STREET', 133: 'EAST 3 STREET', 134: '300 WEST   30 STREET', 135: 'EAST 30 STREET', 136: '31 EAST 32 STREET', 137: '31 EAST   31 STREET', 138: '319 BEACH   98 STREET', 139: 'WEST 32 STREET', 140: '320 WEST 37 STREET', 141: 'EAST 33 STREET', 142: 'WEST   35 STREET', 143: 'WEST 38 STREET', 144: '60 EAST    4 STREET', 145: 'WEST 4 STREET', 146: '400 WEST WEST 63 STREET', 147: '42 EAST    5 STREET', 148: 'EAST 45 STREET', 149: 'WEST   45 STREET', 150: 'WEST   50 STREET', 151: 'WEST 53 STREET', 152: '56 WEST   65 STREET', 153 ...

# %%
for index, row in df.iterrows():
    if row['Incident Address'] in cluster_dict:
        df.at[index, 'Incident Address'] = final_addr[cluster_dict[row['Incident Address']]]

# %% [markdown]
# #### Updating the StreetName using clustering

# %%
street_names = ds.update('Street Name', str.upper).distinct('Street Name')
clusters = KeyCollision(func=Fingerprint(), threads=3).clusters(street_names)

# %%
street_name_dict = {}
cluster_dict = {}
def print_k_clusters_and_integrate_sn(clusters):
    clusters = sorted(clusters, key=lambda x: len(x), reverse=True)
    val_count = sum([len(c) for c in clusters])
    print('Total number of clusters is {} with {} values'.format(len(clusters), val_count))
    for i in range(len(clusters)):
        print('\nCluster {}'.format(i + 1))
        temp_dict = {}
        for key, cnt in clusters[i].items():
          if key == '':
            key = "''"
          print(f'  {key} (x {cnt})')

          temp_dict[key] = int(cnt)
          cluster_dict[key] = i
        street_name_dict[i] = temp_dict

print_k_clusters_and_integrate_sn(clusters)

final_street = {}
for key,value in street_name_dict.items():
    final_street[key] = max(value, key=value.get)
# Out:
# Total number of clusters is 728 with 1458 values
#
# Cluster 1
#   ST JOHNS AVENUE (x 13)
#   AVENUE ST JOHNS (x 2)
#   ST JOHN'S AVENUE (x 1)
#
# Cluster 2
#   PO BOX (x 2)
#   P.O BOX (x 1)
#   P.O. BOX (x 1)
#
# Cluster 3
#   BRIGHTON 1 PLACE (x 3)
#   BRIGHTON    1 PLACE (x 2)
#
# Cluster 4
#   BRIGHTON 1 ROAD (x 8)
#   BRIGHTON    1 ROAD (x 10)
#
# Cluster 5
#   BRIGHTON    1 STREET (x 9)
#   BRIGHTON 1 STREET (x 8)
#
# Cluster 6
#   BRIGHTON    1 WALK (x 1)
#   BRIGHTON 1 WALK (x 1)
#
# Cluster 7
#   EAST 1 STREET (x 61)
#   EAST    1 STREET (x 37)
#
# Cluster 8
#   FLATLANDS 1 STREET (x 3)
#   FLATLANDS    1 STREET (x 3)
#
# Cluster 9
#   NORTH 1 STREET (x 11)
#   NORTH    1 STREET (x 10)
#
# Cluster 10
#   PAERDEGAT    1 STREET (x 4)
#   PAERDEGAT 1 STREET (x 1)
#
# Cluster 11
#   PLUMB 1 STREET (x 6)
#   PLUMB    1 STREET (x 1)
#
# Cluster 12
#   SOUTH    1 STREET (x 32)
#   SOUTH 1 STREET (x 38)
#
# Cluster 13
#   WEST    1 STREET (x 32)
#   WEST 1 STREET (x 39)
#
# Cluster 14
#   BAY   10 STREET (x 8)
#   BAY 10 STREET (x 12)
#
# Cluster 15
#   BRIGHTON 10 PATH (x 1)
#   BRIGHTON   10 PATH (x 1)
#
# Cluster 16
#   BRIGHTON 10 STREET (x 5)
#   BRIGHTON   10 STREET (x 3)
#
# Cluster 17
#   EAST   10 STREET (x 117)
#   EAST 10 STREET (x 158)
#
# Cluster 18
#   FLATLANDS   10 STREET (x 1)
#   FLATLANDS 10 STREET (x 1)
#
# Cluster 19
#   NORTH   10 STREET (x 9)
#   NORTH 10 STREET (x 16)
#
# Cluster 20
#   PAERDEGAT 10 STREET (x 5)
#   PAERDEGAT   10 STREET (x 2)
#
# Cluster 21
#   SOUTH   10 STREET (x 2)
#   SOUTH 10 STREET (x 6)
#
# Cluster 22
#   WEST 10 STREET (x 95)
#   WEST   10 STREET (x 60)
#
# Cluster 23
#   BEACH  100 STREET (x 13)
#   BEACH 100 STREET (x 8)
#
# Cluster 24
#   EAST  100 STREET (x 41)
#   EAST 100 STREET (x 36)
#
# Cluster 25
#   WEST  100 STREET (x 17)
#   WEST 100 STREET (x 16)
#
# Cluster 26
#   BEACH  101 STREET (x 8)
#   BEACH 101 STREET (x 4)
#
# Cluster 27
#   EAST 101 STREET (x 39)
#   EAST  101 STREET (x 26)
#
# Cluster 28
#   WEST 101 STREET (x 16)
#   WEST  101 STREET (x 8)
#
# Cluster 29
#   BEACH 102 STREET (x 7)
#   BEACH  102 STREET (x 5)
#
# Cluster 30
#   EAST 102 STREET (x 98)
#   EAST  102 STREET (x 44)
#
# Cluster 31
#   WEST 102 STREET (x 16)
#   WEST  102 STREET (x 22)
#
# Cluster 32
#   EAST  103 STREET (x 32)
#   EAST 103 STREET (x 53)
#
# Cluster 33
#   WEST 103 STREET (x 23)
#   WEST  103 STREET (x 21)
#
# Cluster 34
#   EAST  104 STREET (x 56)
#   EAST 104 STREET (x 65)
#
# Cluster 35
#   WEST 104 STREET (x 32)
#   WEST  104 STREET (x 41)
#
# Cluster 36
#   BEACH 105 STREET (x 6)
#   BEACH  105 STREET (x 6)
#
# Cluster 37
#   EAST  105 STREET (x 55)
#   EAST 105 STREET (x 73)
#
# Cluster 38
#   WEST  105 STREET (x 28)
#   WEST 105 STREET (x 21)
#
# Cluster 39
#   EAST  106 STREET (x 37)
#   EAST 106 STREET (x 52)
#
# Cluster 40
#   WEST  106 STREET (x 28)
#   WEST 106 STREET (x 22)
#
# Cluster 41
#   EAST 107 STREET (x 19)
#   EAST  107 STREET (x 23)
#
# Cluster 42
#   WEST  107 STREET (x 65)
#   WEST 107 STREET (x 45)
#
# Cluster 43
#   BEACH  108 STREET (x 1)
#   BEACH 108 STREET (x 2)
#
# Cluster 44
#   EAST 108 STREET (x 58)
#   EAST  108 STREET (x 34)
#
# Cluster 45
#   WEST 108 STREET (x 45)
#   WEST  108 STREET (x 38)
#
# Cluster 46
#   EAST 109 STREET (x 41)
#   EAST  109 STREET (x 28)
#
# Cluster 47
#   WEST  109 STREET (x 46)
#   WEST 109 STREET (x 77)
#
# Cluster 48
#   BAY 11 STREET (x 21)
#   BAY   11 STREET (x 8)
#
# Cluster 49
#   BEACH   11 STREET (x 1)
#   BEACH 11 STREET (x 2)
#
# Cluster 50
#   BRIGHTON 11 STREET (x 14)
#   BRIGHTON   11 STREET (x 4)
#
# Cluster 51
#   EAST   11 STREET (x 76)
#   EAST 11 STREET (x 126)
#
# Cluster 52
#   NORTH 11 STREET (x 15)
#   NORTH   11 STREET (x 3)
#
# Cluster 53
#   PAERDEGAT   11 STREET (x 3)
#   PAERDEGAT 11 STREET (x 1)
#
# Cluster 54
#   SOUTH   11 STREET (x 26)
#   SOUTH 11 STREET (x 1)
#
# Cluster 55
#   WEST 11 STREET (x 67)
#   WEST   11 STREET (x 46)
#
# Cluster 56
#   BEACH 110 STREET (x 1)
#   BEACH  110 STREET (x 3)
#
# Cluster 57
#   EAST 110 STREET (x 36)
#   EAST  110 STREET (x 33)
#
# Cluster 58
#   WEST  110 STREET (x 22)
#   WEST 110 STREET (x 34)
#
# Cluster 59
#   EAST  111 STREET (x 42)
#   EAST 111 STREET (x 56)
#
# Cluster 60
#   WEST  111 STREET (x 60)
#   WEST 111 STREET (x 68)
#
# Cluster 61
#   BEACH  112 STREET (x 1)
#   BEACH 112 STREET (x 1)
#
# Cluster 62
#   EAST  112 STREET (x 24)
#   EAST 112 STREET (x 31)
#
# Cluster 63
#   WEST 112 STREET (x 65)
#   WEST  112 STREET (x 28)
#
# Cluster 64
#   BEACH  113 STREET (x 2)
#   BEACH 113 STREET (x 3)
#
# Cluster 65
#   EAST  113 STREET (x 3)
#   EAST 113 STREET (x 1)
#
# Cluster 66
#   WEST  113 STREET (x 22)
#   WEST 113 STREET (x 37)
#
# Cluster 67
#   BEACH 114 STREET (x 7)
#   BEACH  114 STREET (x 5)
#
# Cluster 68
#   EAST  114 STREET (x 20)
#   EAST 114 STREET (x 8)
#
# Cluster 69
#   WEST 114 STREET (x 53)
#   WEST  114 STREET (x 28)
#
# Cluster 70
#   BEACH 115 STREET (x 22)
#   BEACH  115 STREET (x 10)
#
# Cluster 71
#   EAST  115 STREET (x 56)
#   EAST 115 STREET (x 79)
#
# Cluster 72
#   WEST  115 STREET (x 23)
#   WEST 115 STREET (x 37)
#
# Cluster 73
#   B  116 STREET (x 1)
#   B 116 STREET (x 1)
#
# Cluster 74
#   BEACH 116 STREET (x 18)
#   BEACH  116 STREET (x 9)
#
# Cluster 75
#   EAST 116 STREET (x 82)
#   EAST  116 STREET (x 73)
#
# Cluster 76
#   WEST 116 STREET (x 88)
#   WEST  116 STREET (x 62)
#
# Cluster 77
#   BEACH  117 STREET (x 8)
#   BEACH 117 STREET (x 12)
#
# Cluster 78
#   EAST  117 STREET (x 72)
#   EAST 117 STREET (x 56)
#
# Cluster 79
#   WEST 117 STREET (x 36)
#   WEST  117 STREET (x 17)
#
# Cluster 80
#   BEACH  118 STREET (x 5)
#   BEACH 118 STREET (x 7)
#
# Cluster 81
#   EAST  118 STREET (x 40)
#   EAST 118 STREET (x 53)
#
# Cluster 82
#   WEST 118 STREET (x 50)
#   WEST  118 STREET (x 35)
#
# Cluster 83
#   BEACH  119 STREET (x 8)
#   BEACH 119 STREET (x 10)
#
# Cluster 84
#   EAST 119 STREET (x 40)
#   EAST  119 STREET (x 45)
#
# Cluster 85
#   WEST 119 STREET (x 48)
#   WEST  119 STREET (x 37)
#
# Cluster 86
#   BEACH   12 STREET (x 6)
#   BEACH 12 STREET (x 4)
#
# Cluster 87
#   BRIGHTON 12 STREET (x 21)
#   BRIGHTON   12 STREET (x 22)
#
# Cluster 88
#   EAST 12 STREET (x 172)
#   EAST   12 STREET (x 155)
#
# Cluster 89
#   LITTLE WEST 12 STREET (x 5)
#   LITTLE WEST   12 STREET (x 2)
#
# Cluster 90
#   NORTH 12 STREET (x 10)
#   NORTH   12 STREET (x 4)
#
# Cluster 91
#   WEST   12 STREET (x 55)
#   WEST 12 STREET (x 67)
#
# Cluster 92
#   B  120 STREET (x 1)
#   B 120 STREET (x 1)
#
# Cluster 93
#   BEACH 120 STREET (x 2)
#   BEACH  120 STREET (x 6)
#
# Cluster 94
#   EAST 120 STREET (x 14)
#   EAST  120 STREET (x 10)
#
# Cluster 95
#   WEST  120 STREET (x 28)
#   WEST 120 STREET (x 56)
#
# Cluster 96
#   BEACH 121 STREET (x 6)
#   BEACH  121 STREET (x 3)
#
# Cluster 97
#   EAST 121 STREET (x 11)
#   EAST  121 STREET (x 8)
#
# Cluster 98
#   WEST  121 STREET (x 24)
#   WEST 121 STREET (x 30)
#
# Cluster 99
#   BEACH 122 STREET (x 6)
#   BEACH  122 STREET (x 4)
#
# Cluster 100
#   EAST  122 STREET (x 20)
#   EAST 122 STREET (x 14)
#
# Cluster 101
#   WEST 122 STREET (x 32)
#   WEST  122 STREET (x 44)
#
# Cluster 102
#   BEACH 123 STREET (x 3)
#   BEACH  123 STREET (x 4)
#
# Cluster 103
#   EAST 123 STREET (x 13)
#   EAST  123 STREET (x 8)
#
# Cluster 104
#   WEST  123 STREET (x 53)
#   WEST 123 STREET (x 54)
#
# Cluster 105
#   BEACH  124 STREET (x 2)
#   BEACH 124 STREET (x 9)
#
# Cluster 106
#   EAST  124 STREET (x 14)
#   EAST 124 STREET (x 13)
#
# Cluster 107
#   WEST  124 STREET (x 21)
#   WEST 124 STREET (x 21)
#
# Cluster 108
#   BEACH  125 STREET (x 6)
#   BEACH 125 STREET (x 8)
#
# Cluster 109
#   EAST 125 STREET (x 17)
#   EAST  125 STREET (x 25)
#
# Cluster 110
#   WEST  125 STREET (x 42)
#   WEST 125 STREET (x 101)
#
# Cluster 111
#   BEACH  126 STREET (x 3)
#   BEACH 126 STREET (x 2)
#
# Cluster 112
#   EAST 126 STREET (x 40)
#   EAST  126 STREET (x 42)
#
# Cluster 113
#   WEST 126 STREET (x 41)
#   WEST  126 STREET (x 35)
#
# Cluster 114
#   BEACH 127 STREET (x 2)
#   BEACH  127 STREET (x 3)
#
# Cluster 115
#   EAST 127 STREET (x 21)
#   EAST  127 STREET (x 5)
#
# Cluster 116
#   WEST  127 STREET (x 52)
#   WEST 127 STREET (x 62)
#
# Cluster 117
#   BEACH  128 STREET (x 3)
#   BEACH 128 STREET (x 7)
#
# Cluster 118
#   EAST  128 STREET (x 12)
#   EAST 128 STREET (x 12)
#
# Cluster 119
#   WEST 128 STREET (x 50)
#   WEST  128 STREET (x 30)
#
# Cluster 120
#   BEACH 129 STREET (x 11)
#   BEACH  129 STREET (x 10)
#
# Cluster 121
#   EAST  129 STREET (x 16)
#   EAST 129 STREET (x 7)
#
# Cluster 122
#   WEST 129 STREET (x 93)
#   WEST  129 STREET (x 59)
#
# Cluster 123
#   BAY   13 STREET (x 6)
#   BAY 13 STREET (x 13)
#
# Cluster 124
#   BEACH   13 STREET (x 4)
#   BEACH 13 STREET (x 3)
#
# Cluster 125
#   BRIGHTON   13 STREET (x 13)
#   BRIGHTON 13 STREET (x 11)
#
# Cluster 126
#   EAST   13 STREET (x 162)
#   EAST 13 STREET (x 168)
#
# Cluster 127
#   PAERDEGAT 13 STREET (x 1)
#   PAERDEGAT   13 STREET (x 2)
#
# Cluster 128
#   WEST 13 ROAD (x 1)
#   WEST   13 ROAD (x 2)
#
# Cluster 129
#   WEST 13 STREET (x 50)
#   WEST   13 STREET (x 31)
#
# Cluster 130
#   BEACH 130 STREET (x 5)
#   BEACH  130 STREET (x 5)
#
# Cluster 131
#   EAST 130 STREET (x 9)
#   EAST  130 STREET (x 18)
#
# Cluster 132
#   WEST 130 STREET (x 18)
#   WEST  130 STREET (x 29)
#
# Cluster 133
#   BEACH 131 STREET (x 3)
#   BEACH  131 STREET (x 3)
#
# Cluster 134
#   EAST 131 STREET (x 24)
#   EAST  131 STREET (x 12)
#
# Cluster 135
#   WEST  131 STREET (x 35)
#   WEST 131 STREET (x 73)
#
# Cluster 136
#   BEACH  132 STREET (x 4)
#   BEACH 132 STREET (x 5)
#
# Cluster 137
#   EAST  132 STREET (x 30)
#   EAST 132 STREET (x 9)
#
# Cluster 138
#   WEST 132 STREET (x 29)
#   WEST  132 STREET (x 34)
#
# Cluster 139
#   BEACH  133 STREET (x 10)
#   BEACH 133 STREET (x 4)
#
# Cluster 140
#   EAST 133 STREET (x 3)
#   EAST  133 STREET (x 6)
#
# Cluster 141
#   WEST 133 STREET (x 54)
#   WEST  133 STREET (x 56)
#
# Cluster 142
#   BEACH 134 STREET (x 2)
#   BEACH  134 STREET (x 4)
#
# Cluster 143
#   EAST  134 STREET (x 12)
#   EAST 134 STREET (x 12)
#
# Cluster 144
#   WEST  134 STREET (x 53)
#   WEST 134 STREET (x 58)
#
# Cluster 145
#   BEACH  135 STREET (x 3)
#   BEACH 135 STREET (x 4)
#
# Cluster 146
#   EAST 135 STREET (x 17)
#   EAST  135 STREET (x 18)
#
# Cluster 147
#   WEST  135 STREET (x 127)
#   WEST 135 STREET (x 105)
#
# Cluster 148
#   BEACH 136 STREET (x 6)
#   BEACH  136 STREET (x 4)
#
# Cluster 149
#   EAST  136 STREET (x 15)
#   EAST 136 STREET (x 7)
#
# Cluster 150
#   WEST 136 STREET (x 107)
#   WEST  136 STREET (x 67)
#
# Cluster 151
#   EAST 137 STREET (x 55)
#   EAST  137 STREET (x 20)
#
# Cluster 152
#   WEST 137 STREET (x 60)
#   WEST  137 STREET (x 73)
#
# Cluster 153
#   BEACH  138 STREET (x 3)
#   BEACH 138 STREET (x 2)
#
# Cluster 154
#   EAST 138 STREET (x 67)
#   EAST  138 STREET (x 108)
#
# Cluster 155
#   WEST  138 STREET (x 75)
#   WEST 138 STREET (x 72)
#
# Cluster 156
#   BEACH  139 STREET (x 2)
#   BEACH 139 STREET (x 1)
#
# Cluster 157
#   EAST 139 STREET (x 32)
#   EAST  139 STREET (x 48)
#
# Cluster 158
#   WEST 139 STREET (x 104)
#   WEST  139 STREET (x 85)
#
# Cluster 159
#   BAY   14 STREET (x 10)
#   BAY 14 STREET (x 11)
#
# Cluster 160
#   BRIGHTON 14 STREET (x 6)
#   BRIGHTON   14 STREET (x 8)
#
# Cluster 161
#   EAST 14 STREET (x 211)
#   EAST   14 STREET (x 149)
#
# Cluster 162
#   PAERDEGAT 14 STREET (x 5)
#   PAERDEGAT   14 STREET (x 2)
#
# Cluster 163
#   WEST 14 STREET (x 88)
#   WEST   14 STREET (x 48)
#
# Cluster 164
#   BEACH  140 STREET (x 6)
#   BEACH 140 STREET (x 5)
#
# Cluster 165
#   EAST 140 STREET (x 25)
#   EAST  140 STREET (x 24)
#
# Cluster 166
#   WEST 140 STREET (x 66)
#   WEST  140 STREET (x 43)
#
# Cluster 167
#   BEACH  141 STREET (x 5)
#   BEACH 141 STREET (x 3)
#
# Cluster 168
#   EAST 141 STREET (x 47)
#   EAST  141 STREET (x 23)
#
# Cluster 169
#   WEST 141 STREET (x 120)
#   WEST  141 STREET (x 140)
#
# Cluster 170
#   BEACH 142 STREET (x 2)
#   BEACH  142 STREET (x 1)
#
# Cluster 171
#   EAST 142 STREET (x 13)
#   EAST  142 STREET (x 16)
#
# Cluster 172
#   WEST  142 STREET (x 73)
#   WEST 142 STREET (x 79)
#
# Cluster 173
#   BEACH  143 STREET (x 2)
#   BEACH 143 STREET (x 2)
#
# Cluster 174
#   EAST 143 STREET (x 28)
#   EAST  143 STREET (x 9)
#
# Cluster 175
#   WEST 143 STREET (x 85)
#   WEST  143 STREET (x 60)
#
# Cluster 176
#   EAST  144 STREET (x 23)
#   EAST 144 STREET (x 16)
#
# Cluster 177
#   WEST 144 STREET (x 121)
#   WEST  144 STREET (x 81)
#
# Cluster 178
#   BEACH  145 STREET (x 3)
#   BEACH 145 STREET (x 1)
#
# Cluster 179
#   EAST  145 STREET (x 13)
#   EAST 145 STREET (x 19)
#
# Cluster 180
#   WEST  145 STREET (x 96)
#   WEST 145 STREET (x 73)
#
# Cluster 181
#   EAST  146 STREET (x 18)
#   EAST 146 STREET (x 17)
#
# Cluster 182
#   WEST 146 STREET (x 71)
#   WEST  146 STREET (x 45)
#
# Cluster 183
#   BEACH  147 STREET (x 5)
#   BEACH 147 STREET (x 4)
#
# Cluster 184
#   EAST 147 STREET (x 10)
#   EAST  147 STREET (x 10)
#
# Cluster 185
#   WEST  147 STREET (x 91)
#   WEST 147 STREET (x 89)
#
# Cluster 186
#   BEACH 148 STREET (x 3)
#   BEACH  148 STREET (x 3)
#
# Cluster 187
#   EAST  148 STREET (x 27)
#   EAST 148 STREET (x 28)
#
# Cluster 188
#   WEST  148 STREET (x 47)
#   WEST 148 STREET (x 84)
#
# Cluster 189
#   BEACH 149 STREET (x 8)
#   BEACH  149 STREET (x 4)
#
# Cluster 190
#   EAST 149 STREET (x 67)
#   EAST  149 STREET (x 44)
#
# Cluster 191
#   WEST 149 STREET (x 92)
#   WEST  149 STREET (x 56)
#
# Cluster 192
#   BEACH   15 STREET (x 11)
#   BEACH 15 STREET (x 5)
#
# Cluster 193
#   BRIGHTON 15 STREET (x 9)
#   BRIGHTON   15 STREET (x 6)
#
# Cluster 194
#   EAST 15 STREET (x 95)
#   EAST   15 STREET (x 60)
#
# Cluster 195
#   NORTH   15 STREET (x 2)
#   NORTH 15 STREET (x 1)
#
# Cluster 196
#   WEST   15 STREET (x 50)
#   WEST 15 STREET (x 50)
#
# Cluster 197
#   EAST 150 STREET (x 8)
#   EAST  150 STREET (x 6)
#
# Cluster 198
#   WEST 150 STREET (x 55)
#   WEST  150 STREET (x 67)
#
# Cluster 199
#   EAST  151 STREET (x 15)
#   EAST 151 STREET (x 22)
#
# Cluster 200
#   WEST  151 STREET (x 81)
#   WEST 151 STREET (x 77)
#
# Cluster 201
#   EAST  152 STREET (x 23)
#   EAST 152 STREET (x 20)
#
# Cluster 202
#   WEST  152 STREET (x 60)
#   WEST 152 STREET (x 72)
#
# Cluster 203
#   EAST 153 STREET (x 28)
#   EAST  153 STREET (x 39)
#
# Cluster 204
#   WEST  153 STREET (x 23)
#   WEST 153 STREET (x 29)
#
# Cluster 205
#   EAST 154 STREET (x 6)
#   EAST  154 STREET (x 5)
#
# Cluster 206
#   WEST  154 STREET (x 13)
#   WEST 154 STREET (x 17)
#
# Cluster 207
#   EAST  155 STREET (x 4)
#   EAST 155 STREET (x 7)
#
# Cluster 208
#   WEST 155 STREET (x 12)
#   WEST  155 STREET (x 17)
#
# Cluster 209
#   EAST  156 STREET (x 49)
#   EAST 156 STREET (x 89)
#
# Cluster 210
#   WEST 156 STREET (x 73)
#   WEST  156 STREET (x 45)
#
# Cluster 211
#   EAST  157 STREET (x 21)
#   EAST 157 STREET (x 10)
#
# Cluster 212
#   WEST 157 STREET (x 36)
#   WEST  157 STREET (x 20)
#
# Cluster 213
#   EAST  158 STREET (x 16)
#   EAST 158 STREET (x 26)
#
# Cluster 214
#   WEST  158 STREET (x 45)
#   WEST 158 STREET (x 52)
#
# Cluster 215
#   EAST  159 STREET (x 17)
#   EAST 159 STREET (x 14)
#
# Cluster 216
#   WEST 159 STREET (x 58)
#   WEST  159 STREET (x 53)
#
# Cluster 217
#   BAY 16 STREET (x 18)
#   BAY   16 STREET (x 8)
#
# Cluster 218
#   EAST 16 STREET (x 141)
#   EAST   16 STREET (x 88)
#
# Cluster 219
#   WEST   16 STREET (x 70)
#   WEST 16 STREET (x 71)
#
# Cluster 220
#   EAST 160 STREET (x 11)
#   EAST  160 STREET (x 14)
#
# Cluster 221
#   WEST  160 STREET (x 58)
#   WEST 160 STREET (x 43)
#
# Cluster 222
#   EAST  161 STREET (x 45)
#   EAST 161 STREET (x 58)
#
# Cluster 223
#   WEST 161 STREET (x 55)
#   WEST  161 STREET (x 39)
#
# Cluster 224
#   EAST 162 STREET (x 27)
#   EAST  162 STREET (x 36)
#
# Cluster 225
#   WEST  162 STREET (x 81)
#   WEST 162 STREET (x 88)
#
# Cluster 226
#   EAST  163 STREET (x 125)
#   EAST 163 STREET (x 118)
#
# Cluster 227
#   WEST 163 STREET (x 51)
#   WEST  163 STREET (x 32)
#
# Cluster 228
#   EAST  164 STREET (x 28)
#   EAST 164 STREET (x 26)
#
# Cluster 229
#   WEST 164 STREET (x 63)
#   WEST  164 STREET (x 32)
#
# Cluster 230
#   EAST  165 STREET (x 56)
#   EAST 165 STREET (x 45)
#
# Cluster 231
#   WEST  165 STREET (x 26)
#   WEST 165 STREET (x 24)
#
# Cluster 232
#   EAST 166 STREET (x 34)
#   EAST  166 STREET (x 26)
#
# Cluster 233
#   WEST  166 STREET (x 9)
#   WEST 166 STREET (x 12)
#
# Cluster 234
#   EAST  167 STREET (x 49)
#   EAST 167 STREET (x 65)
#
# Cluster 235
#   WEST  167 STREET (x 24)
#   WEST 167 STREET (x 20)
#
# Cluster 236
#   EAST 168 STREET (x 61)
#   EAST  168 STREET (x 56)
#
# Cluster 237
#   WEST 168 STREET (x 22)
#   WEST  168 STREET (x 20)
#
# Cluster 238
#   EAST 169 STREET (x 79)
#   EAST  169 STREET (x 54)
#
# Cluster 239
#   WEST  169 STREET (x 35)
#   WEST 169 STREET (x 51)
#
# Cluster 240
#   B 17 STREET (x 1)
#   B   17 STREET (x 1)
#
# Cluster 241
#   BAY 17 STREET (x 21)
#   BAY   17 STREET (x 7)
#
# Cluster 242
#   BEACH   17 STREET (x 13)
#   BEACH 17 STREET (x 11)
#
# Cluster 243
#   EAST   17 STREET (x 113)
#   EAST 17 STREET (x 212)
#
# Cluster 244
#   WEST   17 STREET (x 62)
#   WEST 17 STREET (x 53)
#
# Cluster 245
#   EAST  170 STREET (x 53)
#   EAST 170 STREET (x 35)
#
# Cluster 246
#   WEST  170 STREET (x 56)
#   WEST 170 STREET (x 69)
#
# Cluster 247
#   EAST 171 STREET (x 20)
#   EAST  171 STREET (x 16)
#
# Cluster 248
#   WEST 171 STREET (x 40)
#   WEST  171 STREET (x 29)
#
# Cluster 249
#   EAST  172 STREET (x 76)
#   EAST 172 STREET (x 45)
#
# Cluster 250
#   WEST 172 STREET (x 81)
#   WEST  172 STREET (x 59)
#
# Cluster 251
#   EAST 173 STREET (x 22)
#   EAST  173 STREET (x 53)
#
# Cluster 252
#   WEST  173 STREET (x 26)
#   WEST 173 STREET (x 59)
#
# Cluster 253
#   EAST  174 STREET (x 33)
#   EAST 174 STREET (x 54)
#
# Cluster 254
#   WEST  174 STREET (x 37)
#   WEST 174 STREET (x 66)
#
# Cluster 255
#   EAST 175 STREET (x 41)
#   EAST  175 STREET (x 53)
#
# Cluster 256
#   WEST 175 STREET (x 41)
#   WEST  175 STREET (x 45)
#
# Cluster 257
#   EAST 176 STREET (x 51)
#   EAST  176 STREET (x 88)
#
# Cluster 258
#   WEST 176 STREET (x 48)
#   WEST  176 STREET (x 28)
#
# Cluster 259
#   EAST  177 STREET (x 29)
#   EAST 177 STREET (x 17)
#
# Cluster 260
#   WEST 177 STREET (x 51)
#   WEST  177 STREET (x 40)
#
# Cluster 261
#   EAST  178 STREET (x 101)
#   EAST 178 STREET (x 76)
#
# Cluster 262
#   WEST 178 STREET (x 48)
#   WEST  178 STREET (x 40)
#
# Cluster 263
#   EAST  179 STREET (x 74)
#   EAST 179 STREET (x 66)
#
# Cluster 264
#   WEST 179 STREET (x 50)
#   WEST  179 STREET (x 33)
#
# Cluster 265
#   EAST 18 STREET (x 195)
#   EAST   18 STREET (x 168)
#
# Cluster 266
#   WEST   18 STREET (x 31)
#   WEST 18 STREET (x 27)
#
# Cluster 267
#   EAST  180 STREET (x 71)
#   EAST 180 STREET (x 42)
#
# Cluster 268
#   WEST  180 STREET (x 62)
#   WEST 180 STREET (x 69)
#
# Cluster 269
#   EAST  181 STREET (x 44)
#   EAST 181 STREET (x 56)
#
# Cluster 270
#   WEST 181 STREET (x 65)
#   WEST  181 STREET (x 55)
#
# Cluster 271
#   EAST 182 STREET (x 78)
#   EAST  182 STREET (x 64)
#
# Cluster 272
#   WEST  182 STREET (x 51)
#   WEST 182 STREET (x 34)
#
# Cluster 273
#   EAST 183 STREET (x 35)
#   EAST  183 STREET (x 38)
#
# Cluster 274
#   WEST 183 STREET (x 47)
#   WEST  183 STREET (x 54)
#
# Cluster 275
#   EAST 184 STREET (x 55)
#   EAST  184 STREET (x 28)
#
# Cluster 276
#   WEST 184 STREET (x 50)
#   WEST  184 STREET (x 25)
#
# Cluster 277
#   EAST  185 STREET (x 7)
#   EAST 185 STREET (x 4)
#
# Cluster 278
#   WEST 185 STREET (x 14)
#   WEST  185 STREET (x 8)
#
# Cluster 279
#   EAST  186 STREET (x 5)
#   EAST 186 STREET (x 3)
#
# Cluster 280
#   WEST 186 STREET (x 48)
#   WEST  186 STREET (x 36)
#
# Cluster 281
#   EAST  187 STREET (x 75)
#   EAST 187 STREET (x 49)
#
# Cluster 282
#   WEST  187 STREET (x 32)
#   WEST 187 STREET (x 33)
#
# Cluster 283
#   EAST 188 STREET (x 49)
#   EAST  188 STREET (x 34)
#
# Cluster 284
#   WEST  188 STREET (x 30)
#   WEST 188 STREET (x 47)
#
# Cluster 285
#   EAST  189 STREET (x 30)
#   EAST 189 STREET (x 18)
#
# Cluster 286
#   WEST  189 STREET (x 28)
#   WEST 189 STREET (x 39)
#
# Cluster 287
#   BAY 19 STREET (x 15)
#   BAY   19 STREET (x 7)
#
# Cluster 288
#   BEACH 19 STREET (x 24)
#   BEACH   19 STREET (x 19)
#
# Cluster 289
#   EAST   19 STREET (x 223)
#   EAST 19 STREET (x 238)
#
# Cluster 290
#   WEST 19 STREET (x 43)
#   WEST   19 STREET (x 46)
#
# Cluster 291
#   EAST 190 STREET (x 10)
#   EAST  190 STREET (x 12)
#
# Cluster 292
#   WEST  190 STREET (x 45)
#   WEST 190 STREET (x 68)
#
# Cluster 293
#   EAST  191 STREET (x 10)
#   EAST 191 STREET (x 14)
#
# Cluster 294
#   WEST 191 STREET (x 42)
#   WEST  191 STREET (x 26)
#
# Cluster 295
#   WEST 192 STREET (x 27)
#   WEST  192 STREET (x 15)
#
# Cluster 296
#   EAST 193 STREET (x 10)
#   EAST  193 STREET (x 22)
#
# Cluster 297
#   WEST  193 STREET (x 12)
#   WEST 193 STREET (x 25)
#
# Cluster 298
#   EAST 194 STREET (x 33)
#   EAST  194 STREET (x 32)
#
# Cluster 299
#   EAST  195 STREET (x 5)
#   EAST 195 STREET (x 11)
#
# Cluster 300
#   WEST 195 STREET (x 11)
#   WEST  195 STREET (x 9)
#
# Cluster 301
#   EAST  196 STREET (x 54)
#   EAST 196 STREET (x 52)
#
# Cluster 302
#   WEST 196 STREET (x 5)
#   WEST  196 STREET (x 5)
#
# Cluster 303
#   EAST  197 STREET (x 29)
#   EAST 197 STREET (x 27)
#
# Cluster 304
#   WEST 197 STREET (x 16)
#   WEST  197 STREET (x 30)
#
# Cluster 305
#   EAST  198 STREET (x 20)
#   EAST 198 STREET (x 15)
#
# Cluster 306
#   EAST  199 STREET (x 18)
#   EAST 199 STREET (x 35)
#
# Cluster 307
#   BRIGHTON 2 PLACE (x 2)
#   BRIGHTON    2 PLACE (x 1)
#
# Cluster 308
#   BRIGHTON 2 STREET (x 9)
#   BRIGHTON    2 STREET (x 7)
#
# Cluster 309
#   EAST 2 STREET (x 163)
#   EAST    2 STREET (x 119)
#
# Cluster 310
#   FLATLANDS    2 STREET (x 9)
#   FLATLANDS 2 STREET (x 2)
#
# Cluster 311
#   PAERDEGAT    2 STREET (x 4)
#   PAERDEGAT 2 STREET (x 3)
#
# Cluster 312
#   SOUTH    2 STREET (x 58)
#   SOUTH 2 STREET (x 75)
#
# Cluster 313
#   WEST 2 STREET (x 24)
#   WEST    2 STREET (x 16)
#
# Cluster 314
#   BAY 20 STREET (x 14)
#   BAY   20 STREET (x 3)
#
# Cluster 315
#   BEACH   20 STREET (x 5)
#   BEACH 20 STREET (x 12)
#
# Cluster 316
#   EAST   20 STREET (x 19)
#   EAST 20 STREET (x 32)
#
# Cluster 317
#   WEST 20 STREET (x 48)
#   WEST   20 STREET (x 37)
#
# Cluster 318
#   EAST 201 STREET (x 28)
#   EAST  201 STREET (x 23)
#
# Cluster 319
#   EAST  202 STREET (x 14)
#   EAST 202 STREET (x 8)
#
# Cluster 320
#   WEST 202 STREET (x 1)
#   WEST  202 STREET (x 1)
#
# Cluster 321
#   EAST 203 STREET (x 25)
#   EAST  203 STREET (x 29)
#
# Cluster 322
#   WEST  203 STREET (x 3)
#   WEST 203 STREET (x 2)
#
# Cluster 323
#   EAST 204 STREET (x 15)
#   EAST  204 STREET (x 15)
#
# Cluster 324
#   WEST  204 STREET (x 59)
#   WEST 204 STREET (x 47)
#
# Cluster 325
#   EAST 205 STREET (x 40)
#   EAST  205 STREET (x 31)
#
# Cluster 326
#   WEST 205 STREET (x 8)
#   WEST  205 STREET (x 9)
#
# Cluster 327
#   EAST  206 STREET (x 12)
#   EAST 206 STREET (x 14)
#
# Cluster 328
#   EAST 207 STREET (x 9)
#   EAST  207 STREET (x 7)
#
# Cluster 329
#   WEST 207 STREET (x 54)
#   WEST  207 STREET (x 27)
#
# Cluster 330
#   EAST  208 STREET (x 20)
#   EAST 208 STREET (x 25)
#
# Cluster 331
#   EAST 209 STREET (x 12)
#   EAST  209 STREET (x 24)
#
# Cluster 332
#   EAST 21 STREET (x 346)
#   EAST   21 STREET (x 217)
#
# Cluster 333
#   WEST 21 STREET (x 53)
#   WEST   21 STREET (x 54)
#
# Cluster 334
#   EAST  210 STREET (x 4)
#   EAST 210 STREET (x 5)
#
# Cluster 335
#   EAST  211 STREET (x 10)
#   EAST 211 STREET (x 11)
#
# Cluster 336
#   WEST  211 STREET (x 18)
#   WEST 211 STREET (x 19)
#
# Cluster 337
#   EAST 212 STREET (x 10)
#   EAST  212 STREET (x 7)
#
# Cluster 338
#   WEST 212 STREET (x 10)
#   WEST  212 STREET (x 23)
#
# Cluster 339
#   EAST  213 STREET (x 42)
#   EAST 213 STREET (x 24)
#
# Cluster 340
#   WEST 213 STREET (x 18)
#   WEST  213 STREET (x 9)
#
# Cluster 341
#   EAST  214 STREET (x 45)
#   EAST 214 STREET (x 22)
#
# Cluster 342
#   WEST  214 STREET (x 8)
#   WEST 214 STREET (x 14)
#
# Cluster 343
#   EAST  215 STREET (x 20)
#   EAST 215 STREET (x 28)
#
# Cluster 344
#   WEST 215 STREET (x 8)
#   WEST  215 STREET (x 3)
#
# Cluster 345
#   EAST 216 STREET (x 25)
#   EAST  216 STREET (x 18)
#
# Cluster 346
#   EAST 217 STREET (x 26)
#   EAST  217 STREET (x 25)
#
# Cluster 347
#   WEST 217 STREET (x 4)
#   WEST  217 STREET (x 1)
#
# Cluster 348
#   EAST 218 STREET (x 17)
#   EAST  218 STREET (x 8)
#
# Cluster 349
#   WEST 218 STREET (x 17)
#   WEST  218 STREET (x 15)
#
# Cluster 350
#   EAST  219 STREET (x 12)
#   EAST 219 STREET (x 24)
#
# Cluster 351
#   BAY   22 STREET (x 4)
#   BAY 22 STREET (x 10)
#
# Cluster 352
#   BEACH 22 STREET (x 7)
#   BEACH   22 STREET (x 8)
#
# Cluster 353
#   EAST   22 STREET (x 115)
#   EAST 22 STREET (x 155)
#
# Cluster 354
#   WEST 22 STREET (x 61)
#   WEST   22 STREET (x 56)
#
# Cluster 355
#   EAST 220 STREET (x 45)
#   EAST  220 STREET (x 20)
#
# Cluster 356
#   EAST 221 STREET (x 34)
#   EAST  221 STREET (x 17)
#
# Cluster 357
#   EAST 222 STREET (x 50)
#   EAST  222 STREET (x 40)
#
# Cluster 358
#   EAST  223 STREET (x 34)
#   EAST 223 STREET (x 52)
#
# Cluster 359
#   EAST  224 STREET (x 56)
#   EAST 224 STREET (x 47)
#
# Cluster 360
#   EAST 225 STREET (x 36)
#   EAST  225 STREET (x 33)
#
# Cluster 361
#   WEST 225 STREET (x 31)
#   WEST  225 STREET (x 16)
#
# Cluster 362
#   EAST 226 STREET (x 21)
#   EAST  226 STREET (x 23)
#
# Cluster 363
#   EAST  227 STREET (x 21)
#   EAST 227 STREET (x 29)
#
# Cluster 364
#   WEST 227 STREET (x 6)
#   WEST  227 STREET (x 9)
#
# Cluster 365
#   EAST  228 STREET (x 35)
#   EAST 228 STREET (x 47)
#
# Cluster 366
#   WEST  228 STREET (x 14)
#   WEST 228 STREET (x 16)
#
# Cluster 367
#   EAST  229 STREET (x 27)
#   EAST 229 STREET (x 71)
#
# Cluster 368
#   BAY 23 STREET (x 16)
#   BAY   23 STREET (x 5)
#
# Cluster 369
#   EAST 23 STREET (x 203)
#   EAST   23 STREET (x 106)
#
# Cluster 370
#   WEST 23 STREET (x 83)
#   WEST   23 STREET (x 73)
#
# Cluster 371
#   EAST  230 STREET (x 62)
#   EAST 230 STREET (x 20)
#
# Cluster 372
#   WEST 230 STREET (x 11)
#   WEST  230 STREET (x 13)
#
# Cluster 373
#   EAST  231 STREET (x 142)
#   EAST 231 STREET (x 29)
#
# Cluster 374
#   WEST 231 STREET (x 22)
#   WEST  231 STREET (x 8)
#
# Cluster 375
#   EAST 232 STREET (x 30)
#   EAST  232 STREET (x 31)
#
# Cluster 376
#   WEST 232 STREET (x 19)
#   WEST  232 STREET (x 6)
#
# Cluster 377
#   EAST  233 STREET (x 50)
#   EAST 233 STREET (x 53)
#
# Cluster 378
#   WEST 233 STREET (x 8)
#   WEST  233 STREET (x 5)
#
# Cluster 379
#   EAST  234 STREET (x 34)
#   EAST 234 STREET (x 37)
#
# Cluster 380
#   WEST  234 STREET (x 2)
#   WEST 234 STREET (x 1)
#
# Cluster 381
#   EAST 235 STREET (x 30)
#   EAST  235 STREET (x 18)
#
# Cluster 382
#   WEST  235 STREET (x 7)
#   WEST 235 STREET (x 9)
#
# Cluster 383
#   EAST  236 STREET (x 39)
#   EAST 236 STREET (x 31)
#
# Cluster 384
#   WEST  236 STREET (x 7)
#   WEST 236 STREET (x 10)
#
# Cluster 385
#   EAST  237 STREET (x 19)
#   EAST 237 STREET (x 10)
#
# Cluster 386
#   WEST  237 STREET (x 3)
#   WEST 237 STREET (x 2)
#
# Cluster 387
#   EAST  238 STREET (x 9)
#   EAST 238 STREET (x 4)
#
# Cluster 388
#   WEST  238 STREET (x 47)
#   WEST 238 STREET (x 38)
#
# Cluster 389
#   EAST  239 STREET (x 7)
#   EAST 239 STREET (x 12)
#
# Cluster 390
#   WEST 239 STREET (x 7)
#   WEST  239 STREET (x 4)
#
# Cluster 391
#   BAY 24 STREET (x 1)
#   BAY   24 STREET (x 1)
#
# Cluster 392
#   BEACH 24 STREET (x 4)
#   BEACH   24 STREET (x 1)
#
# Cluster 393
#   EAST 24 STREET (x 84)
#   EAST   24 STREET (x 54)
#
# Cluster 394
#   WEST 24 STREET (x 71)
#   WEST   24 STREET (x 82)
#
# Cluster 395
#   EAST 240 STREET (x 6)
#   EAST  240 STREET (x 2)
#
# Cluster 396
#   WEST  240 STREET (x 5)
#   WEST 240 STREET (x 1)
#
# Cluster 397
#   EAST 241 STREET (x 11)
#   EAST  241 STREET (x 17)
#
# Cluster 398
#   EAST 242 STREET (x 28)
#   EAST  242 STREET (x 28)
#
# Cluster 399
#   WEST 242 STREET (x 12)
#   WEST  242 STREET (x 13)
#
# Cluster 400
#   EAST  243 STREET (x 23)
#   EAST 243 STREET (x 21)
#
# Cluster 401
#   WEST 246 STREET (x 5)
#   WEST  246 STREET (x 10)
#
# Cluster 402
#   WEST  247 STREET (x 2)
#   WEST 247 STREET (x 1)
#
# Cluster 403
#   BAY 25 STREET (x 12)
#   BAY   25 STREET (x 22)
#
# Cluster 404
#   BEACH   25 STREET (x 13)
#   BEACH 25 STREET (x 9)
#
# Cluster 405
#   EAST   25 STREET (x 38)
#   EAST 25 STREET (x 46)
#
# Cluster 406
#   WEST 25 STREET (x 74)
#   WEST   25 STREET (x 48)
#
# Cluster 407
#   WEST 251 STREET (x 5)
#   WEST  251 STREET (x 3)
#
# Cluster 408
#   WEST 254 STREET (x 4)
#   WEST  254 STREET (x 4)
#
# Cluster 409
#   WEST 255 STREET (x 1)
#   WEST  255 STREET (x 2)
#
# Cluster 410
#   WEST 256 STREET (x 7)
#   WEST  256 STREET (x 2)
#
# Cluster 411
#   BAY 26 STREET (x 17)
#   BAY   26 STREET (x 8)
#
# Cluster 412
#   BEACH   26 STREET (x 8)
#   BEACH 26 STREET (x 10)
#
# Cluster 413
#   EAST 26 STREET (x 110)
#   EAST   26 STREET (x 94)
#
# Cluster 414
#   WEST 26 STREET (x 52)
#   WEST   26 STREET (x 30)
#
# Cluster 415
#   WEST 260 STREET (x 4)
#   WEST  260 STREET (x 1)
#
# Cluster 416
#   WEST 261 STREET (x 2)
#   WEST  261 STREET (x 6)
#
# Cluster 417
#   WEST 262 STREET (x 10)
#   WEST  262 STREET (x 4)
#
# Cluster 418
#   BAY 27 STREET (x 1)
#   BAY   27 STREET (x 1)
#
# Cluster 419
#   BEACH   27 STREET (x 15)
#   BEACH 27 STREET (x 4)
#
# Cluster 420
#   EAST 27 STREET (x 106)
#   EAST   27 STREET (x 80)
#
# Cluster 421
#   WEST   27 STREET (x 36)
#   WEST 27 STREET (x 39)
#
# Cluster 422
#   BAY 28 STREET (x 15)
#   BAY   28 STREET (x 7)
#
# Cluster 423
#   EAST   28 STREET (x 86)
#   EAST 28 STREET (x 159)
#
# Cluster 424
#   WEST 28 STREET (x 46)
#   WEST   28 STREET (x 60)
#
# Cluster 425
#   BAY   29 STREET (x 18)
#   BAY 29 STREET (x 12)
#
# Cluster 426
#   BEACH   29 STREET (x 14)
#   BEACH 29 STREET (x 6)
#
# Cluster 427
#   EAST 29 STREET (x 149)
#   EAST   29 STREET (x 99)
#
# Cluster 428
#   WEST   29 STREET (x 60)
#   WEST 29 STREET (x 65)
#
# Cluster 429
#   BEACH    3 STREET (x 2)
#   BEACH 3 STREET (x 1)
#
# Cluster 430
#   BRIGHTON 3 STREET (x 13)
#   BRIGHTON    3 STREET (x 13)
#
# Cluster 431
#   EAST    3 STREET (x 116)
#   EAST 3 STREET (x 186)
#
# Cluster 432
#   FLATLANDS    3 STREET (x 2)
#   FLATLANDS 3 STREET (x 5)
#
# Cluster 433
#   NORTH 3 STREET (x 16)
#   NORTH    3 STREET (x 13)
#
# Cluster 434
#   PAERDEGAT    3 STREET (x 5)
#   PAERDEGAT 3 STREET (x 6)
#
# Cluster 435
#   SOUTH 3 STREET (x 77)
#   SOUTH    3 STREET (x 75)
#
# Cluster 436
#   WEST 3 STREET (x 50)
#   WEST    3 STREET (x 22)
#
# Cluster 437
#   BAY 30 STREET (x 2)
#   BAY   30 STREET (x 3)
#
# Cluster 438
#   BEACH   30 STREET (x 3)
#   BEACH 30 STREET (x 4)
#
# Cluster 439
#   EAST 30 STREET (x 47)
#   EAST   30 STREET (x 27)
#
# Cluster 440
#   WEST   30 STREET (x 56)
#   WEST 30 STREET (x 95)
#
# Cluster 441
#   BAY 31 STREET (x 13)
#   BAY   31 STREET (x 5)
#
# Cluster 442
#   BEACH 31 STREET (x 10)
#   BEACH   31 STREET (x 5)
#
# Cluster 443
#   EAST   31 STREET (x 96)
#   EAST 31 STREET (x 93)
#
# Cluster 444
#   WEST   31 STREET (x 34)
#   WEST 31 STREET (x 27)
#
# Cluster 445
#   BAY   32 STREET (x 11)
#   BAY 32 STREET (x 25)
#
# Cluster 446
#   BEACH   32 STREET (x 10)
#   BEACH 32 STREET (x 5)
#
# Cluster 447
#   EAST   32 STREET (x 64)
#   EAST 32 STREET (x 83)
#
# Cluster 448
#   WEST 32 STREET (x 35)
#   WEST   32 STREET (x 13)
#
# Cluster 449
#   EAST   33 STREET (x 43)
#   EAST 33 STREET (x 57)
#
# Cluster 450
#   WEST   33 STREET (x 36)
#   WEST 33 STREET (x 52)
#
# Cluster 451
#   BAY   34 STREET (x 6)
#   BAY 34 STREET (x 15)
#
# Cluster 452
#   EAST 34 STREET (x 122)
#   EAST   34 STREET (x 105)
#
# Cluster 453
#   WEST   34 STREET (x 43)
#   WEST 34 STREET (x 48)
#
# Cluster 454
#   BAY   35 STREET (x 5)
#   BAY 35 STREET (x 11)
#
# Cluster 455
#   EAST 35 STREET (x 82)
#   EAST   35 STREET (x 78)
#
# Cluster 456
#   WEST 35 STREET (x 29)
#   WEST   35 STREET (x 31)
#
# Cluster 457
#   BEACH   36 STREET (x 7)
#   BEACH 36 STREET (x 5)
#
# Cluster 458
#   EAST   36 STREET (x 50)
#   EAST 36 STREET (x 61)
#
# Cluster 459
#   WEST   36 STREET (x 35)
#   WEST 36 STREET (x 51)
#
# Cluster 460
#   BAY   37 STREET (x 10)
#   BAY 37 STREET (x 19)
#
# Cluster 461
#   BEACH 37 STREET (x 2)
#   BEACH   37 STREET (x 7)
#
# Cluster 462
#   EAST 37 STREET (x 68)
#   EAST   37 STREET (x 63)
#
# Cluster 463
#   WEST   37 STREET (x 44)
#   WEST 37 STREET (x 57)
#
# Cluster 464
#   BAY 38 STREET (x 15)
#   BAY   38 STREET (x 5)
#
# Cluster 465
#   BEACH   38 STREET (x 1)
#   BEACH 38 STREET (x 2)
#
# Cluster 466
#   EAST   38 STREET (x 63)
#   EAST 38 STREET (x 84)
#
# Cluster 467
#   WEST 38 STREET (x 33)
#   WEST   38 STREET (x 29)
#
# Cluster 468
#   EAST   39 STREET (x 49)
#   EAST 39 STREET (x 92)
#
# Cluster 469
#   WEST 39 STREET (x 37)
#   WEST   39 STREET (x 22)
#
# Cluster 470
#   BEACH 4 STREET (x 1)
#   BEACH    4 STREET (x 2)
#
# Cluster 471
#   BRIGHTON 4 STREET (x 23)
#   BRIGHTON    4 STREET (x 13)
#
# Cluster 472
#   EAST 4 STREET (x 209)
#   EAST    4 STREET (x 105)
#
# Cluster 473
#   EAST 4 WALK (x 2)
#   EAST    4 WALK (x 2)
#
# Cluster 474
#   FLATLANDS    4 STREET (x 1)
#   FLATLANDS 4 STREET (x 6)
#
# Cluster 475
#   NORTH 4 PLACE (x 2)
#   NORTH    4 PLACE (x 1)
#
# Cluster 476
#   NORTH 4 STREET (x 25)
#   NORTH    4 STREET (x 9)
#
# Cluster 477
#   PAERDEGAT    4 STREET (x 2)
#   PAERDEGAT 4 STREET (x 2)
#
# Cluster 478
#   SOUTH 4 STREET (x 101)
#   SOUTH    4 STREET (x 65)
#
# Cluster 479
#   WEST 4 STREET (x 83)
#   WEST    4 STREET (x 46)
#
# Cluster 480
#   BAY 40 STREET (x 13)
#   BAY   40 STREET (x 9)
#
# Cluster 481
#   BEACH 40 STREET (x 8)
#   BEACH   40 STREET (x 4)
#
# Cluster 482
#   EAST   40 STREET (x 29)
#   EAST 40 STREET (x 42)
#
# Cluster 483
#   WEST 40 STREET (x 38)
#   WEST   40 STREET (x 27)
#
# Cluster 484
#   BAY   41 STREET (x 3)
#   BAY 41 STREET (x 6)
#
# Cluster 485
#   BEACH 41 STREET (x 2)
#   BEACH   41 STREET (x 1)
#
# Cluster 486
#   EAST 41 STREET (x 16)
#   EAST   41 STREET (x 13)
#
# Cluster 487
#   WEST   41 STREET (x 11)
#   WEST 41 STREET (x 11)
#
# Cluster 488
#   EAST 42 STREET (x 42)
#   EAST   42 STREET (x 26)
#
# Cluster 489
#   WEST   42 STREET (x 61)
#   WEST 42 STREET (x 71)
#
# Cluster 490
#   BAY 43 STREET (x 8)
#   BAY   43 STREET (x 4)
#
# Cluster 491
#   BEACH 43 STREET (x 5)
#   BEACH   43 STREET (x 7)
#
# Cluster 492
#   EAST 43 STREET (x 41)
#   EAST   43 STREET (x 27)
#
# Cluster 493
#   WEST 43 STREET (x 56)
#   WEST   43 STREET (x 38)
#
# Cluster 494
#   BAY   44 STREET (x 1)
#   BAY 44 STREET (x 7)
#
# Cluster 495
#   BEACH 44 STREET (x 7)
#   BEACH   44 STREET (x 6)
#
# Cluster 496
#   EAST   44 STREET (x 18)
#   EAST 44 STREET (x 24)
#
# Cluster 497
#   WEST   44 STREET (x 36)
#   WEST 44 STREET (x 91)
#
# Cluster 498
#   BEACH 45 STREET (x 2)
#   BEACH   45 STREET (x 8)
#
# Cluster 499
#   EAST 45 STREET (x 46)
#   EAST   45 STREET (x 49)
#
# Cluster 500
#   WEST   45 STREET (x 73)
#   WEST 45 STREET (x 59)
#
# Cluster 501
#   BAY 46 STREET (x 6)
#   BAY   46 STREET (x 11)
#
# Cluster 502
#   BEACH   46 STREET (x 7)
#   BEACH 46 STREET (x 2)
#
# Cluster 503
#   EAST 46 STREET (x 94)
#   EAST   46 STREET (x 73)
#
# Cluster 504
#   WEST   46 STREET (x 56)
#   WEST 46 STREET (x 93)
#
# Cluster 505
#   BAY 47 STREET (x 9)
#   BAY   47 STREET (x 3)
#
# Cluster 506
#   BEACH   47 STREET (x 14)
#   BEACH 47 STREET (x 3)
#
# Cluster 507
#   EAST 47 STREET (x 11)
#   EAST   47 STREET (x 8)
#
# Cluster 508
#   WEST   47 STREET (x 60)
#   WEST 47 STREET (x 48)
#
# Cluster 509
#   BEACH   48 STREET (x 6)
#   BEACH 48 STREET (x 1)
#
# Cluster 510
#   EAST 48 STREET (x 88)
#   EAST   48 STREET (x 55)
#
# Cluster 511
#   WEST 48 STREET (x 97)
#   WEST   48 STREET (x 57)
#
# Cluster 512
#   BAY 49 STREET (x 14)
#   BAY   49 STREET (x 4)
#
# Cluster 513
#   EAST 49 STREET (x 75)
#   EAST   49 STREET (x 74)
#
# Cluster 514
#   WEST   49 STREET (x 40)
#   WEST 49 STREET (x 63)
#
# Cluster 515
#   BRIGHTON    5 STREET (x 14)
#   BRIGHTON 5 STREET (x 18)
#
# Cluster 516
#   EAST 5 STREET (x 154)
#   EAST    5 STREET (x 95)
#
# Cluster 517
#   NORTH    5 STREET (x 14)
#   NORTH 5 STREET (x 16)
#
# Cluster 518
#   SOUTH 5 STREET (x 26)
#   SOUTH    5 STREET (x 29)
#
# Cluster 519
#   WEST 5 STREET (x 47)
#   WEST    5 STREET (x 36)
#
# Cluster 520
#   BAY   50 STREET (x 4)
#   BAY 50 STREET (x 4)
#
# Cluster 521
#   EAST 50 STREET (x 30)
#   EAST   50 STREET (x 43)
#
# Cluster 522
#   WEST   50 STREET (x 41)
#   WEST 50 STREET (x 38)
#
# Cluster 523
#   BEACH   51 STREET (x 3)
#   BEACH 51 STREET (x 2)
#
# Cluster 524
#   EAST 51 STREET (x 93)
#   EAST   51 STREET (x 88)
#
# Cluster 525
#   WEST 51 STREET (x 53)
#   WEST   51 STREET (x 64)
#
# Cluster 526
#   EAST   52 STREET (x 103)
#   EAST 52 STREET (x 115)
#
# Cluster 527
#   WEST 52 STREET (x 43)
#   WEST   52 STREET (x 44)
#
# Cluster 528
#   BEACH   53 STREET (x 1)
#   BEACH 53 STREET (x 1)
#
# Cluster 529
#   EAST 53 PLACE (x 3)
#   EAST   53 PLACE (x 1)
#
# Cluster 530
#   EAST   53 STREET (x 67)
#   EAST 53 STREET (x 96)
#
# Cluster 531
#   WEST   53 STREET (x 32)
#   WEST 53 STREET (x 22)
#
# Cluster 532
#   BEACH   54 STREET (x 4)
#   BEACH 54 STREET (x 8)
#
# Cluster 533
#   EAST   54 STREET (x 88)
#   EAST 54 STREET (x 109)
#
# Cluster 534
#   WEST 54 STREET (x 43)
#   WEST   54 STREET (x 39)
#
# Cluster 535
#   EAST 55 STREET (x 88)
#   EAST   55 STREET (x 51)
#
# Cluster 536
#   WEST 55 STREET (x 84)
#   WEST   55 STREET (x 63)
#
# Cluster 537
#   BEACH   56 PLACE (x 25)
#   BEACH 56 PLACE (x 5)
#
# Cluster 538
#   EAST   56 STREET (x 41)
#   EAST 56 STREET (x 84)
#
# Cluster 539
#   WEST   56 STREET (x 45)
#   WEST 56 STREET (x 61)
#
# Cluster 540
#   BEACH   57 STREET (x 6)
#   BEACH 57 STREET (x 2)
#
# Cluster 541
#   EAST   57 PLACE (x 1)
#   EAST 57 PLACE (x 2)
#
# Cluster 542
#   EAST 57 STREET (x 81)
#   EAST   57 STREET (x 51)
#
# Cluster 543
#   WEST 57 STREET (x 69)
#   WEST   57 STREET (x 80)
#
# Cluster 544
#   EAST 58 STREET (x 56)
#   EAST   58 STREET (x 66)
#
# Cluster 545
#   WEST 58 STREET (x 54)
#   WEST   58 STREET (x 104)
#
# Cluster 546
#   BEACH   59 STREET (x 18)
#   BEACH 59 STREET (x 7)
#
# Cluster 547
#   EAST 59 PLACE (x 3)
#   EAST   59 PLACE (x 1)
#
# Cluster 548
#   EAST 59 STREET (x 66)
#   EAST   59 STREET (x 45)
#
# Cluster 549
#   WEST 59 STREET (x 5)
#   WEST   59 STREET (x 7)
#
# Cluster 550
#   BRIGHTON    6 STREET (x 9)
#   BRIGHTON 6 STREET (x 25)
#
# Cluster 551
#   EAST 6 STREET (x 98)
#   EAST    6 STREET (x 80)
#
# Cluster 552
#   NORTH    6 STREET (x 30)
#   NORTH 6 STREET (x 29)
#
# Cluster 553
#   PAERDEGAT 6 STREET (x 2)
#   PAERDEGAT    6 STREET (x 1)
#
# Cluster 554
#   SOUTH    6 STREET (x 4)
#   SOUTH 6 STREET (x 19)
#
# Cluster 555
#   WEST 6 STREET (x 44)
#   WEST    6 STREET (x 15)
#
# Cluster 556
#   BEACH 60 STREET (x 8)
#   BEACH   60 STREET (x 7)
#
# Cluster 557
#   EAST   60 STREET (x 49)
#   EAST 60 STREET (x 38)
#
# Cluster 558
#   WEST   60 STREET (x 10)
#   WEST 60 STREET (x 15)
#
# Cluster 559
#   BEACH 61 STREET (x 8)
#   BEACH   61 STREET (x 4)
#
# Cluster 560
#   EAST 61 STREET (x 30)
#   EAST   61 STREET (x 28)
#
# Cluster 561
#   WEST 61 STREET (x 11)
#   WEST   61 STREET (x 8)
#
# Cluster 562
#   BEACH 62 STREET (x 6)
#   BEACH   62 STREET (x 4)
#
# Cluster 563
#   EAST 62 STREET (x 18)
#   EAST   62 STREET (x 26)
#
# Cluster 564
#   WEST 62 STREET (x 14)
#   WEST   62 STREET (x 4)
#
# Cluster 565
#   BEACH   63 STREET (x 4)
#   BEACH 63 STREET (x 7)
#
# Cluster 566
#   EAST 63 STREET (x 52)
#   EAST   63 STREET (x 44)
#
# Cluster 567
#   WEST 63 STREET (x 19)
#   WEST   63 STREET (x 7)
#
# Cluster 568
#   BEACH 64 STREET (x 6)
#   BEACH   64 STREET (x 6)
#
# Cluster 569
#   EAST   64 STREET (x 49)
#   EAST 64 STREET (x 39)
#
# Cluster 570
#   WEST   64 STREET (x 12)
#   WEST 64 STREET (x 10)
#
# Cluster 571
#   BEACH   65 STREET (x 2)
#   BEACH 65 STREET (x 7)
#
# Cluster 572
#   EAST   65 STREET (x 32)
#   EAST 65 STREET (x 37)
#
# Cluster 573
#   WEST 65 STREET (x 14)
#   WEST   65 STREET (x 12)
#
# Cluster 574
#   BEACH   66 STREET (x 13)
#   BEACH 66 STREET (x 4)
#
# Cluster 575
#   EAST   66 STREET (x 30)
#   EAST 66 STREET (x 45)
#
# Cluster 576
#   WEST   66 STREET (x 11)
#   WEST 66 STREET (x 11)
#
# Cluster 577
#   BEACH   67 STREET (x 9)
#   BEACH 67 STREET (x 7)
#
# Cluster 578
#   EAST   67 STREET (x 18)
#   EAST 67 STREET (x 16)
#
# Cluster 579
#   WEST   67 STREET (x 10)
#   WEST 67 STREET (x 11)
#
# Cluster 580
#   BEACH 68 STREET (x 7)
#   BEACH   68 STREET (x 10)
#
# Cluster 581
#   EAST 68 STREET (x 35)
#   EAST   68 STREET (x 18)
#
# Cluster 582
#   WEST 68 STREET (x 23)
#   WEST   68 STREET (x 19)
#
# Cluster 583
#   BEACH 69 STREET (x 13)
#   BEACH   69 STREET (x 12)
#
# Cluster 584
#   EAST 69 STREET (x 63)
#   EAST   69 STREET (x 48)
#
# Cluster 585
#   WEST 69 STREET (x 28)
#   WEST   69 STREET (x 14)
#
# Cluster 586
#   BAY 7 STREET (x 10)
#   BAY    7 STREET (x 4)
#
# Cluster 587
#   BRIGHTON 7 STREET (x 20)
#   BRIGHTON    7 STREET (x 10)
#
# Cluster 588
#   EAST    7 ROAD (x 1)
#   EAST 7 ROAD (x 2)
#
# Cluster 589
#   EAST 7 STREET (x 165)
#   EAST    7 STREET (x 118)
#
# Cluster 590
#   FLATLANDS    7 STREET (x 1)
#   FLATLANDS 7 STREET (x 1)
#
# Cluster 591
#   NORTH    7 STREET (x 74)
#   NORTH 7 STREET (x 37)
#
# Cluster 592
#   PAERDEGAT    7 STREET (x 2)
#   PAERDEGAT 7 STREET (x 2)
#
# Cluster 593
#   WEST    7 STREET (x 35)
#   WEST 7 STREET (x 40)
#
# Cluster 594
#   BEACH 70 STREET (x 3)
#   BEACH   70 STREET (x 18)
#
# Cluster 595
#   EAST   70 STREET (x 38)
#   EAST 70 STREET (x 52)
#
# Cluster 596
#   WEST   70 STREET (x 25)
#   WEST 70 STREET (x 26)
#
# Cluster 597
#   EAST 71 STREET (x 30)
#   EAST   71 STREET (x 20)
#
# Cluster 598
#   WEST   71 STREET (x 65)
#   WEST 71 STREET (x 47)
#
# Cluster 599
#   BEACH   72 STREET (x 6)
#   BEACH 72 STREET (x 3)
#
# Cluster 600
#   EAST 72 STREET (x 56)
#   EAST   72 STREET (x 44)
#
# Cluster 601
#   WEST   72 STREET (x 75)
#   WEST 72 STREET (x 72)
#
# Cluster 602
#   BEACH 73 STREET (x 1)
#   BEACH   73 STREET (x 4)
#
# Cluster 603
#   EAST   73 STREET (x 47)
#   EAST 73 STREET (x 52)
#
# Cluster 604
#   WEST   73 STREET (x 36)
#   WEST 73 STREET (x 41)
#
# Cluster 605
#   BEACH   74 STREET (x 1)
#   BEACH 74 STREET (x 2)
#
# Cluster 606
#   EAST   74 STREET (x 40)
#   EAST 74 STREET (x 28)
#
# Cluster 607
#   WEST   74 STREET (x 30)
#   WEST 74 STREET (x 32)
#
# Cluster 608
#   EAST 75 STREET (x 33)
#   EAST   75 STREET (x 31)
#
# Cluster 609
#   WEST   75 STREET (x 34)
#   WEST 75 STREET (x 27)
#
# Cluster 610
#   EAST 76 STREET (x 52)
#   EAST   76 STREET (x 24)
#
# Cluster 611
#   WEST   76 STREET (x 27)
#   WEST 76 STREET (x 29)
#
# Cluster 612
#   EAST   77 STREET (x 52)
#   EAST 77 STREET (x 44)
#
# Cluster 613
#   WEST 77 STREET (x 25)
#   WEST   77 STREET (x 19)
#
# Cluster 614
#   EAST 78 STREET (x 51)
#   EAST   78 STREET (x 55)
#
# Cluster 615
#   WEST   78 STREET (x 13)
#   WEST 78 STREET (x 8)
#
# Cluster 616
#   EAST   79 STREET (x 34)
#   EAST 79 STREET (x 53)
#
# Cluster 617
#   WEST   79 STREET (x 15)
#   WEST 79 STREET (x 14)
#
# Cluster 618
#   BAY 8 STREET (x 16)
#   BAY    8 STREET (x 5)
#
# Cluster 619
#   BRIGHTON    8 STREET (x 14)
#   BRIGHTON 8 STREET (x 11)
#
# Cluster 620
#   EAST    8 ROAD (x 2)
#   EAST 8 ROAD (x 1)
#
# Cluster 621
#   EAST 8 STREET (x 125)
#   EAST    8 STREET (x 74)
#
# Cluster 622
#   NORTH 8 STREET (x 24)
#   NORTH    8 STREET (x 18)
#
# Cluster 623
#   PAERDEGAT 8 STREET (x 2)
#   PAERDEGAT    8 STREET (x 1)
#
# Cluster 624
#   SOUTH 8 STREET (x 17)
#   SOUTH    8 STREET (x 10)
#
# Cluster 625
#   WEST 8 STREET (x 81)
#   WEST    8 STREET (x 36)
#
# Cluster 626
#   BEACH   80 STREET (x 3)
#   BEACH 80 STREET (x 2)
#
# Cluster 627
#   EAST 80 STREET (x 55)
#   EAST   80 STREET (x 66)
#
# Cluster 628
#   WEST   80 STREET (x 23)
#   WEST 80 STREET (x 25)
#
# Cluster 629
#   EAST 81 STREET (x 56)
#   EAST   81 STREET (x 58)
#
# Cluster 630
#   WEST 81 STREET (x 18)
#   WEST   81 STREET (x 33)
#
# Cluster 631
#   EAST   82 STREET (x 59)
#   EAST 82 STREET (x 76)
#
# Cluster 632
#   WEST   82 STREET (x 30)
#   WEST 82 STREET (x 25)
#
# Cluster 633
#   EAST   83 STREET (x 71)
#   EAST 83 STREET (x 86)
#
# Cluster 634
#   WEST   83 STREET (x 42)
#   WEST 83 STREET (x 27)
#
# Cluster 635
#   BEACH 84 STREET (x 9)
#   BEACH   84 STREET (x 8)
#
# Cluster 636
#   EAST 84 STREET (x 75)
#   EAST   84 STREET (x 54)
#
# Cluster 637
#   WEST 84 STREET (x 26)
#   WEST   84 STREET (x 27)
#
# Cluster 638
#   EAST 85 STREET (x 70)
#   EAST   85 STREET (x 52)
#
# Cluster 639
#   WEST 85 STREET (x 27)
#   WEST   85 STREET (x 28)
#
# Cluster 640
#   BEACH   86 STREET (x 3)
#   BEACH 86 STREET (x 4)
#
# Cluster 641
#   EAST 86 STREET (x 100)
#   EAST   86 STREET (x 86)
#
# Cluster 642
#   WEST   86 STREET (x 40)
#   WEST 86 STREET (x 30)
#
# Cluster 643
#   BEACH   87 STREET (x 10)
#   BEACH 87 STREET (x 4)
#
# Cluster 644
#   EAST 87 STREET (x 76)
#   EAST   87 STREET (x 82)
#
# Cluster 645
#   WEST   87 STREET (x 46)
#   WEST 87 STREET (x 37)
#
# Cluster 646
#   OLD BEACH   88 STREET (x 1)
#   OLD BEACH 88 STREET (x 1)
#
# Cluster 647
#   BEACH   88 STREET (x 9)
#   BEACH 88 STREET (x 5)
#
# Cluster 648
#   EAST 88 STREET (x 86)
#   EAST   88 STREET (x 85)
#
# Cluster 649
#   WEST   88 STREET (x 25)
#   WEST 88 STREET (x 22)
#
# Cluster 650
#   BEACH   89 STREET (x 7)
#   BEACH 89 STREET (x 1)
#
# Cluster 651
#   EAST   89 STREET (x 66)
#   EAST 89 STREET (x 62)
#
# Cluster 652
#   WEST   89 STREET (x 29)
#   WEST 89 STREET (x 28)
#
# Cluster 653
#   BEACH    9 STREET (x 18)
#   BEACH 9 STREET (x 11)
#
# Cluster 654
#   EAST 9 STREET (x 151)
#   EAST    9 STREET (x 92)
#
# Cluster 655
#   FLATLANDS    9 STREET (x 2)
#   FLATLANDS 9 STREET (x 3)
#
# Cluster 656
#   NORTH    9 STREET (x 9)
#   NORTH 9 STREET (x 13)
#
# Cluster 657
#   PAERDEGAT 9 STREET (x 3)
#   PAERDEGAT    9 STREET (x 1)
#
# Cluster 658
#   SOUTH    9 STREET (x 6)
#   SOUTH 9 STREET (x 20)
#
# Cluster 659
#   WEST    9 STREET (x 34)
#   WEST 9 STREET (x 47)
#
# Cluster 660
#   BEACH   90 STREET (x 11)
#   BEACH 90 STREET (x 6)
#
# Cluster 661
#   EAST 90 STREET (x 37)
#   EAST   90 STREET (x 35)
#
# Cluster 662
#   WEST 90 STREET (x 39)
#   WEST   90 STREET (x 18)
#
# Cluster 663
#   BEACH   91 STREET (x 7)
#   BEACH 91 STREET (x 4)
#
# Cluster 664
#   EAST 91 STREET (x 101)
#   EAST   91 STREET (x 75)
#
# Cluster 665
#   WEST 91 STREET (x 45)
#   WEST   91 STREET (x 19)
#
# Cluster 666
#   BEACH   92 STREET (x 11)
#   BEACH 92 STREET (x 10)
#
# Cluster 667
#   EAST   92 STREET (x 92)
#   EAST 92 STREET (x 109)
#
# Cluster 668
#   WEST   92 STREET (x 22)
#   WEST 92 STREET (x 24)
#
# Cluster 669
#   BEACH 93 STREET (x 1)
#   BEACH   93 STREET (x 3)
#
# Cluster 670
#   EAST   93 STREET (x 82)
#   EAST 93 STREET (x 100)
#
# Cluster 671
#   WEST   93 STREET (x 40)
#   WEST 93 STREET (x 32)
#
# Cluster 672
#   EAST 94 STREET (x 111)
#   EAST   94 STREET (x 74)
#
# Cluster 673
#   WEST   94 STREET (x 34)
#   WEST 94 STREET (x 38)
#
# Cluster 674
#   BEACH   95 STREET (x 3)
#   BEACH 95 STREET (x 1)
#
# Cluster 675
#   EAST 95 STREET (x 85)
#   EAST   95 STREET (x 86)
#
# Cluster 676
#   WEST   95 STREET (x 46)
#   WEST 95 STREET (x 35)
#
# Cluster 677
#   BEACH   96 STREET (x 10)
#   BEACH 96 STREET (x 5)
#
# Cluster 678
#   EAST 96 STREET (x 118)
#   EAST   96 STREET (x 97)
#
# Cluster 679
#   WEST   96 STREET (x 50)
#   WEST 96 STREET (x 27)
#
# Cluster 680
#   BEACH   97 STREET (x 11)
#   BEACH 97 STREET (x 1)
#
# Cluster 681
#   EAST   97 STREET (x 17)
#   EAST 97 STREET (x 26)
#
# Cluster 682
#   WEST 97 STREET (x 24)
#   WEST   97 STREET (x 32)
#
# Cluster 683
#   BEACH   98 STREET (x 12)
#   BEACH 98 STREET (x 11)
#
# Cluster 684
#   EAST 98 STREET (x 79)
#   EAST   98 STREET (x 58)
#
# Cluster 685
#   WEST 98 STREET (x 11)
#   WEST   98 STREET (x 7)
#
# Cluster 686
#   BEACH 99 STREET (x 2)
#   BEACH   99 STREET (x 1)
#
# Cluster 687
#   EAST 99 STREET (x 36)
#   EAST   99 STREET (x 31)
#
# Cluster 688
#   WEST 99 STREET (x 15)
#   WEST   99 STREET (x 15)
#
# Cluster 689
#   AVENUE A (x 173)
#   A AVENUE (x 3)
#
# Cluster 690
#   ST ANDREWS ROAD (x 4)
#   ST ANDREW'S ROAD (x 1)
#
# Cluster 691
#   SAINT ANNS AVENUE (x 3)
#   SAINT ANN'S AVENUE (x 2)
#
# Cluster 692
#   ST ANNS AVENUE (x 61)
#   ST ANN'S AVENUE (x 18)
#
# Cluster 693
#   FOREST AVE (x 1)
#   FOREST AVE \ (x 1)
#
# Cluster 694
#   AVENUE B (x 116)
#   B AVENUE (x 2)
#
# Cluster 695
#   AVENUE C (x 173)
#   C AVENUE (x 2)
#
# Cluster 696
#   AVENUE D (x 184)
#   D AVENUE (x 2)
#
# Cluster 697
#   MT EDEN AVENUE WEST (x 1)
#   WEST MT EDEN AVENUE (x 5)
#
# Cluster 698
#   NORTH GANNON AVENUE (x 8)
#   GANNON AVENUE NORTH (x 2)
#
# Cluster 699
#   HUNTS POINT AVENUE (x 55)
#   HUNT'S POINT AVENUE (x 1)
#
# Cluster 700
#   AVENUE ST JOHN (x 27)
#   ST JOHN AVENUE (x 4)
#
# Cluster 701
#   SAINT JOHN'S AVENUE (x 1)
#   SAINT JOHNS AVENUE (x 3)
#
# Cluster 702
#   L AVENUE (x 1)
#   AVENUE L (x 164)
#
# Cluster 703
#   AVENUE M (x 154)
#   M AVENUE (x 1)
#
# Cluster 704
#   SAINT MARKS AVENUE (x 76)
#   SAINT MARK'S AVENUE (x 2)
#
# Cluster 705
#   ST MARKS AVENUE (x 344)
#   ST MARK'S AVENUE (x 8)
#
# Cluster 706
#   SAINT MARYS AVENUE (x 5)
#   SAINT MARY'S AVENUE (x 1)
#
# Cluster 707
#   ST MARYS AVENUE (x 12)
#   ST MARY'S AVENUE (x 1)
#
# Cluster 708
#   AVENUE O (x 131)
#   O AVENUE (x 1)
#
# Cluster 709
#   OGORMAN AVENUE (x 4)
#   O'GORMAN AVENUE (x 2)
#
# Cluster 710
#   ST PAULS AVENUE (x 24)
#   ST PAUL'S AVENUE (x 2)
#
# Cluster 711
#   SAINT PETERS AVENUE (x 2)
#   SAINT PETER'S AVENUE (x 1)
#
# Cluster 712
#   ST PETERS AVENUE (x 19)
#   ST PETER'S AVENUE (x 2)
#
# Cluster 713
#   AVENUE U (x 165)
#   U AVENUE (x 2)
#
# Cluster 714
#   AVENUE WEST (x 1)
#   WEST AVENUE (x 14)
#
# Cluster 715
#   AVENUE X (x 106)
#   X AVENUE (x 1)
#
# Cluster 716
#   COOP CITY BOULEVARD (x 3)
#   CO-OP CITY BOULEVARD (x 4)
#
# Cluster 717
#   NORTH CHESTNUT DRIVE (x 3)
#   CHESTNUT DRIVE NORTH (x 2)
#
# Cluster 718
#   CLARKE PLACE EAST (x 26)
#   EAST CLARKE PLACE (x 21)
#
# Cluster 719
#   O'CONNELL COURT (x 1)
#   OCONNELL COURT (x 2)
#
# Cluster 720
#   SAINT PAUL'S COURT (x 1)
#   SAINT PAULS COURT (x 2)
#
# Cluster 721
#   ST PAULS COURT (x 31)
#   ST PAUL'S COURT (x 3)
#
# Cluster 722
#   SOUTH OAK DRIVE (x 6)
#   OAK DRIVE SOUTH (x 1)
#
# Cluster 723
#   HOR HARDING EXPRESSWAY SR SOUTH (x 3)
#   HOR HARDING EXPRESSWAY SOUTH SR (x 1)
#
# Cluster 724
#   SAINT JOHNS PLACE (x 56)
#   SAINT JOHN'S PLACE (x 5)
#
# Cluster 725
#   ST JOHNS PLACE (x 389)
#   ST JOHN'S PLACE (x 18)
#
# Cluster 726
#   SAINT MARKS PLACE (x 44)
#   SAINT MARK'S PLACE (x 1)
#
# Cluster 727
#   ST MARKS PLACE (x 136)
#   ST MARK'S PLACE (x 3)
#
# Cluster 728
#   ST PAULS PLACE (x 39)
#   ST PAUL'S PLACE (x 2)

# %%
for index, row in df.iterrows():
    if row['Street Name'] in cluster_dict:
        df.at[index, 'Street Name'] = final_street[cluster_dict[row['Street Name']]]

# %% [markdown]
# #### Updating the Cross Street1 column using clustering

# %%
cross_street_1 = ds.update('Cross Street 1', str.upper).distinct('Cross Street 1')
clusters = KeyCollision(func=Fingerprint(), threads=3).clusters(cross_street_1)

# %%
cross_street_1_dict = {}
cluster_dict = {}

def print_k_clusters_and_integrate_cs1(clusters):
    clusters = sorted(clusters, key=lambda x: len(x), reverse=True)
    val_count = sum([len(c) for c in clusters])
    print('Total number of clusters is {} with {} values'.format(len(clusters), val_count))
    for i in range(len(clusters)):
        print('\nCluster {}'.format(i + 1))
        temp_dict = {}
        for key, cnt in clusters[i].items():
          if key == '':
            key = "''"
          print(f'  {key} (x {cnt})')
          temp_dict[key] = int(cnt)
          cluster_dict[key] = i
        cross_street_1_dict[i] = temp_dict

print_k_clusters_and_integrate_cs1(clusters)
# Out:
# Total number of clusters is 656 with 1319 values
#
# Cluster 1
#   '' (x 109851)
#   ???????????????????????????? (x 30)
#   ???????????????????????????????? (x 1)
#
# Cluster 2
#   CROSS BRONX EXPWY ET 1 C-D SB (x 22)
#   CROSS BRONX EXPWY SB ET 1 C-D (x 2)
#   CROSS BRONX EXPWY ET    1 C-D SB (x 2)
#
# Cluster 3
#   CROSS BRONX EXPWY ET 1 D SB (x 19)
#   CROSS BRONX EXPWY ET    1 D SB (x 1)
#   CROSS BRONX EXPWY SB ET 1 D (x 1)
#
# Cluster 4
#   HENRY HUDSON PARKWAY ET 17 NB (x 8)
#   HENRY HUDSON PARKWAY ET   17 NB (x 4)
#   HENRY HUDSON PARKWAY NB ET 17 (x 1)
#
# Cluster 5
#   EAST 179 STREET (x 133)
#   EAST  179 STREET (x 7)
#   EAST 179 STREET & EAST (x 1)
#
# Cluster 6
#   BROOKLYN QUEENS EXPWY ET 33  EB (x 1)
#   BROOKLYN QUEENS EXPWY ET   33 EB (x 1)
#   BROOKLYN QUEENS EXPWY ET 33 EB (x 3)
#
# Cluster 7
#   BROOKLYN QUEENS EXPWY ET 43  WB (x 1)
#   BROOKLYN QUEENS EXPWY ET   43 WB (x 1)
#   BROOKLYN QUEENS EXPWY ET 43 WB (x 1)
#
# Cluster 8
#   CROSS BRONX EXPWY NB ET 1 B (x 9)
#   CROSS BRONX EXPWY NB ET    1 B (x 8)
#
# Cluster 9
#   BRIGHTON 1 PLACE (x 6)
#   BRIGHTON    1 PLACE (x 1)
#
# Cluster 10
#   BRIGHTON 1 STREET (x 4)
#   BRIGHTON    1 STREET (x 1)
#
# Cluster 11
#   MAJOR DEEGAN EXPWY ET 1  SB (x 1)
#   MAJOR DEEGAN EXPWY ET 1 SB (x 1)
#
# Cluster 12
#   EAST 1 STREET (x 95)
#   EAST    1 STREET (x 8)
#
# Cluster 13
#   FLATLANDS    1 STREET (x 1)
#   FLATLANDS 1 STREET (x 4)
#
# Cluster 14
#   SOUTH 1 STREET (x 30)
#   SOUTH    1 STREET (x 2)
#
# Cluster 15
#   WEST 1 STREET (x 12)
#   WEST    1 STREET (x 4)
#
# Cluster 16
#   BAY   10 STREET (x 1)
#   BAY 10 STREET (x 1)
#
# Cluster 17
#   BRIGHTON 10 PATH (x 6)
#   BRIGHTON   10 PATH (x 1)
#
# Cluster 18
#   EAST 10 STREET (x 68)
#   EAST   10 STREET (x 10)
#
# Cluster 19
#   STATEN ISLAND EXPWY ET 10 WB (x 1)
#   STATEN ISLAND EXPWY WB ET 10 (x 1)
#
# Cluster 20
#   HENRY HUDSON PARKWAY ET 10 NB (x 3)
#   HENRY HUDSON PARKWAY ET   10 NB (x 1)
#
# Cluster 21
#   FLATLANDS   10 STREET (x 1)
#   FLATLANDS 10 STREET (x 3)
#
# Cluster 22
#   NORTH 10 STREET (x 7)
#   NORTH   10 STREET (x 5)
#
# Cluster 23
#   WEST 10 STREET (x 62)
#   WEST   10 STREET (x 7)
#
# Cluster 24
#   EAST 100 STREET (x 21)
#   EAST  100 STREET (x 1)
#
# Cluster 25
#   WEST 100 STREET (x 55)
#   WEST  100 STREET (x 3)
#
# Cluster 26
#   EAST 101 STREET (x 21)
#   EAST  101 STREET (x 4)
#
# Cluster 27
#   WEST 101 STREET (x 13)
#   WEST  101 STREET (x 2)
#
# Cluster 28
#   BEACH 102 STREET (x 2)
#   BEACH  102 STREET (x 1)
#
# Cluster 29
#   EAST 102 STREET (x 6)
#   EAST  102 STREET (x 2)
#
# Cluster 30
#   WEST 102 STREET (x 27)
#   WEST  102 STREET (x 3)
#
# Cluster 31
#   EAST 103 STREET (x 15)
#   EAST  103 STREET (x 1)
#
# Cluster 32
#   WEST 103 STREET (x 27)
#   WEST  103 STREET (x 4)
#
# Cluster 33
#   EAST 104 STREET (x 38)
#   EAST  104 STREET (x 3)
#
# Cluster 34
#   WEST 104 STREET (x 28)
#   WEST  104 STREET (x 1)
#
# Cluster 35
#   BEACH  105 STREET (x 1)
#   BEACH 105 STREET (x 21)
#
# Cluster 36
#   E 105 ST (x 15)
#   105 ST E (x 1)
#
# Cluster 37
#   EAST 105 STREET (x 60)
#   EAST  105 STREET (x 9)
#
# Cluster 38
#   WEST 105 STREET (x 47)
#   WEST  105 STREET (x 7)
#
# Cluster 39
#   EAST 106 STREET (x 25)
#   EAST  106 STREET (x 3)
#
# Cluster 40
#   WEST 106 STREET (x 35)
#   WEST  106 STREET (x 4)
#
# Cluster 41
#   EAST  107 STREET (x 6)
#   EAST 107 STREET (x 13)
#
# Cluster 42
#   WEST 107 STREET (x 26)
#   WEST  107 STREET (x 3)
#
# Cluster 43
#   BEACH  108 STREET (x 3)
#   BEACH 108 STREET (x 1)
#
# Cluster 44
#   EAST 108 STREET (x 26)
#   EAST  108 STREET (x 1)
#
# Cluster 45
#   WEST 108 STREET (x 15)
#   WEST  108 STREET (x 2)
#
# Cluster 46
#   EAST 109 STREET (x 25)
#   EAST  109 STREET (x 1)
#
# Cluster 47
#   WEST 109 STREET (x 6)
#   WEST  109 STREET (x 3)
#
# Cluster 48
#   11 ST E (x 1)
#   E 11 ST (x 18)
#
# Cluster 49
#   EAST 11 STREET (x 87)
#   EAST   11 STREET (x 10)
#
# Cluster 50
#   HENRY HUDSON PARKWAY ET 11 SB (x 2)
#   HENRY HUDSON PARKWAY ET   11 SB (x 1)
#
# Cluster 51
#   NORTH 11 STREET (x 19)
#   NORTH   11 STREET (x 1)
#
# Cluster 52
#   WEST 11 STREET (x 22)
#   WEST   11 STREET (x 1)
#
# Cluster 53
#   BEACH  110 STREET (x 1)
#   BEACH 110 STREET (x 1)
#
# Cluster 54
#   EAST 110 STREET (x 18)
#   EAST  110 STREET (x 3)
#
# Cluster 55
#   WEST 110 STREET (x 12)
#   WEST  110 STREET (x 1)
#
# Cluster 56
#   EAST 111 STREET (x 21)
#   EAST  111 STREET (x 2)
#
# Cluster 57
#   WEST  111 STREET (x 2)
#   WEST 111 STREET (x 28)
#
# Cluster 58
#   EAST 112 STREET (x 78)
#   EAST  112 STREET (x 7)
#
# Cluster 59
#   WEST 112 STREET (x 39)
#   WEST  112 STREET (x 4)
#
# Cluster 60
#   EAST  113 STREET (x 1)
#   EAST 113 STREET (x 2)
#
# Cluster 61
#   WEST 113 STREET (x 64)
#   WEST  113 STREET (x 6)
#
# Cluster 62
#   EAST 114 STREET (x 10)
#   EAST  114 STREET (x 1)
#
# Cluster 63
#   WEST 114 STREET (x 53)
#   WEST  114 STREET (x 5)
#
# Cluster 64
#   EAST 115 STREET (x 70)
#   EAST  115 STREET (x 3)
#
# Cluster 65
#   WEST 115 STREET (x 27)
#   WEST  115 STREET (x 6)
#
# Cluster 66
#   BEACH 116 STREET (x 1)
#   BEACH  116 STREET (x 1)
#
# Cluster 67
#   EAST 116 STREET (x 32)
#   EAST  116 STREET (x 3)
#
# Cluster 68
#   WEST 116 STREET (x 20)
#   WEST  116 STREET (x 5)
#
# Cluster 69
#   EAST 117 STREET (x 22)
#   EAST  117 STREET (x 3)
#
# Cluster 70
#   WEST 117 STREET (x 13)
#   WEST  117 STREET (x 3)
#
# Cluster 71
#   EAST  118 STREET (x 3)
#   EAST 118 STREET (x 17)
#
# Cluster 72
#   W 118 ST (x 1)
#   118 ST W (x 1)
#
# Cluster 73
#   WEST 118 STREET (x 19)
#   WEST  118 STREET (x 3)
#
# Cluster 74
#   EAST 119 STREET (x 18)
#   EAST  119 STREET (x 3)
#
# Cluster 75
#   WEST 119 STREET (x 38)
#   WEST  119 STREET (x 1)
#
# Cluster 76
#   VAN WYCK EXPRESSWAY ET   12 A SB (x 1)
#   VAN WYCK EXPRESSWAY ET 12 A SB (x 1)
#
# Cluster 77
#   BEACH 12 STREET (x 18)
#   BEACH   12 STREET (x 1)
#
# Cluster 78
#   BRIGHTON 12 STREET (x 13)
#   BRIGHTON   12 STREET (x 1)
#
# Cluster 79
#   EAST 12 STREET (x 128)
#   EAST   12 STREET (x 15)
#
# Cluster 80
#   N 12 ST (x 8)
#   12 ST N (x 2)
#
# Cluster 81
#   NORTH 12 STREET (x 16)
#   NORTH   12 STREET (x 1)
#
# Cluster 82
#   W 12 ST (x 17)
#   12 ST W (x 1)
#
# Cluster 83
#   WEST 12 STREET (x 35)
#   WEST   12 STREET (x 2)
#
# Cluster 84
#   EAST 120 STREET (x 22)
#   EAST  120 STREET (x 2)
#
# Cluster 85
#   WEST 120 STREET (x 21)
#   WEST  120 STREET (x 2)
#
# Cluster 86
#   WEST 121 STREET (x 23)
#   WEST  121 STREET (x 4)
#
# Cluster 87
#   WEST 122 STREET (x 56)
#   WEST  122 STREET (x 4)
#
# Cluster 88
#   EAST 123 STREET (x 16)
#   EAST  123 STREET (x 1)
#
# Cluster 89
#   WEST 123 STREET (x 46)
#   WEST  123 STREET (x 2)
#
# Cluster 90
#   EAST 124 STREET (x 13)
#   EAST  124 STREET (x 3)
#
# Cluster 91
#   EAST 125 STREET (x 5)
#   EAST  125 STREET (x 3)
#
# Cluster 92
#   WEST 125 STREET (x 25)
#   WEST  125 STREET (x 2)
#
# Cluster 93
#   EAST 126 STREET (x 13)
#   EAST  126 STREET (x 4)
#
# Cluster 94
#   WEST 126 STREET (x 31)
#   WEST  126 STREET (x 1)
#
# Cluster 95
#   EAST  127 STREET (x 1)
#   EAST 127 STREET (x 4)
#
# Cluster 96
#   WEST 127 STREET (x 22)
#   WEST  127 STREET (x 1)
#
# Cluster 97
#   BEACH  128 STREET (x 1)
#   BEACH 128 STREET (x 1)
#
# Cluster 98
#   EAST 128 STREET (x 10)
#   EAST  128 STREET (x 1)
#
# Cluster 99
#   WEST 128 STREET (x 14)
#   WEST  128 STREET (x 1)
#
# Cluster 100
#   BEACH 129 STREET (x 3)
#   BEACH  129 STREET (x 1)
#
# Cluster 101
#   WEST 129 STREET (x 34)
#   WEST  129 STREET (x 4)
#
# Cluster 102
#   BEACH 13 STREET (x 5)
#   BEACH   13 STREET (x 1)
#
# Cluster 103
#   BELT PARKWAY EXIT 13 WESTBOUND (x 6)
#   BELT PARKWAY WESTBOUND EXIT 13 (x 3)
#
# Cluster 104
#   EAST 13 STREET (x 95)
#   EAST   13 STREET (x 11)
#
# Cluster 105
#   WEST   13 ROAD (x 1)
#   WEST 13 ROAD (x 3)
#
# Cluster 106
#   WEST 13 STREET (x 23)
#   WEST   13 STREET (x 5)
#
# Cluster 107
#   WEST 130 STREET (x 42)
#   WEST  130 STREET (x 2)
#
# Cluster 108
#   BEACH  131 STREET (x 1)
#   BEACH 131 STREET (x 1)
#
# Cluster 109
#   EAST  131 STREET (x 1)
#   EAST 131 STREET (x 9)
#
# Cluster 110
#   W 131 ST (x 3)
#   131 ST W (x 1)
#
# Cluster 111
#   WEST 131 STREET (x 44)
#   WEST  131 STREET (x 4)
#
# Cluster 112
#   EAST 132 STREET (x 29)
#   EAST  132 STREET (x 5)
#
# Cluster 113
#   WEST 132 STREET (x 22)
#   WEST  132 STREET (x 1)
#
# Cluster 114
#   WEST 133 STREET (x 38)
#   WEST  133 STREET (x 6)
#
# Cluster 115
#   EAST 134 STREET (x 2)
#   EAST  134 STREET (x 3)
#
# Cluster 116
#   WEST 134 STREET (x 23)
#   WEST  134 STREET (x 4)
#
# Cluster 117
#   MAJOR DEEGAN EP SB EN E  135 ST (x 2)
#   MAJOR DEEGAN EP SB EN E 135 ST (x 1)
#
# Cluster 118
#   EAST 135 STREET (x 20)
#   EAST  135 STREET (x 3)
#
# Cluster 119
#   WEST 135 STREET (x 26)
#   WEST  135 STREET (x 3)
#
# Cluster 120
#   EAST 136 STREET (x 13)
#   EAST  136 STREET (x 4)
#
# Cluster 121
#   WEST 136 STREET (x 19)
#   WEST  136 STREET (x 1)
#
# Cluster 122
#   EAST 137 STREET (x 18)
#   EAST  137 STREET (x 2)
#
# Cluster 123
#   WEST 137 STREET (x 27)
#   WEST  137 STREET (x 1)
#
# Cluster 124
#   BEACH 138 STREET (x 2)
#   BEACH  138 STREET (x 1)
#
# Cluster 125
#   BRUCKNER EXPWY EB EN E  138 ST (x 2)
#   BRUCKNER EXPWY EB EN E 138 ST (x 1)
#
# Cluster 126
#   EAST  138 STREET (x 4)
#   EAST 138 STREET (x 21)
#
# Cluster 127
#   WEST 138 STREET (x 41)
#   WEST  138 STREET (x 3)
#
# Cluster 128
#   HARLEM RIVER DRV NB EN E  139 ST (x 1)
#   HARLEM RIVER DRV NB EN E 139 ST (x 11)
#
# Cluster 129
#   EAST  139 STREET (x 3)
#   EAST 139 STREET (x 11)
#
# Cluster 130
#   BAY 14 STREET (x 11)
#   BAY   14 STREET (x 1)
#
# Cluster 131
#   BEACH 14 STREET (x 4)
#   BEACH   14 STREET (x 1)
#
# Cluster 132
#   EAST 14 STREET (x 85)
#   EAST   14 STREET (x 3)
#
# Cluster 133
#   BEACH 140 STREET (x 2)
#   BEACH  140 STREET (x 1)
#
# Cluster 134
#   EAST 140 STREET (x 13)
#   EAST  140 STREET (x 1)
#
# Cluster 135
#   WEST 140 STREET (x 61)
#   WEST  140 STREET (x 4)
#
# Cluster 136
#   EAST 141 STREET (x 25)
#   EAST  141 STREET (x 5)
#
# Cluster 137
#   WEST 141 STREET (x 151)
#   WEST  141 STREET (x 6)
#
# Cluster 138
#   EAST 142 STREET (x 7)
#   EAST  142 STREET (x 1)
#
# Cluster 139
#   WEST 142 STREET (x 85)
#   WEST  142 STREET (x 3)
#
# Cluster 140
#   EAST  143 STREET (x 3)
#   EAST 143 STREET (x 16)
#
# Cluster 141
#   WEST 143 STREET (x 42)
#   WEST  143 STREET (x 7)
#
# Cluster 142
#   BEACH 144 STREET (x 2)
#   BEACH  144 STREET (x 2)
#
# Cluster 143
#   EAST 144 STREET (x 12)
#   EAST  144 STREET (x 3)
#
# Cluster 144
#   WEST 144 STREET (x 32)
#   WEST  144 STREET (x 2)
#
# Cluster 145
#   EAST 145 STREET (x 18)
#   EAST  145 STREET (x 3)
#
# Cluster 146
#   WEST 145 STREET (x 66)
#   WEST  145 STREET (x 4)
#
# Cluster 147
#   EAST 146 STREET (x 8)
#   EAST  146 STREET (x 2)
#
# Cluster 148
#   146 ST W (x 1)
#   W 146 ST (x 3)
#
# Cluster 149
#   WEST 146 STREET (x 49)
#   WEST  146 STREET (x 2)
#
# Cluster 150
#   EAST 147 STREET (x 51)
#   EAST  147 STREET (x 3)
#
# Cluster 151
#   WEST  147 STREET (x 6)
#   WEST 147 STREET (x 43)
#
# Cluster 152
#   WEST 148 STREET (x 54)
#   WEST  148 STREET (x 12)
#
# Cluster 153
#   BEACH  149 STREET (x 1)
#   BEACH 149 STREET (x 2)
#
# Cluster 154
#   EAST 149 STREET (x 76)
#   EAST  149 STREET (x 10)
#
# Cluster 155
#   WEST  149 STREET (x 6)
#   WEST 149 STREET (x 70)
#
# Cluster 156
#   BRIGHTON 15 STREET (x 11)
#   BRIGHTON   15 STREET (x 1)
#
# Cluster 157
#   E 15 ST (x 14)
#   15 ST E (x 1)
#
# Cluster 158
#   EAST 15 STREET (x 47)
#   EAST   15 STREET (x 3)
#
# Cluster 159
#   NORTH   15 STREET (x 2)
#   NORTH 15 STREET (x 3)
#
# Cluster 160
#   EAST 150 STREET (x 58)
#   EAST  150 STREET (x 4)
#
# Cluster 161
#   WEST 150 STREET (x 83)
#   WEST  150 STREET (x 4)
#
# Cluster 162
#   EAST  151 STREET (x 14)
#   EAST 151 STREET (x 21)
#
# Cluster 163
#   WEST 151 STREET (x 66)
#   WEST  151 STREET (x 6)
#
# Cluster 164
#   WEST 152 STREET (x 40)
#   WEST  152 STREET (x 4)
#
# Cluster 165
#   EAST 153 STREET (x 91)
#   EAST  153 STREET (x 13)
#
# Cluster 166
#   WEST 153 STREET (x 48)
#   WEST  153 STREET (x 4)
#
# Cluster 167
#   EAST 154 STREET (x 3)
#   EAST  154 STREET (x 1)
#
# Cluster 168
#   EAST 155 STREET (x 8)
#   EAST  155 STREET (x 1)
#
# Cluster 169
#   WEST 155 STREET (x 21)
#   WEST  155 STREET (x 3)
#
# Cluster 170
#   156 ST E (x 2)
#   E 156 ST (x 18)
#
# Cluster 171
#   EAST 156 STREET (x 107)
#   EAST  156 STREET (x 10)
#
# Cluster 172
#   WEST 156 STREET (x 12)
#   WEST  156 STREET (x 1)
#
# Cluster 173
#   EAST 157 STREET (x 30)
#   EAST  157 STREET (x 5)
#
# Cluster 174
#   WEST 157 STREET (x 11)
#   WEST  157 STREET (x 4)
#
# Cluster 175
#   E 158 ST (x 5)
#   158 ST E (x 1)
#
# Cluster 176
#   EAST 158 STREET (x 55)
#   EAST  158 STREET (x 4)
#
# Cluster 177
#   WEST  158 STREET (x 2)
#   WEST 158 STREET (x 22)
#
# Cluster 178
#   EAST 159 STREET (x 31)
#   EAST  159 STREET (x 3)
#
# Cluster 179
#   WEST 159 STREET (x 16)
#   WEST  159 STREET (x 1)
#
# Cluster 180
#   BAY 16 STREET (x 15)
#   BAY   16 STREET (x 1)
#
# Cluster 181
#   E 16 ST (x 18)
#   16 ST E (x 1)
#
# Cluster 182
#   EAST 16 STREET (x 69)
#   EAST   16 STREET (x 13)
#
# Cluster 183
#   WEST 16 STREET (x 20)
#   WEST   16 STREET (x 6)
#
# Cluster 184
#   EAST 160 STREET (x 19)
#   EAST  160 STREET (x 1)
#
# Cluster 185
#   WEST  160 STREET (x 3)
#   WEST 160 STREET (x 34)
#
# Cluster 186
#   E 161 ST (x 9)
#   161 ST E (x 1)
#
# Cluster 187
#   EAST  161 STREET (x 16)
#   EAST 161 STREET (x 97)
#
# Cluster 188
#   EAST 162 STREET (x 51)
#   EAST  162 STREET (x 4)
#
# Cluster 189
#   WEST 162 STREET (x 136)
#   WEST  162 STREET (x 17)
#
# Cluster 190
#   EAST  163 STREET (x 9)
#   EAST 163 STREET (x 150)
#
# Cluster 191
#   WEST 163 STREET (x 18)
#   WEST  163 STREET (x 5)
#
# Cluster 192
#   164 ST E (x 1)
#   E 164 ST (x 11)
#
# Cluster 193
#   EAST 164 STREET (x 123)
#   EAST  164 STREET (x 19)
#
# Cluster 194
#   WEST 164 STREET (x 102)
#   WEST  164 STREET (x 2)
#
# Cluster 195
#   EAST  165 STREET (x 16)
#   EAST 165 STREET (x 204)
#
# Cluster 196
#   W 165 ST (x 11)
#   165 ST W (x 1)
#
# Cluster 197
#   WEST 165 STREET (x 81)
#   WEST  165 STREET (x 5)
#
# Cluster 198
#   EAST 166 STREET (x 156)
#   EAST  166 STREET (x 10)
#
# Cluster 199
#   WEST 166 STREET (x 51)
#   WEST  166 STREET (x 4)
#
# Cluster 200
#   E 167 ST (x 27)
#   167 ST E (x 5)
#
# Cluster 201
#   EAST 167 STREET (x 245)
#   EAST  167 STREET (x 37)
#
# Cluster 202
#   WEST 167 STREET (x 71)
#   WEST  167 STREET (x 9)
#
# Cluster 203
#   EAST 168 STREET (x 192)
#   EAST  168 STREET (x 14)
#
# Cluster 204
#   WEST 168 STREET (x 23)
#   WEST  168 STREET (x 2)
#
# Cluster 205
#   EAST 169 STREET (x 236)
#   EAST  169 STREET (x 18)
#
# Cluster 206
#   WEST 169 STREET (x 68)
#   WEST  169 STREET (x 9)
#
# Cluster 207
#   BAY   17 STREET (x 1)
#   BAY 17 STREET (x 7)
#
# Cluster 208
#   BEACH 17 STREET (x 3)
#   BEACH   17 STREET (x 1)
#
# Cluster 209
#   EAST 17 STREET (x 86)
#   EAST   17 STREET (x 5)
#
# Cluster 210
#   WEST 17 STREET (x 27)
#   WEST   17 STREET (x 6)
#
# Cluster 211
#   EAST 170 STREET (x 92)
#   EAST  170 STREET (x 15)
#
# Cluster 212
#   WEST 170 STREET (x 67)
#   WEST  170 STREET (x 4)
#
# Cluster 213
#   EAST 171 STREET (x 76)
#   EAST  171 STREET (x 8)
#
# Cluster 214
#   WEST 171 STREET (x 61)
#   WEST  171 STREET (x 7)
#
# Cluster 215
#   E 172 ST (x 26)
#   172 ST E (x 2)
#
# Cluster 216
#   EAST 172 STREET (x 289)
#   EAST  172 STREET (x 35)
#
# Cluster 217
#   WEST 172 STREET (x 39)
#   WEST  172 STREET (x 7)
#
# Cluster 218
#   EAST 173 STREET (x 141)
#   EAST  173 STREET (x 16)
#
# Cluster 219
#   WEST 173 STREET (x 21)
#   WEST  173 STREET (x 2)
#
# Cluster 220
#   E 174 ST (x 12)
#   174 ST E (x 1)
#
# Cluster 221
#   EAST 174 STREET (x 80)
#   EAST  174 STREET (x 6)
#
# Cluster 222
#   W 174 ST (x 22)
#   174 ST W (x 1)
#
# Cluster 223
#   WEST 174 STREET (x 70)
#   WEST  174 STREET (x 6)
#
# Cluster 224
#   EAST 175 STREET (x 74)
#   EAST  175 STREET (x 10)
#
# Cluster 225
#   WEST 175 STREET (x 87)
#   WEST  175 STREET (x 7)
#
# Cluster 226
#   EAST 176 STREET (x 53)
#   EAST  176 STREET (x 6)
#
# Cluster 227
#   WEST 176 STREET (x 195)
#   WEST  176 STREET (x 15)
#
# Cluster 228
#   E 177 ST (x 3)
#   177 ST E (x 1)
#
# Cluster 229
#   EAST 177 STREET (x 26)
#   EAST  177 STREET (x 6)
#
# Cluster 230
#   WEST 177 STREET (x 87)
#   WEST  177 STREET (x 4)
#
# Cluster 231
#   EAST 178 STREET (x 107)
#   EAST  178 STREET (x 8)
#
# Cluster 232
#   WEST 178 STREET (x 7)
#   WEST  178 STREET (x 1)
#
# Cluster 233
#   G WASHINGTON BR EN W 179 ST (x 4)
#   G WASHINGTON BR EN W  179 ST (x 1)
#
# Cluster 234
#   W 179 ST (x 5)
#   179 ST W (x 1)
#
# Cluster 235
#   WEST  179 STREET (x 7)
#   WEST 179 STREET (x 60)
#
# Cluster 236
#   EAST 18 ROAD (x 2)
#   EAST   18 ROAD (x 1)
#
# Cluster 237
#   EAST 18 STREET (x 120)
#   EAST   18 STREET (x 16)
#
# Cluster 238
#   HENRY HUDSON PARKWAY ET 18 NB (x 2)
#   HENRY HUDSON PARKWAY NB ET 18 (x 1)
#
# Cluster 239
#   WEST 18 STREET (x 26)
#   WEST   18 STREET (x 1)
#
# Cluster 240
#   EAST 180 STREET (x 158)
#   EAST  180 STREET (x 15)
#
# Cluster 241
#   WEST 180 STREET (x 56)
#   WEST  180 STREET (x 11)
#
# Cluster 242
#   EAST 181 STREET (x 186)
#   EAST  181 STREET (x 9)
#
# Cluster 243
#   WEST 181 STREET (x 58)
#   WEST  181 STREET (x 3)
#
# Cluster 244
#   E 182 ST (x 9)
#   182 ST E (x 1)
#
# Cluster 245
#   EAST  182 STREET (x 21)
#   EAST 182 STREET (x 145)
#
# Cluster 246
#   WEST 182 STREET (x 23)
#   WEST  182 STREET (x 2)
#
# Cluster 247
#   E 183 ST (x 21)
#   183 ST E (x 2)
#
# Cluster 248
#   EAST 183 STREET (x 241)
#   EAST  183 STREET (x 14)
#
# Cluster 249
#   WEST 183 STREET (x 156)
#   WEST  183 STREET (x 17)
#
# Cluster 250
#   E 184 ST (x 15)
#   184 ST E (x 1)
#
# Cluster 251
#   EAST 184 STREET (x 175)
#   EAST  184 STREET (x 19)
#
# Cluster 252
#   WEST  184 STREET (x 7)
#   WEST 184 STREET (x 75)
#
# Cluster 253
#   EAST 186 STREET (x 7)
#   EAST  186 STREET (x 4)
#
# Cluster 254
#   WEST 186 STREET (x 49)
#   WEST  186 STREET (x 5)
#
# Cluster 255
#   EAST 187 STREET (x 113)
#   EAST  187 STREET (x 14)
#
# Cluster 256
#   EAST 188 STREET (x 95)
#   EAST  188 STREET (x 6)
#
# Cluster 257
#   WEST 188 STREET (x 54)
#   WEST  188 STREET (x 2)
#
# Cluster 258
#   EAST 189 STREET (x 24)
#   EAST  189 STREET (x 3)
#
# Cluster 259
#   WEST 189 STREET (x 25)
#   WEST  189 STREET (x 5)
#
# Cluster 260
#   BAY 19 STREET (x 7)
#   BAY   19 STREET (x 1)
#
# Cluster 261
#   EAST 19 STREET (x 104)
#   EAST   19 STREET (x 15)
#
# Cluster 262
#   EAST 190 STREET (x 24)
#   EAST  190 STREET (x 2)
#
# Cluster 263
#   W 190 ST (x 30)
#   190 ST W (x 1)
#
# Cluster 264
#   WEST 190 STREET (x 123)
#   WEST  190 STREET (x 16)
#
# Cluster 265
#   EAST 191 STREET (x 10)
#   EAST  191 STREET (x 1)
#
# Cluster 266
#   WEST 191 STREET (x 15)
#   WEST  191 STREET (x 2)
#
# Cluster 267
#   EAST 192 STREET (x 44)
#   EAST  192 STREET (x 4)
#
# Cluster 268
#   WEST 192 STREET (x 46)
#   WEST  192 STREET (x 5)
#
# Cluster 269
#   EAST 193 STREET (x 30)
#   EAST  193 STREET (x 3)
#
# Cluster 270
#   WEST 193 STREET (x 24)
#   WEST  193 STREET (x 5)
#
# Cluster 271
#   EAST 194 STREET (x 65)
#   EAST  194 STREET (x 8)
#
# Cluster 272
#   EAST 195 STREET (x 20)
#   EAST  195 STREET (x 2)
#
# Cluster 273
#   WEST 195 STREET (x 66)
#   WEST  195 STREET (x 7)
#
# Cluster 274
#   E 196 ST (x 6)
#   196 ST E (x 1)
#
# Cluster 275
#   EAST 196 STREET (x 97)
#   EAST  196 STREET (x 5)
#
# Cluster 276
#   WEST 196 STREET (x 76)
#   WEST  196 STREET (x 14)
#
# Cluster 277
#   EAST 197 STREET (x 53)
#   EAST  197 STREET (x 6)
#
# Cluster 278
#   W 197 ST (x 4)
#   197 ST W (x 1)
#
# Cluster 279
#   WEST 197 STREET (x 90)
#   WEST  197 STREET (x 9)
#
# Cluster 280
#   EAST  198 STREET (x 7)
#   EAST 198 STREET (x 62)
#
# Cluster 281
#   EAST 199 STREET (x 26)
#   EAST  199 STREET (x 1)
#
# Cluster 282
#   CROSS BRONX EXPWY ET 2 A WB (x 2)
#   CROSS BRONX EXPWY WB ET 2 A (x 1)
#
# Cluster 283
#   BRIGHTON 2 STREET (x 7)
#   BRIGHTON    2 STREET (x 6)
#
# Cluster 284
#   MAJOR DEEGAN EXPWY ET 2  NB (x 1)
#   MAJOR DEEGAN EXPWY ET 2 NB (x 1)
#
# Cluster 285
#   EAST 2 STREET (x 101)
#   EAST    2 STREET (x 9)
#
# Cluster 286
#   KINGSBOROUGH    2 WALK (x 1)
#   KINGSBOROUGH 2 WALK (x 1)
#
# Cluster 287
#   SOUTH 2 STREET (x 39)
#   SOUTH    2 STREET (x 5)
#
# Cluster 288
#   BAY 20 STREET (x 4)
#   BAY   20 STREET (x 1)
#
# Cluster 289
#   BEACH 20 STREET (x 15)
#   BEACH   20 STREET (x 2)
#
# Cluster 290
#   HARLEM RIVER DRIVE EXIT   20 SB (x 1)
#   HARLEM RIVER DRIVE EXIT 20 SB (x 1)
#
# Cluster 291
#   EAST 20 STREET (x 20)
#   EAST   20 STREET (x 2)
#
# Cluster 292
#   WEST 20 STREET (x 22)
#   WEST   20 STREET (x 5)
#
# Cluster 293
#   WEST  202 STREET (x 2)
#   WEST 202 STREET (x 1)
#
# Cluster 294
#   EAST 203 STREET (x 23)
#   EAST  203 STREET (x 5)
#
# Cluster 295
#   WEST  203 STREET (x 1)
#   WEST 203 STREET (x 1)
#
# Cluster 296
#   204 ST E (x 1)
#   E 204 ST (x 8)
#
# Cluster 297
#   EAST 204 STREET (x 66)
#   EAST  204 STREET (x 8)
#
# Cluster 298
#   204 ST W (x 2)
#   W 204 ST (x 12)
#
# Cluster 299
#   WEST  204 STREET (x 30)
#   WEST 204 STREET (x 97)
#
# Cluster 300
#   EAST 205 STREET (x 53)
#   EAST  205 STREET (x 2)
#
# Cluster 301
#   WEST 205 STREET (x 5)
#   WEST  205 STREET (x 2)
#
# Cluster 302
#   EAST  206 STREET (x 6)
#   EAST 206 STREET (x 41)
#
# Cluster 303
#   WEST 206 STREET (x 6)
#   WEST  206 STREET (x 2)
#
# Cluster 304
#   EAST 207 STREET (x 38)
#   EAST  207 STREET (x 4)
#
# Cluster 305
#   W 207 ST (x 12)
#   207 ST W (x 1)
#
# Cluster 306
#   WEST 207 STREET (x 67)
#   WEST  207 STREET (x 5)
#
# Cluster 307
#   EAST 208 STREET (x 34)
#   EAST  208 STREET (x 2)
#
# Cluster 308
#   EAST 209 STREET (x 53)
#   EAST  209 STREET (x 7)
#
# Cluster 309
#   BELT PARKWAY EXIT 21 WESTBOUND (x 3)
#   BELT PARKWAY EXIT   21 WESTBOUND (x 1)
#
# Cluster 310
#   GRAND CENTRAL PKWY ET 21 S EB (x 2)
#   GRAND CENTRAL PKWY ET 21 S  EB (x 1)
#
# Cluster 311
#   EAST 21 STREET (x 88)
#   EAST   21 STREET (x 12)
#
# Cluster 312
#   GOWANUS EXPRESSWAY EXIT 21 EB (x 4)
#   GOWANUS EXPRESSWAY EXIT   21 EB (x 1)
#
# Cluster 313
#   WEST 21 STREET (x 25)
#   WEST   21 STREET (x 2)
#
# Cluster 314
#   EAST 210 STREET (x 1)
#   EAST  210 STREET (x 2)
#
# Cluster 315
#   EAST 211 STREET (x 22)
#   EAST  211 STREET (x 4)
#
# Cluster 316
#   EAST 212 STREET (x 34)
#   EAST  212 STREET (x 7)
#
# Cluster 317
#   LIE EASTBOUND ENTRANCE 212 ST (x 3)
#   LIE EASTBOUND ENTRANCE  212 ST (x 1)
#
# Cluster 318
#   WEST 212 STREET (x 3)
#   WEST  212 STREET (x 1)
#
# Cluster 319
#   EAST 213 STREET (x 47)
#   EAST  213 STREET (x 3)
#
# Cluster 320
#   WEST 213 STREET (x 7)
#   WEST  213 STREET (x 1)
#
# Cluster 321
#   EAST 214 STREET (x 16)
#   EAST  214 STREET (x 2)
#
# Cluster 322
#   WEST 214 STREET (x 23)
#   WEST  214 STREET (x 2)
#
# Cluster 323
#   WEST 215 STREET (x 32)
#   WEST  215 STREET (x 4)
#
# Cluster 324
#   EAST 216 STREET (x 30)
#   EAST  216 STREET (x 2)
#
# Cluster 325
#   219 ST E (x 2)
#   E 219 ST (x 1)
#
# Cluster 326
#   EAST  219 STREET (x 3)
#   EAST 219 STREET (x 8)
#
# Cluster 327
#   BAY 22 STREET (x 11)
#   BAY   22 STREET (x 2)
#
# Cluster 328
#   BEACH 22 STREET (x 36)
#   BEACH   22 STREET (x 5)
#
# Cluster 329
#   LONG ISLAND EXPWY ET 22 D EB (x 3)
#   LONG ISLAND EXPWY ET 22 D  EB (x 1)
#
# Cluster 330
#   EAST 22 STREET (x 57)
#   EAST   22 STREET (x 6)
#
# Cluster 331
#   WEST 22 STREET (x 15)
#   WEST   22 STREET (x 1)
#
# Cluster 332
#   EAST  220 STREET (x 1)
#   EAST 220 STREET (x 6)
#
# Cluster 333
#   E 221 ST (x 3)
#   221 ST E (x 1)
#
# Cluster 334
#   EAST  221 STREET (x 1)
#   EAST 221 STREET (x 4)
#
# Cluster 335
#   E 222 ST (x 5)
#   222 ST E (x 1)
#
# Cluster 336
#   EAST 223 STREET (x 19)
#   EAST  223 STREET (x 1)
#
# Cluster 337
#   EAST 224 STREET (x 22)
#   EAST  224 STREET (x 2)
#
# Cluster 338
#   EAST 225 STREET (x 18)
#   EAST  225 STREET (x 2)
#
# Cluster 339
#   WEST 225 STREET (x 66)
#   WEST  225 STREET (x 4)
#
# Cluster 340
#   EAST 226 STREET (x 27)
#   EAST  226 STREET (x 1)
#
# Cluster 341
#   EAST 227 STREET (x 33)
#   EAST  227 STREET (x 3)
#
# Cluster 342
#   WEST 227 STREET (x 21)
#   WEST  227 STREET (x 3)
#
# Cluster 343
#   EAST 228 STREET (x 32)
#   EAST  228 STREET (x 2)
#
# Cluster 344
#   WEST  228 STREET (x 2)
#   WEST 228 STREET (x 6)
#
# Cluster 345
#   EAST 229 STREET (x 16)
#   EAST  229 STREET (x 1)
#
# Cluster 346
#   WEST 229 STREET (x 23)
#   WEST  229 STREET (x 6)
#
# Cluster 347
#   EAST 23 STREET (x 70)
#   EAST   23 STREET (x 9)
#
# Cluster 348
#   WEST 23 STREET (x 21)
#   WEST   23 STREET (x 1)
#
# Cluster 349
#   W 230 ST (x 5)
#   230 ST W (x 2)
#
# Cluster 350
#   WEST 230 STREET (x 36)
#   WEST  230 STREET (x 5)
#
# Cluster 351
#   WEST 231 STREET (x 24)
#   WEST  231 STREET (x 2)
#
# Cluster 352
#   EAST 232 STREET (x 6)
#   EAST  232 STREET (x 4)
#
# Cluster 353
#   W 232 ST (x 4)
#   232 ST W (x 1)
#
# Cluster 354
#   E 233 ST (x 20)
#   233 ST E (x 3)
#
# Cluster 355
#   EAST  233 STREET (x 9)
#   EAST 233 STREET (x 88)
#
# Cluster 356
#   WEST 233 STREET (x 16)
#   WEST  233 STREET (x 2)
#
# Cluster 357
#   EAST 234 STREET (x 11)
#   EAST  234 STREET (x 1)
#
# Cluster 358
#   W 234 ST (x 6)
#   234 ST W (x 1)
#
# Cluster 359
#   WEST 234 STREET (x 39)
#   WEST  234 STREET (x 3)
#
# Cluster 360
#   WEST 235 STREET (x 18)
#   WEST  235 STREET (x 2)
#
# Cluster 361
#   E 236 ST (x 9)
#   236 ST E (x 2)
#
# Cluster 362
#   EAST 236 STREET (x 50)
#   EAST  236 STREET (x 6)
#
# Cluster 363
#   W 236 ST (x 5)
#   236 ST W (x 1)
#
# Cluster 364
#   WEST 236 STREET (x 60)
#   WEST  236 STREET (x 3)
#
# Cluster 365
#   WEST 238 STREET (x 92)
#   WEST  238 STREET (x 6)
#
# Cluster 366
#   E 239 ST (x 3)
#   239 ST E (x 1)
#
# Cluster 367
#   EAST 239 STREET (x 28)
#   EAST  239 STREET (x 3)
#
# Cluster 368
#   239 ST W (x 1)
#   W 239 ST (x 1)
#
# Cluster 369
#   EAST 24 STREET (x 43)
#   EAST   24 STREET (x 3)
#
# Cluster 370
#   WEST   24 STREET (x 4)
#   WEST 24 STREET (x 25)
#
# Cluster 371
#   EAST 240 STREET (x 31)
#   EAST  240 STREET (x 1)
#
# Cluster 372
#   240 ST W (x 1)
#   W 240 ST (x 1)
#
# Cluster 373
#   EAST 241 STREET (x 36)
#   EAST  241 STREET (x 4)
#
# Cluster 374
#   EAST 242 STREET (x 9)
#   EAST  242 STREET (x 1)
#
# Cluster 375
#   WEST  242 STREET (x 1)
#   WEST 242 STREET (x 7)
#
# Cluster 376
#   BAY 25 STREET (x 36)
#   BAY   25 STREET (x 2)
#
# Cluster 377
#   E 25 ST (x 5)
#   25 ST E (x 1)
#
# Cluster 378
#   EAST 25 STREET (x 34)
#   EAST   25 STREET (x 7)
#
# Cluster 379
#   WEST 25 STREET (x 20)
#   WEST   25 STREET (x 4)
#
# Cluster 380
#   WEST  250 STREET (x 1)
#   WEST 250 STREET (x 2)
#
# Cluster 381
#   WEST 251 STREET (x 12)
#   WEST  251 STREET (x 1)
#
# Cluster 382
#   W 252 ST (x 1)
#   252 ST W (x 1)
#
# Cluster 383
#   WEST 252 STREET (x 4)
#   WEST  252 STREET (x 3)
#
# Cluster 384
#   WEST 254 STREET (x 12)
#   WEST  254 STREET (x 4)
#
# Cluster 385
#   WEST  255 STREET (x 2)
#   WEST 255 STREET (x 8)
#
# Cluster 386
#   WEST 256 STREET (x 9)
#   WEST  256 STREET (x 1)
#
# Cluster 387
#   259 ST W (x 1)
#   W 259 ST (x 2)
#
# Cluster 388
#   WEST 259 STREET (x 11)
#   WEST  259 STREET (x 1)
#
# Cluster 389
#   EAST   26 STREET (x 11)
#   EAST 26 STREET (x 85)
#
# Cluster 390
#   GOWANUS EXPRESSWAY EXIT   26 EB (x 2)
#   GOWANUS EXPRESSWAY EXIT 26 EB (x 1)
#
# Cluster 391
#   WEST 26 STREET (x 21)
#   WEST   26 STREET (x 2)
#
# Cluster 392
#   WEST 261 STREET (x 26)
#   WEST  261 STREET (x 5)
#
# Cluster 393
#   WEST 262 STREET (x 4)
#   WEST  262 STREET (x 1)
#
# Cluster 394
#   WEST   27 DRIVE (x 1)
#   WEST 27 DRIVE (x 1)
#
# Cluster 395
#   E 27 ST (x 12)
#   27 ST E (x 1)
#
# Cluster 396
#   EAST 27 STREET (x 56)
#   EAST   27 STREET (x 7)
#
# Cluster 397
#   WEST 27 STREET (x 25)
#   WEST   27 STREET (x 2)
#
# Cluster 398
#   BAY 28 STREET (x 11)
#   BAY   28 STREET (x 1)
#
# Cluster 399
#   E 28 ST (x 14)
#   28 ST E (x 1)
#
# Cluster 400
#   EAST 28 STREET (x 101)
#   EAST   28 STREET (x 14)
#
# Cluster 401
#   WEST 28 STREET (x 14)
#   WEST   28 STREET (x 6)
#
# Cluster 402
#   EAST 29 STREET (x 64)
#   EAST   29 STREET (x 5)
#
# Cluster 403
#   LONG ISLAND EXPWY ET 29 WB (x 1)
#   LONG ISLAND EXPWY ET 29   WB (x 1)
#
# Cluster 404
#   WEST 29 STREET (x 37)
#   WEST   29 STREET (x 4)
#
# Cluster 405
#   BRIGHTON 3 STREET (x 9)
#   BRIGHTON    3 STREET (x 2)
#
# Cluster 406
#   E 3 ST (x 16)
#   3 ST E (x 1)
#
# Cluster 407
#   EAST 3 STREET (x 132)
#   EAST    3 STREET (x 10)
#
# Cluster 408
#   NORTH 3 STREET (x 6)
#   NORTH    3 STREET (x 2)
#
# Cluster 409
#   SOUTH 3 STREET (x 18)
#   SOUTH    3 STREET (x 2)
#
# Cluster 410
#   WEST 3 STREET (x 26)
#   WEST    3 STREET (x 4)
#
# Cluster 411
#   EAST 30 STREET (x 37)
#   EAST   30 STREET (x 3)
#
# Cluster 412
#   WEST   30 STREET (x 4)
#   WEST 30 STREET (x 13)
#
# Cluster 413
#   BAY   31 STREET (x 1)
#   BAY 31 STREET (x 13)
#
# Cluster 414
#   EAST 31 STREET (x 82)
#   EAST   31 STREET (x 5)
#
# Cluster 415
#   WEST 31 STREET (x 7)
#   WEST   31 STREET (x 2)
#
# Cluster 416
#   BROOKLYN QUEENS EP ET   32 B WB (x 1)
#   BROOKLYN QUEENS EP ET 32 B WB (x 1)
#
# Cluster 417
#   BAY 32 STREET (x 6)
#   BAY   32 STREET (x 4)
#
# Cluster 418
#   EAST 32 STREET (x 76)
#   EAST   32 STREET (x 7)
#
# Cluster 419
#   WEST 32 STREET (x 18)
#   WEST   32 STREET (x 3)
#
# Cluster 420
#   GRAND CENTRAL PKWY EB EN 33 ST (x 6)
#   GRAND CENTRAL PKWY EB EN   33 ST (x 1)
#
# Cluster 421
#   EAST 33 STREET (x 34)
#   EAST   33 STREET (x 5)
#
# Cluster 422
#   WEST 33 STREET (x 16)
#   WEST   33 STREET (x 6)
#
# Cluster 423
#   E 34 ST (x 11)
#   34 ST E (x 1)
#
# Cluster 424
#   EAST 34 STREET (x 96)
#   EAST   34 STREET (x 9)
#
# Cluster 425
#   WEST 34 STREET (x 22)
#   WEST   34 STREET (x 5)
#
# Cluster 426
#   EAST 35 STREET (x 54)
#   EAST   35 STREET (x 7)
#
# Cluster 427
#   WEST 35 STREET (x 25)
#   WEST   35 STREET (x 1)
#
# Cluster 428
#   EAST   36 STREET (x 7)
#   EAST 36 STREET (x 38)
#
# Cluster 429
#   WEST 36 STREET (x 24)
#   WEST   36 STREET (x 2)
#
# Cluster 430
#   E 37 ST (x 20)
#   37 ST E (x 1)
#
# Cluster 431
#   EAST 37 STREET (x 61)
#   EAST   37 STREET (x 14)
#
# Cluster 432
#   WEST 37 STREET (x 31)
#   WEST   37 STREET (x 4)
#
# Cluster 433
#   EAST 38 STREET (x 57)
#   EAST   38 STREET (x 6)
#
# Cluster 434
#   WEST 38 STREET (x 23)
#   WEST   38 STREET (x 1)
#
# Cluster 435
#   EAST 39 STREET (x 29)
#   EAST   39 STREET (x 6)
#
# Cluster 436
#   S    4 ST EN WILLIAMSBURG BRDG (x 1)
#   S 4 ST EN WILLIAMSBURG BRDG (x 1)
#
# Cluster 437
#   E 4 ST (x 20)
#   4 ST E (x 1)
#
# Cluster 438
#   EAST 4 STREET (x 111)
#   EAST    4 STREET (x 8)
#
# Cluster 439
#   FLATLANDS 4 STREET (x 2)
#   FLATLANDS    4 STREET (x 2)
#
# Cluster 440
#   NORTH 4 PLACE (x 7)
#   NORTH    4 PLACE (x 3)
#
# Cluster 441
#   NORTH 4 STREET (x 8)
#   NORTH    4 STREET (x 3)
#
# Cluster 442
#   SOUTH 4 STREET (x 33)
#   SOUTH    4 STREET (x 3)
#
# Cluster 443
#   WEST 4 STREET (x 82)
#   WEST    4 STREET (x 6)
#
# Cluster 444
#   BAY 40 STREET (x 14)
#   BAY   40 STREET (x 1)
#
# Cluster 445
#   BROOKLYN QUEENS EXPWY ET 40 EB (x 8)
#   BROOKLYN QUEENS EXPWY ET   40 EB (x 1)
#
# Cluster 446
#   EAST 40 STREET (x 46)
#   EAST   40 STREET (x 1)
#
# Cluster 447
#   WEST 40 STREET (x 27)
#   WEST   40 STREET (x 4)
#
# Cluster 448
#   BAY   41 STREET (x 1)
#   BAY 41 STREET (x 3)
#
# Cluster 449
#   BEACH 41 STREET (x 3)
#   BEACH   41 STREET (x 3)
#
# Cluster 450
#   E 41 ST (x 6)
#   41 ST E (x 1)
#
# Cluster 451
#   EAST   41 STREET (x 4)
#   EAST 41 STREET (x 5)
#
# Cluster 452
#   WEST 41 STREET (x 23)
#   WEST   41 STREET (x 5)
#
# Cluster 453
#   EAST 42 STREET (x 32)
#   EAST   42 STREET (x 7)
#
# Cluster 454
#   WEST 42 STREET (x 11)
#   WEST   42 STREET (x 1)
#
# Cluster 455
#   BAY 43 STREET (x 6)
#   BAY   43 STREET (x 1)
#
# Cluster 456
#   BEACH 43 STREET (x 2)
#   BEACH   43 STREET (x 2)
#
# Cluster 457
#   EAST 43 STREET (x 33)
#   EAST   43 STREET (x 2)
#
# Cluster 458
#   WEST 43 STREET (x 28)
#   WEST   43 STREET (x 6)
#
# Cluster 459
#   EAST 44 STREET (x 15)
#   EAST   44 STREET (x 3)
#
# Cluster 460
#   WEST 44 STREET (x 24)
#   WEST   44 STREET (x 6)
#
# Cluster 461
#   EAST 45 STREET (x 45)
#   EAST   45 STREET (x 5)
#
# Cluster 462
#   BAY 46 STREET (x 12)
#   BAY   46 STREET (x 1)
#
# Cluster 463
#   EAST 46 STREET (x 57)
#   EAST   46 STREET (x 3)
#
# Cluster 464
#   WEST 46 STREET (x 23)
#   WEST   46 STREET (x 6)
#
# Cluster 465
#   BEACH 47 STREET (x 1)
#   BEACH   47 STREET (x 1)
#
# Cluster 466
#   WEST   47 STREET BIKE PATH (x 2)
#   WEST 47 STREET BIKE PATH (x 1)
#
# Cluster 467
#   EAST   47 STREET (x 2)
#   EAST 47 STREET (x 11)
#
# Cluster 468
#   WEST 47 STREET (x 27)
#   WEST   47 STREET (x 5)
#
# Cluster 469
#   BAY 48 STREET (x 2)
#   BAY   48 STREET (x 1)
#
# Cluster 470
#   EAST 48 STREET (x 47)
#   EAST   48 STREET (x 9)
#
# Cluster 471
#   WEST 48 STREET (x 39)
#   WEST   48 STREET (x 5)
#
# Cluster 472
#   BAY   49 STREET (x 2)
#   BAY 49 STREET (x 3)
#
# Cluster 473
#   EAST 49 STREET (x 33)
#   EAST   49 STREET (x 3)
#
# Cluster 474
#   WEST 49 STREET (x 30)
#   WEST   49 STREET (x 3)
#
# Cluster 475
#   WILLIAMSBURG BRIDGE ET S 5 ST (x 4)
#   WILLIAMSBURG BRIDGE ET S    5 ST (x 2)
#
# Cluster 476
#   BRIGHTON 5 STREET (x 5)
#   BRIGHTON    5 STREET (x 1)
#
# Cluster 477
#   FDR DRIVE EXIT 5 SOUTHBOUND (x 2)
#   FDR DRIVE SOUTHBOUND EXIT 5 (x 1)
#
# Cluster 478
#   EAST 5 STREET (x 64)
#   EAST    5 STREET (x 6)
#
# Cluster 479
#   PROSPECT EXPRESSWAY EXIT 5 EB (x 1)
#   PROSPECT EXPRESSWAY EXIT    5 EB (x 1)
#
# Cluster 480
#   NORTH 5 STREET (x 10)
#   NORTH    5 STREET (x 1)
#
# Cluster 481
#   WEST 5 STREET (x 35)
#   WEST    5 STREET (x 8)
#
# Cluster 482
#   EAST   50 STREET (x 2)
#   EAST 50 STREET (x 24)
#
# Cluster 483
#   WEST 50 STREET (x 30)
#   WEST   50 STREET (x 3)
#
# Cluster 484
#   EAST 51 STREET (x 69)
#   EAST   51 STREET (x 8)
#
# Cluster 485
#   WEST 51 STREET (x 34)
#   WEST   51 STREET (x 4)
#
# Cluster 486
#   EAST   52 STREET (x 6)
#   EAST 52 STREET (x 45)
#
# Cluster 487
#   WEST 52 STREET (x 26)
#   WEST   52 STREET (x 3)
#
# Cluster 488
#   EAST 53 STREET (x 52)
#   EAST   53 STREET (x 5)
#
# Cluster 489
#   WEST 53 STREET (x 29)
#   WEST   53 STREET (x 5)
#
# Cluster 490
#   BEACH 54 STREET (x 13)
#   BEACH   54 STREET (x 2)
#
# Cluster 491
#   EAST 54 STREET (x 45)
#   EAST   54 STREET (x 8)
#
# Cluster 492
#   WEST 54 STREET (x 27)
#   WEST   54 STREET (x 8)
#
# Cluster 493
#   EAST 55 STREET (x 42)
#   EAST   55 STREET (x 6)
#
# Cluster 494
#   EAST 56 STREET (x 33)
#   EAST   56 STREET (x 9)
#
# Cluster 495
#   WEST 56 STREET (x 13)
#   WEST   56 STREET (x 1)
#
# Cluster 496
#   EAST 57 STREET (x 41)
#   EAST   57 STREET (x 2)
#
# Cluster 497
#   W 57 ST (x 14)
#   57 ST W (x 1)
#
# Cluster 498
#   WEST 57 STREET (x 22)
#   WEST   57 STREET (x 6)
#
# Cluster 499
#   EAST 58 STREET (x 37)
#   EAST   58 STREET (x 9)
#
# Cluster 500
#   EAST 59 STREET (x 19)
#   EAST   59 STREET (x 2)
#
# Cluster 501
#   BEACH 6 STREET (x 30)
#   BEACH    6 STREET (x 3)
#
# Cluster 502
#   EAST    6 ROAD (x 1)
#   EAST 6 ROAD (x 1)
#
# Cluster 503
#   EAST 6 STREET (x 51)
#   EAST    6 STREET (x 7)
#
# Cluster 504
#   KINGSBOROUGH 6 WALK (x 1)
#   KINGSBOROUGH    6 WALK (x 1)
#
# Cluster 505
#   NORTH    6 PLACE (x 2)
#   NORTH 6 PLACE (x 1)
#
# Cluster 506
#   NORTH 6 STREET (x 13)
#   NORTH    6 STREET (x 2)
#
# Cluster 507
#   EAST 60 PLACE (x 2)
#   EAST   60 PLACE (x 2)
#
# Cluster 508
#   EAST   60 STREET (x 5)
#   EAST 60 STREET (x 12)
#
# Cluster 509
#   WEST   60 STREET (x 8)
#   WEST 60 STREET (x 5)
#
# Cluster 510
#   EAST 61 STREET (x 17)
#   EAST   61 STREET (x 2)
#
# Cluster 511
#   EAST 62 STREET (x 20)
#   EAST   62 STREET (x 3)
#
# Cluster 512
#   BEACH 63 STREET (x 2)
#   BEACH   63 STREET (x 1)
#
# Cluster 513
#   EAST 63 STREET (x 19)
#   EAST   63 STREET (x 3)
#
# Cluster 514
#   WEST 63 STREET (x 17)
#   WEST   63 STREET (x 2)
#
# Cluster 515
#   EAST 64 STREET (x 23)
#   EAST   64 STREET (x 4)
#
# Cluster 516
#   WEST 64 STREET (x 17)
#   WEST   64 STREET (x 1)
#
# Cluster 517
#   EAST 65 STREET (x 17)
#   EAST   65 STREET (x 2)
#
# Cluster 518
#   WEST 65 STREET (x 8)
#   WEST   65 STREET (x 3)
#
# Cluster 519
#   EAST 66 STREET (x 23)
#   EAST   66 STREET (x 3)
#
# Cluster 520
#   WEST 66 STREET (x 27)
#   WEST   66 STREET (x 3)
#
# Cluster 521
#   BEACH 67 STREET (x 3)
#   BEACH   67 STREET (x 1)
#
# Cluster 522
#   EAST 67 STREET (x 9)
#   EAST   67 STREET (x 3)
#
# Cluster 523
#   WEST 67 STREET (x 20)
#   WEST   67 STREET (x 1)
#
# Cluster 524
#   I 678 (x 21)
#   I  678 (x 1)
#
# Cluster 525
#   BEACH 68 STREET (x 2)
#   BEACH   68 STREET (x 1)
#
# Cluster 526
#   EAST   68 STREET (x 9)
#   EAST 68 STREET (x 19)
#
# Cluster 527
#   W 68 ST (x 5)
#   68 ST W (x 1)
#
# Cluster 528
#   WEST 68 STREET (x 19)
#   WEST   68 STREET (x 2)
#
# Cluster 529
#   BEACH 69 STREET (x 20)
#   BEACH   69 STREET (x 2)
#
# Cluster 530
#   EAST 69 STREET (x 16)
#   EAST   69 STREET (x 1)
#
# Cluster 531
#   WEST 69 STREET (x 17)
#   WEST   69 STREET (x 1)
#
# Cluster 532
#   BEACH 7 STREET (x 2)
#   BEACH    7 STREET (x 1)
#
# Cluster 533
#   BRIGHTON 7 STREET (x 6)
#   BRIGHTON    7 STREET (x 1)
#
# Cluster 534
#   E 7 ST (x 18)
#   7 ST E (x 1)
#
# Cluster 535
#   EAST 7 STREET (x 110)
#   EAST    7 STREET (x 9)
#
# Cluster 536
#   STATEN ISLAND EXPWY ET 7 EB (x 4)
#   STATEN ISLAND EXPWY ET 7  EB (x 1)
#
# Cluster 537
#   EAST 70 STREET (x 17)
#   EAST   70 STREET (x 2)
#
# Cluster 538
#   WEST 70 STREET (x 13)
#   WEST   70 STREET (x 1)
#
# Cluster 539
#   EAST 71 STREET (x 19)
#   EAST   71 STREET (x 2)
#
# Cluster 540
#   WEST 71 STREET (x 10)
#   WEST   71 STREET (x 2)
#
# Cluster 541
#   BEACH 72 STREET (x 6)
#   BEACH   72 STREET (x 1)
#
# Cluster 542
#   EAST 72 STREET (x 39)
#   EAST   72 STREET (x 4)
#
# Cluster 543
#   WEST 72 STREET (x 10)
#   WEST   72 STREET (x 1)
#
# Cluster 544
#   EAST 73 STREET (x 25)
#   EAST   73 STREET (x 4)
#
# Cluster 545
#   WEST 73 STREET (x 10)
#   WEST   73 STREET (x 1)
#
# Cluster 546
#   BEACH 74 STREET (x 6)
#   BEACH   74 STREET (x 1)
#
# Cluster 547
#   EAST 74 STREET (x 19)
#   EAST   74 STREET (x 1)
#
# Cluster 548
#   WEST 74 STREET (x 18)
#   WEST   74 STREET (x 2)
#
# Cluster 549
#   EAST 75 STREET (x 25)
#   EAST   75 STREET (x 1)
#
# Cluster 550
#   WEST 75 STREET (x 8)
#   WEST   75 STREET (x 2)
#
# Cluster 551
#   EAST 76 STREET (x 31)
#   EAST   76 STREET (x 6)
#
# Cluster 552
#   WEST 76 STREET (x 10)
#   WEST   76 STREET (x 1)
#
# Cluster 553
#   BEACH 77 STREET (x 2)
#   BEACH   77 STREET (x 1)
#
# Cluster 554
#   GRAND CENTRAL PKWY EB EN 77 ST (x 2)
#   GRAND CENTRAL PKWY EB EN   77 ST (x 1)
#
# Cluster 555
#   EAST 77 STREET (x 33)
#   EAST   77 STREET (x 6)
#
# Cluster 556
#   WEST 77 STREET (x 17)
#   WEST   77 STREET (x 1)
#
# Cluster 557
#   EAST 78 STREET (x 24)
#   EAST   78 STREET (x 3)
#
# Cluster 558
#   EAST   79 STREET (x 4)
#   EAST 79 STREET (x 16)
#
# Cluster 559
#   WEST 79 STREET (x 5)
#   WEST   79 STREET (x 1)
#
# Cluster 560
#   BRIGHTON 8 STREET (x 4)
#   BRIGHTON    8 STREET (x 1)
#
# Cluster 561
#   MAJOR DEEGAN EXPWY ET 8 NB (x 3)
#   MAJOR DEEGAN EXPWY ET    8 NB (x 2)
#
# Cluster 562
#   E 8 ST (x 16)
#   8 ST E (x 1)
#
# Cluster 563
#   EAST 8 STREET (x 100)
#   EAST    8 STREET (x 7)
#
# Cluster 564
#   NORTH 8 STREET (x 33)
#   NORTH    8 STREET (x 2)
#
# Cluster 565
#   SOUTH 8 STREET (x 5)
#   SOUTH    8 STREET (x 1)
#
# Cluster 566
#   WEST 8 STREET (x 7)
#   WEST    8 STREET (x 3)
#
# Cluster 567
#   EAST 80 STREET (x 23)
#   EAST   80 STREET (x 6)
#
# Cluster 568
#   WEST 80 STREET (x 12)
#   WEST   80 STREET (x 2)
#
# Cluster 569
#   BEACH 81 STREET (x 11)
#   BEACH   81 STREET (x 1)
#
# Cluster 570
#   EAST 81 STREET (x 50)
#   EAST   81 STREET (x 8)
#
# Cluster 571
#   EAST 82 STREET (x 23)
#   EAST   82 STREET (x 3)
#
# Cluster 572
#   WEST 82 STREET (x 16)
#   WEST   82 STREET (x 4)
#
# Cluster 573
#   E 83 ST (x 16)
#   83 ST E (x 1)
#
# Cluster 574
#   EAST 83 STREET (x 23)
#   EAST   83 STREET (x 5)
#
# Cluster 575
#   WEST 83 STREET (x 25)
#   WEST   83 STREET (x 1)
#
# Cluster 576
#   EAST 84 STREET (x 51)
#   EAST   84 STREET (x 5)
#
# Cluster 577
#   WEST 84 STREET (x 23)
#   WEST   84 STREET (x 3)
#
# Cluster 578
#   EAST 85 STREET (x 29)
#   EAST   85 STREET (x 1)
#
# Cluster 579
#   WEST   85 STREET (x 6)
#   WEST 85 STREET (x 19)
#
# Cluster 580
#   BEACH 86 STREET (x 1)
#   BEACH   86 STREET (x 2)
#
# Cluster 581
#   EAST 86 STREET (x 34)
#   EAST   86 STREET (x 5)
#
# Cluster 582
#   EAST 87 STREET (x 38)
#   EAST   87 STREET (x 2)
#
# Cluster 583
#   WEST 87 STREET (x 16)
#   WEST   87 STREET (x 2)
#
# Cluster 584
#   BEACH 88 STREET (x 2)
#   BEACH   88 STREET (x 1)
#
# Cluster 585
#   EAST 88 STREET (x 48)
#   EAST   88 STREET (x 4)
#
# Cluster 586
#   WEST 88 STREET (x 18)
#   WEST   88 STREET (x 4)
#
# Cluster 587
#   EAST   89 STREET (x 4)
#   EAST 89 STREET (x 36)
#
# Cluster 588
#   WEST   89 STREET (x 2)
#   WEST 89 STREET (x 10)
#
# Cluster 589
#   BEACH 9 STREET (x 6)
#   BEACH    9 STREET (x 2)
#
# Cluster 590
#   BELT PARKWAY EXIT 9 EASTBOUND (x 6)
#   BELT PARKWAY EXIT    9 EASTBOUND (x 1)
#
# Cluster 591
#   BELT PARKWAY WESTBOUND EXIT 9 (x 1)
#   BELT PARKWAY EXIT 9 WESTBOUND (x 4)
#
# Cluster 592
#   E 9 ST (x 25)
#   9 ST E (x 1)
#
# Cluster 593
#   EAST 9 STREET (x 106)
#   EAST    9 STREET (x 12)
#
# Cluster 594
#   NORTH 9 STREET (x 16)
#   NORTH    9 STREET (x 1)
#
# Cluster 595
#   9 ST S (x 1)
#   S 9 ST (x 4)
#
# Cluster 596
#   SOUTH    9 STREET (x 4)
#   SOUTH 9 STREET (x 30)
#
# Cluster 597
#   WEST 9 STREET (x 33)
#   WEST    9 STREET (x 2)
#
# Cluster 598
#   BEACH 90 STREET (x 3)
#   BEACH   90 STREET (x 1)
#
# Cluster 599
#   EAST   90 STREET (x 4)
#   EAST 90 STREET (x 15)
#
# Cluster 600
#   WEST 90 STREET (x 16)
#   WEST   90 STREET (x 3)
#
# Cluster 601
#   EAST 91 STREET (x 51)
#   EAST   91 STREET (x 6)
#
# Cluster 602
#   WEST 91 STREET (x 13)
#   WEST   91 STREET (x 1)
#
# Cluster 603
#   BEACH 92 STREET (x 6)
#   BEACH   92 STREET (x 2)
#
# Cluster 604
#   EAST 92 STREET (x 48)
#   EAST   92 STREET (x 7)
#
# Cluster 605
#   WEST 92 STREET (x 21)
#   WEST   92 STREET (x 4)
#
# Cluster 606
#   BEACH   93 STREET (x 3)
#   BEACH 93 STREET (x 1)
#
# Cluster 607
#   EAST 93 STREET (x 40)
#   EAST   93 STREET (x 8)
#
# Cluster 608
#   WEST 93 STREET (x 14)
#   WEST   93 STREET (x 1)
#
# Cluster 609
#   EAST 94 STREET (x 62)
#   EAST   94 STREET (x 10)
#
# Cluster 610
#   WEST 94 STREET (x 19)
#   WEST   94 STREET (x 4)
#
# Cluster 611
#   E 95 ST (x 16)
#   95 ST E (x 1)
#
# Cluster 612
#   EAST 95 STREET (x 91)
#   EAST   95 STREET (x 5)
#
# Cluster 613
#   EAST 96 STREET (x 40)
#   EAST   96 STREET (x 8)
#
# Cluster 614
#   WEST 96 STREET (x 15)
#   WEST   96 STREET (x 1)
#
# Cluster 615
#   EAST 97 STREET (x 32)
#   EAST   97 STREET (x 4)
#
# Cluster 616
#   WEST 97 STREET (x 28)
#   WEST   97 STREET (x 6)
#
# Cluster 617
#   EAST   98 STREET (x 9)
#   EAST 98 STREET (x 29)
#
# Cluster 618
#   W 98 ST (x 2)
#   98 ST W (x 1)
#
# Cluster 619
#   WEST 98 STREET (x 16)
#   WEST   98 STREET (x 3)
#
# Cluster 620
#   BEACH   99 STREET (x 1)
#   BEACH 99 STREET (x 1)
#
# Cluster 621
#   EAST 99 STREET (x 25)
#   EAST   99 STREET (x 3)
#
# Cluster 622
#   ST ANNS AVE (x 7)
#   ST ANN'S AVE (x 2)
#
# Cluster 623
#   ST ANNS AVENUE (x 64)
#   ST ANN'S AVENUE (x 1)
#
# Cluster 624
#   ST AUSTINS PLACE SOUTH (x 2)
#   SOUTH ST AUSTINS PLACE (x 1)
#
# Cluster 625
#   BAY AVE E (x 1)
#   E BAY AVE (x 2)
#
# Cluster 626
#   E TREMONT AVE (x 19)
#   TREMONT AVE E (x 1)
#
# Cluster 627
#   S GANNON AVE (x 6)
#   GANNON AVE S (x 1)
#
# Cluster 628
#   AVE M (x 9)
#   M AVE (x 1)
#
# Cluster 629
#   ST MARKS AVE (x 13)
#   ST MARK'S AVE (x 3)
#
# Cluster 630
#   OCONNOR AVE (x 1)
#   O'CONNOR AVE (x 1)
#
# Cluster 631
#   ST RAYMOND'S AVE (x 3)
#   ST RAYMONDS AVE (x 1)
#
# Cluster 632
#   AVE U (x 7)
#   U AVE (x 1)
#
# Cluster 633
#   AVE X (x 6)
#   X AVE (x 1)
#
# Cluster 634
#   AVENUE C (x 308)
#   C AVENUE (x 2)
#
# Cluster 635
#   AVENUE ST JOHN (x 31)
#   ST JOHN AVENUE (x 1)
#
# Cluster 636
#   AVENUE K (x 342)
#   K AVENUE (x 1)
#
# Cluster 637
#   ST MARKS AVENUE (x 71)
#   ST MARK'S AVENUE (x 11)
#
# Cluster 638
#   ST PAULS AVENUE (x 11)
#   ST PAUL'S AVENUE (x 1)
#
# Cluster 639
#   ST PETERS AVENUE (x 28)
#   ST PETER'S AVENUE (x 4)
#
# Cluster 640
#   ST RAYMONDS AVENUE (x 12)
#   ST RAYMOND'S AVENUE (x 2)
#
# Cluster 641
#   AVENUE T (x 446)
#   T AVENUE (x 1)
#
# Cluster 642
#   ST MARYS CEMETERY BOUNDARY (x 4)
#   ST MARY'S CEMETERY BOUNDARY (x 1)
#
# Cluster 643
#   THOMAS S BOYLAND ST (x 2)
#   THOMAS S. BOYLAND ST (x 1)
#
# Cluster 644
#   CLARKE PLACE WEST (x 6)
#   WEST CLARKE PLACE (x 1)
#
# Cluster 645
#   ST PAULS COURT (x 11)
#   ST PAUL'S COURT (x 2)
#
# Cluster 646
#   ST GEORGE'S CRESCENT (x 2)
#   ST GEORGES CRESCENT (x 1)
#
# Cluster 647
#   E HOUSTON ST (x 9)
#   HOUSTON ST E (x 1)
#
# Cluster 648
#   GRAND ST EXTENSION (x 3)
#   GRAND EXTENSION ST (x 1)
#
# Cluster 649
#   ST JOHN'S PL (x 2)
#   ST JOHNS PL (x 11)
#
# Cluster 650
#   ST JOHNS PLACE (x 101)
#   ST JOHN'S PLACE (x 17)
#
# Cluster 651
#   ST MARKS PL (x 7)
#   ST MARK'S PL (x 1)
#
# Cluster 652
#   ST MARKS PLACE (x 37)
#   ST MARK'S PLACE (x 2)
#
# Cluster 653
#   MARY ST (x 1)
#   ST MARY ST (x 1)
#
# Cluster 654
#   ST MARYS STREET (x 4)
#   ST MARY'S STREET (x 1)
#
# Cluster 655
#   ST PAULS PLACE (x 75)
#   ST PAUL'S PLACE (x 14)
#
# Cluster 656
#   ST PETERS PLACE (x 3)
#   ST PETER'S PLACE (x 1)

# %%
final_cs1 = {}
for key,value in cross_street_1_dict.items():
    final_cs1[key] = max(value, key=value.get)

# %%
for index, row in df.iterrows():
    if row['Cross Street 1'] in cluster_dict:
        df.at[index, 'Cross Street 1'] = final_cs1[cluster_dict[row['Cross Street 1']]]

# %% [markdown]
# #### Updating the Cross Street2 column using clustering

# %%
cross_street_2 = ds.update('Cross Street 2', str.upper).distinct('Cross Street 2')
clusters = KeyCollision(func=Fingerprint(), threads=3).clusters(cross_street_2)

# %%
cross_street_2_dict = {}
cluster_dict = {}
def print_k_clusters_and_integrate_cs2(clusters):
    clusters = sorted(clusters, key=lambda x: len(x), reverse=True)
    val_count = sum([len(c) for c in clusters])
    print('Total number of clusters is {} with {} values'.format(len(clusters), val_count))
    for i in range(len(clusters)):
        print('\nCluster {}'.format(i + 1))
        temp_dict = {}
        for key, cnt in clusters[i].items():
          if key == '':
            key = "''"
          print(f'  {key} (x {cnt})')

          temp_dict[key] = int(cnt)
          cluster_dict[key] = i
        cross_street_2_dict[i] = temp_dict

print_k_clusters_and_integrate_cs2(clusters)
# Out:
# Total number of clusters is 673 with 1351 values
#
# Cluster 1
#   LONG ISLAND EXPWY ET   19 WB (x 1)
#   LONG ISLAND EXPWY ET 19 WB (x 3)
#   LONG ISLAND EXPWY ET 19  WB (x 1)
#
# Cluster 2
#   HARLEM RIVER DRIVE EXIT 21 NB (x 13)
#   HARLEM RIVER DRIVE EXIT   21 NB (x 1)
#   HARLEM RIVER DRIVE NB EXIT 21 (x 3)
#
# Cluster 3
#   GOWANUS EXPRESSWAY EXIT 22 WB (x 26)
#   GOWANUS EXPRESSWAY WB EXIT 22 (x 4)
#   GOWANUS EXPRESSWAY EXIT   22 WB (x 1)
#
# Cluster 4
#   HARLEM RIVER DRIVE EXIT 23 SB (x 18)
#   HARLEM RIVER DRIVE EXIT   23 SB (x 2)
#   HARLEM RIVER DRIVE EXIT 23  SB (x 1)
#
# Cluster 5
#   CROSS BRONX EXPWY ET 4 A  EB (x 1)
#   CROSS BRONX EXPWY ET 4 A   EB (x 1)
#   CROSS BRONX EXPWY ET 4 A EB (x 1)
#
# Cluster 6
#   '' (x 110144)
#   ???????????????????????????? (x 13)
#
# Cluster 7
#   CROSS BRONX EXPWY NB ET 1 A (x 18)
#   CROSS BRONX EXPWY NB ET    1 A (x 1)
#
# Cluster 8
#   CROSS BRONX EXPWY SB ET    1 A (x 1)
#   CROSS BRONX EXPWY SB ET 1 A (x 5)
#
# Cluster 9
#   CROSS BRONX EXPWY NB ET 1 B (x 3)
#   CROSS BRONX EXPWY NB ET    1 B (x 1)
#
# Cluster 10
#   BRIGHTON 1 TERRACE (x 3)
#   BRIGHTON    1 TERRACE (x 1)
#
# Cluster 11
#   BRONX RIVER PARKWAY EXIT 1 SB (x 11)
#   BRONX RIVER PARKWAY EXIT    1 SB (x 1)
#
# Cluster 12
#   MAJOR DEEGAN EXPWY ET 1 SB (x 1)
#   MAJOR DEEGAN EXPWY SB ET 1 (x 1)
#
# Cluster 13
#   EAST 1 STREET (x 43)
#   EAST    1 STREET (x 5)
#
# Cluster 14
#   W SHORE EXPRESSWAY EXIT 1 SB (x 3)
#   W SHORE EXPRESSWAY EXIT    1 SB (x 1)
#
# Cluster 15
#   NORTH    1 STREET (x 1)
#   NORTH 1 STREET (x 4)
#
# Cluster 16
#   PAERDEGAT 1 STREET (x 6)
#   PAERDEGAT    1 STREET (x 1)
#
# Cluster 17
#   PLUMB 1 STREET (x 2)
#   PLUMB    1 STREET (x 2)
#
# Cluster 18
#   SOUTH 1 STREET (x 27)
#   SOUTH    1 STREET (x 2)
#
# Cluster 19
#   BRIGHTON 10 TERRACE (x 5)
#   BRIGHTON   10 TERRACE (x 1)
#
# Cluster 20
#   EAST 10 STREET (x 97)
#   EAST   10 STREET (x 12)
#
# Cluster 21
#   NEW ENGLAND THRWY EXIT 10  NB (x 1)
#   NEW ENGLAND THRWY EXIT 10 NB (x 2)
#
# Cluster 22
#   NORTH 10 STREET (x 18)
#   NORTH   10 STREET (x 1)
#
# Cluster 23
#   SOUTH   10 STREET (x 3)
#   SOUTH 10 STREET (x 10)
#
# Cluster 24
#   WEST   10 STREET (x 6)
#   WEST 10 STREET (x 38)
#
# Cluster 25
#   BEACH  100 STREET (x 1)
#   BEACH 100 STREET (x 2)
#
# Cluster 26
#   EAST 100 STREET (x 23)
#   EAST  100 STREET (x 2)
#
# Cluster 27
#   WEST 100 STREET (x 20)
#   WEST  100 STREET (x 4)
#
# Cluster 28
#   EAST 101 STREET (x 24)
#   EAST  101 STREET (x 1)
#
# Cluster 29
#   EAST 102 STREET (x 27)
#   EAST  102 STREET (x 1)
#
# Cluster 30
#   WEST 102 STREET (x 13)
#   WEST  102 STREET (x 2)
#
# Cluster 31
#   EAST 103 STREET (x 6)
#   EAST  103 STREET (x 3)
#
# Cluster 32
#   WEST 103 STREET (x 69)
#   WEST  103 STREET (x 7)
#
# Cluster 33
#   EAST 104 STREET (x 16)
#   EAST  104 STREET (x 1)
#
# Cluster 34
#   WEST 104 STREET (x 27)
#   WEST  104 STREET (x 5)
#
# Cluster 35
#   BEACH 105 STREET (x 1)
#   BEACH  105 STREET (x 1)
#
# Cluster 36
#   EAST 105 STREET (x 42)
#   EAST  105 STREET (x 6)
#
# Cluster 37
#   WEST 105 STREET (x 28)
#   WEST  105 STREET (x 2)
#
# Cluster 38
#   E 106 ST (x 3)
#   106 ST E (x 1)
#
# Cluster 39
#   EAST  106 STREET (x 5)
#   EAST 106 STREET (x 13)
#
# Cluster 40
#   WEST 106 STREET (x 47)
#   WEST  106 STREET (x 7)
#
# Cluster 41
#   EAST 107 STREET (x 22)
#   EAST  107 STREET (x 2)
#
# Cluster 42
#   WEST 107 STREET (x 19)
#   WEST  107 STREET (x 5)
#
# Cluster 43
#   EAST  108 STREET (x 11)
#   EAST 108 STREET (x 63)
#
# Cluster 44
#   WEST 108 STREET (x 24)
#   WEST  108 STREET (x 4)
#
# Cluster 45
#   EAST 109 STREET (x 19)
#   EAST  109 STREET (x 1)
#
# Cluster 46
#   WEST 109 STREET (x 15)
#   WEST  109 STREET (x 1)
#
# Cluster 47
#   BEACH 11 STREET (x 4)
#   BEACH   11 STREET (x 1)
#
# Cluster 48
#   BELT PARKWAY EXIT 11 NORTH   WB (x 1)
#   BELT PARKWAY EXIT 11 NORTH WB (x 2)
#
# Cluster 49
#   EAST 11 STREET (x 62)
#   EAST   11 STREET (x 6)
#
# Cluster 50
#   STATEN ISLAND EXPWY ET 11 WB (x 1)
#   STATEN ISLAND EXPWY ET 11  WB (x 1)
#
# Cluster 51
#   HENRY HUDSON PARKWAY ET 11 NB (x 8)
#   HENRY HUDSON PARKWAY ET   11 NB (x 1)
#
# Cluster 52
#   HENRY HUDSON PARKWAY ET   11 SB (x 3)
#   HENRY HUDSON PARKWAY ET 11 SB (x 11)
#
# Cluster 53
#   NORTH 11 STREET (x 16)
#   NORTH   11 STREET (x 1)
#
# Cluster 54
#   WEST 11 STREET (x 30)
#   WEST   11 STREET (x 5)
#
# Cluster 55
#   EAST 110 STREET (x 22)
#   EAST  110 STREET (x 1)
#
# Cluster 56
#   E 111 ST (x 5)
#   111 ST E (x 1)
#
# Cluster 57
#   EAST 111 STREET (x 41)
#   EAST  111 STREET (x 2)
#
# Cluster 58
#   WEST 111 STREET (x 14)
#   WEST  111 STREET (x 4)
#
# Cluster 59
#   EAST 112 STREET (x 26)
#   EAST  112 STREET (x 1)
#
# Cluster 60
#   WEST  112 STREET (x 3)
#   WEST 112 STREET (x 28)
#
# Cluster 61
#   EAST  113 STREET (x 1)
#   EAST 113 STREET (x 2)
#
# Cluster 62
#   WEST 113 STREET (x 37)
#   WEST  113 STREET (x 5)
#
# Cluster 63
#   WEST 114 STREET (x 67)
#   WEST  114 STREET (x 6)
#
# Cluster 64
#   EAST 115 STREET (x 79)
#   EAST  115 STREET (x 8)
#
# Cluster 65
#   WEST 115 STREET (x 53)
#   WEST  115 STREET (x 7)
#
# Cluster 66
#   EAST 116 STREET (x 69)
#   EAST  116 STREET (x 3)
#
# Cluster 67
#   WEST 116 STREET (x 22)
#   WEST  116 STREET (x 4)
#
# Cluster 68
#   EAST 117 STREET (x 33)
#   EAST  117 STREET (x 2)
#
# Cluster 69
#   WEST  117 STREET (x 6)
#   WEST 117 STREET (x 22)
#
# Cluster 70
#   EAST 118 STREET (x 23)
#   EAST  118 STREET (x 3)
#
# Cluster 71
#   WEST 118 STREET (x 13)
#   WEST  118 STREET (x 4)
#
# Cluster 72
#   EAST  119 STREET (x 3)
#   EAST 119 STREET (x 17)
#
# Cluster 73
#   W 119 ST (x 3)
#   119 ST W (x 1)
#
# Cluster 74
#   WEST 119 STREET (x 22)
#   WEST  119 STREET (x 3)
#
# Cluster 75
#   12 ST E (x 1)
#   E 12 ST (x 20)
#
# Cluster 76
#   EAST 12 STREET (x 130)
#   EAST   12 STREET (x 16)
#
# Cluster 77
#   LITTLE WEST 12 STREET (x 4)
#   LITTLE WEST   12 STREET (x 1)
#
# Cluster 78
#   WEST 12 STREET (x 19)
#   WEST   12 STREET (x 8)
#
# Cluster 79
#   EAST 120 STREET (x 19)
#   EAST  120 STREET (x 3)
#
# Cluster 80
#   WEST 120 STREET (x 41)
#   WEST  120 STREET (x 2)
#
# Cluster 81
#   WEST 121 STREET (x 20)
#   WEST  121 STREET (x 3)
#
# Cluster 82
#   BEACH  122 STREET (x 3)
#   BEACH 122 STREET (x 1)
#
# Cluster 83
#   EAST 122 STREET (x 16)
#   EAST  122 STREET (x 1)
#
# Cluster 84
#   WEST 122 STREET (x 23)
#   WEST  122 STREET (x 3)
#
# Cluster 85
#   WEST 123 STREET (x 59)
#   WEST  123 STREET (x 3)
#
# Cluster 86
#   EAST 124 STREET (x 17)
#   EAST  124 STREET (x 2)
#
# Cluster 87
#   WEST 124 STREET (x 25)
#   WEST  124 STREET (x 1)
#
# Cluster 88
#   EAST 125 STREET (x 12)
#   EAST  125 STREET (x 2)
#
# Cluster 89
#   WEST 125 STREET (x 26)
#   WEST  125 STREET (x 1)
#
# Cluster 90
#   EAST 126 STREET (x 5)
#   EAST  126 STREET (x 1)
#
# Cluster 91
#   WEST  126 STREET (x 2)
#   WEST 126 STREET (x 26)
#
# Cluster 92
#   EAST 127 STREET (x 14)
#   EAST  127 STREET (x 4)
#
# Cluster 93
#   WEST 127 STREET (x 26)
#   WEST  127 STREET (x 3)
#
# Cluster 94
#   EAST  128 STREET (x 3)
#   EAST 128 STREET (x 4)
#
# Cluster 95
#   WEST 128 STREET (x 24)
#   WEST  128 STREET (x 2)
#
# Cluster 96
#   BEACH  129 STREET (x 1)
#   BEACH 129 STREET (x 1)
#
# Cluster 97
#   EAST 129 STREET (x 9)
#   EAST  129 STREET (x 1)
#
# Cluster 98
#   WEST 129 STREET (x 14)
#   WEST  129 STREET (x 2)
#
# Cluster 99
#   BAY 13 STREET (x 9)
#   BAY   13 STREET (x 2)
#
# Cluster 100
#   BRIGHTON 13 STREET (x 13)
#   BRIGHTON   13 STREET (x 1)
#
# Cluster 101
#   MAJOR DEEGAN EXPWY ET 13   NB (x 1)
#   MAJOR DEEGAN EXPWY ET   13 NB (x 5)
#
# Cluster 102
#   DR M L KING JR EP ET 13 SB (x 1)
#   DR M L KING JR EP ET   13 SB (x 2)
#
# Cluster 103
#   FDR DRIVE EXIT 13 SOUTHBOUND (x 3)
#   FDR DRIVE EXIT   13 SOUTHBOUND (x 2)
#
# Cluster 104
#   EAST 13 STREET (x 128)
#   EAST   13 STREET (x 14)
#
# Cluster 105
#   WEST 13 STREET (x 36)
#   WEST   13 STREET (x 2)
#
# Cluster 106
#   BEACH 130 STREET (x 3)
#   BEACH  130 STREET (x 1)
#
# Cluster 107
#   WEST 130 STREET (x 34)
#   WEST  130 STREET (x 5)
#
# Cluster 108
#   EAST 131 STREET (x 9)
#   EAST  131 STREET (x 1)
#
# Cluster 109
#   WEST 131 STREET (x 15)
#   WEST  131 STREET (x 1)
#
# Cluster 110
#   BEACH  132 STREET (x 1)
#   BEACH 132 STREET (x 1)
#
# Cluster 111
#   EAST  132 STREET (x 2)
#   EAST 132 STREET (x 8)
#
# Cluster 112
#   WEST 132 STREET (x 13)
#   WEST  132 STREET (x 2)
#
# Cluster 113
#   W 133 ST (x 4)
#   133 ST W (x 1)
#
# Cluster 114
#   WEST 133 STREET (x 79)
#   WEST  133 STREET (x 6)
#
# Cluster 115
#   EAST 134 STREET (x 7)
#   EAST  134 STREET (x 4)
#
# Cluster 116
#   WEST 134 STREET (x 38)
#   WEST  134 STREET (x 6)
#
# Cluster 117
#   EAST 135 STREET (x 11)
#   EAST  135 STREET (x 4)
#
# Cluster 118
#   WEST 135 STREET (x 25)
#   WEST  135 STREET (x 3)
#
# Cluster 119
#   EAST 136 STREET (x 12)
#   EAST  136 STREET (x 2)
#
# Cluster 120
#   WEST 136 STREET (x 17)
#   WEST  136 STREET (x 3)
#
# Cluster 121
#   EAST 137 STREET (x 22)
#   EAST  137 STREET (x 4)
#
# Cluster 122
#   WEST 137 STREET (x 20)
#   WEST  137 STREET (x 1)
#
# Cluster 123
#   EAST 138 STREET (x 26)
#   EAST  138 STREET (x 2)
#
# Cluster 124
#   WEST 138 STREET (x 23)
#   WEST  138 STREET (x 1)
#
# Cluster 125
#   BEACH 139 STREET (x 2)
#   BEACH  139 STREET (x 1)
#
# Cluster 126
#   HARLEM RIVER DRV NB EN E 139 ST (x 2)
#   HARLEM RIVER DRV NB EN E  139 ST (x 1)
#
# Cluster 127
#   EAST 139 STREET (x 16)
#   EAST  139 STREET (x 2)
#
# Cluster 128
#   WEST 139 STREET (x 40)
#   WEST  139 STREET (x 2)
#
# Cluster 129
#   FDR DRIVE SB ENTRANCE E   14 ST (x 1)
#   FDR DRIVE SB ENTRANCE E 14 ST (x 10)
#
# Cluster 130
#   EAST 14 STREET (x 95)
#   EAST   14 STREET (x 7)
#
# Cluster 131
#   HENRY HUDSON PARKWAY ET   14 NB (x 1)
#   HENRY HUDSON PARKWAY ET 14 NB (x 1)
#
# Cluster 132
#   NORTH   14 STREET (x 1)
#   NORTH 14 STREET (x 2)
#
# Cluster 133
#   WEST 14 ROAD (x 4)
#   WEST   14 ROAD (x 1)
#
# Cluster 134
#   WEST 14 STREET (x 16)
#   WEST   14 STREET (x 2)
#
# Cluster 135
#   EAST  140 STREET (x 7)
#   EAST 140 STREET (x 15)
#
# Cluster 136
#   WEST 140 STREET (x 32)
#   WEST  140 STREET (x 1)
#
# Cluster 137
#   BEACH 141 STREET (x 2)
#   BEACH  141 STREET (x 1)
#
# Cluster 138
#   EAST 141 STREET (x 4)
#   EAST  141 STREET (x 1)
#
# Cluster 139
#   WEST 141 STREET (x 76)
#   WEST  141 STREET (x 8)
#
# Cluster 140
#   EAST 142 STREET (x 22)
#   EAST  142 STREET (x 3)
#
# Cluster 141
#   WEST 142 STREET (x 107)
#   WEST  142 STREET (x 6)
#
# Cluster 142
#   BEACH 143 STREET (x 2)
#   BEACH  143 STREET (x 1)
#
# Cluster 143
#   EAST 143 STREET (x 5)
#   EAST  143 STREET (x 1)
#
# Cluster 144
#   W 143 ST (x 7)
#   143 ST W (x 1)
#
# Cluster 145
#   WEST 143 STREET (x 59)
#   WEST  143 STREET (x 5)
#
# Cluster 146
#   EAST 144 STREET (x 28)
#   EAST  144 STREET (x 3)
#
# Cluster 147
#   WEST 144 STREET (x 48)
#   WEST  144 STREET (x 9)
#
# Cluster 148
#   BEACH 145 STREET (x 2)
#   BEACH  145 STREET (x 1)
#
# Cluster 149
#   EAST 145 STREET (x 11)
#   EAST  145 STREET (x 3)
#
# Cluster 150
#   WEST 145 STREET (x 91)
#   WEST  145 STREET (x 5)
#
# Cluster 151
#   EAST 146 STREET (x 6)
#   EAST  146 STREET (x 1)
#
# Cluster 152
#   146 ST W (x 1)
#   W 146 ST (x 5)
#
# Cluster 153
#   WEST 146 STREET (x 55)
#   WEST  146 STREET (x 3)
#
# Cluster 154
#   EAST 147 STREET (x 19)
#   EAST  147 STREET (x 3)
#
# Cluster 155
#   147 ST W (x 1)
#   W 147 ST (x 3)
#
# Cluster 156
#   WEST 147 STREET (x 48)
#   WEST  147 STREET (x 4)
#
# Cluster 157
#   EAST 148 STREET (x 5)
#   EAST  148 STREET (x 1)
#
# Cluster 158
#   WEST  148 STREET (x 6)
#   WEST 148 STREET (x 41)
#
# Cluster 159
#   EAST 149 STREET (x 57)
#   EAST  149 STREET (x 3)
#
# Cluster 160
#   WEST 149 STREET (x 47)
#   WEST  149 STREET (x 11)
#
# Cluster 161
#   EAST 15 STREET (x 75)
#   EAST   15 STREET (x 4)
#
# Cluster 162
#   WEST   15 STREET (x 3)
#   WEST 15 STREET (x 23)
#
# Cluster 163
#   EAST 150 STREET (x 22)
#   EAST  150 STREET (x 8)
#
# Cluster 164
#   WEST  150 STREET (x 7)
#   WEST 150 STREET (x 93)
#
# Cluster 165
#   EAST 151 STREET (x 44)
#   EAST  151 STREET (x 3)
#
# Cluster 166
#   WEST  151 STREET (x 2)
#   WEST 151 STREET (x 55)
#
# Cluster 167
#   EAST 152 STREET (x 21)
#   EAST  152 STREET (x 1)
#
# Cluster 168
#   WEST 152 STREET (x 66)
#   WEST  152 STREET (x 7)
#
# Cluster 169
#   WEST 153 STREET (x 40)
#   WEST  153 STREET (x 5)
#
# Cluster 170
#   EAST  154 STREET (x 2)
#   EAST 154 STREET (x 11)
#
# Cluster 171
#   WEST 154 STREET (x 11)
#   WEST  154 STREET (x 2)
#
# Cluster 172
#   EAST 155 STREET (x 10)
#   EAST  155 STREET (x 1)
#
# Cluster 173
#   WEST 155 STREET (x 32)
#   WEST  155 STREET (x 9)
#
# Cluster 174
#   EAST 156 STREET (x 110)
#   EAST  156 STREET (x 11)
#
# Cluster 175
#   E 157 ST (x 6)
#   157 ST E (x 1)
#
# Cluster 176
#   EAST 157 STREET (x 62)
#   EAST  157 STREET (x 9)
#
# Cluster 177
#   WEST 157 STREET (x 26)
#   WEST  157 STREET (x 3)
#
# Cluster 178
#   E 158 ST (x 11)
#   158 ST E (x 1)
#
# Cluster 179
#   EAST 158 STREET (x 85)
#   EAST  158 STREET (x 8)
#
# Cluster 180
#   WEST 158 STREET (x 16)
#   WEST  158 STREET (x 4)
#
# Cluster 181
#   EAST 159 STREET (x 22)
#   EAST  159 STREET (x 3)
#
# Cluster 182
#   WEST  159 STREET (x 1)
#   WEST 159 STREET (x 19)
#
# Cluster 183
#   BAY 16 STREET (x 6)
#   BAY   16 STREET (x 3)
#
# Cluster 184
#   BEACH 16 STREET (x 3)
#   BEACH   16 STREET (x 1)
#
# Cluster 185
#   E 16 ST (x 16)
#   16 ST E (x 1)
#
# Cluster 186
#   EAST 16 STREET (x 49)
#   EAST   16 STREET (x 6)
#
# Cluster 187
#   16 ST W (x 1)
#   W 16 ST (x 5)
#
# Cluster 188
#   WEST 16 STREET (x 28)
#   WEST   16 STREET (x 1)
#
# Cluster 189
#   EAST 160 STREET (x 15)
#   EAST  160 STREET (x 2)
#
# Cluster 190
#   WEST 160 STREET (x 56)
#   WEST  160 STREET (x 4)
#
# Cluster 191
#   EAST 161 STREET (x 73)
#   EAST  161 STREET (x 2)
#
# Cluster 192
#   WEST 161 STREET (x 36)
#   WEST  161 STREET (x 3)
#
# Cluster 193
#   EAST 162 STREET (x 41)
#   EAST  162 STREET (x 2)
#
# Cluster 194
#   WEST 162 STREET (x 39)
#   WEST  162 STREET (x 2)
#
# Cluster 195
#   EAST 163 STREET (x 114)
#   EAST  163 STREET (x 8)
#
# Cluster 196
#   WEST 163 STREET (x 126)
#   WEST  163 STREET (x 16)
#
# Cluster 197
#   E 164 ST (x 7)
#   164 ST E (x 1)
#
# Cluster 198
#   EAST  164 STREET (x 4)
#   EAST 164 STREET (x 120)
#
# Cluster 199
#   WEST 164 STREET (x 33)
#   WEST  164 STREET (x 6)
#
# Cluster 200
#   E 165 ST (x 14)
#   165 ST E (x 1)
#
# Cluster 201
#   EAST 165 STREET (x 182)
#   EAST  165 STREET (x 16)
#
# Cluster 202
#   WEST 165 STREET (x 115)
#   WEST  165 STREET (x 4)
#
# Cluster 203
#   EAST  166 STREET (x 14)
#   EAST 166 STREET (x 118)
#
# Cluster 204
#   WEST 166 STREET (x 67)
#   WEST  166 STREET (x 5)
#
# Cluster 205
#   EAST 167 STREET (x 182)
#   EAST  167 STREET (x 5)
#
# Cluster 206
#   WEST 167 STREET (x 49)
#   WEST  167 STREET (x 4)
#
# Cluster 207
#   EAST 168 STREET (x 214)
#   EAST  168 STREET (x 33)
#
# Cluster 208
#   WEST 168 STREET (x 69)
#   WEST  168 STREET (x 5)
#
# Cluster 209
#   EAST 169 STREET (x 203)
#   EAST  169 STREET (x 13)
#
# Cluster 210
#   WEST 169 STREET (x 21)
#   WEST  169 STREET (x 2)
#
# Cluster 211
#   BAY 17 STREET (x 5)
#   BAY   17 STREET (x 1)
#
# Cluster 212
#   E 17 ST (x 14)
#   17 ST E (x 1)
#
# Cluster 213
#   EAST 17 STREET (x 65)
#   EAST   17 STREET (x 8)
#
# Cluster 214
#   WEST 17 STREET (x 19)
#   WEST   17 STREET (x 7)
#
# Cluster 215
#   EAST 170 STREET (x 165)
#   EAST  170 STREET (x 24)
#
# Cluster 216
#   WEST 170 STREET (x 64)
#   WEST  170 STREET (x 10)
#
# Cluster 217
#   EAST 171 STREET (x 102)
#   EAST  171 STREET (x 16)
#
# Cluster 218
#   WEST 171 STREET (x 30)
#   WEST  171 STREET (x 2)
#
# Cluster 219
#   E 172 ST (x 33)
#   172 ST E (x 1)
#
# Cluster 220
#   EAST 172 STREET (x 264)
#   EAST  172 STREET (x 21)
#
# Cluster 221
#   WEST 172 STREET (x 92)
#   WEST  172 STREET (x 7)
#
# Cluster 222
#   EAST  173 STREET (x 46)
#   EAST 173 STREET (x 95)
#
# Cluster 223
#   WEST 173 STREET (x 24)
#   WEST  173 STREET (x 3)
#
# Cluster 224
#   E 174 ST (x 20)
#   174 ST E (x 1)
#
# Cluster 225
#   EAST 174 STREET (x 216)
#   EAST  174 STREET (x 24)
#
# Cluster 226
#   WEST 174 STREET (x 78)
#   WEST  174 STREET (x 5)
#
# Cluster 227
#   EAST 175 STREET (x 194)
#   EAST  175 STREET (x 15)
#
# Cluster 228
#   WEST 175 STREET (x 70)
#   WEST  175 STREET (x 5)
#
# Cluster 229
#   EAST 176 STREET (x 88)
#   EAST  176 STREET (x 10)
#
# Cluster 230
#   WEST 176 STREET (x 133)
#   WEST  176 STREET (x 22)
#
# Cluster 231
#   EAST 177 STREET (x 39)
#   EAST  177 STREET (x 4)
#
# Cluster 232
#   WEST 177 STREET (x 76)
#   WEST  177 STREET (x 4)
#
# Cluster 233
#   EAST 178 STREET (x 71)
#   EAST  178 STREET (x 9)
#
# Cluster 234
#   WEST 178 STREET (x 74)
#   WEST  178 STREET (x 6)
#
# Cluster 235
#   EAST 179 STREET (x 125)
#   EAST  179 STREET (x 8)
#
# Cluster 236
#   WEST 179 STREET (x 64)
#   WEST  179 STREET (x 7)
#
# Cluster 237
#   BELT PARKWAY EXIT 18 B WB (x 1)
#   BELT PARKWAY EXIT 18 B  WB (x 1)
#
# Cluster 238
#   EAST 18 STREET (x 89)
#   EAST   18 STREET (x 5)
#
# Cluster 239
#   WEST 18 STREET (x 25)
#   WEST   18 STREET (x 6)
#
# Cluster 240
#   EAST 180 STREET (x 181)
#   EAST  180 STREET (x 24)
#
# Cluster 241
#   WEST 180 STREET (x 72)
#   WEST  180 STREET (x 7)
#
# Cluster 242
#   EAST 181 STREET (x 190)
#   EAST  181 STREET (x 16)
#
# Cluster 243
#   HENRY HUDSON PY NB EN W  181 ST (x 1)
#   HENRY HUDSON PY NB EN W 181 ST (x 3)
#
# Cluster 244
#   WEST 181 STREET (x 56)
#   WEST  181 STREET (x 12)
#
# Cluster 245
#   EAST 182 STREET (x 186)
#   EAST  182 STREET (x 10)
#
# Cluster 246
#   W 182 ST (x 2)
#   182 ST W (x 1)
#
# Cluster 247
#   WEST 182 STREET (x 60)
#   WEST  182 STREET (x 7)
#
# Cluster 248
#   EAST 183 STREET (x 158)
#   EAST  183 STREET (x 16)
#
# Cluster 249
#   WEST 183 STREET (x 51)
#   WEST  183 STREET (x 8)
#
# Cluster 250
#   184 ST E (x 1)
#   E 184 ST (x 10)
#
# Cluster 251
#   EAST 184 STREET (x 80)
#   EAST  184 STREET (x 9)
#
# Cluster 252
#   WEST 184 STREET (x 46)
#   WEST  184 STREET (x 1)
#
# Cluster 253
#   EAST 185 STREET (x 22)
#   EAST  185 STREET (x 5)
#
# Cluster 254
#   WEST 185 STREET (x 20)
#   WEST  185 STREET (x 3)
#
# Cluster 255
#   WEST 186 STREET (x 63)
#   WEST  186 STREET (x 6)
#
# Cluster 256
#   E 187 ST (x 7)
#   187 ST E (x 1)
#
# Cluster 257
#   EAST 187 STREET (x 168)
#   EAST  187 STREET (x 10)
#
# Cluster 258
#   WEST 187 STREET (x 63)
#   WEST  187 STREET (x 4)
#
# Cluster 259
#   E 188 ST (x 14)
#   188 ST E (x 1)
#
# Cluster 260
#   EAST 188 STREET (x 121)
#   EAST  188 STREET (x 12)
#
# Cluster 261
#   WEST 188 STREET (x 35)
#   WEST  188 STREET (x 3)
#
# Cluster 262
#   EAST 189 STREET (x 49)
#   EAST  189 STREET (x 6)
#
# Cluster 263
#   WEST 189 STREET (x 37)
#   WEST  189 STREET (x 1)
#
# Cluster 264
#   BAY 19 STREET (x 11)
#   BAY   19 STREET (x 1)
#
# Cluster 265
#   BEACH 19 STREET (x 9)
#   BEACH   19 STREET (x 1)
#
# Cluster 266
#   EAST 19 STREET (x 120)
#   EAST   19 STREET (x 16)
#
# Cluster 267
#   WEST 19 STREET (x 27)
#   WEST   19 STREET (x 3)
#
# Cluster 268
#   EAST 190 STREET (x 12)
#   EAST  190 STREET (x 1)
#
# Cluster 269
#   WEST 190 STREET (x 128)
#   WEST  190 STREET (x 17)
#
# Cluster 270
#   WEST 191 STREET (x 10)
#   WEST  191 STREET (x 3)
#
# Cluster 271
#   EAST 192 STREET (x 70)
#   EAST  192 STREET (x 4)
#
# Cluster 272
#   WEST 192 STREET (x 137)
#   WEST  192 STREET (x 13)
#
# Cluster 273
#   EAST 193 STREET (x 75)
#   EAST  193 STREET (x 6)
#
# Cluster 274
#   WEST 193 STREET (x 28)
#   WEST  193 STREET (x 4)
#
# Cluster 275
#   EAST 194 STREET (x 39)
#   EAST  194 STREET (x 8)
#
# Cluster 276
#   EAST 195 STREET (x 18)
#   EAST  195 STREET (x 3)
#
# Cluster 277
#   195 ST W (x 1)
#   W 195 ST (x 5)
#
# Cluster 278
#   WEST 195 STREET (x 45)
#   WEST  195 STREET (x 5)
#
# Cluster 279
#   EAST 196 STREET (x 203)
#   EAST  196 STREET (x 20)
#
# Cluster 280
#   WEST 196 STREET (x 13)
#   WEST  196 STREET (x 4)
#
# Cluster 281
#   EAST 197 STREET (x 70)
#   EAST  197 STREET (x 2)
#
# Cluster 282
#   WEST 197 STREET (x 44)
#   WEST  197 STREET (x 10)
#
# Cluster 283
#   EAST 198 STREET (x 41)
#   EAST  198 STREET (x 5)
#
# Cluster 284
#   EAST 199 STREET (x 67)
#   EAST  199 STREET (x 9)
#
# Cluster 285
#   BRIGHTON    2 LANE (x 2)
#   BRIGHTON 2 LANE (x 2)
#
# Cluster 286
#   FDR DRIVE EXIT 2 NORTHBOUND (x 4)
#   FDR DRIVE EXIT    2 NORTHBOUND (x 1)
#
# Cluster 287
#   EAST 2 STREET (x 155)
#   EAST    2 STREET (x 13)
#
# Cluster 288
#   FLATLANDS    2 STREET (x 1)
#   FLATLANDS 2 STREET (x 4)
#
# Cluster 289
#   SOUTH 2 STREET (x 25)
#   SOUTH    2 STREET (x 2)
#
# Cluster 290
#   WHITESTONE EXPWY SB EN 20 AVE (x 1)
#   WHITESTONE EXPWY SB EN   20 AVE (x 1)
#
# Cluster 291
#   BAY 20 STREET (x 6)
#   BAY   20 STREET (x 1)
#
# Cluster 292
#   HARLEM RIVER DRIVE EXIT   20 SB (x 3)
#   HARLEM RIVER DRIVE SB EXIT 20 (x 1)
#
# Cluster 293
#   EAST 20 ROAD (x 2)
#   EAST   20 ROAD (x 1)
#
# Cluster 294
#   EAST 20 STREET (x 26)
#   EAST   20 STREET (x 5)
#
# Cluster 295
#   LONG ISLAND EXPWY ET   20 WB (x 1)
#   LONG ISLAND EXPWY ET 20 WB (x 2)
#
# Cluster 296
#   EAST 201 STREET (x 89)
#   EAST  201 STREET (x 8)
#
# Cluster 297
#   WEST 202 STREET (x 1)
#   WEST  202 STREET (x 1)
#
# Cluster 298
#   WEST  203 STREET (x 2)
#   WEST 203 STREET (x 1)
#
# Cluster 299
#   EAST 204 STREET (x 97)
#   EAST  204 STREET (x 17)
#
# Cluster 300
#   WEST 204 STREET (x 134)
#   WEST  204 STREET (x 14)
#
# Cluster 301
#   205 ST E (x 1)
#   E 205 ST (x 5)
#
# Cluster 302
#   EAST 205 STREET (x 66)
#   EAST  205 STREET (x 7)
#
# Cluster 303
#   WEST  205 STREET (x 4)
#   WEST 205 STREET (x 1)
#
# Cluster 304
#   EAST 206 STREET (x 43)
#   EAST  206 STREET (x 2)
#
# Cluster 305
#   EAST  207 STREET (x 4)
#   EAST 207 STREET (x 45)
#
# Cluster 306
#   WEST 207 STREET (x 121)
#   WEST  207 STREET (x 22)
#
# Cluster 307
#   EAST 208 STREET (x 16)
#   EAST  208 STREET (x 1)
#
# Cluster 308
#   EAST 209 STREET (x 32)
#   EAST  209 STREET (x 2)
#
# Cluster 309
#   BEACH 21 STREET (x 5)
#   BEACH   21 STREET (x 2)
#
# Cluster 310
#   EAST 21 STREET (x 81)
#   EAST   21 STREET (x 7)
#
# Cluster 311
#   WEST 21 STREET (x 26)
#   WEST   21 STREET (x 7)
#
# Cluster 312
#   210 ST E (x 1)
#   E 210 ST (x 2)
#
# Cluster 313
#   EAST 210 STREET (x 15)
#   EAST  210 STREET (x 1)
#
# Cluster 314
#   EAST 211 STREET (x 123)
#   EAST  211 STREET (x 12)
#
# Cluster 315
#   EAST 212 STREET (x 68)
#   EAST  212 STREET (x 5)
#
# Cluster 316
#   EAST 213 STREET (x 55)
#   EAST  213 STREET (x 10)
#
# Cluster 317
#   WEST 213 STREET (x 3)
#   WEST  213 STREET (x 1)
#
# Cluster 318
#   EAST 214 STREET (x 13)
#   EAST  214 STREET (x 2)
#
# Cluster 319
#   WEST 214 STREET (x 10)
#   WEST  214 STREET (x 1)
#
# Cluster 320
#   EAST 215 STREET (x 16)
#   EAST  215 STREET (x 2)
#
# Cluster 321
#   WEST 215 STREET (x 29)
#   WEST  215 STREET (x 3)
#
# Cluster 322
#   EAST 216 STREET (x 28)
#   EAST  216 STREET (x 2)
#
# Cluster 323
#   WEST 216 STREET (x 7)
#   WEST  216 STREET (x 1)
#
# Cluster 324
#   EAST 217 STREET (x 12)
#   EAST  217 STREET (x 1)
#
# Cluster 325
#   EAST 218 STREET (x 5)
#   EAST  218 STREET (x 1)
#
# Cluster 326
#   WEST  218 STREET (x 5)
#   WEST 218 STREET (x 27)
#
# Cluster 327
#   EAST 219 STREET (x 19)
#   EAST  219 STREET (x 1)
#
# Cluster 328
#   LONG ISLAND EXPWY ET 22 A   WB (x 1)
#   LONG ISLAND EXPWY ET 22 A WB (x 1)
#
# Cluster 329
#   GRAND CENTRAL PARKWAY ET 22  EB (x 1)
#   GRAND CENTRAL PARKWAY EB ET 22 (x 1)
#
# Cluster 330
#   EAST 22 STREET (x 62)
#   EAST   22 STREET (x 9)
#
# Cluster 331
#   WEST 22 STREET (x 25)
#   WEST   22 STREET (x 2)
#
# Cluster 332
#   E 220 ST (x 1)
#   220 ST E (x 2)
#
# Cluster 333
#   EAST  220 STREET (x 3)
#   EAST 220 STREET (x 10)
#
# Cluster 334
#   EAST 221 STREET (x 17)
#   EAST  221 STREET (x 1)
#
# Cluster 335
#   EAST  222 STREET (x 4)
#   EAST 222 STREET (x 23)
#
# Cluster 336
#   EAST 224 STREET (x 30)
#   EAST  224 STREET (x 1)
#
# Cluster 337
#   EAST 225 STREET (x 11)
#   EAST  225 STREET (x 1)
#
# Cluster 338
#   EAST 226 STREET (x 21)
#   EAST  226 STREET (x 2)
#
# Cluster 339
#   EAST 227 STREET (x 19)
#   EAST  227 STREET (x 1)
#
# Cluster 340
#   WEST 227 STREET (x 19)
#   WEST  227 STREET (x 3)
#
# Cluster 341
#   EAST 228 STREET (x 42)
#   EAST  228 STREET (x 3)
#
# Cluster 342
#   WEST 228 STREET (x 16)
#   WEST  228 STREET (x 3)
#
# Cluster 343
#   EAST 229 STREET (x 70)
#   EAST  229 STREET (x 2)
#
# Cluster 344
#   WEST 229 STREET (x 92)
#   WEST  229 STREET (x 4)
#
# Cluster 345
#   BAY 23 STREET (x 8)
#   BAY   23 STREET (x 1)
#
# Cluster 346
#   EAST 23 STREET (x 66)
#   EAST   23 STREET (x 5)
#
# Cluster 347
#   WEST 23 STREET (x 15)
#   WEST   23 STREET (x 2)
#
# Cluster 348
#   WEST 230 STREET (x 23)
#   WEST  230 STREET (x 10)
#
# Cluster 349
#   W 231 ST (x 8)
#   231 ST W (x 2)
#
# Cluster 350
#   WEST 231 STREET (x 72)
#   WEST  231 STREET (x 4)
#
# Cluster 351
#   EAST 232 STREET (x 10)
#   EAST  232 STREET (x 1)
#
# Cluster 352
#   WEST 232 STREET (x 22)
#   WEST  232 STREET (x 3)
#
# Cluster 353
#   EAST 233 STREET (x 23)
#   EAST  233 STREET (x 5)
#
# Cluster 354
#   WEST 233 STREET (x 13)
#   WEST  233 STREET (x 2)
#
# Cluster 355
#   EAST  234 STREET (x 2)
#   EAST 234 STREET (x 10)
#
# Cluster 356
#   WEST 234 STREET (x 13)
#   WEST  234 STREET (x 1)
#
# Cluster 357
#   E 235 ST (x 3)
#   235 ST E (x 1)
#
# Cluster 358
#   EAST 235 STREET (x 15)
#   EAST  235 STREET (x 2)
#
# Cluster 359
#   WEST  235 STREET (x 4)
#   WEST 235 STREET (x 26)
#
# Cluster 360
#   W 236 ST (x 11)
#   236 ST W (x 1)
#
# Cluster 361
#   WEST 236 STREET (x 51)
#   WEST  236 STREET (x 5)
#
# Cluster 362
#   E 237 ST (x 8)
#   237 ST E (x 2)
#
# Cluster 363
#   EAST 237 STREET (x 35)
#   EAST  237 STREET (x 5)
#
# Cluster 364
#   WEST  237 STREET (x 1)
#   WEST 237 STREET (x 1)
#
# Cluster 365
#   WEST 238 STREET (x 78)
#   WEST  238 STREET (x 12)
#
# Cluster 366
#   E 239 ST (x 3)
#   239 ST E (x 1)
#
# Cluster 367
#   EAST 239 STREET (x 32)
#   EAST  239 STREET (x 2)
#
# Cluster 368
#   WEST 239 STREET (x 31)
#   WEST  239 STREET (x 1)
#
# Cluster 369
#   EAST 24 STREET (x 41)
#   EAST   24 STREET (x 10)
#
# Cluster 370
#   WEST 24 STREET (x 21)
#   WEST   24 STREET (x 3)
#
# Cluster 371
#   240 ST E (x 1)
#   E 240 ST (x 2)
#
# Cluster 372
#   EAST 240 STREET (x 27)
#   EAST  240 STREET (x 4)
#
# Cluster 373
#   WEST 240 STREET (x 12)
#   WEST  240 STREET (x 6)
#
# Cluster 374
#   EAST 241 STREET (x 32)
#   EAST  241 STREET (x 3)
#
# Cluster 375
#   EAST 242 STREET (x 31)
#   EAST  242 STREET (x 5)
#
# Cluster 376
#   242 ST W (x 1)
#   W 242 ST (x 2)
#
# Cluster 377
#   EAST 243 STREET (x 2)
#   EAST  243 STREET (x 1)
#
# Cluster 378
#   WEST 246 STREET (x 23)
#   WEST  246 STREET (x 4)
#
# Cluster 379
#   BAY   25 STREET (x 2)
#   BAY 25 STREET (x 7)
#
# Cluster 380
#   EAST 25 STREET (x 32)
#   EAST   25 STREET (x 1)
#
# Cluster 381
#   WEST   25 STREET (x 5)
#   WEST 25 STREET (x 25)
#
# Cluster 382
#   W 251 ST (x 2)
#   251 ST W (x 1)
#
# Cluster 383
#   WEST 251 STREET (x 7)
#   WEST  251 STREET (x 3)
#
# Cluster 384
#   WEST 252 STREET (x 15)
#   WEST  252 STREET (x 5)
#
# Cluster 385
#   WEST  253 STREET (x 6)
#   WEST 253 STREET (x 2)
#
# Cluster 386
#   WEST  254 STREET (x 6)
#   WEST 254 STREET (x 1)
#
# Cluster 387
#   WEST 255 STREET (x 9)
#   WEST  255 STREET (x 4)
#
# Cluster 388
#   WEST 256 STREET (x 17)
#   WEST  256 STREET (x 4)
#
# Cluster 389
#   E 26 ST (x 9)
#   26 ST E (x 1)
#
# Cluster 390
#   EAST 26 STREET (x 54)
#   EAST   26 STREET (x 9)
#
# Cluster 391
#   WEST 26 STREET (x 15)
#   WEST   26 STREET (x 5)
#
# Cluster 392
#   WEST 261 STREET (x 11)
#   WEST  261 STREET (x 2)
#
# Cluster 393
#   WEST 262 STREET (x 13)
#   WEST  262 STREET (x 1)
#
# Cluster 394
#   WEST  263 STREET (x 3)
#   WEST 263 STREET (x 7)
#
# Cluster 395
#   EAST 27 STREET (x 54)
#   EAST   27 STREET (x 7)
#
# Cluster 396
#   WEST 27 STREET (x 16)
#   WEST   27 STREET (x 4)
#
# Cluster 397
#   E 28 ST (x 13)
#   28 ST E (x 1)
#
# Cluster 398
#   EAST   28 STREET (x 10)
#   EAST 28 STREET (x 89)
#
# Cluster 399
#   WEST 28 STREET (x 29)
#   WEST   28 STREET (x 4)
#
# Cluster 400
#   BAY 29 STREET (x 10)
#   BAY   29 STREET (x 1)
#
# Cluster 401
#   EAST 29 STREET (x 99)
#   EAST   29 STREET (x 15)
#
# Cluster 402
#   WEST 29 STREET (x 14)
#   WEST   29 STREET (x 5)
#
# Cluster 403
#   EAST 3 STREET (x 128)
#   EAST    3 STREET (x 13)
#
# Cluster 404
#   FLATLANDS    3 STREET (x 1)
#   FLATLANDS 3 STREET (x 1)
#
# Cluster 405
#   KINGSBOROUGH    3 WALK (x 1)
#   KINGSBOROUGH 3 WALK (x 1)
#
# Cluster 406
#   NORTH 3 STREET (x 13)
#   NORTH    3 STREET (x 1)
#
# Cluster 407
#   SOUTH 3 STREET (x 34)
#   SOUTH    3 STREET (x 2)
#
# Cluster 408
#   WEST 3 STREET (x 120)
#   WEST    3 STREET (x 9)
#
# Cluster 409
#   EAST 30 STREET (x 15)
#   EAST   30 STREET (x 3)
#
# Cluster 410
#   WEST   30 STREET (x 6)
#   WEST 30 STREET (x 36)
#
# Cluster 411
#   EAST 31 STREET (x 59)
#   EAST   31 STREET (x 4)
#
# Cluster 412
#   WEST   31 STREET (x 4)
#   WEST 31 STREET (x 16)
#
# Cluster 413
#   BROOKLYN QUEENS EP ET 32 A WB (x 9)
#   BROOKLYN QUEENS EP ET   32 A WB (x 4)
#
# Cluster 414
#   BAY 32 STREET (x 40)
#   BAY   32 STREET (x 1)
#
# Cluster 415
#   EAST 32 STREET (x 80)
#   EAST   32 STREET (x 6)
#
# Cluster 416
#   WEST   32 STREET (x 2)
#   WEST 32 STREET (x 7)
#
# Cluster 417
#   BROOKLYN QUEENS EXPWY ET 33  EB (x 1)
#   BROOKLYN QUEENS EXPWY ET 33 EB (x 7)
#
# Cluster 418
#   CROSS ISLAND PARKWAY SB ET 33 (x 1)
#   CROSS ISLAND PARKWAY ET 33 SB (x 1)
#
# Cluster 419
#   EAST 33 STREET (x 42)
#   EAST   33 STREET (x 3)
#
# Cluster 420
#   WEST 33 STREET (x 23)
#   WEST   33 STREET (x 6)
#
# Cluster 421
#   FDR DRIVE SB ENTRANCE E 34 ST (x 2)
#   FDR DRIVE SB ENTRANCE E   34 ST (x 2)
#
# Cluster 422
#   EAST 34 STREET (x 64)
#   EAST   34 STREET (x 8)
#
# Cluster 423
#   WEST 34 STREET (x 12)
#   WEST   34 STREET (x 9)
#
# Cluster 424
#   E 35 ST (x 9)
#   35 ST E (x 1)
#
# Cluster 425
#   EAST 35 STREET (x 91)
#   EAST   35 STREET (x 8)
#
# Cluster 426
#   WEST 35 STREET (x 30)
#   WEST   35 STREET (x 7)
#
# Cluster 427
#   EAST 36 STREET (x 25)
#   EAST   36 STREET (x 4)
#
# Cluster 428
#   WEST 36 STREET (x 24)
#   WEST   36 STREET (x 1)
#
# Cluster 429
#   BAY 37 STREET (x 10)
#   BAY   37 STREET (x 1)
#
# Cluster 430
#   EAST 37 STREET (x 69)
#   EAST   37 STREET (x 11)
#
# Cluster 431
#   WEST 37 STREET (x 20)
#   WEST   37 STREET (x 1)
#
# Cluster 432
#   BAY 38 STREET (x 15)
#   BAY   38 STREET (x 3)
#
# Cluster 433
#   E 38 ST (x 16)
#   38 ST E (x 1)
#
# Cluster 434
#   EAST 38 STREET (x 59)
#   EAST   38 STREET (x 13)
#
# Cluster 435
#   WEST 38 STREET (x 21)
#   WEST   38 STREET (x 2)
#
# Cluster 436
#   BROOKLYN QUEENS EP ET 39 W  WB (x 1)
#   BROOKLYN QUEENS EP ET 39 W WB (x 1)
#
# Cluster 437
#   EAST 39 STREET (x 46)
#   EAST   39 STREET (x 6)
#
# Cluster 438
#   WEST 39 STREET (x 23)
#   WEST   39 STREET (x 1)
#
# Cluster 439
#   S 4 ST EN WILLIAMSBURG BRDG (x 7)
#   S    4 ST EN WILLIAMSBURG BRDG (x 1)
#
# Cluster 440
#   BRIGHTON 4 COURT (x 2)
#   BRIGHTON    4 COURT (x 1)
#
# Cluster 441
#   BRIGHTON 4 STREET (x 7)
#   BRIGHTON    4 STREET (x 2)
#
# Cluster 442
#   BRONX RIVER PARKWAY EXIT 4 NB (x 3)
#   BRONX RIVER PARKWAY EXIT 4  NB (x 1)
#
# Cluster 443
#   FDR DRIVE EXIT 4 SOUTHBOUND (x 6)
#   FDR DRIVE SOUTHBOUND EXIT 4 (x 1)
#
# Cluster 444
#   E 4 ST (x 13)
#   4 ST E (x 1)
#
# Cluster 445
#   EAST 4 STREET (x 89)
#   EAST    4 STREET (x 9)
#
# Cluster 446
#   NORTH 4 PLACE (x 3)
#   NORTH    4 PLACE (x 2)
#
# Cluster 447
#   NORTH    4 STREET (x 3)
#   NORTH 4 STREET (x 5)
#
# Cluster 448
#   SOUTH 4 STREET (x 16)
#   SOUTH    4 STREET (x 4)
#
# Cluster 449
#   WEST 4 STREET (x 60)
#   WEST    4 STREET (x 13)
#
# Cluster 450
#   BAY 40 STREET (x 10)
#   BAY   40 STREET (x 1)
#
# Cluster 451
#   EAST 40 STREET (x 31)
#   EAST   40 STREET (x 8)
#
# Cluster 452
#   BAY 41 STREET (x 16)
#   BAY   41 STREET (x 1)
#
# Cluster 453
#   BROOKLYN QUEENS EXPWY ET 41 WB (x 1)
#   BROOKLYN QUEENS EXPWY ET   41 WB (x 1)
#
# Cluster 454
#   EAST 41 STREET (x 25)
#   EAST   41 STREET (x 1)
#
# Cluster 455
#   WEST 41 STREET (x 28)
#   WEST   41 STREET (x 3)
#
# Cluster 456
#   BEACH 42 STREET (x 4)
#   BEACH   42 STREET (x 3)
#
# Cluster 457
#   BROOKLYN QUEENS EXPWY ET   42 WB (x 1)
#   BROOKLYN QUEENS EXPWY ET 42 WB (x 1)
#
# Cluster 458
#   E 42 ST (x 7)
#   42 ST E (x 1)
#
# Cluster 459
#   EAST 42 STREET (x 17)
#   EAST   42 STREET (x 4)
#
# Cluster 460
#   WEST 42 STREET (x 23)
#   WEST   42 STREET (x 6)
#
# Cluster 461
#   BAY 43 STREET (x 8)
#   BAY   43 STREET (x 1)
#
# Cluster 462
#   EAST 43 STREET (x 30)
#   EAST   43 STREET (x 7)
#
# Cluster 463
#   WEST 43 STREET (x 11)
#   WEST   43 STREET (x 2)
#
# Cluster 464
#   BEACH 44 STREET (x 2)
#   BEACH   44 STREET (x 2)
#
# Cluster 465
#   EAST   44 STREET (x 1)
#   EAST 44 STREET (x 10)
#
# Cluster 466
#   WEST 44 STREET (x 28)
#   WEST   44 STREET (x 7)
#
# Cluster 467
#   EAST 45 STREET (x 40)
#   EAST   45 STREET (x 4)
#
# Cluster 468
#   WEST 45 STREET (x 24)
#   WEST   45 STREET (x 6)
#
# Cluster 469
#   BEACH 46 STREET (x 1)
#   BEACH   46 STREET (x 1)
#
# Cluster 470
#   EAST 46 STREET (x 41)
#   EAST   46 STREET (x 5)
#
# Cluster 471
#   BAY 47 STREET (x 10)
#   BAY   47 STREET (x 1)
#
# Cluster 472
#   WEST 47 STREET BIKE PATH (x 3)
#   WEST   47 STREET BIKE PATH (x 4)
#
# Cluster 473
#   EAST 47 STREET (x 17)
#   EAST   47 STREET (x 1)
#
# Cluster 474
#   WEST 47 STREET (x 22)
#   WEST   47 STREET (x 5)
#
# Cluster 475
#   EAST   48 STREET (x 3)
#   EAST 48 STREET (x 54)
#
# Cluster 476
#   WEST 48 STREET (x 27)
#   WEST   48 STREET (x 5)
#
# Cluster 477
#   BAY 49 STREET (x 4)
#   BAY   49 STREET (x 1)
#
# Cluster 478
#   EAST 49 STREET (x 36)
#   EAST   49 STREET (x 6)
#
# Cluster 479
#   WEST 49 STREET (x 39)
#   WEST   49 STREET (x 7)
#
# Cluster 480
#   E 5 ST (x 16)
#   5 ST E (x 1)
#
# Cluster 481
#   EAST 5 STREET (x 103)
#   EAST    5 STREET (x 10)
#
# Cluster 482
#   KINGSBOROUGH 5 WALK (x 1)
#   KINGSBOROUGH    5 WALK (x 1)
#
# Cluster 483
#   NORTH 5 STREET (x 13)
#   NORTH    5 STREET (x 4)
#
# Cluster 484
#   SOUTH 5 STREET (x 16)
#   SOUTH    5 STREET (x 4)
#
# Cluster 485
#   WEST 5 STREET (x 36)
#   WEST    5 STREET (x 4)
#
# Cluster 486
#   WEST 50 STREET (x 31)
#   WEST   50 STREET (x 6)
#
# Cluster 487
#   EAST 51 STREET (x 66)
#   EAST   51 STREET (x 5)
#
# Cluster 488
#   WEST 51 STREET (x 30)
#   WEST   51 STREET (x 4)
#
# Cluster 489
#   EAST 52 STREET (x 67)
#   EAST   52 STREET (x 9)
#
# Cluster 490
#   WEST 52 STREET (x 33)
#   WEST   52 STREET (x 7)
#
# Cluster 491
#   EAST   53 STREET (x 7)
#   EAST 53 STREET (x 48)
#
# Cluster 492
#   W 53 ST (x 6)
#   53 ST W (x 1)
#
# Cluster 493
#   WEST 53 STREET (x 26)
#   WEST   53 STREET (x 4)
#
# Cluster 494
#   EAST 54 STREET (x 49)
#   EAST   54 STREET (x 7)
#
# Cluster 495
#   WEST 54 STREET (x 29)
#   WEST   54 STREET (x 4)
#
# Cluster 496
#   EAST 55 STREET (x 50)
#   EAST   55 STREET (x 11)
#
# Cluster 497
#   WEST 55 STREET (x 28)
#   WEST   55 STREET (x 9)
#
# Cluster 498
#   BEACH   56 STREET (x 1)
#   BEACH 56 STREET (x 1)
#
# Cluster 499
#   EAST 56 STREET (x 46)
#   EAST   56 STREET (x 8)
#
# Cluster 500
#   EAST   57 PLACE (x 1)
#   EAST 57 PLACE (x 4)
#
# Cluster 501
#   EAST 57 STREET (x 32)
#   EAST   57 STREET (x 7)
#
# Cluster 502
#   WEST 57 STREET (x 12)
#   WEST   57 STREET (x 3)
#
# Cluster 503
#   BEACH 58 STREET (x 12)
#   BEACH   58 STREET (x 1)
#
# Cluster 504
#   EAST 58 STREET (x 39)
#   EAST   58 STREET (x 1)
#
# Cluster 505
#   W 58 ST (x 8)
#   58 ST W (x 1)
#
# Cluster 506
#   WEST 58 STREET (x 21)
#   WEST   58 STREET (x 7)
#
# Cluster 507
#   BEACH 59 STREET (x 8)
#   BEACH   59 STREET (x 4)
#
# Cluster 508
#   EAST 59 STREET (x 29)
#   EAST   59 STREET (x 10)
#
# Cluster 509
#   WEST 59 STREET (x 11)
#   WEST   59 STREET (x 1)
#
# Cluster 510
#   CROSS BRONX EXPWY ET 6 A EB (x 3)
#   CROSS BRONX EXPWY ET    6 A EB (x 1)
#
# Cluster 511
#   BELT PARKWAY WB EN E 6 ST (x 4)
#   BELT PARKWAY WB EN E    6 ST (x 1)
#
# Cluster 512
#   BRIGHTON 6 STREET (x 16)
#   BRIGHTON    6 STREET (x 1)
#
# Cluster 513
#   EAST 6 STREET (x 36)
#   EAST    6 STREET (x 5)
#
# Cluster 514
#   NORTH 6 STREET (x 18)
#   NORTH    6 STREET (x 1)
#
# Cluster 515
#   PAERDEGAT    6 STREET (x 1)
#   PAERDEGAT 6 STREET (x 1)
#
# Cluster 516
#   SOUTH    6 STREET (x 1)
#   SOUTH 6 STREET (x 1)
#
# Cluster 517
#   WEST 6 STREET (x 45)
#   WEST    6 STREET (x 1)
#
# Cluster 518
#   EAST   60 STREET (x 3)
#   EAST 60 STREET (x 13)
#
# Cluster 519
#   WEST   60 STREET (x 3)
#   WEST 60 STREET (x 11)
#
# Cluster 520
#   BEACH 61 STREET (x 1)
#   BEACH   61 STREET (x 1)
#
# Cluster 521
#   EAST   61 STREET (x 6)
#   EAST 61 STREET (x 11)
#
# Cluster 522
#   GOWANUS EXPRESSWAY WB EN 61 ST (x 9)
#   GOWANUS EXPRESSWAY WB EN   61 ST (x 1)
#
# Cluster 523
#   WEST   61 STREET (x 11)
#   WEST 61 STREET (x 9)
#
# Cluster 524
#   EAST 62 STREET (x 17)
#   EAST   62 STREET (x 3)
#
# Cluster 525
#   BEACH   63 STREET (x 2)
#   BEACH 63 STREET (x 4)
#
# Cluster 526
#   EAST 63 STREET (x 23)
#   EAST   63 STREET (x 3)
#
# Cluster 527
#   W 63 ST (x 2)
#   63 ST W (x 1)
#
# Cluster 528
#   WEST 63 STREET (x 17)
#   WEST   63 STREET (x 1)
#
# Cluster 529
#   EAST 64 STREET (x 19)
#   EAST   64 STREET (x 4)
#
# Cluster 530
#   WEST 64 STREET (x 33)
#   WEST   64 STREET (x 1)
#
# Cluster 531
#   EAST 65 STREET (x 19)
#   EAST   65 STREET (x 4)
#
# Cluster 532
#   WEST   65 STREET (x 2)
#   WEST 65 STREET (x 3)
#
# Cluster 533
#   EAST 66 STREET (x 17)
#   EAST   66 STREET (x 3)
#
# Cluster 534
#   WEST 66 STREET (x 8)
#   WEST   66 STREET (x 5)
#
# Cluster 535
#   EAST 67 STREET (x 11)
#   EAST   67 STREET (x 2)
#
# Cluster 536
#   WEST 67 STREET (x 14)
#   WEST   67 STREET (x 1)
#
# Cluster 537
#   I 678 (x 21)
#   I  678 (x 6)
#
# Cluster 538
#   EAST 68 STREET (x 12)
#   EAST   68 STREET (x 2)
#
# Cluster 539
#   WEST 68 STREET (x 25)
#   WEST   68 STREET (x 3)
#
# Cluster 540
#   BEACH 69 STREET (x 2)
#   BEACH   69 STREET (x 1)
#
# Cluster 541
#   E 69 ST (x 7)
#   69 ST E (x 1)
#
# Cluster 542
#   EAST   69 STREET (x 8)
#   EAST 69 STREET (x 21)
#
# Cluster 543
#   W 69 ST (x 4)
#   69 ST W (x 1)
#
# Cluster 544
#   WEST 69 STREET (x 19)
#   WEST   69 STREET (x 2)
#
# Cluster 545
#   FDR DRIVE EXIT 7 NORTHBOUND (x 4)
#   FDR DRIVE EXIT    7 NORTHBOUND (x 1)
#
# Cluster 546
#   EAST 7 STREET (x 85)
#   EAST    7 STREET (x 5)
#
# Cluster 547
#   FLATLANDS 7 STREET (x 2)
#   FLATLANDS    7 STREET (x 2)
#
# Cluster 548
#   NORTH 7 STREET (x 33)
#   NORTH    7 STREET (x 3)
#
# Cluster 549
#   WEST 7 STREET (x 8)
#   WEST    7 STREET (x 1)
#
# Cluster 550
#   EAST 70 STREET (x 16)
#   EAST   70 STREET (x 1)
#
# Cluster 551
#   WEST 70 STREET (x 24)
#   WEST   70 STREET (x 3)
#
# Cluster 552
#   EAST 71 STREET (x 17)
#   EAST   71 STREET (x 2)
#
# Cluster 553
#   WEST 71 STREET (x 13)
#   WEST   71 STREET (x 2)
#
# Cluster 554
#   BEACH 72 STREET (x 19)
#   BEACH   72 STREET (x 3)
#
# Cluster 555
#   EAST 72 STREET (x 21)
#   EAST   72 STREET (x 4)
#
# Cluster 556
#   BEACH 73 STREET (x 1)
#   BEACH   73 STREET (x 1)
#
# Cluster 557
#   EAST 73 STREET (x 29)
#   EAST   73 STREET (x 3)
#
# Cluster 558
#   WEST 73 STREET (x 10)
#   WEST   73 STREET (x 1)
#
# Cluster 559
#   EAST   74 STREET (x 4)
#   EAST 74 STREET (x 23)
#
# Cluster 560
#   WEST 74 STREET (x 11)
#   WEST   74 STREET (x 1)
#
# Cluster 561
#   BEACH 75 STREET (x 6)
#   BEACH   75 STREET (x 1)
#
# Cluster 562
#   EAST 75 STREET (x 16)
#   EAST   75 STREET (x 1)
#
# Cluster 563
#   WEST 75 STREET (x 17)
#   WEST   75 STREET (x 2)
#
# Cluster 564
#   EAST 76 STREET (x 27)
#   EAST   76 STREET (x 2)
#
# Cluster 565
#   WEST 76 STREET (x 8)
#   WEST   76 STREET (x 5)
#
# Cluster 566
#   EAST 77 STREET (x 26)
#   EAST   77 STREET (x 3)
#
# Cluster 567
#   WEST 77 STREET (x 11)
#   WEST   77 STREET (x 2)
#
# Cluster 568
#   EAST 78 STREET (x 32)
#   EAST   78 STREET (x 7)
#
# Cluster 569
#   EAST 79 STREET (x 23)
#   EAST   79 STREET (x 2)
#
# Cluster 570
#   BEACH 8 STREET (x 26)
#   BEACH    8 STREET (x 2)
#
# Cluster 571
#   BRIGHTON 8 COURT (x 1)
#   BRIGHTON    8 COURT (x 1)
#
# Cluster 572
#   BRIGHTON 8 STREET (x 14)
#   BRIGHTON    8 STREET (x 1)
#
# Cluster 573
#   FDR DRIVE EXIT    8 NORTHBOUND (x 1)
#   FDR DRIVE EXIT 8 NORTHBOUND (x 4)
#
# Cluster 574
#   E 8 ST (x 21)
#   8 ST E (x 1)
#
# Cluster 575
#   EAST 8 STREET (x 104)
#   EAST    8 STREET (x 10)
#
# Cluster 576
#   NORTH    8 STREET (x 2)
#   NORTH 8 STREET (x 16)
#
# Cluster 577
#   WEST 8 STREET (x 34)
#   WEST    8 STREET (x 2)
#
# Cluster 578
#   EAST   80 STREET (x 10)
#   EAST 80 STREET (x 57)
#
# Cluster 579
#   WEST 80 STREET (x 8)
#   WEST   80 STREET (x 2)
#
# Cluster 580
#   BEACH 81 STREET (x 2)
#   BEACH   81 STREET (x 1)
#
# Cluster 581
#   EAST 81 STREET (x 23)
#   EAST   81 STREET (x 4)
#
# Cluster 582
#   WEST 81 STREET (x 16)
#   WEST   81 STREET (x 3)
#
# Cluster 583
#   EAST 82 STREET (x 49)
#   EAST   82 STREET (x 9)
#
# Cluster 584
#   EAST 83 STREET (x 25)
#   EAST   83 STREET (x 3)
#
# Cluster 585
#   WEST 83 STREET (x 17)
#   WEST   83 STREET (x 4)
#
# Cluster 586
#   BEACH 84 STREET (x 9)
#   BEACH   84 STREET (x 1)
#
# Cluster 587
#   E 84 ST (x 10)
#   84 ST E (x 1)
#
# Cluster 588
#   EAST 84 STREET (x 23)
#   EAST   84 STREET (x 6)
#
# Cluster 589
#   WEST 84 STREET (x 25)
#   WEST   84 STREET (x 1)
#
# Cluster 590
#   EAST 85 STREET (x 50)
#   EAST   85 STREET (x 4)
#
# Cluster 591
#   WEST 85 STREET (x 23)
#   WEST   85 STREET (x 4)
#
# Cluster 592
#   EAST 86 STREET (x 32)
#   EAST   86 STREET (x 3)
#
# Cluster 593
#   WEST   86 STREET (x 7)
#   WEST 86 STREET (x 19)
#
# Cluster 594
#   BEACH 87 STREET (x 1)
#   BEACH   87 STREET (x 2)
#
# Cluster 595
#   EAST 87 STREET (x 34)
#   EAST   87 STREET (x 3)
#
# Cluster 596
#   WEST 87 STREET (x 6)
#   WEST   87 STREET (x 2)
#
# Cluster 597
#   EAST 88 STREET (x 42)
#   EAST   88 STREET (x 3)
#
# Cluster 598
#   EAST 89 STREET (x 43)
#   EAST   89 STREET (x 4)
#
# Cluster 599
#   WEST 89 STREET (x 18)
#   WEST   89 STREET (x 3)
#
# Cluster 600
#   BEACH 9 STREET (x 6)
#   BEACH    9 STREET (x 2)
#
# Cluster 601
#   E 9 ST (x 16)
#   9 ST E (x 1)
#
# Cluster 602
#   EAST 9 STREET (x 80)
#   EAST    9 STREET (x 9)
#
# Cluster 603
#   NORTH 9 STREET (x 6)
#   NORTH    9 STREET (x 4)
#
# Cluster 604
#   SOUTH 9 STREET (x 11)
#   SOUTH    9 STREET (x 4)
#
# Cluster 605
#   WEST 9 STREET (x 33)
#   WEST    9 STREET (x 7)
#
# Cluster 606
#   EAST 90 STREET (x 27)
#   EAST   90 STREET (x 2)
#
# Cluster 607
#   WEST   90 STREET (x 2)
#   WEST 90 STREET (x 10)
#
# Cluster 608
#   BEACH 91 STREET (x 3)
#   BEACH   91 STREET (x 1)
#
# Cluster 609
#   EAST   91 STREET (x 4)
#   EAST 91 STREET (x 26)
#
# Cluster 610
#   WEST 91 STREET (x 16)
#   WEST   91 STREET (x 3)
#
# Cluster 611
#   EAST 92 STREET (x 61)
#   EAST   92 STREET (x 5)
#
# Cluster 612
#   WEST 92 STREET (x 13)
#   WEST   92 STREET (x 1)
#
# Cluster 613
#   EAST 93 STREET (x 49)
#   EAST   93 STREET (x 7)
#
# Cluster 614
#   WEST 93 STREET (x 22)
#   WEST   93 STREET (x 5)
#
# Cluster 615
#   BEACH   94 STREET (x 5)
#   BEACH 94 STREET (x 6)
#
# Cluster 616
#   EAST 94 STREET (x 40)
#   EAST   94 STREET (x 6)
#
# Cluster 617
#   WEST 94 STREET (x 14)
#   WEST   94 STREET (x 4)
#
# Cluster 618
#   EAST 95 STREET (x 63)
#   EAST   95 STREET (x 14)
#
# Cluster 619
#   WEST 95 STREET (x 19)
#   WEST   95 STREET (x 4)
#
# Cluster 620
#   E 96 ST (x 13)
#   96 ST E (x 1)
#
# Cluster 621
#   EAST 96 STREET (x 93)
#   EAST   96 STREET (x 7)
#
# Cluster 622
#   WEST 96 STREET (x 17)
#   WEST   96 STREET (x 1)
#
# Cluster 623
#   EAST 97 STREET (x 16)
#   EAST   97 STREET (x 2)
#
# Cluster 624
#   WEST 97 STREET (x 16)
#   WEST   97 STREET (x 2)
#
# Cluster 625
#   EAST   98 STREET (x 8)
#   EAST 98 STREET (x 58)
#
# Cluster 626
#   WEST 98 STREET (x 11)
#   WEST   98 STREET (x 3)
#
# Cluster 627
#   EAST   99 STREET (x 5)
#   EAST 99 STREET (x 39)
#
# Cluster 628
#   WEST 99 STREET (x 16)
#   WEST   99 STREET (x 3)
#
# Cluster 629
#   AVE A (x 2)
#   A AVE (x 1)
#
# Cluster 630
#   ST ANNS AVE (x 12)
#   ST ANN'S AVE (x 3)
#
# Cluster 631
#   N BURGHER AVE (x 6)
#   BURGHER AVE N (x 1)
#
# Cluster 632
#   W BURNSIDE AVE (x 16)
#   BURNSIDE AVE W (x 1)
#
# Cluster 633
#   CONDUIT AVE N (x 1)
#   N CONDUIT AVE (x 7)
#
# Cluster 634
#   E MT EDEN AVE (x 2)
#   MT EDEN AVE E (x 1)
#
# Cluster 635
#   E TREMONT AVE (x 25)
#   TREMONT AVE E (x 2)
#
# Cluster 636
#   N GANNON AVE (x 11)
#   GANNON AVE N (x 1)
#
# Cluster 637
#   NORTH GANNON AVE (x 1)
#   GANNON AVE NORTH (x 1)
#
# Cluster 638
#   S GANNON AVE (x 1)
#   GANNON AVE S (x 1)
#
# Cluster 639
#   HUNTS POINT AVE (x 3)
#   HUNT'S POINT AVE (x 1)
#
# Cluster 640
#   ST JOHNS AVE (x 3)
#   ST JOHN'S AVE (x 1)
#
# Cluster 641
#   ST MARKS AVE (x 13)
#   ST MARK'S AVE (x 3)
#
# Cluster 642
#   ST MARY'S AVE (x 3)
#   ST MARYS AVE (x 3)
#
# Cluster 643
#   O'GORMAN AVE (x 4)
#   OGORMAN AVE (x 1)
#
# Cluster 644
#   PARK AVE (x 102)
#   PARK  AVE (x 1)
#
# Cluster 645
#   AVENUE D (x 353)
#   D AVENUE (x 2)
#
# Cluster 646
#   AVENUE ST JOHN (x 43)
#   ST JOHN AVENUE (x 1)
#
# Cluster 647
#   ST JOHN'S AVENUE (x 1)
#   ST JOHNS AVENUE (x 6)
#
# Cluster 648
#   AVENUE L (x 344)
#   L AVENUE (x 1)
#
# Cluster 649
#   ST LUKES AVENUE (x 1)
#   ST LUKE'S AVENUE (x 1)
#
# Cluster 650
#   ST MARKS AVENUE (x 81)
#   ST MARK'S AVENUE (x 15)
#
# Cluster 651
#   ST MARYS AVENUE (x 5)
#   ST MARY'S AVENUE (x 2)
#
# Cluster 652
#   O'CONNOR AVENUE (x 6)
#   OCONNOR AVENUE (x 1)
#
# Cluster 653
#   ST PAULS AVENUE (x 8)
#   ST PAUL'S AVENUE (x 1)
#
# Cluster 654
#   ST PETER'S AVENUE (x 1)
#   ST PETERS AVENUE (x 8)
#
# Cluster 655
#   ST RAYMONDS AVENUE (x 15)
#   ST RAYMOND'S AVENUE (x 2)
#
# Cluster 656
#   AVENUE U (x 440)
#   U AVENUE (x 1)
#
# Cluster 657
#   BOBBY OSHEA WAY (x 1)
#   BOBBY O'SHEA WAY (x 1)
#
# Cluster 658
#   ST PAULS COURT (x 18)
#   ST PAUL'S COURT (x 4)
#
# Cluster 659
#   ST GEORGES CRESCENT (x 5)
#   ST GEORGE'S CRESCENT (x 2)
#
# Cluster 660
#   ST PAULS CT (x 2)
#   ST PAUL'S CT (x 1)
#
# Cluster 661
#   E GUN HILL RD (x 17)
#   GUN HILL RD E (x 1)
#
# Cluster 662
#   E KINGSBRIDGE RD (x 1)
#   KINGSBRIDGE RD E (x 1)
#
# Cluster 663
#   W FINGERBOARD RD (x 1)
#   FINGERBOARD RD W (x 1)
#
# Cluster 664
#   W FORDHAM RD (x 10)
#   FORDHAM RD W (x 1)
#
# Cluster 665
#   ST JAMES PL (x 4)
#   ST. JAMES PL (x 1)
#
# Cluster 666
#   ST JOHNS PL (x 9)
#   ST JOHN'S PL (x 5)
#
# Cluster 667
#   ST JOHNS PLACE (x 89)
#   ST JOHN'S PLACE (x 13)
#
# Cluster 668
#   W KINGSBRIDGE RD (x 12)
#   KINGSBRIDGE RD W (x 2)
#
# Cluster 669
#   ST LUKES PLACE (x 1)
#   ST LUKE'S PLACE (x 1)
#
# Cluster 670
#   ST MARKS PL (x 6)
#   ST MARK'S PL (x 6)
#
# Cluster 671
#   ST MARKS PLACE (x 58)
#   ST MARK'S PLACE (x 15)
#
# Cluster 672
#   ST PAUL'S PLACE (x 7)
#   ST PAULS PLACE (x 29)
#
# Cluster 673
#   ST PETERS PLACE (x 6)
#   ST PETER'S PLACE (x 1)

# %%
final_cs2 = {}
for key,value in cross_street_2_dict.items():
    final_cs2[key] = max(value, key=value.get)

# %%
for index, row in df.iterrows():
    if row['Cross Street 2'] in cluster_dict:
        df.at[index, 'Cross Street 2'] = final_cs2[cluster_dict[row['Cross Street 2']]]

# %%
df[['Latitude','Longitude']].describe(percentiles=[.01,.05,.1,.25,.5,.9,.95,.99])
# since there is no large variance in bins there are no outlier's
# Out:
#             Latitude      Longitude
# count  288024.000000  288024.000000
# mean       40.728834     -73.924603
# std         0.085836       0.082476
# min        40.498949     -74.254437
# 1%         40.550832     -74.169787
# 5%         40.595663     -74.076645
# 10%        40.617444     -74.002017
# 25%        40.666924     -73.969975
# 50%        40.721681     -73.927999
# 90%        40.851418     -73.818856
# 95%        40.867411     -73.783425
# 99%        40.889692     -73.737609
# max        40.912869     -73.700597

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.dtypes
# Out:
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                       object
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Address Type                       object
# City                               object
# Status                             object
# Resolution Description             object
# Resolution Action Updated Date     object
# Community Board                    object
# BBL                               float64
# Borough                            object
# X Coordinate (State Plane)        float64
# Y Coordinate (State Plane)        float64
# Open Data Channel Type             object
# Park Borough                       object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# dtype: object

# %% [markdown]
# #### Finalizing the columns: Location Type, Address Type, Status, Resolution Description, Community Board, BBL, X-Cord, Y-Cord, Open Data Channel Type, Park Borough, Location

# %%
df['Latitude'].isnull().sum()
# Out:
# 20578

# %%
df['Latitude'].unique()
# Out:
# array([40.84469154, 40.72516461, 40.60978147, ..., 40.55994995,
#        40.62947745, 40.73740737])

# %% [markdown]
# #### We have null values in Latitude column, but we can't impute it because Latitude is different for every location.

# %%
df = df[df['Latitude'].notna()]

# %%
df['Latitude'].isnull().sum()
# Out:
# 0

# %%
df['Longitude'].isnull().sum()
# Out:
# 0

# %%
df['Location'].isnull().sum()
# Out:
# 0

# %%
df['Location Type'].isnull().sum()
# Out:
# 63990

# %% [markdown]
# #### If we look at unique values in the 'Location Type' column, we'll see that some values are in title case while others are in upper case.

# %%
df['Location Type'].unique()
# Out:
# array([nan, 'Residential Building/House', 'Restaurant/Bar/Deli/Bakery',
#        'Street/Sidewalk', 'RESIDENTIAL BUILDING', 'Street', 'Home',
#        'Other (Explain Below)', 'Sidewalk', 'Comercial',
#        'Government Building', '3+ Family Apt. Building', 'Mixed Use',
#        'Recreation Center', 'Park', 'Store/Commercial',
#        '1-2 Family Dwelling', 'Club/Bar/Restaurant', 'Curb',
#        'Street and Sidewalk', 'Commercial Building', 'Park/Playground',
#        'Other', 'Bridge', 'Residential', 'Lot',
#        '3+ Family Apartment Building', 'Public Garden', 'Above Address',
#        'Street/Curbside', 'Vacant Building', 'Street Address',
#        'Speed Reducer', 'Residence', 'Vacant Lot', 'School', 'Pet Shop',
#        'Property Address', 'Public Garden/Park', 'Highway',
#        'Single Room Occupancy (SRO)', 'Parking Lot/Garage',
#        '3+ Family Mixed Use Building', 'Bus Stop Shelter',
#        'Residential Building', 'Crosswalk', 'School/Pre-School',
#        'Public School', 'Public/Unfenced Area', 'Tattoo Parlor',
#        'House of Worship', 'Construction Site', 'Catering Service',
#        'Residential Property', 'Taxi', 'Parking Lot', 'Vehicle Lane',
#        'Senior Center', 'Bar/Restaurant', 'Catch Basin/Sewer', 'Store',
#        'Building (Non-Residential)', '1-2 Family Mixed Use Building',
#        'Food Cart Vendor', 'Mobile Food Vendor', 'Overpass',
#        'Private House', 'Pool', 'Restaurant', 'Street Fair Vendor',
#        'Public Park/Garden', 'Bike Lane', 'House and Store',
#        'Day Care/Nursery', 'Stairwell', 'Soup Kitchen', 'Commercial',
#        'Cafeteria - Private School', 'Tanning Salon',
#        "DRIE Tenant's Address", 'Apartment', 'Spa Pool', 'Street Area',
#        'Lobby', 'Beach', 'Steam Room', 'Hallway', 'Abandoned Building',
#        'Vacant Lot/Property', '1-3 Family Dwelling', 'Hospital',
#        'Office Building', 'Business', 'Cafeteria - College/University',
#        'Kennel/Animal Shelter', 'Cafeteria - Public School',
#        'Roadway Tunnel', 'Pvt Residnt Proprty', 'Common Area',
#        "Dentist's Office", 'Health Club or Gym', 'Subway Station',
#        'Summer Camp', 'Wooded Area', 'Building', 'Street Vendor', 'Yard',
#        'Golf', 'Private School', 'Tire Shop', 'School Safety Zone',
#        'Theater', 'Public Stairs', 'Correctional Facility - City',
#        'Green Cart Vendor', 'Nursing Home', 'Garage', 'Medical Facility',
#        'Correctional Facility - State', 'Sauna',
#        'Airport or Train/Bus Station',
#        'Other (explain in Complaint Details)', 'Commercial Property',
#        'School - College/University', "Doctor's Office", 'Public Plaza',
#        'School - K-12 Public'], dtype=object)

# %% [markdown]
# #### Below, all of the values in the column are converted to title case.
# We also replace the null values with the 'Unrecognized'

# %%
df['Location Type'] = df['Location Type'].str.title()
df['Location Type'] = df['Location Type'].replace(np.nan, 'Unrecognized')

# %%
df['Location Type'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Address Type column has Null values but we can't impute/replace it with some another value as it is a string value. So we replace the null values with 'UNRECOGNIZED'.

# %%
df['Address Type'].isnull().sum()
# Out:
# 9765

# %%
df['Address Type'].unique()
# Out:
# array(['ADDRESS', nan, 'INTERSECTION', 'BLOCKFACE', 'LATLONG',
#        'PLACENAME', 'UNRECOGNIZED'], dtype=object)

# %%
df['Address Type'] = df['Address Type'].replace(np.nan, 'UNRECOGNIZED')

# %%
df['Address Type'].isnull().sum()
# Out:
# 0

# %%
df['Status'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Resolution Description has some rows without any reasons provided. There might be a chance that officer forgot to register it. We can not impute it with any other random description because description is unique for all the complaints.

# %%
df['Resolution Description'].isnull().sum()
# Out:
# 5922

# %%
df['Resolution Description'].unique()
# Out:
# array(['The Police Department responded to the complaint and took action to fix the condition.',
#        'The Department of Health and Mental Hygiene has received and processed your complaint.  All restaurants and mobile food vendors are inspected annually.  Restaurant inspection results can be found on WWW.NYC.GOV or a copy of the inspection can be requested from 311.',
#        'The Department of Housing Preservation and Development inspected the following conditions. No violations were issued. The complaint has been closed.',
#        'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verification.',
#        'The agency has declined the new tree request because the suggested location cannot be planted due to infrastructure conflicts.',
#        'The Police Department responded to the complaint and determined that police action was not necessary.',
#        'The Department of Housing Preservation and Development inspected the following conditions. Violations were issued. Information about specific violations is available at www.nyc.gov/hpd.',
#        'The Department of Transportation inspected the condition you reported and found that the condition meets its standards and/or there is a valid permit to conduct work.',
#        'The Police Department responded and upon arrival those responsible for the condition were gone.',
#        'The Police Department responded to the complaint and with the information available observed no evidence of the violation at that time.',
#        'Thank you for your report. The City will use the information you provided for tracking and reporting purposes. 311 will not have any further status information.',
#        'The Department of Housing Preservation and Development responded to a complaint of no heat or hot water and was advised by a tenant in the building that heat and hot water had been restored. If the condition still exists, please file a new complaint.',
#        'The Department of Health and Mental Hygiene has sent official written notification to the Owner/Landlord warning them of potential violations and instructing them to correct the situation.  If the situation persists 21 days after your initial complaint, please make a new complaint.',
#        'The Department of Parks and Recreation has reviewed this request and will visit the location to investigate the condition.',
#        'The Department of Sanitation picked up the items.',
#        'The Department of Parks and Recreation has corrected the condition.',
#        'The Department of Housing Preservation and Development was not able to gain access to inspect the following conditions. The complaint has been closed. If the condition still exists, please file a new complaint.',
#        'The Police Department issued a summons in response to the complaint.',
#        nan,
#        'The condition has been inspected and a work order was created.',
#        'The City has removed the graffiti from this property.',
#        'The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new complaint.',
#        'The Department of Health and Mental Hygiene has received and processed your complaint.  The facility will receive an inspection from the Bureau of Food Safety and Community Sanitation.  Inspection results are not published.',
#        'The Department of Health and Mental Hygiene will review your complaint to determine appropriate action.  Complaints of this type usually result in an inspection.  Please call 311 in 30 days from the date of your complaint for status',
#        'The Department of Transportation inspected the condition and issued a summons to the responsible party.  A re-inspection will be done within 10 days.  If the condition still exists, a second summons will be issued.  In some cases, the Department of Transportation will make the repairs and charge the responsible party for the costs.',
#        'A sidewalk dismissal inspection (work done by owner) has been scheduled.  Department of Transportation is in direct contact with the responsible party.',
#        'The graffiti on this property has been scheduled to be removed by the City.',
#        'The Department of Sanitation collected the E-waste.',
#        'The Department of Housing Preservation and Development responded to a complaint of no heat or hot water. Heat was not required at the time of the inspection. No violations were issued. If the condition still exists, please file a new complaint.',
#        'The Department of Parks and Recreation has completed the requested work order and corrected the problem.',
#        'The condition was inspected and it was determined that no work order was necessary. The condition will not be inspected again for at least 90 days.',
#        'The City inspected the condition you reported and asked the Department of Environmental Protection to address the issue.',
#        'The Department of Housing Preservation and Development inspected the following conditions. Violations were previously issued for these conditions. Information about specific violations is available at www.nyc.gov/hpd.',
#        'The Department of Transportation inspected the condition you reported. You can find additional information in the "Notes to Customer" field.',
#        'The Department of Housing Preservation and Development was not able to gain access to your apartment or others in the building to inspect for a lack of heat or hot water. The complaint has been closed. If the condition still exists, please file a new complaint.',
#        "The Department of Health and Mental Hygiene's Office of Vector Surveillance and Control has inspected the property and no standing water conditions were found.",
#        'The Department of Transportation has completed the request or corrected the condition.',
#        'A Taxi and Limousine Commission hearing was scheduled.',
#        'The Department of Parks and Recreation visited the location but could not find the tree condition you reported.',
#        'The Department of Transportation inspected the location for the condition you reported and could not find the problem. It you would like to pursue the complaint, please call 311 or (212)  639-9675 with additional information.',
#        'The cleaning crew was dispatched, but the owner refused to have the graffiti removed.',
#        "This complaint does not fall under the Police Department's jurisdiction.",
#        'The Police Department responded to the complaint but officers were unable to gain entry into the premises.',
#        'The Department of Sanitation investigated this complaint and found no violation at the location.',
#        'This request has been inspected and is pending prioritization for possible inclusion in the pilot program.',
#        'The Department of Sanitation investigated this complaint and found no condition at the location.',
#        'The Police Department reviewed your complaint and provided additional information below.',
#        'The Department of Sanitation investigated and found that the bike did not meet the criteria to be classified as derelict.',
#        'The Department of Housing Preservation and Development was unable to access the rooms where the following conditions were reported. No violations were issued. The complaint has been closed.',
#        'The Department of Transportation requires 30 days to respond to this type of complaint. Please note your Service Request number for future reference.',
#        'The phone company has already notified the Public Pay Telephone Unit that there is a long term project that has affected the phone. No inspection is necessary.',
#        'The Department of Sanitation removed the items.',
#        'The Department of Parks and Recreation has determined that the requested location cannot receive a new tree because of conflicts with surrounding infrastructure.',
#        'The Department of Sanitation cleaned the location.',
#        'Based on the information provided by the customer, the Taxi and Limousine Commission has determined that a hearing is not necessary or not possible.',
#        'The Department of Parks and Recreation usually requires 8 days to inspect this issue and may take up to 45 days to resolve it, if warranted.  Please note your Service Request number for future reference.',
#        'The Department of Parks and Recreation has determined that the issue will be addressed in the next pruning cycle through the routine block pruning program.',
#        'The Department of Transportation inspected the condition and issued a notice to the responsible party to correct the condition.',
#        'The Department of Parks and Recreation inspected but the condition was not found.',
#        'UNDER SECTION 2904 OF THE New York City Charter and Section 19-152 of the New York City Administrative Code, the property owner is responsible for maintaining, repairing and installing sidewalks adjoining their properties.Â\xa0 The Department of Transportation has inspected the location and issued a violation to the property owner.',
#        'The Department of Health and Mental Hygiene will review this Service Request. These types of complaints usually result in agency contact or an inspection. Status will be available at www.nyc.gov/311 within 30 days of the date you submitted the request. Note the Service Request number for future reference.',
#        'General maintenance and cleaning is on a regular schedule. The next scheduled maintenance and cleaning will correct the condition.',
#        'The Department of Transportation inspected the condition you reported and temporarily addressed the condition. The Agency will notify the responsible party.',
#        'The Department of Transportation has inspected/investigated the condition. See customer notes for more information.',
#        'The condition has been inspected/investigated, see customer notes for more information.',
#        'The Department of Transportation inspected the condition and made the determination that the street meets resurfacing standards and will be planned for either the next or future resurfacing seasons (2 - 3 years).  The Department of Transportation works with Community Boards and elected officials to determine resurfacing priority.  For specific scheduling information regarding your street, contact your Community Board.',
#        'The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new complaint.',
#        'The Department of Sanitation picked up the items. Due to conditions or operational needs, service was rescheduled.',
#        'The complaint confirmation letter was not returned to the Taxi and Limousine Commission, therefore the complaint cannot be processed.',
#        'The Department of Parks and Recreation inspected and determined the issue was out of its jurisdiction.',
#        'Your request can not be processed at this time because of insufficient contact information. Please create a new Service Request on NYC.gov and provide more detailed contact information.',
#        'The Department of Sanitation picked up the items and determined that the missed collection complaint was not warranted.',
#        'The Department of Parks and Recreation will send you a brochure in approximately 5 days with additional information about fulfilling your tree request and contact information for follow up. Please note your Service Request number for future reference.',
#        'The Department of Parks and Recreation performed the work necessary to correct the condition.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition',
#        'The Department of Parks and Recreation usually requires 30 days to inspect this type of complaint. Please note your Service Request number for future reference.',
#        'The Department of Transportation has approved the sidewalk re-inspection request. The property owner will be notified by mail within 120 days with the date of re-inspection.',
#        "The Department of Housing Preservation and Development conducted or attempted to conduct an inspection.  More information about inspection results can be found through HPD's website at www.nyc.gov/hpd by using HPDONLINE (enter your address on the home page) and entering your SR number under the complaint status option.",
#        'The Department of Transportation has denied the sidewalk re-inspection request. The request to re-inspect is past the 45 day original notification period.  The property owners are responsible for maintaining, repairing and installing sidewalks adjoining their properties.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition s',
#        'The Department of Sanitation will note this location for periodic surveillance, which may take place at various times.',
#        'The Department of Sanitation did not find any E-Waste at the location. Call 311 to make another appointment if you still need E-Waste removal.',
#        'The Taxi and Limousine Commission reviewed your complaint. The driver or owner pled guilty to a violation and paid a fine. TLC has sent you a written confirmation of this outcome.',
#        'Thank you for your report. It will help the City ensure that the vaccine mandate is being enforced safely.',
#        'The injured person has been transported to a hospital.',
#        'The Department of Transportation inspected the condition  you reported and issued a notice to the responsible party to correct the condition.',
#        'The Department of Transportation will inspect the condition to determine if the location can be added to a curb contract (3-5 years). The property owner will be notified if there are sidewalk defects. Property owners are responsible for repairing and installing sidewalks adjoining their property, according to Section 19-152 of the NYC Administrative Code. Community Boards and elected officials may contribute funding for curb, affecting timeframe for construction.',
#        'The Department of Transportation inspected and has requested the Department of Environmental Protection address the issue. The condition will be re-inspected in 60 days.',
#        'The Department of Sanitation picked up the items and determined that the missed collection complaint was not warranted because the items contained mixed materials and/or possible trade (commercial) waste.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please fi',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, pl',
#        'See Notes to Customer',
#        'The Department of Transportation contacted the customer and resolved the Service Request or provided the information requested.',
#        'The Taxi and Limousine Commission will send a confirmation letter in 14 days to confirm your complaint details.  At the hearing you may be required to provide information regarding this complaint.  Please note your Service Request number for future reference.',
#        'The Department of Parks and Recreation has planted the tree(s).',
#        'The following complaint conditions are still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection.',
#        'The Department of Transportation inspected the location more than six months ago and has notified the property owner of any defective sidewalk conditions. The property owner is responsible for maintaining, repairing and installing sidewalks adjoining their property, according to Section 19-152 of the New York City Administrative Code.',
#        'The Department of Health and Mental Hygiene has sent official written documentation to the Owner or Landlord warning them of potential violations and instructing them to correct the situation.  If the situation persists 21 days after the initial complaint, please submit a new Service Request.',
#        'Â\xa0The Department of Sanitation has noted this as a location of concern.',
#        'The request submitted did not have sufficient information for the Department of Transportation to respond.',
#        'A hearing was scheduled at the OATH/Taxi and Limousine Tribunal.',
#        'The Department of Housing Preservation and Development was unable to access the rooms where the following  conditions were reported. No violations were issued. The complaint has been closed.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still ex',
#        'The Department of Health and Mental Hygiene has investigated the complaint and no violations were issued.',
#        'The condition was inspected and it was in compliance with Department of Transportation standards, not hazardous, or a valid permit exists.',
#        'The Service Request submitted did not have sufficient location or complaint information for the agency to respond.',
#        'Upon inspection the reported condition was not found, and, therefore, no action was taken.',
#        'The Department of Health and Mental Hygiene has investigated the Service Request and there were minor violation of rules and regulations.  A Notice Of Violation was not issued and a reinspection is not required.',
#        'The Department of Finance will investigate the issue and attempt to provide status within 21 days. Please note your Service Request number for future reference.',
#        'The Department of Health and Mental Hygiene has determined that the reported incident is isolated.  They will inspect the location according to its normal schedule for sanitary inspections. You can provide more information in a new Service Request by calling 311 or going online to www.nyc.gov/311.',
#        'The Department of Sanitation investigated this complaint and issued a Notice of Violation.',
#        'The complaint has been investigated and the condition has been corrected.',
#        'The Department of Sanitation has investigated the complaint and addressed the issue. If the problem persists, call 311 to enter a new complaint. If you are outside of New York City, please call (212) NEW-YORK (212-639-9675).',
#        'The Department of Transportation inspected the condition and made the determination that the street meets resurfacing standards and will be scheduled for this current resurfacing season (April - November).  For specific weekly scheduling information regarding your street,  contact your Community Board or visit our website www.NYC.gov/dot.',
#        'The Department of Sanitation has removed illegal postings from the location. The Department will issue a Notice of Violation to the responsible party once it is identified.',
#        'The Department of Health and Mental Hygiene will review your complaint to determine appropriate action.  Complaints of this type usually result in an inspection.  Please call 311 in 37 days from the date of your complaint for status.',
#        'The Taxi and Limousine Commission requires you to attend a hearing to process a complaint against a driver or car service company. Your complaint has been closed.',
#        'The Department of Transportation has determined that this issue is not within its jurisdiction.',
#        'The Department of Parks and Recreation visited the site and inspected the condition. No work is necessary at this time.',
#        'The Department of Parks and Recreation attempted to inspect the reported condition, but could not find the location. Please file a new Service Request with adequate site details, including a full street address and descriptive location information.',
#        'The Department of Transportation inspected the condition you reported. It has been entered into the maintenance system. It will be repaired within 30 days.',
#        'Upon preliminary inspection, the phone was found to be dirty, but it has since been cleaned and a follow-up inspection has confirmed that the phone is in proper condition.',
#        'The Department of Parks and Recreation has inspected the location and will perform work to correct the condition.',
#        'The Department of Transportation inspected the condition and approved your request.  Street markings will be painted during this current work season (April - November).',
#        'The Department of Health and Mental Hygiene will review your complaint to determine appropriate action.  Complaints of this type usually result in complainant contact or an inspection by the Department. The Department may contact you if you provided a phone number.  Status will be available 45 days after the date of your complaint by calling 311.  Please note your Service Request number for future reference.',
#        'The City inspected the property for cleaning, but no graffiti was found.',
#        'The Department of Sanitation picked up the items and determined that the complaint was not warranted.',
#        'For updated status of your complaint go online at nyc.gov/311 and use the Check Status field or call 311.',
#        'The Department of Health and Mental Hygiene will review your complaint within 24 hours.  Complaints of this type usually result in complainant contact and/or inspection by the agency. Initial status will be available 14 days after the date of your complaint by calling 311. If you are experiencing medical symptoms, please seek medical attention or consult the NYC Poison Control Center which can be reached through 311.   Please note your Service Request number for future reference.',
#        'The  Department of Transportation inspected the condition you reported and issued a Corrective Action Repair (CAR) to the contractor or utility company. The responsible party has a maximum of 30 days to correct the condition. If after that time the condition still exists, the Agency may issue the responsible party a summons and/or correct the condition.',
#        'The complaint you filed is a duplicate of a condition already reported by another tenant for a building-wide condition. The original complaint is still open. HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection of your unit if the original complainant is not available for verifi',
#        'The Department of Parks and Recreation inspected and determined the issue was out of its jurisdiction. The condition may be on private property or in an area serviced by another organization.',
#        'The Department of Parks and Recreation inspected the requested repair site. The timeframe for repair work depends on available funding for the program, the severity of damage, and the other sidewalk requests in the surrounding district. For more information, refer to the information sheet that you received from the agency.',
#        "The Department of Transportation will inspect the condition and determine if the location will be added to the next or future season's curb construction contract (2 - 3 years). Community Boards and elected officials are consulted to determine curb construction priority and scheduling.  For scheduling information regarding a specific curb, contact the local Community Board.",
#        'The Department of Housing Preservation and Development contacted an occupant of the apartment or building and verified that the complaint was addressed.  The complaint has been closed.',
#        'The Department of Health and Mental Hygiene has contacted the customer and closed the Service Request.  If the Agency was unable to make phone contact, a letter was sent to the customer to call the Office of Environmental Investigations at 212-442-3372 to schedule an appointment.',
#        'The Department of Sanitation picked up the items. Earlier pickup was prevented by snow.',
#        'The Department of Buildings contacted you and scheduled an inspection. See Notes to Customer for more details.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file',
#        'The Taxi and Limousine Commission (TLC) called and left a message for you. They needed to confirm the details of your complaint. When you did not respond within 14 days, your complaint was closed. If you still want to pursue this complaint, you can open a new Service Request with a daytime phone number included.',
#        "Please contact the Department of Health and Mental Hygiene's Pest Control Services for updated status of your complaint by calling (718) 583-6133.",
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please fil',
#        'The Department of Transportation inspected the condition. Street markings will be painted in future markings seasons or when contracts are awarded.',
#        "Please contact the Department of Health and Mental Hygiene's Pest Control Services for updated status of your complaint.  Brooklyn North Office (718) 625-5846 covers zip codes: 11201, 11205, 11206, 11211, 11213, 11215, 11216, 11217, 11221, 11222, 11225, 11231, 11232, 11233, 11237, 11238, 11239.  Brooklyn South Office (718) 629-5800 covers zip codes: 11204, 11207, 11208, 11209, 11210, 11212, 11214, 11218, 11219, 11220, 11203, 11223, 11224, 11225, 11226, 11228, 11229, 11230, 11234, 11235, 11236.",
#        'The Department of Health and Mental Hygiene has reviewed your Service Request. A warning letter has been sent to the responsible party notifying them to correct the condition.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exist',
#        'The Department of Health and Mental Hygiene regulates restaurants and other establishments that mostly sell food which is prepared on the premises. New York State Agriculture and Markets regulates those establishments that mostly sell pre-packaged food, including supermarkets, bodegas, green markets, fish and meat markets, and delis. This Service Request involves an establishment under the jurisdiction of the New York State Agriculture and Markets. For complaint status, call (718) 722-2876.',
#        'The location has been inspected and is scheduled for planting during the spring planting season.  The spring planting season runs from approximately March to May, weather permitting.',
#        'The Department of Sanitation is in the process of investigating this complaint.',
#        'The Taxi and Limousine Commission (TLC) has received your complaint. Within 45 days, the TLC representative who will be handling your case will contact you.',
#        'The Department of Parks and Recreation prunes street trees on a seven year pruning cycle.  However, the Department of Parks and Recreation reviews service requests for street tree pruning and as warranted, will take immediate action to correct the condition.',
#        'The Department of Health and Mental Hygiene will review your complaint to determine appropriate action.  Complaints of this type usually result in complainant contact or an inspection. You may be contacted if you provided a phone number.  Status will be available 45 days after the date of your complaint by calling 311. If you are experiencing medical symptoms, please seek medical attention or consult the NYC Poison Control Center. Please note your Service Request number for future reference.',
#        'The Department of Transportation inspected the condition you reported and issued a summons to the responsible party.  A re-inspection will be done within 10 days.  If the condition still exists, a second summons will be issued.  In some cases, the Department of Transportation will make the repairs and charge the responsible party for the costs.',
#        'The Department of Housing Preservation and Development conducted an inspection for the following conditions and identified potential lead-based paint conditions.  HPD will attempt to contact you to schedule a follow-up inspection to test the paint for lead',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a n',
#        'No action was taken because the Department of Parks and Recreation determined that the issue is out of its jurisdiction. The condition may be on private property or in an area serviced by another organization.',
#        'The New York City Economic Development Corporation determined that this issue is not within its jurisdiction because the helicopter did not belong to a tour operating company. Instead, it was most likely a law enforcement or news gathering helicopter, which is not subject to the routing protocols established for tour helicopters.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, plea',
#        'Work to correct the reported condition is under review for a future capital project.',
#        'The Department of Health and Mental Hygiene has investigated the complaint and no violations were cited.',
#        'The Department of Health and Mental Hygiene has sent official written documentation to the Owner/Landlord warning them of potential violations and instructing them to correct the situation.  If the situation persists 21 days after your initial complaint, please log another complaint.',
#        'The Department of Health and Mental Hygiene has received and processed your complaint. All restaurants and mobile food vendors are inspected annually. Restaurant inspection results can be found on WWW.NYC.GOV or a copy of the inspection can be requested from 311.',
#        'The Taxi and Limousine Commission was unable to identify the driver or car service company named in your complaint.',
#        'The Department of Parks and Recreation usually requires 5 days to inspect this issue and may take up to 30 days to resolve it, if warranted.  Please note your Service Request number for future reference.',
#        'See notes.',
#        'The Department of Transportation inspected the condition you reported and determined that this issue is not within its jurisdiction.',
#        "Please contact the Department of Health and Mental Hygiene's Pest Control Services for updated status of your complaint by calling (212) 360-5928.",
#        'The Department of Housing Preservation and Development was not able to gain access to your apartment to inspect for a lack of heat or hot water. However, HPD was able to verify that heat or hot water was inadequate by inspecting another apartment and a violation was issued. Information about specific violations is available at www.nyc.gov/hpd.',
#        'The Department of Sanitation collected the requested items.',
#        'The Department of Transportation is unable to schedule a sidewalk dismissal inspection because there is no record of a permit to make a sidewalk repair.  Owner must obtain a permit of record.  Once a permit is obtained, the owner must call 3-1-1 to make another request for sidewalk dismissal - work done by owner.',
#        'Your bus shelter request has been studied and the site is not feasible for a shelter.',
#        'The Taxi and Limousine Commission requires you to attend a hearing to process a complaint against a yellow cab driver. Your complaint has been closed.',
#        'The Taxi and Limousine Commission has recorded the complaint you made. Within 45 days, you will be contacted by the TLC representative who will be handling your case.',
#        "The Department of Housing Preservation and Development has closed this complaint administratively. More information can be found through HPD's website at www.nyc.gov/hpd by using HPDONLINE (enter your address on the home page) and entering your SR number under the complaint status option.",
#        'The condition was inspected and determined to be under the jurisdiction of another Department of Transportation unit.  The unit has been notified.',
#        'The location has been inspected and is scheduled for planting during the fall planting season.  The fall planting season runs from approximately October to December, weather permitting.',
#        'The Department of Health and Mental Hygiene has reviewed the complaint and has referred it to another Office/Bureau/Agency',
#        'The Department of Parks and Recreation has informed the responsible public utility who will correct the condition.',
#        'The Department of Transportation will inspect the complaint location  and notify the property owner within 180 days if a defective sidewalk condition exists.   The property owner is responsible for maintaining, repairing and installing sidewalks adjoining their property, according to Section 19-152 of the New York City Administrative Code.',
#        'A representative from the Taxi and Limousine Commission (TLC) called and left a message for you and emailed you but has not been able to get in touch with you to confirm the details of your complaint. As a result, the TLC has closed your complaint. If you would like to have your complaint reopened, please call (212) 676-1046.',
#        'The Police Department responded to the complaint and a report was prepared.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, ple',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please',
#        'The location does not meet the criteria for Litter Basket placement.',
#        "The Department of Transportation inspected the condition and determined it was in compliance with the Agency's standards, not hazardous, or a valid permit exists.",
#        'Callers should contact the DOHMH Foodborne Illness unit directly at (646) 632-6103 weekdays from 9AM to 5PM.  DOHMH will review your complaint within 24 hours.  Complaints of this type usually result in complainant contact and/or inspection. Initial status will be available 14 days after the date of your complaint. If you are experiencing medical symptoms, please seek medical attention or consult the NYC Poison Control Center.  Please note your Service Request number for future reference.',
#        'The Department of Transportation has inspected the location and notified the property owner of any defective sidewalk conditions. The property owner is responsible for maintaining, repairing and installing sidewalks adjoining their property, according to Section 19-152 of the New York City Administrative Code.',
#        'The Department of Parks and Recreation usually requires 10 days to review a request and determine the appropriate action. Please note your Service Request number for future reference.',
#        "The Department of Transportation's inspectors could not find the address you reported. If you would like to pursue the complaint, please check the address and call 311 or (212) 639-9675 with updated location information.",
#        "Please contact the Department of Health and Mental Hygiene's Pest Control Services for updated status of your complaint by calling (718) 520-4974.",
#        'The reported condition was inspected and a report has been filed.',
#        'The cleaning crew could not locate the property requiring graffiti removal.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition st',
#        'The New York City Economic Development Corporation determined that the helicopter tour operator was operating within the limits of the New York City Helicopter Sightseeing Plan which establishes specific routing for tour flights.',
#        'The Department of Transportation inspected the condition, sent notice to responsible party, and temporary repairs were made to make the area safe.',
#        'The Department of Parks and Recreation usually requires 5 days to review a request and determine the appropriate action. Please note your Service Request number for future reference.',
#        'Upon inspection, the reported condition was not found, therefore no action was taken.',
#        'The Department of Parks and Recreation has determined that this issue is not within its jurisdiction. It has been referred to the New York Police Department.',
#        'The injured person has refused medical attention.',
#        'The agency has mailed literature to the customer concerning the Sidewalk Consultation, and is currently evaluating the request.',
#        'Your report has been sent to the Taxi and Limousine Commission (TLC). You are not available to participate in a hearing so TLC cannot take any action against the driver or car service company. No further information will be available for your report.',
#        'The Department of Transportation investigated this Service Request and determined this street requires general maintenance.  This location has been processed into another system and is expected to be repaired in 30 days.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, p',
#        'The Department of Sanitation picked up the items and determined that the missed collection complaint was not warranted because the items were placed out for collection on the wrong day.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, ple',
#        'The Department of Transportation has denied the request to dismiss the Sidewalk violation because there is no record of City repair.',
#        'The Department of Transportation inspected the condition and determined it was in compliance with their standards, not hazardous, or a valid permit exists.',
#        'The Department of Health and Mental Hygiene has investigated the complaint.  No Health Code violations or health hazards noted. No further action needed.',
#        'The Department of Sanitation investigated this complaint and salted the area.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a ne',
#        'Thank you for your report. The Department of Health and Mental Hygiene will use the information that you provided to help track and control mosquito populations throughout the City. No further information will be available from 311 on your report.',
#        'The Taxi and Limousine Commission (TLC) has received your complaint. Within 30 days, the TLC representative who will be handling your case will contact you.',
#        'The Department of Transportation contacted the customer and resolved the service request or provided the information requested.',
#        'The Police Department made an arrest in response to the complaint.',
#        'See notes for information.',
#        'The Department of Sanitation found an open service request already exists for the same location.',
#        'The Department of Health and Mental Hygiene will review your complaint to determine the appropriate action. Complaints of this type usually result in an inspection. You can get the status 14 days after filing your complaint  by calling 311 or (646) 632-6101 on weekdays between 9 AM and 5 PM.  Please note your Service Request number for future reference.',
#        'The Department of Parks and Recreation has inspected the situation in question and determined that the issue is out of its jurisdiction.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exis',
#        'The Department of Sanitation investigated and the vehicle owner claimed the vehicle, therefore it could not be classified as abandoned and derelict.',
#        'The Departent of Sanitation found that this is not a vacant lot. There appears to be a business in operation at the location.',
#        'The Health Departmentâ\x80\x99s Office of Environmental Investigations has determined this case was an isolated incident. The Departmentâ\x80\x99s Bureau of Food Safety and Community Sanitation will review to see if a sanitary inspection is necessary. You can get results of all food safety inspections by going online to www.nyc.gov/health/restaurants.',
#        'The Department of Health and Mental Hygiene will review the Service Request. Complaints of this type usually result in Agency contact or an inspection. Status will be available from 311 within 45 days of the Service Request submission date.  Please note the Service Request number for future reference.',
#        'The contractor has reported that the requested work has been completed.',
#        'No action was taken because the Department of Parks and Recreation determined that the issue is out of its jurisdiction.',
#        'The Department of Health and Mental Hygiene has contacted the customer and closed the Service Request.  If the Agency was unable to make phone contact, a letter was sent to the customer to call the Office of Environmental Investigations to schedule an appointment.',
#        'Work to correct the reported condition has been deferred because of seasonal considerations and will be corrected as soon as possible.',
#        'The New York City Economic Development Corporation determined that this issue is not within its jurisdiction because the helicopter did not belong to a tour company departing from a NYC heliport.Â\xa0 Instead, it was most likely a law enforcement or news gathering helicopter not subject to the routing protocols established for tour helicopters. It may also have been a helicopter that departed as a charter or tour from another City but flew over NYC airspace. Helicopter tours originating from outside NYC are not subject to the same City regulations as tours departing from heliports managed by NYCEDC. Any City regulation of these flights is pre-empted by federal law and subject only to the jurisdiction of the Federal Aviation Administration. To file a complaint with the FAA, you can contact the New York Flight Standards District Office at the following web address:Â\xa0https://www.faa.gov/about/office_org/field_offices/fsdo/',
#        'No action was taken because the Department of Parks and Recreation determined that the issue reported was out of its jurisdiction.',
#        'The reported condition was inspected and a work order has been filed to correct it.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, pleas',
#        'The following complaint conditions are still open.  HPD may attempt to contact you to verify the correction of the condition or may conduct an inspection.',
#        'The Department of Housing Preservation and Development inspected the following conditions. A Section 8 Failure was issued. Both the tenant and the property owner will receive a notice in the mail regarding the details of the Failure and the resulting action by the Agency.',
#        'The Department of Transportation investigated this request and determined this street requires a reconstruction project.  This location is part of an existing project or may be included in a future project.  These projects are long term and vary in length.',
#        'The Department of Sanitation picked up the items. Earlier pickup was prevented by construction work.',
#        'The Department of Health and Mental Hygiene will  investigate the complaint. Please visit 311 Online at www.nyc.gov/311 or call 311 in 30 days for an updated status of your complaint.',
# ...
#        'The Taxi and Limousine Commission received your complaint and will notify you by mail of the scheduled hearing date. A hearing will be scheduled within 45 days.',
#        'The Department of Health and Mental Hygiene determined that this issue is not within its jurisdiction. It has been referred to the Department of Buildings.',
#        'The Department of Health and Mental Hygiene has sent an official warning to the establishment. If the situation persists 45 days after the initial report, call 311 and file a new Service Reqeust.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been clo',
#        'The Department of Transportation inspected the condition and issued a Corrective Action Repair (CAR) to the contractor or utility company. The responsible party has a maximum of 30 days to correct the condition. If the condition still exists, a summons will be issued. In some cases, the Department of Transportation will make the repairs and charge the responsible party for the costs.',
#        'A representative from the Taxi and Limousine Commission (TLC) called and left a message for you and emailed you but has not been able to get in touch with you to confirm the details of your complaint. As a result, the TLC has closed your complaint. If you would like to have your complaint reopened, please call (718) 391-5617.',
#        'The Department of Transportation inspected the bike and made the determination it is unusuable. The Agency will remove it within the next calendar year.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the cond',
#        'NYC Parks created a work order for the tree condition and is expects to address the issue within 28 days from the date of the tree assessment, barring any weather-related requests.   NYC Parks work priority categories range from Category A through D, with A being the most critical and time-sensitive. We will complete all work in Category A first and address work in lower priority categories in accordance with available resources. For more information about the Tree Risk Management Program, visit the NYC Urban Forest page on the NYC Parks website at nyc.gov/parks/trees.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new c',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new compl',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development responded to a complaint of no heat or hot water and was advised by a tenant in the building that heat and hot water had been restored. If the condition still exists, pl',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition s',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, pl',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, plea',
#        'The Department of Health and Mental Hygiene regulates restaurants and other establishments that mostly sell food which is prepared on the premises. New York State Agriculture and Markets regulates those establishments that mostly sell pre-packaged food, including supermarkets, bodegas, green markets, fish and meat markets, and delis. This Service Request was referred to the New York State Agriculture and Markets.',
#        'The Department of Sanitation picked up the items and determined that the missed collection complaint was not warranted because more than six bulk items or bags were placed out for pickup at one time.',
#        'The Department of Health and Mental Hygiene will review your complaint to determine appropriate action. Complaints of this type usually result in an inspection. Please call 311 in 30 days from the date of your complaint for status.',
#        "Your complaint has been forwarded to the New York Police Department for a non-emergency response. If the police determine the vehicle is illegally parked, they will ticket the vehicle and then you may either contact a private towing company to remove the vehicle or ask your local precinct to contact 'rotation tow'. Any fees charged for towing will have to be paid by the vehicle owner. 311 will have additional information in 8 hours. Please note your service request number for future reference.",
#        'The Department of Consumer Affairs has determined that this issue is not within its jurisdiction and should be referred to the Department of Environmental Protection. 311 can help you file a complaint or contact the agency for further assistance.',
#        "The Department of Sanitation inspected the property you reported and found it to be wetlands. The City does not have jurisdiciton over wetlands. You may contact New York State's Department of Environmental Conservation for more assistance.",
#        'The Department of Health and Mental Hygiene will review your complaint to determine appropriate action.  Complaints of this type usually result in an inspection.  Please call 311 in 30 days from the date of your complaint for status.  Please note your Service Request number for future reference.',
#        'The Department of Health and Mental Hygiene cannot send official written documentation because the mailing information provided was incorrect or incomplete.  Please verify the mailing information provided and submit a new Service Request.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition sti',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exis',
#        'The Department of Health and Mental Hygiene has investigated the complaint and the establishment was closed for violations, the violations were corrected, and the establishment was re-opened.',
#        'The Department of Sanitation will address the situation at the location by providing educational outreach about proper sanitation procedures.',
#        'The property was inspected for cleaning, but no graffiti was found.',
#        'The Department of Sanitation has sent this complaint to the appropriate district garage or bureau for further action.',
#        'The Department of Transportation has denied the sidewalk re-inspection request. The request to re-inspect is past the 75 day original notification period. The property owners are responsible for maintaining, repairing and installing sidewalks adjoining their properties.',
#        'Your complaint was referred to the Department of Consumer Affairs. There was insufficient information and the Department was not able to act on the matter.',
#        'The Taxi and Limousine Commission sent you a confirmation letter to be completed and returned. If the form is not returned, your complaint will be closed.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please fil',
#        'The Department of Parks and Recreation usually requires 4 days to inspect the condition. If warranted, the issue will be resolved within 10 days if the tree is blocking a traffic signal or a sign that guides traffic. Signs that do not guide traffic will be addressed within 20 days. Please note your Service Request number for future reference.',
#        'The Department of Transportation will inspect the condition  you reported and will determine the next action.',
#        'The Office of Veterinary Public Health Services has investigated the complaint and there were minor violations of rules and regulations.  A Notice Of Violation was not issued and a Reinspection is not required.',
#        'This is a NYC Department of Transpiration Â\xa0Bike-Share location. Please report conditions at this location to NYC DOT via 3-1-1.',
#        'See Notes to Customer.',
#        'NYC Parks visited the location but could not find the tree condition you reported.',
#        'NYC Parks created a work order for the tree condition.  Please note that addressing this work can take up to a year or more depending on the higher priority work identified during this period and resources available to address this work.    NYC Parks work priority categories range from Category A through D, with A being the most critical and time-sensitive. We will complete all work in Category A first and address work in lower priority categories in accordance with available resources. For more information about the Tree Risk Management Program, visit the NYC Urban Forest page on the NYC Parks website at nyc.gov/parks/trees.   Alternatively, you may choose complete the work yourself by hiring an independent contractor. The contractor must complete a Tree Work Permit application on the NYC Parks website at nyc.gov/parks/trees.',
#        'The Department of Parks and Recreation has completed the consultation.  Advice on how to repair the sidewalk without damaging the tree was provided.',
#        'The Department of Parks and Recreation has determined that this issue is not within its jurisdiction. It has been referred to the Economic Development Corporation.',
#        'The Department of Transportation inspected the condition and issued a summons to the responsible party. A re-inspection will be done within 10 days. If the condition still exists, a second summons will be issued. In some cases, the Department of Transportation will make the repairs and charge the responsible party for the costs.',
#        'The Department of Information Technology and Telecommunications determined that no inspection is necessary.',
#        'No action was taken because NYC Parks determined that the issue is out of its jurisdiction. The condition may be on private property or in an area serviced by another organization.',
#        'Scheduled for lot cleaning. If access is gained, cleaning should be completed within 2 - 4 weeks.',
#        'The Department of Health and Mental Hygiene has investigated the complaint and issued violations. The agency will continue to monitor.',
#        'The Department of Parks and Recreation usually requires 10 days to inspect the issue and may take up to 45 days to resolve it, if warranted. Please note your Service Request number for future reference.',
#        'The Department of Transportation inspected this location and determined that the establishment has 24 hours to come into compliance.',
#        'The Department of Parks and Recreation has determined that this issue is not within its jurisdiction. Please contact the New York Police Department for assistance.',
#        'A Department of Transportation field crew met the customer at the problem meter and returned the credit card to the customer.',
#        'The Department of Parks and Recreation has determined that this issue is not within its jurisdiction. Please file a Service Request with the Department of Citywide Administrative Services.',
#        'The Department of Health and Mental Hygiene has investigated the complaint.  Owner/manager ordered to abate nuisance.  Violations of rules and regulations issued and fines may be levied as appropriate.',
#        'The Department of Buildings investigated this complaint and determined that no further action was necessary.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been cl',
#        'The Department of Transportation requires 45 days to respond to this type of complaint.  Please note your Service Request number for future reference.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please file a new comp',
#        'No Link kiosk was found at this location. Please confirm the location and submit a new Service Request if the problem has not been resolved.',
#        'The Department of Health and Mental Hygiene has investigated the complaint and Could Not Locate the establishment or an Incorrect Address was provided.  Please confirm the address and resubmit a new complaint.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted an occupant of the apartment and verified that the following conditions were corrected. The complaint has been closed. If the conditio',
#        'The Taxi and Limousine Commission will contact you within 14 days to confirm your complaint details. Please note your Service Request number for future reference.',
#        'More than one complaint was received for this building-wide condition.This complaint status is for the initial complaint.The Department of Housing Preservation and Development contacted a tenant in the building and verified that the following conditions were corrected. The complaint has been closed. If the condition still exists, please fi',
#        'The agency was unable to respond to this complaint because they allocated resources to other critical services at the time. All complaints are used for future enforcement planning.'],
#       dtype=object)

# %%
df = df[df['Resolution Description'].notna()]

# %%
df['Resolution Description'].isnull().sum()
# Out:
# 0

# %%
df['Community Board'].isnull().sum()
# Out:
# 0

# %%
df['BBL'].isnull().sum()
# Out:
# 30882

# %%
df['BBL'].unique()
# Out:
# array([1.00402005e+09, 4.09854000e+09, 4.02093024e+09, ...,
#        5.05683013e+09, 3.05731006e+09, 4.00611001e+09])

# %%
df['BBL'].isnull().sum()
# Out:
# 30882

# %%
df['X Coordinate (State Plane)'].isnull().sum()
# Out:
# 0

# %%
df['Y Coordinate (State Plane)'].isnull().sum()
# Out:
# 0

# %%
df['Open Data Channel Type'].isnull().sum()
# Out:
# 0

# %%
df['Park Borough'].isnull().sum()
# Out:
# 2049

# %% [markdown]
# ## We copy the same values of Borough in Park Borough

# %%
df['Park Borough'] = df['Borough']

# %%
df['Park Borough'].unique()
# Out:
# array(['MANHATTAN', 'QUEENS', 'BROOKLYN', 'STATEN ISLAND', 'BRONX'],
#       dtype=object)

# %%
df['Park Borough'].isnull().sum()
# Out:
# 0

# %%
df['Location'].isnull().sum()
# Out:
# 0

# %%
df['Complaint Type'].unique()
# Out:
# array(['Noise - residential', 'Food establishment', 'Blocked driveway',
#        'Water leak', 'Heat/hot water', 'New tree request',
#        'Paint/plaster', 'Street condition', 'Noise - street/sidewalk',
#        'Noise survey', 'Root/sewer/sidewalk condition', 'General',
#        'Missed collection (all materials)', 'Dead tree',
#        'Illegal parking', 'Unsanitary condition', 'Electric', 'Graffiti',
#        'Smoking', 'Rodent', 'Sidewalk condition', 'Flooring/stairs',
#        'Heating', 'Vending', 'Electronics waste', 'Derelict vehicle',
#        'Maintenance or facility', 'Overgrown tree/branches',
#        'Noise - commercial', 'Broken muni meter', 'Standing water',
#        'Taxi complaint', 'Damaged tree', 'Noise - vehicle',
#        'Other enforcement', 'Plumbing', 'Safety', 'Derelict bicycle',
#        'Curb condition', 'Public payphone complaint',
#        'Sanitation condition', 'Traffic', 'Door/window', 'Noise - park',
#        'Dirty conditions', 'Street sign - dangling', 'Drinking',
#        'Street sign - damaged', 'Broken parking meter', 'Vacant lot',
#        'Unsanitary animal pvt property', 'Non-emergency police matter',
#        'Animal abuse', 'Illegal tree damage', 'Collection truck noise',
#        'General construction', 'Paint - plaster',
#        'Electronics waste appointment', 'Outside building', 'Elevator',
#        'Derelict vehicles', 'Vaccine mandate non-compliance', 'Nonconst',
#        'Dpr internal', 'Street sign - missing', 'Litter basket / request',
#        'Traffic/illegal parking', 'Construction',
#        'For hire vehicle complaint', 'Dead/dying tree', 'Appliance',
#        'Illegal animal kept as pet', 'Indoor sewage',
#        'Violation of park rules', 'Unsanitary animal facility', 'Snow',
#        'Dof property - payment issue', 'Food poisoning', 'Window guard',
#        'Abandoned vehicle', 'Mold', 'Drug activity', 'Indoor air quality',
#        'Request xmas tree collection', 'Noise - helicopter',
#        'Unsanitary pigeon condition', 'Missed collection',
#        'Overflowing litter baskets', 'Bus stop shelter placement',
#        'Disorderly youth', 'Unleashed dog', 'Recycling enforcement',
#        'Tattooing', 'For hire vehicle report', 'Noise - house of worship',
#        'Mosquitoes', 'Found property', 'Day care',
#        'Bus stop shelter complaint', 'Animal in a park',
#        'Sweeping/missed', 'Posting advertisement', 'Illegal dumping',
#        'Illegal animal sold', 'Non-residential heat',
#        'Harboring bees/wasps', 'Bike rack condition',
#        'Beach/pool/sauna complaint', 'Sweeping/inadequate',
#        'Overflowing recycling baskets', 'Public toilet',
#        'Mobile food vendor', 'Tanning', 'Sweeping/missed-inadequate',
#        'School maintenance', 'Dirty condition', 'Adopt-a-basket', 'Drie',
#        'Outdoor dining', 'Taxi report', 'Pet shop',
#        'Litter basket request', 'Street sweeping complaint',
#        'Oem disabled vehicle', 'Calorie labeling', 'Radioactive material',
#        'Drinking water', 'Animal-abuse', 'Residential disposal complaint',
#        'Linknyc', 'Litter basket complaint', 'Consumer complaint',
#        'X-ray machine/equipment', 'Dead animal', 'Summer camp',
#        'Building condition', 'Bottled water', 'Lifeguard',
#        'Lost property', 'Obstruction', 'Dumpster complaint',
#        'Dof parking - payment issue', 'Incorrect data'], dtype=object)

# %%
df.shape
# Out:
# (206298, 27)

# %% [markdown]
# ##We again run remove duplicates as we may have changed some values and hence obtained some duplicates in the process.

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (205920, 27)

# %% [markdown]
# ## With this we conclude our cleaning process and we are ready to perform analysis on the cleaned data.
